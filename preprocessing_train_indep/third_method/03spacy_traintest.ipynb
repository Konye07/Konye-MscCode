# %% [markdown]
# # **Csomagok behívása**

# %%
#Szükséges csomagok és adatbázis importálása
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Concatenate
import numpy as np
import tensorflow as tf
import spacy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fájlok behívása, ellenőrzése és felkészítése

# %%
# Betölteni padded sequences, tokenizer, és számokat
padded_train = np.load('/content/padded_train03.npy')
padded_test = np.load('/content/padded_test03.npy')

# Tokenizer visszatöltése
with open('/content/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Címkék betöltése (real = 1, fake = 0)
train_file = '/content/train_harmadik.csv'
test_file = '/content/teszt_harmadik.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

labels_train = df_train['label'].values
labels_test = df_test['label'].values

# Betölteni embedding mátrixot
embedding_matrix = np.load('/content/embedding_matrix.npy')

# Ellenőrzés
print(f"Train padded sequences shape: {padded_train.shape}")
print(f"Test padded sequences shape: {padded_test.shape}")
print(f"Train labels shape: {labels_train.shape}")
print(f"Test labels shape: {labels_test.shape}")
# Out:
# Train padded sequences shape: (59520, 600)
# Test padded sequences shape: (14880, 600)
# Train labels shape: (59520,)
# Test labels shape: (14880,)

# %%
# Max szókincs és szekvencia hossz
MAX_VOCAB_SIZE = 25000
MAX_LENGTH = 600
EMBEDDING_DIM = 300  # GloVe 300d

# input shape
MAX_SEQUENCE_LENGTH = padded_train.shape[1]

# Szöveges input (LSTM/GRU bemenet)
text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
embedding_layer = Embedding(
    input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
    output_dim=embedding_matrix.shape[1],
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)(text_input)

model_output = embedding_layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
MAX_SEQUENCE_LENGTH = padded_train.shape[1]  # Train hossz
EMBEDDING_DIM = embedding_matrix.shape[1]  # GloVe embeddings

# 10%-os validációs halmaz leválasztása a tanító adatokból
padded_train_final, padded_val, y_train_final, y_val = train_test_split(
    padded_train, labels_train, test_size=0.1, random_state=42
)
# Float32-re konvertálás TensorFlow kompatibilitás miatt
padded_train_final = np.array(padded_train_final, dtype=np.float32)
padded_val = np.array(padded_val, dtype=np.float32)
padded_test = np.array(padded_test, dtype=np.float32)
y_train_final = np.array(y_train_final, dtype=np.float32)
y_val = np.array(y_val, dtype=np.float32)
y_test = np.array(labels_test, dtype=np.float32)

# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# # LSTM MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ## Modell lefuttatása

# %%
# LSTM modell, trainable, non-trainable embedding

def create_lstm_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings
    )(text_input)

    # LSTM rétegek
    lstm_out = LSTM(128, return_sequences=True, dropout=0.3)(text_embedding)
    lstm_out = Dropout(0.3)(lstm_out)  # Dropout réteg az első LSTM után
    lstm_out = LSTM(64,return_sequences=True, dropout=0.3)(lstm_out)
    lstm_out = Dropout(0.3)(lstm_out) # Dropout réteg az második LSTM után
    lstm_out = LSTM(32, dropout=0.3)(lstm_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(lstm_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása
lstm_trainable = create_lstm_model(trainable_embeddings=True)  # Trainable embedding

lstm_trainable.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_1 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 600, 128)            │         219,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 600, 64)             │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,781,505 (29.68 MB)
#  Trainable params: 7,781,505 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Modell tanítása a validációs adatok figyelésével
lstm_history_trainable = lstm_trainable.fit(
    padded_train_final, y_train_final,
    validation_data=(padded_val, y_val),  # Validációs halmaz
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság: {test_accuracy:.4f}, Teszthalmaz veszteség: {test_loss:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 77s 84ms/step - accuracy: 0.8634 - loss: 0.3274 - val_accuracy: 0.9377 - val_loss: 0.1749
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 83ms/step - accuracy: 0.9509 - loss: 0.1409 - val_accuracy: 0.9172 - val_loss: 0.1953
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 72s 86ms/step - accuracy: 0.9622 - loss: 0.1136 - val_accuracy: 0.9446 - val_loss: 0.1718
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 83ms/step - accuracy: 0.9757 - loss: 0.0754 - val_accuracy: 0.9528 - val_loss: 0.1477
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 83ms/step - accuracy: 0.9853 - loss: 0.0466 - val_accuracy: 0.9548 - val_loss: 0.1529
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 85ms/step - accuracy: 0.9887 - loss: 0.0355 - val_accuracy: 0.9535 - val_loss: 0.1506
# Epoch 7/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 82ms/step - accuracy: 0.9921 - loss: 0.0256 - val_accuracy: 0.9548 - val_loss: 0.1631
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9485 - loss: 0.1588
# Teszthalmaz pontosság: 0.9440, Teszthalmaz veszteség: 0.1725

# %%
# Valószínűség becslése
lstm_y_prob = lstm_trainable.predict(padded_test)

lstm_y_pred = (lstm_y_prob > 0.5).astype(int)

lstm_accuracy = accuracy_score(y_test, lstm_y_pred)
lstm_precision = precision_score(y_test, lstm_y_pred)
lstm_recall = recall_score(y_test, lstm_y_pred)
lstm_f1 = f1_score(y_test, lstm_y_pred)

print(f"Accuracy: {lstm_accuracy:.4f}")
print(f"Precision: {lstm_precision:.4f}")
print(f"Recall: {lstm_recall:.4f}")
print(f"F1-score: {lstm_f1:.4f}")
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
# Accuracy: 0.9460
# Precision: 0.9467
# Recall: 0.9452
# F1-score: 0.9459

# %% [markdown]
# ## LSTM Modell ábrák

# %%
import matplotlib.pyplot as plt

# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(lstm_history_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(lstm_history_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9490 - loss: 0.1590

# %%
# Confusion Matrix
cm_lstm = confusion_matrix(y_test, lstm_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_lstm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix LSTM Modellre')
plt.show()

print(classification_report(y_test, lstm_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95      7440
#          1.0       0.95      0.95      0.95      7440
#
#     accuracy                           0.95     14880
#    macro avg       0.95      0.95      0.95     14880
# weighted avg       0.95      0.95      0.95     14880

# %%
# Flatten
y_true = y_test.flatten()
y_pred = lstm_y_pred.flatten()
y_prob = lstm_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás besorolás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás besorolás) LSTM Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": lstm_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = lstm_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_lstm.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 41   Hamis negatív (FN)           1.0                 0
# 53   Hamis negatív (FN)           1.0                 0
# 68   Hamis negatív (FN)           1.0                 0
# 82   Hamis negatív (FN)           1.0                 0
# 151  Hamis pozitív (FP)           0.0                 1
# 156  Hamis negatív (FN)           1.0                 0
# 168  Hamis negatív (FN)           1.0                 0
# 176  Hamis pozitív (FP)           0.0                 1
# 186  Hamis pozitív (FP)           0.0                 1
# 188  Hamis pozitív (FP)           0.0                 1
# 244  Hamis negatív (FN)           1.0                 0
# 249  Hamis negatív (FN)           1.0                 0
# 275  Hamis negatív (FN)           1.0                 0
# 297  Hamis pozitív (FP)           0.0                 1
# 327  Hamis pozitív (FP)           0.0                 1
# 340  Hamis pozitív (FP)           0.0                 1
# 356  Hamis negatív (FN)           1.0                 0
# 393  Hamis negatív (FN)           1.0                 0
# 401  Hamis negatív (FN)           1.0                 0
# 408  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 41                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'editor' 'note' 'follow' 'column' 'originally' 'appear' 'website' 'defense' 'watch' 'reprint' 'permission' 'like' 'million' 'american' 'saw' 'speech' 'dnc' 'thursday' 'night' 'wish' 'offer' 'sympathy' 'death' 'son' 'captain' 'humayun' 'khan' 'kill' 'action' 'iraq' 'army' 'officer' 'veteran' 'gulf' 'war' 'certainly' 'understand' 'pain' 'anguish' 'wife' 'endure' 'day' 'son' 'die' 'save' 'life' 'fellow' 'soldier' 'jesus' 'tell' 'disciple' 'accord' 'gospel' 'john' 'great' 'love' 'man' 'man' 'lay' 'life' 'friend' 'captain' 'khan' 'hero' 'sure' 'soldier' 'serve' 'regard' 'know' 'wife' 'rest' 'assure' 'million' 'veteran' 'regard' 'son' 'hero' 'paraphrase' 'book' 'son' 'son' 'ultimate' 'sacrifice' 'country' 'country' 'new' 'family' 'openly' 'embrace' 'certainly' 'love' 'family' 'arrive' 'america' 'pakistan' 'country' 'adopt' 'american' 'way' 'learn' 'history' 'apparently' 'acquire' 'pocket' 'constitution' 'way' 'good' 'sir' 'muslim' 'america' 'desire' 'assimilate' 'wish' 'live' 'sharia' 'law' 'unacceptable' 'american' 'law' 'land' 'yous' 'constitution' 'know' 'mr' 'khan' 'live' 'violent' 'times' 'dangerous' 'time' 'muslim' 'madman' 'isis' 'radical' 'jihadi' 'group' 'murder' 'terror' 'spree' 'globe' 'religion' 'peace' 'islam' 'fact' 'confirm' 'time' 'muslim' 'shoot' 'bomb' 'torture' 'innocent' 'men' 'woman' 'child' 'mean' 'muslim' 'terrorist' 'terrorist' 'sir' 'muslim' 'muslim' 'terrorist' 'attack' 'sign' 'time' 'regardless' 'feckless' 'nave' 'leftist' 'ideologue' 'barack' 'obama' 'colleague' 'john' 'kerry' 'francois' 'hollande' 'angela' 'merkel' 'state' 'united' 'state' 'west' 'war' 'radical' 'islam' 'job' 'president' 'united' 'state' 'protect' 'nation' 'enemy' 'foreign' 'domestic' 'unfortunately' 'mr' 'obama' 'islam' 'refuse' 'accept' 'reality' 'result' 'death' 'thousand' 'innocent' 'people' 'world' 'group' 'like' 'isi' 'al' 'qaeda' 'goal' 'complete' 'destruction' 'judeochristian' 'culture' 'religion' 'way' 'life' 'american' 'family' 'decade' 'century' 'family' 'like' 'relative' 'fight' 'civil' 'war' 'wwii' 'korea' 'vietnam' 'desert' 'storm' 'family' 'relatives' 'fought' 'american' 'revolution' 'plan' 'let' 'country' 'devour' 'muslim' 'maniac' 'american' 'sir' 'unarmed' 'socialist' 'european' 'zombie' 'necessary' 'protect' 'united' 'state' 'democrat' 'liberals' 'world' 'rise' 'colored' 'glass' 'conservative' 'understand' 'good' 'evil' 'world' 'evil' 'destroy' 'destroys' 'strong' 'measure' 'wartime' 'measure' 'take' 'protect' 'country' 'wish' 'annihilate' 'way' 'life' 'mr' 'trump' 'plan' 'temporarily' 'halt' 'immigration' 'muslim' 'country' 'know' 'support' 'terrorism' 'harbor' 'terrorist' 'group' 'pragmatic' 'constitutional' 'constitutional' 'duty' 'president' 'united' 'state' 'protect' 'nation' 'simply' 'way' 'vet' 'hundred' 'thousand' 'muslim' 'refugee' 'war' 'zone' 'like' 'syria' 'iraq' 'afghanistan' 'europe' 'destroy' 'reckless' 'leader' 'like' 'angela' 'merkel' 'open' 'continent' 'door' 'flood' 'million' 'undocumented' 'muslim' 'arrive' 'bad' 'attitude' 'jihad' 'think' 'american' 'stupid' 'leave' 'live' 'dream' 'world' 'right' 'mr' 'trump' 'understand' 'threat' 'nation' 'threat' 'sir' 'swedish' 'lutheran' 'name' 'anna' 'lars' 'threat' 'sir' 'radical' 'i ...
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'far' 'weaken' 'environmental' 'protection' 'agency' 'donald' 'trump' 'need' 'beef' 'say' 'guy' 'new' 'york' 'time' 'william' 'd' 'march' 'time' 'write' 'strong' 'credible' 'regulatory' 'regime' 'essential' 'smooth' 'function' 'economy' 'interest' 'use' 'word' 'credible' 'worthless' 'bureaucrat' 'embody' 'wrong' 'epa' 'urgently' 'need' 'let' 'forget' 'epa' 'administrator' 'responsible' 'probably' 'black' 'moment' 'institution' 'history' 'man' 'ban' 'consequence' 'result' 'million' 'unnecessary' 'death' 'world' 'malaria' 'sure' 'deliberately' 'murder' 'people' 'fact' 'remain' 'effective' 'killer' 'mosquito' 'ban' 'help' 'create' 'regulatory' 'effect' 'deprive' 'world' 'best' 'defence' 'big' 'health' 'problem' 'told' 'story' 'month' 'worth' 'repeat' 'repeated' 'time' 'dreadful' 'man' 'pop' 'assume' 'mantle' 'authority' 'simply' 'earn' 'note' 'lawyer' 'train' 'scientist' 'man' 'responsible' 'ban' 'scientific' 'basis' 'whatsoever' 'fact' 'judge' 'edmund' 'sweeney' 'preside' 'epa' 'hear' ...
# 68                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'yous' 'republican' 'presidential' 'candidate' 'dona ...
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'anthony' 'scaramucci' 'president' 'donald' 'trump' 'new' 'communication' 'director' 'say' 'sunday' 'task' 'halt' 'leaks' 'staff' 'team' 'fire' 'leak' 'stop' 'leak' 'stop' 'dramatic' 'action' 'stop' 'leak' 'scaramucci' 'say' 'fox' 'news' 'sunday' 'scaramucci' 'tell' 'cbss' 'face' 'nation' 'leaker' 'actually' 'unamerican' 'lead' 'team' 'meeting' 'monday' 'hire' 'scaramucci' 'wall' 'street' 'financier ...
# 151                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 156  'beirut' 'lebanon' 'month' 'fierce' 'bombardment' 'fail' 'diplomacy' 'syrian' 'government' 'begin' 'remove' 'resident' 'district' 'city' 'aleppo' 'thursday' 'process' 'president' 'bashar' 'control' 'countrys' 'large' 'city' 'cold' 'hungry' 'carry' 'child' 'people' 'wound' 'board' 'green' 'bus' 'ambulance' 'carry' 'batch' 'evacuee' 'rebel' 'enclave' 'second' 'group' 'people' 'depart' 'later' 'leave' 'nightfall' 'mr' 'assad' 'hail' 'evacuation' 'video' 'release' 'office' 'say' 'liberation' 'aleppo' 'serve' 'historical' 'watershed' 'like' 'birth' 'christ' 'revelation' 'quran' 'collapse' 'soviet' 'union' 'world' 'war' 'want' 'confirm' 'happen' 'today' 'history' 'write' 'syrian' 'citizen' 'mr' 'assad' 'say' 'smile' 'dark' 'blue' 'suit' 'write' 'start' 'today' 'start' 'year' 'ago' 'crisis' 'war' 'syria' 'begin' 'remain' 'unclear' 'people' 'civilian' 'fighter' 'remain' 'eastern' 'aleppo' 'aid' 'worker' 'guess' 'day' 'successful' 'evacuation' 'return' 'city' 'mr' 'assads' 'control' 'signal' 'major' 'turn' 'point' 'nearly' 'conflict' 'early' 'war' 'aleppo' 'countrys' 'industrial' 'center' 'split' 'government' 'hold' 'west' 'rebel' 'hold' 'neighborhood' 'east' 'vast' 'military' 'aid' 'syrian' 'government' 'iran' 'russia' 'lebanese' 'militant' 'group' 'hezbollah' 'turn' 'tide' 'government' 'favor' 'allow' 'surround' 'rebel' 'evacuation' 'deal' 'reach' 'russia' 'turkey' 'back' 'rebel' 'month' 'heavy' 'shell' 'airstrikes' 'leave' 'entire' 'neighborhood' 'ruin' 'kill' 'hundred' 'people' 'rebel' 'east' 'aleppo' 'frequently' 'shell' 'area' 'kill' 'civilian' 'people' 'city' 'consider' 'rebel' 'dangerous' 'militant' 'glad' 'oust' 'united' 'state' 'support' 'rebel' 'turkey' 'saudi' 'arabia' 'gulf' 'state' 'struggle' 'failed' 'reach' 'accord' 'end' 'war' 'united' 'state' 'help' 'broker' 'evacuation' 'agreement' 'absolutely' 'justification' 'whatsoever' 'indiscriminate' 'savage' 'brutality' 'civilian' 'show' 'regime' 'russian' 'iranian' 'ally' 'past' 'week' 'past' 'year' 'secretary' 'state' 'john' 'kerry' 'say' 'assad' 'regime' 'actually' 'carry' 'short' 'massacre' 'loss' 'foothold' 'aleppo' 'major' 'blow' 'opposition' 'hold' 'sway' 'syrias' 'provincial' 'capital' 'idlib' 'syrian' 'branch' 'al' 'qaeda' 'major' 'force' 'territory' 'rebel' 'hold' 'harder' 'united' 'state' 'ally' 'syrian' 'government' 'negotiate' 'obama' 'administration' 'goal' 'resident' 'reach' 'eastern' 'aleppo' 'thursday' 'say' 'felt' 'gravity' 'leave' 'place' 'live' 'suffer' 'long' 'bid' 'farewell' 'place' 'thing' 'miss' 'ponder' 'opposition' 'fail' 'realize' 'leave' 'soon' 'say' 'visited' 'family' 'home' 'sit' 'old' 'tree' 'think' 'native' 'american' 'palestinian' 'people' 'force' 'home' 'understood' 'feeling' 'today' 'say' 'land' 'memory' 'theirs' 'participate' 'uprising' 'mr' 'assad' 'start' 'conflict' 'felt' 'go' 'wrong' 'arm' 'today' 'hour' 'leave' 'big' 'mistake' 'carry' 'weapon' 'say' 'assume' 'declared' 'enemy' 'assad' 'government' 'allow' 'return' 'leave' 'message' 'come' 'later' 'salem' 'dentist' 'leave' 'handwritten' 'note' 'near' 'door' 'small' 'community' 'center' 'child' 'warn' 'destroy' 'thing' 'child' 'benefit' 'read' 'reach' 'facebook' 'thursday' 'mr' 'say' 'sign' 'heard' 'government' 'troop' 'loot' 'neighborhood' 'seize' 'rebel' 'situation' 'well' 'today' 'people' 'relax' 'little' 'bit' 'shell' 'airstrikes' 'yesterday' 'stop' 'say' 'appear' 'cover' 'track' 'leave' 'east' 'aleppo' 'television' 'image' 'rebel' 'enclave' 'show' 'rise' 'column' 'smoke' 'activist' 'say' 'fighter' 'set' 'fire' 'headquarters' 'ammunition' 'store' 'evacuation' 'start' 'delay' 'twice' 'wednesday' 'morning' 'militia' 'fighter' 'unhappy' 'deal' 'fire' 'vehicle' 'try' 'bring' 'people' 'thursday' 'gunfire' 'target' 'rescue' 'worker' 'clear' 'rubble' 'road' 'kill' 'wound' 'accord' 'antigovernment' 'activist' 'syrian' 'observatory' 'human' 'right' 'oppose' 'government' 'track' 'conflict' 'britain' 'say' 'presence' 'foreign' 'fighter' 'evacuate' 'complicated' 'deal' 'syrian' 'government'  ...
# 168                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 176                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 186                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 188                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# ...
# 393                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 401                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'yous' 'democratic' 'presidential' 'candidate' 'hillary' 'clinton' 'say' 'sunday' 'russian' 'intelligence' 'service' 'hack' 'democratic' 'national' 'committee' 'computer' 'question' 'republican' 'rival' 'donald' 'trump' 'russian' 'president' 'vladimir' 'putin' 'know' 'russian' 'intelligence' 'service' 'hack' 'dnc' 'know' 'arrange' 'lot' 'email' 'release' 'know' 'donald' 'trump' 'show' 'trouble' 'willingness' 'putin' 'support' 'putin' 'clinton' 'say' 'interview' 'fox' 'news' 'sunday' 'white' 'house' 'decline' 'speculate' 'hack' 'democratic' 'party' 'computer' 'refer' 'ongoing' 'investigation' 'federal' 'bureau' 'investigation' 'cybersecurity' 'expert' 'yous' 'official' 'say' 'believe' 'russia' 'engineer' 'release' 'email' 'influence' 'november' 'yous' 'presidential' 'election' 'report' 'computer' 'network' 'clinton' 'campaign' 'hack' 'broad' 'cyber' 'attack' 'democratic' 'political' 'organization' 'united' 'state' 'tolerate' 'country' 'especially' 'consider' 'adversary' 'clinton' 'say' 'trump' 'encourage' 'praise' 'putin' 'despite' 'appear' 'deliberate' 'effort' 'try' 'affect' 'election' 'think' 'raise' 'national' 'security' 'issue' 'say' 'ask' 'believe' 'putin' 'wanted' 'trump' 'white' 'house' 'clinton' 'say' 'go' 'jump' 'conclusion' 'think' 'lay' 'fact' 'raise' 'issue' 'russian' 'interference' 'election' 'democracy' 'clinton' 'tell' 'fox' 'interview' 'tap' 'saturday' 'republican' 'presidential' 'nominee' 'praise' 'putin' 'say' 'strong' 'leader' 'yous' 'president' 'barack' 'obama' 'democrat' 'trump' 'week' 'invite' 'russia' 'dig' 'tens' 'thousand' 'miss' 'email' 'clinton' 'time' 'yous' 'state' 'department' 'russia' 'listen' 'hope' 'able' 'find' 'emails' 'miss' 'trump' 'tell' 'reporter' 'later' 'say' 'sarcastic' 'comment' 'raise' 'concern' 'intelligence' 'expert' 'criticism' 'trump' 'urge' 'foreign' 'government' 'spy' 'american' 'senator' 'jeff' 'session' 'supporter' 'trump' 'criticize' 'clinton' 'leave' 'email' 'sys ...
# 408                                                              'harris' 'lay' 'struggle' 'die' 'tell' 'surround' 'officer' 'lose' 'breath' 'officer' 'yell' 'fuck' 'breath' 'insist' 'die' 'man' 'handcuffed' 'fuck' 'breath' 'encapsulate' 'word' 'systemic' 'disregard' 'police' 'regularly' 'black' 'people' 'america' 'week' 'watch' 'michael' 'slager' 'execute' 'walter' 'scott' 'south' 'carolina' 'dare' 'run' 'away' 'week' 'tune' 'trial' 'chicago' 'police' 'officer' 'dante' 'charge' 'involuntary' 'manslaughter' 'kill' 'yearold' 'boyd' 'march' 'case' 'eric' 'garner' 'staten' 'island' 'tamir' 'rice' 'cleveland' 'walter' 'scott' 'south' 'carolina' 'eric' 'harris' 'tulsa' 'see' 'video' 'law' 'enforcement' 'officer' 'critically' 'injure' 'citizen' 'refuse' 'administer' 'medical' 'care' 'fatal' 'consequence' 'give' 'origin' 'police' 'country' 'connection' 'slave' 'patrol' 'form' 'social' 'control' 'illusion' 'police' 'hold' 'black' 'life' 'high' 'regard' 'police' 'complicity' 'participation' 'lynching' 'kkk' 'clear' 'explicit' 'tacit' 'refusal' 'black' 'people' 'right' 'breathe' 'significant' 'fact' 'tulsa' 'county' 'sheriff' 'office' 'paytoplay' 'force' 'significant' 'fact' 'white' 'men' 'sign' 'government' 'approval' 'right' 'play' 'cop' 'robber' 'weekend' 'appal' 'black' 'live' 'provide' 'fodder' 'sport' 'street' 'logic' 'term' 'neoliberalism' 'moment' 'feel' 'pessimistic' 'narrative' 'linear' 'progress' 'racial' 'issue' 'conclude' 'united' 'arab' 'emirate' 'give' 'million' 'new' 'york' 'city' 'police' 'foundation' 'accord' 'nypd' 'spokesperson' 'money' 'upgrade' 'equipment' 'aid' 'criminal' 'investigation' 'new' 'york' 'city' 'tulsa' 'private' 'funding' 'law' 'enforcement' 'significantly' 'impact' 'way' 'local' 'policing' 'tulsa' 'result' 'paytoplay' 'scheme' 'new' 'york' 'city' 'allow' 'large' 'infusion' 'cash' 'donation' 'specific' 'use' 'come' 'public' 'scrutiny' 'private' 'fund' 'form' 'neoliberal' 'police' 'private' 'citizen' 'private' 'monies' 'impact' 'culture' 'police' 'escape' 'governmental' 'check' 'balance' 'endanger' 'new' 'york' 'action' 'enable' 'purchase' 'unspecified' 'form' 'equipment' 'instance' 'exacerbate' 'culture' 'militarize' 'policing' 'nypd' 'money' 'allow' 'nypd' 'travel' 'uae' 'learn' 'counterterrorism' 'measure' 'wake' 'external' 'training' 'helpful' 'essentially' 'sound' 'like' 'case' 'nypd' 'allow' 'money' 'play' 'global' 'cop' 'robber' 'test' 'tactic' 'black' 'brown' 'people' 'police' 'heavily' 'city' 'case' 'tulsa' 'privately' 'form' 'law' 'enforcement' 'place' 'pretend' 'deputy' 'confrontation' 'result' 'eric' 'harris' 'lose' 'life' 'lose' 'breath' 'lay' 'die' 'refuse' 'right' 'breathe' 'refusal' 'come' 'chorus' 'taunt' 'get' 'deserve' 'chose' 'run' 'breath' 'seep' 'black' 'body' 'public' 'service' 'officer' 'taunt' 'barrage' 'profanity' 'refusal' 'breath' 'black' 'people' 'endemic' 'american' 'condition' 'black' 'body' 'make' 'hold' 'dear' 'sacred' 'profane' 'thing' 'hand' 'white' 'people' 'famous' 'writer' 'american' 'prophet' 'james' 'baldwin' 'return' 'america' 'live' 'france' 'decade' 'interview' 'new' 'york' 'time' 'say' 'left' 'america' 'personal' 'decision' 'want' 'write' 'big' 'picnic' 'black' 'grow' 'street' 'harlem' 'remember' 'president' 'roosevelt' 'liberal' 'have' 'lot' 'trouble' 'anti' 'lynch' 'bill' 'want' 'mind' 'vote' 'mind' 'restaurant' 'mind' 'school' 'mind' 'fair' 'employment' 'policy' 'leave' 'need' 'place' 'breathe' 'feel' 'hand' 'throat' 'baldwin' 'name' 'moment' 'sound' 'similar' 'vote' 'insecure' 'racial' 'indiana' 'pass' 'legislation' 'allow' 'business' 'include' 'eatery' 'discriminate' 'customer' 'base' 'religious' 'assessment' 'fitness' 'serve' 'public' 'school' 'abysmal' 'condition' 'country' 'fast' 'food' 'worker' 'wag' 'campaign' 'minimum' 'wage' 'baldwin' 'illuminate' 'way' 'america' 'exist' 'place' 'predicate' 'refusal' 'black' 'breath' 'denial' 'black' 'people' 'right' 'freely' 'world' 'lose' 'life' 'have' 'break' 'play' 'toy' 'gun' 'stand' 'street' 'chat' 'friend'  ...
#
#      Predikció valószínűsége
# 41                    0.0115
# 53                    0.0560
# 68                    0.2189
# 82                    0.0480
# 151                   0.9942
# 156                   0.0088
# 168                   0.0821
# 176                   0.6364
# 186                   0.8639
# 188                   0.9636
# 244                   0.0073
# 249                   0.4578
# 275                   0.4051
# 297                   0.7897
# 327                   0.7070
# 340                   0.7883
# 356                   0.2322
# 393                   0.0186
# 401                   0.2060
# 408                   0.0796

# %% [markdown]
# # GRU MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ### Modell lefuttatása

# %%
# GRU modell

def create_gru_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),  # Ensure within vocab limit
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings  # Toggle trainability
    )(text_input)

    # GRU rétegek
    gru_out = GRU(128, return_sequences=True, dropout=0.3)(text_embedding)
    gru_out = Dropout(0.3)(gru_out)  # Dropout réteg az első GRU után
    gru_out = GRU(64,return_sequences=True, dropout=0.3)(gru_out)
    gru_out = Dropout(0.3)(gru_out)
    gru_out = GRU(32, dropout=0.3)(gru_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(gru_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása (Trainable)
gru_trainable = create_gru_model(trainable_embeddings=True)  # Trainable

gru_trainable.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_2 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 600, 128)            │         165,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 600, 64)             │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,711,809 (29.42 MB)
#  Trainable params: 7,711,809 (29.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# GRU modell tanítása a validációs adatok figyelésével
history_gru_trainable = gru_trainable.fit(
    padded_train_final, y_train_final,  # Ugyanaz a tanító adathalmaz, mint az LSTM-nél
    validation_data=(padded_val, y_val),  # Ugyanaz a validációs halmaz, mint az LSTM-nél
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság (GRU): {test_accuracy_gru:.4f}, Teszthalmaz veszteség (GRU): {test_loss_gru:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 68s 79ms/step - accuracy: 0.7682 - loss: 0.4433 - val_accuracy: 0.9474 - val_loss: 0.1373
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 66s 78ms/step - accuracy: 0.9629 - loss: 0.1087 - val_accuracy: 0.9681 - val_loss: 0.0882
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.9890 - loss: 0.0395 - val_accuracy: 0.9696 - val_loss: 0.0855
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9929 - loss: 0.0235 - val_accuracy: 0.9713 - val_loss: 0.1042
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.9967 - loss: 0.0106 - val_accuracy: 0.9728 - val_loss: 0.1122
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9974 - loss: 0.0084 - val_accuracy: 0.9719 - val_loss: 0.1232
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9708 - loss: 0.0892
# Teszthalmaz pontosság (GRU): 0.9687, Teszthalmaz veszteség (GRU): 0.0960

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Valószínűség becslése
gru_y_prob = gru_trainable.predict(padded_test)

gru_y_pred = (gru_y_prob > 0.5).astype(int)

accuracy = accuracy_score(y_test, gru_y_pred)
precision = precision_score(y_test, gru_y_pred)
recall = recall_score(y_test, gru_y_pred)
f1 = f1_score(y_test, gru_y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step
# Accuracy: 0.9685
# Precision: 0.9720
# Recall: 0.9648
# F1-score: 0.9684

# %% [markdown]
# ## GRU modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = gru_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_gru_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(history_gru_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(history_gru_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(history_gru_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9699 - loss: 0.0898

# %%
# Confusion Matrix
cm_gru = confusion_matrix(y_test, gru_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_gru, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix GRU Modellre')
plt.show()

print(classification_report(y_test, gru_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97      7440
#          1.0       0.97      0.96      0.97      7440
#
#     accuracy                           0.97     14880
#    macro avg       0.97      0.97      0.97     14880
# weighted avg       0.97      0.97      0.97     14880

# %%
# Flatten
y_true = y_test.flatten()
y_pred = gru_y_pred.flatten()
y_prob = gru_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás) GRU Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": gru_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = gru_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_gru.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 25   Hamis pozitív (FP)           0.0                 1
# 41   Hamis negatív (FN)           1.0                 0
# 53   Hamis negatív (FN)           1.0                 0
# 81   Hamis pozitív (FP)           0.0                 1
# 128  Hamis negatív (FN)           1.0                 0
# 168  Hamis negatív (FN)           1.0                 0
# 244  Hamis negatív (FN)           1.0                 0
# 295  Hamis negatív (FN)           1.0                 0
# 356  Hamis negatív (FN)           1.0                 0
# 399  Hamis pozitív (FP)           0.0                 1
# 404  Hamis pozitív (FP)           0.0                 1
# 408  Hamis negatív (FN)           1.0                 0
# 454  Hamis pozitív (FP)           0.0                 1
# 464  Hamis pozitív (FP)           0.0                 1
# 504  Hamis pozitív (FP)           0.0                 1
# 508  Hamis negatív (FN)           1.0                 0
# 579  Hamis negatív (FN)           1.0                 0
# 618  Hamis negatív (FN)           1.0                 0
# 631  Hamis pozitív (FP)           0.0                 1
# 642  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    'official' 'justice' 'department' 'education' 'department' 'join' 'force' 'write' 'letter' 'reject' 'obama' 'administration' 'policy' 'nondiscrimination' 'law' 'support' 'rollback' 'policy' 'explain' 'b ...
# 41                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'editor' 'note' 'follow' 'column' 'originally' 'appear' 'website' 'defense' 'watch' 'reprint' 'permission' 'like' 'million' 'american' 'saw' 'speech' 'dnc' 'thursday' 'night' 'wish' 'offer' 'sympathy' 'death' 'son' 'captain' 'humayun' 'khan' 'kill' 'action' 'iraq' 'army' 'officer' 'veteran' 'gulf' 'war' 'certainly' 'understand' 'pain' 'anguish' 'wife' 'endure' 'day' 'son' 'die' 'save' 'life' 'fellow' 'soldier' 'jesus' 'tell' 'disciple' 'accord' 'gospel' 'john' 'great' 'love' 'man' 'man' 'lay' 'life' 'friend' 'captain' 'khan' 'hero' 'sure' 'soldier' 'serve' 'regard' 'know' 'wife' 'rest' 'assure' 'million' 'veteran' 'regard' 'son' 'hero' 'paraphrase' 'book' 'son' 'son' 'ultimate' 'sacrifice' 'country' 'country' 'new' 'family' 'openly' 'embrace' 'certainly' 'love' 'family' 'arrive' 'america' 'pakistan' 'country' 'adopt' 'american' 'way' 'learn' 'history' 'apparently' 'acquire' 'pocket' 'constitution' 'way' 'good' 'sir' 'muslim' 'america' 'desire' 'assimilate' 'wish' 'live' 'sharia' 'law' 'unacceptable' 'american' 'law' 'land' 'yous' 'constitution' 'know' 'mr' 'khan' 'live' 'violent' 'times' 'dangerous' 'time' 'muslim' 'madman' 'isis' 'radical' 'jihadi' 'group' 'murder' 'terror' 'spree' 'globe' 'religion' 'peace' 'islam' 'fact' 'confirm' 'time' 'muslim' 'shoot' 'bomb' 'torture' 'innocent' 'men' 'woman' 'child' 'mean' 'muslim' 'terrorist' 'terrorist' 'sir' 'muslim' 'muslim' 'terrorist' 'attack' 'sign' 'time' 'regardless' 'feckless' 'nave' 'leftist' 'ideologue' 'barack' 'obama' 'colleague' 'john' 'kerry' 'francois' 'hollande' 'angela' 'merkel' 'state' 'united' 'state' 'west' 'war' 'radical' 'islam' 'job' 'president' 'united' 'state' 'protect' 'nation' 'enemy' 'foreign' 'domestic' 'unfortunately' 'mr' 'obama' 'islam' 'refuse' 'accept' 'reality' 'result' 'death' 'thousand' 'innocent' 'people' 'world' 'group' 'like' 'isi' 'al' 'qaeda' 'goal' 'complete' 'destruction' 'judeochristian' 'culture' 'religion' 'way' 'life' 'american' 'family' 'decade' 'century' 'family' 'like' 'relative' 'fight' 'civil' 'war' 'wwii' 'korea' 'vietnam' 'desert' 'storm' 'family' 'relatives' 'fought' 'american' 'revolution' 'plan' 'let' 'country' 'devour' 'muslim' 'maniac' 'american' 'sir' 'unarmed' 'socialist' 'european' 'zombie' 'necessary' 'protect' 'united' 'state' 'democrat' 'liberals' 'world' 'rise' 'colored' 'glass' 'conservative' 'understand' 'good' 'evil' 'world' 'evil' 'destroy' 'destroys' 'strong' 'measure' 'wartime' 'measure' 'take' 'protect' 'country' 'wish' 'annihilate' 'way' 'life' 'mr' 'trump' 'plan' 'temporarily' 'halt' 'immigration' 'muslim' 'country' 'know' 'support' 'terrorism' 'harbor' 'terrorist' 'group' 'pragmatic' 'constitutional' 'constitutional' 'duty' 'president' 'united' 'state' 'protect' 'nation' 'simply' 'way' 'vet' 'hundred' 'thousand' 'muslim' 'refugee' 'war' 'zone' 'like' 'syria' 'iraq' 'afghanistan' 'europe' 'destroy' 'reckless' 'leader' 'like' 'angela' 'merkel' 'open' 'continent' 'door' 'flood' 'million' 'undocumented' 'muslim' 'arrive' 'bad' 'attitude' 'jihad' 'think' 'american' 'stupid' 'leave' 'live' 'dream' 'world' 'right' 'mr' 'trump' 'understand' 'threat' 'nation' 'threat' 'sir' 'swedish' 'lutheran' 'name' 'anna' 'lars' 'threat' 'sir' 'radical' 'islam' 'god' 'yous' 'immigration' 'authority' 'suppose' 'know ...
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'far' 'weaken' 'environmental' 'protection' 'agency' 'donald' 'trump' 'need' 'beef' 'say' 'guy' 'new' 'york' 'time' 'william' 'd' 'march' 'time' 'write' 'strong' 'credible' 'regulatory' 'regime' 'essential' 'smooth' 'function' 'economy' 'interest' 'use' 'word' 'credible' 'worthless' 'bureaucrat' 'embody' 'wrong' 'epa' 'urgently' 'need' 'let' 'forget' 'epa' 'administrator' 'responsible' 'probably' 'black' 'moment' 'institution' 'history' 'man' 'ban' 'consequence' 'result' 'million' 'unnecessary' 'death' 'world' 'malaria' 'sure' 'deliberately' 'murder' 'people' 'fact' 'remain' 'effective' 'killer' 'mosquito' 'ban' 'help' 'create' 'regulatory' 'effect' 'deprive' 'world' 'best' 'defence' 'big' 'health' 'problem' 'told' 'story' 'month' 'worth' 'repeat' 'repeated' 'time' 'dreadful' 'man' 'pop' 'assume' 'mantle' 'authority' 'simply' 'earn' 'note' 'lawyer' 'train' 'scientist' 'man' 'responsible' 'ban' 'scientific' 'basis' 'whatsoever' 'fact' 'judge' 'edmund' 'sweeney' 'preside' 'epa' 'hear' 'examine' 'page' 'expert' 'testimony' 'conclude' 'carcinoge ...
# 81                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    'bana' 'alabedbana' 'september' 'year' 'old' 'live' 'aleppo' 'syria' 'vox' 'report' 'aleppo' 'significant' 'battlefield' 'country' 'continuous' 'fight' 'bashar' 'alassad' 'government' 'rebel' 'bana' 'recently' 'create' 'twitter' 'account' 'mother' 'finally' 'world' 'life' 'like' 'wartorn' 'city' 'interview' 'independent' 'journal' 'review' 'bana' 'say' 'violence' 'country' 'know' 'ask' 'describe' 'happens' 'bomb' 'go' 'say' 'bombing' 'predictable' 'hit' 'civilian' 'place' 'fear' 'thousand' 'live' 'fear' 'day' 'afraid' 'die' 'tonight' 'bomb' 'kill' 'bana' 'aleppo' 'bana' 'alabedbana' 'october' 'unlike' 'child' 'bana' 'school' 'explained' 'typical' 'day' 'invo ...
# 128                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'kiev' 'ukraine' 'say' 'review' 'request' 'georgia' 'arrest' 'extradite' 'georgian' 'president' 'mikheil' 'saakashvili' 'colorful' 'divisive' 'figure' 'politics' 'country' 'ukraine' 'day' 'brought' 'help' 'drive' 'reform' 'ukrainian' 'uprising' 'oust' 'prorussian' 'leader' 'saakashvili' 'loggerheads' 'kiev' 'authority' 'quit' 'governor' 'odessa' 'region' 'year' 'accuse' 'president' 'petro' 'poroshenko' 'abet' 'corruption' 'strip' 'ukrainian' 'citizenship' 'trip' 'abroad' 'try' 'reenter' 'ukraine' 'polish' 'border' 'sunday' 'staff' 'lawyer' 'expect' 'supporter' 'lawmaker' 'sympathetic' 'unclear' 'ukrainian' 'border' 'guard' 'respond' 'justice' 'ministry' 'send' 'request' 'georgia' 'ukraine' 'general' 'prosecutor' 'extradition' 'review' 'deputy' 'justice' 'minister' 'tell' 'news' 'conference' 'saakashvili' 'representative' 'say' 'question' 'extradition' 'saakashvili' 'firstly' 'need' 'let' 'ukraine' 'resolve' 'issue' 'look' 'like' 'intimidation' 'saakashvili' 'take' 'power' 'georgia' 'peaceful' 'prowestern' 'uprise' 'know' 'rise' 'revolution' 'president' 'time' 'short' 'disastrous' 'fiveday' 'war' 'russia' 'conflict' 'critic' 'argue' 'result' 'miscalculation' 'yearold' 'want' 'separate' 'criminal' 'charge' 'georgia' 'include' 'abuse' 'office' 'sa ...
# 168                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 244                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'public' 'service' 'announcement' 'friends' 'vox' 'enormous' 'false' 'information' 'facebook' 'internet' 'tv' 'election' 'day' 'country' 'favor' 'ignore' 'politician' 'play' 'fast' 'loose' 'truth' 'cable' 'news' 'network' 'get' 'story' 'wrong' 'internet' 'place' 'conspiracy' 'theory' 'mislead' 'story' 'photo' 'campaign' 'see' 'unprecedented' 'increase' 'sheer' 'number' 'false' 'news' 'story' 'share' 'facebook' 'post' 'entirely' 'fake' 'news' 'site' 'run' 'young' 'people' 'look' 'money' 'long' 'bitter' 'election' 'denver' 'guardian' 'earlier' 'month' 'run' 'story' 'headline' 'fbi' 'agent' 'suspect' 'hillary' 'email' 'leak' 'find' 'dead' 'apparent' 'article' 'ricochet' 'facebook' 'gain' 'ten' 'thousand' 'share' 'despite' 'fact' 'thing' 'denver' 'guardian' 'story' 'question' 'complete' 'fabrication' 'dynamic' 'deeply' 'concern' 'president' 'barack' 'obama' 'arguably' 'user' 'social' 'medium' 'american' 'political' 'history' 'politician' 'target' 'majority' 'facebooks' 'paranoid' 'outright' 'racist' 'viral' 'post' 'long' 'start' 'believing' 'say' 'campaign' 'stop' 'ann' 'arbor' 'michigan' 'monday' 'creates' 'dust' 'cloud' 'nonsense' 'matter' 'current' 'official' 'believe' 'russia' 'try' 'deliberately' 'spread' 'false' 'information' 'election' 'day' 'wouldbe' 'hillary' 'clinton' 'voter' 'stay' 'home' 'simply' 'shake' 'overall' 'confidence' 'american' 'political' 'system' 'mean' 'read' 'election' 'day' 'appear' 'dramatic' 'true' 'probably' 'good' 'simple' 'reason' 'november' 'fox' 'news' 'air' 'video' 'clip' 'show' 'member' 'black' 'panther' 'stand' 'outside' 'poll' 'station' 'philadelphia' 'single' 'person' 'single' 'polling' 'station' 'heavily' 'black' 'heavily' 'democratic' 'area' 'fox' 'anchor' 'strongly' 'suggest' 'broad' 'pattern' 'voter' 'intimidation' 'militant' 'determine' 'stop' 'nominee' 'mitt' 'romney' 'segment' 'frequently' 'day' 'year' 'certainly' 'possible' 'fox' 'news' 'leftleaning' 'station' 'like' 'msnbc' 'find' 'similar' 'type' 'clip' 'present' 'way' 'deliberately' 'mislead' 'amazingly' 'literally' 'problem' 'big' 'concern' 'proliferation' 'entirely' 'fake' 'news' 'site' 'entirely' 'fake' 'story' 'operate' 'entrepreneur' 'live' 'overseas' 'buzzfeed' 'article' 'earlier' 'month' 'find' 'young' 'people' 'macedonian' 'town' 'population' 'create' 'protrump' 'news' 'site' 'run' 'post' 'day' 'aggregate' 'completely' 'fringe' 'rightwing' 'site' 'example' 'story' 'website' 'call' 'post' 'article' 'headline' 'hillary' 'clinton' 'like' 'people' 'like' 'donald' 'trump' 'run' 'office' 'honest' 'buy' 'story' 'complete' 'fabrication' 'immediately' 'go' 'viral' 'share' 'reaction' 'comment' 'facebook' 'week' 'contrast' 'buzzfeed' 'note' 'new' 'york' 'time' 'bombshell' 'reveal' 'trump' 'declare' 'million' 'loss' 'income' 'tax' 'return' 'draw' 'comparatively' 'small' 'facebook' 'interaction' 'entire' 'month' 'kind' 'traffic' 'lucrative' 'business' 'macedonian' 'tell' 'buzzfeed' 'month' 'push' 'information' 'know' 'untrue' 'yes' 'info' 'blog' 'bad' 'false' 'misleading' 'youngster' 'tell' 'buzzfeed' 'rationale' 'get' 'people' 'click' 'engage' 'use' 'trump' 'get' 'boost' 'pay' 'troll' 'russia' 'pretend' 'american' 'multiple' 'social' 'medium' 'account' 'use' 'protrump' 'comment' 'traditional' 'publication' 'like' 'new' 'york' 'time' 'facebook' 'twitter' 'lie' 'false' 'information' 'get' 'parrot' 'conservativ ...
# 295                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'mass' 'think' 'dog' 'labrador' 'husky' 'de' 'pit' 'bull' 'lovable' 'day' 'care' 'add' 'pet' 'dog' 'planet' 'million' 'billion' 'dog' 'earth' 'accord' 'estimate' 'million' 'flea' 'collar' 'certainly' 'human' 'walk' 'pick' 'feces' 'call' 'village' 'dog' 'street' 'dog' 'dog' 'thing' 'haunt' 'garbage' 'dump' 'neighborhood' 'world' 'new' 'book' 'dog' 'raymond' 'argue' 'want' 'understand' 'nature' 'dog' 'need' 'know' 'animal' 'vast' 'majority' 'stray' 'lose' 'pet' 'adapt' 'closest' 'live' 'thing' 'dog' 'emerge' 'thousand' 'year' 'ago' 'scientist' 'disagree' 'genetics' 'dog' 'acknowledge' 'billion' 'dog' 'worth' 'study' 'major' 'figure' 'science' 'decade' 'raymond' 'found' 'professor' 'hampshire' 'college' 'amherst' 'biologist' 'science' 'writer' 'groundbreaking' 'work' 'dog' 'herd' 'dog' 'dog' 'origin' 'evolution' 'dog' 'say' 'recently' 'sit' 'porch' 'house' 'build' 'set' 'acre' 'land' 'talk' 'length' 'dog' 'village' 'deep' 'interest' 'animal' 'dog' 'child' 'kind' 'uncle' 'bring' 'ray' 'dog' 'pup' 'female' 'hung' 'load' 'ramp' 'chemical' 'plant' 'cambridge' 'mass' 'live' 'look' 'like' 'village' 'dog' 'world' 'say' 'graduate' 'boston' 'university' 'late' '1950s' 'continue' 'give' 'dog' 'graduation' 'present' 'say' 'mix' 'graduate' 'move' 'amherst' 'area' 'taught' 'russian' 'receive' 'master' 'degree' 'wildlife' 'biology' 'ray' 'pursue' 'ph' 'd' 'university' 'massachusetts' 'field' 'study' 'different' 'subject' 'dive' 'deeply' 'world' 'neighbor' 'race' 'dog' 'thing' 'lead' 'dr' 'start' 'race' 'dog' 'house' 'cement' 'den' 'hill' 'house' 'join' 'hampshire' 'college' 'found' 'faculty' 'continue' 'research' 'energy' 'expenditure' 'dog' 'develop' 'win' 'strain' 'alaskan' 'village' 'dog' 'border' 'time' 'live' 'dog' 'home' 'talk' 'nostalgia' 'bad' 'dog' 'good' 'like' 'jane' 'bad' 'dog' 'dr' 'say' 'tell' 'thousand' 'bad' 'story' 'jane' 'say' 'mountain' 'pas' 'sheep' 'worry' 'way' 'mountain' 'pick' 'stray' 'miss' 'have' 'dog' 'score' 'ms' 'say' 'miss' 'pet' 'dog' 'die' 'jack' 'russell' 'belong' 'grandchild' 'live' 'benefit' 'enjoy' 'observe' 'flood' 'wildlife' 'avoid' 'land' 'dog' 'fox' 'deer' 'animal' 'early' '1970s' 'begin' 'study' 'dog' 'travel' 'world' 'find' 'dog' 'sheep' 'bring' 'home' 'help' 'develop' 'shepherd' 'breed' 'united' 'state' 'start' 'livestock' 'project' 'hampshire' 'study' 'effective' 'dog' 'protect' 'sheep' 'livestock' 'book' 'dog' 'startle' 'new' 'understanding' 'origin' 'behavior' 'evolution' 'challenge' 'way' 'scientist' 'think' 'beginning' 'dog' 'argue' 'widely' 'hold' 'view' 'day' 'grab' 'wolf' 'pup' 'den' 'start' 'breed' 'program' 'instead' 'argue' 'dog' 'wild' 'start' 'hang' 'human' 'leftover' 'gradually' 'evolve' 'dependent' 'human' 'science' 'share' 'view' 'today' 'researcher' 'think' 'plausible' 'route' 'travel' 'year' 'look' 'introduce' 'sheep' 'farmer' 'dog' 'attend' 'conference' 'notice' 'dog' 'street' 'go' 'begin' 'think' 'dog' 'life' 'interest' 'dr' 'say' 'animal' 'unique' 'kind' 'social' 'behavior' 'start' 'study' 'early' '1990s' 'work' 'luigi' 'la' 'university' 'rome' 'study' 'urban' 'dog' 'live' 'garbage' 'taught' 'class' 'mexico' 'city' 'dump' 'dr' 'say' 'continue' 'observe' 'village' 'dog' 'world' 'argue' 'new' 'book' 'dog' 'stray' 'assume' 'lose' 'pet' 'wander' 'group' 'village' 'dog' 'large' 'dog' 'world' 'africa' 'mongolia' 'china' 'america' ...
# 356                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'sunday' 'art' 'leisure' 'section' 'profile' 'john' 'mayer' 'singer' 'songwriter' 'guitar' 'happen' 'talker' 'well' 'worse' 'run' 'interview' 'change' 'course' 'career' 'musician' 'celebrity' 'recently' 'decision' 'put' 'record' 'video' 'saddle' 'guilt' 'say' 'month' 'los' 'angeles' 'feel' 'like' 'work' 'b' 'long' 'people' 'believe' 'work' 'add' 'take' 'year' 'o' 'k' 'come' 'let' 'party' 'go' 'fool' 'mr' 'mayer' 'release' 'month' 'new' 'album' 'search' 'hop' 'return' 'pop' 'mainstream' 'trail' 'record' 'studio' 'shoot' 'music' 'video' 'frenetic' 'day' 'cap' 'additional' 'interview' 'dinner' 'additional' 'edit' 'excerpt' 'hour' 'conversation' 'read' 'story' 'google' 'result' 'certain' 'thing' 'get' 'big' 'knock' 'place' 'popular' 'malign' 'interesting' 'thing' 'life' 'wrong' 'time' 'think' 'lot' 'people' 'impression' 'outdated' 'autopsy' 'life' 'turn' 'impression' 'big' 'star' 'appreciate' 'market' 'correction' 'actually' 'market' 'correction' 'probably' 'big' 'quickly' 'revise' 'statement' 'like' 'little' 'big' 'brother' 'baby' 'rattle' 'man' 'look' 'picture' 'give' 'bath' 'lie' 'hotel' 'penthouse' 'hollywood' 'clich' 'flow' 'freely' 'brain' 'stuff' 'healthy' 'work' 'mechanism' 'place' 'life' 'fabulous' 'bit' 'time' 'international' 'space' 'station' 'let' 'sense' 'love' 'international' 'space' 'station' 'pretty' 'cool' 'reason' 'settle' 'astronaut' 'hat' 'upset' 'way' 'real' 'question' 'appearance' 'job' 'prevent' 'absolutely' 'entitle' 'psychologically' 'scary' 'go' 'kid' 'fairfield' 'conn' 'rock' 'star' 'fairfield' 'conn' 'good' 'people' 'job' 'marry' 'watch' 'tv' 'start' 'life' 'good' 'people' 'live' 'fed ...
# 399                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'sandy' 'spring' 'ga' 'april' 'yous' 'president' 'donald' 'trump' 'congressional' 'election' 'tuesday' 'reliably' 'republican' 'northern' 'suburb' 'atlanta' 'spell' 'trouble' 'democratic' 'upstart' 'jon' 'ossoff' 'pull' 'surprise' 'msnbc' 'morning' 'joe' 'host' 'guest' 'attempt' 'contain' 'excitement' 'possibility' 'democrat' 'win' 'seat' 'house' 'leader' 'newt' 'gingrich' 'special' 'election' 'hop' 'replace' 'tom' 'price' 'georgia' '6th' 'district' 'trump' 'actively' 'campaign' 'ossoff' 'social' 'today' 'vote' 'georgia' 'force' 'runoff' 'easy' 'win' 'dem' 'ossoff' 'raise' 'bad' 'crime' '2nd' 'donald' 'j' 'trump' 'realdonaldtrump' 'april' '2017a' 'yearold' 'political' 'novice' 'ossoff' 'run' 'lone' 'democrat' 'field' ' ...
# ...
# 618                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'scott' 'host' 'cbs' 'news' 'minute' 'embarrass' 'sunday' 'segment' 'fake' 'news' 'despite' 'have' 'final' 'cut' 'hostile' 'interview' 'activist' 'mike' 'cernovich' 'lawyer' 'independent' 'dominant' 'voice' 'twitter' 'build' 'significant' 'buzz' 'minute' 'reveal' 'thursday' 'grant' 'interview' 'hour' 'live' 'broadcast' 'cernovich' 'anticipate' 'conversation' 'selectively' 'edit' 'publish' 'partial' 'transcript' 'concern' 'base' 'long' 'history' 'network' 'news' 'program' 'mislead' 'downright' 'comical' 'edit' 'conservative' 'worst' 'possible' 'light' 'segment' 'air' 'open' 'statement' 'clear' 'story' 'smear' 'job' 'election' 'nation' 'assault' 'masquerade' 'reporter' 'poison' 'conversation' 'lie' 'leave' 'right' 'influence' 'outcome' 'buck' 'president' 'use' 'term' 'fake' 'news' 'discredit' 'responsible' 'reporting' 'like' 'go' 'con' 'artist' 'insert' 'truly' 'fake' 'news' 'national' 'conversation' 'fraudulent' 'software' 'scam' 'social' 'medium' 'account' 'story' 'fake' 'consequence' 'real' 'emphasis' 'add' 'later' 'introduce' 'cernovich' 'depict' 'like' 'little' 'boy' 'hunch' 'laptop' 'call' 'magnet' 'reader' 'taste' 'story' 'basis' 'fact' 'setup' 'end' 'humiliate' 'target' 'watch' 'key' 'exchange' 'story' 'get' 'traction' 'deny' 'clinton' 'doctor' 'national' 'parkinson' 'foundation' 'pic' 'twitter' 'minute' 'march' 'bring' 'article' 'website' 'physician' 'later' 'out' 'orlando' 'dr' 'ted' 'noel' 'argued' 'explanation' 'clinton' 'bizarre' 'physical' 'tic' 'parkinson' 'disease' 'confront' 'cernovich' 'headline' 'hillary' 'clinton' 'parkinson' 'disease' 'physician' 'confirms' 'expose' 'belief' 'unproven' 'claim' 'cernovich' 'seizure' 'froze' 'walk' 'motorcade' 'day' 'september' 'pneumonia' 'mean' 'cernovich' 'know' 'told' 'campaign' 'tell' 'cernovich' 'trust' 'campaign ...
# 631                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'bni' 'store' 'oct' 'come' 'soon' 'french' 'neighborhood' 'near' 'illegal' 'alien' 'muslim' 'invader' 'set' 'fire' 'calais' 'jungle' 'camp' 'camp' 'shut' 'hey' 'woman' 'child' 'french' 'authority' 'say' 'wednesday' 'fin ...
# 642                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
#
#      Predikció valószínűsége
# 25                    0.8985
# 41                    0.0120
# 53                    0.3405
# 81                    0.8969
# 128                   0.2212
# 168                   0.2782
# 244                   0.0240
# 295                   0.1715
# 356                   0.0856
# 399                   0.7360
# 404                   0.9642
# 408                   0.0018
# 454                   0.5594
# 464                   0.9870
# 504                   0.7575
# 508                   0.0155
# 579                   0.0659
# 618                   0.1996
# 631                   0.9441
# 642                   0.1061

# %% [markdown]
# # Tanulás-validáció-teszt összehasonlítása két modellnél

# %%
test_loss_lstm, test_accuracy_lstm = lstm_trainable.evaluate(padded_test, y_test, verbose=0)
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test, verbose=0)

# Ábra létrehozása két alábrával
plt.figure(figsize=(12, 5))

# Tanulási, validációs és teszthalmaz veszteség ábrázolása
plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='LSTM tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='LSTM validációs veszteség', color='#7fcdbb')
plt.plot(history_gru_trainable.history['loss'], label='GRU tanulási veszteség', color='red')
plt.plot(history_gru_trainable.history['val_loss'], label='GRU validációs veszteség', color='orange')
plt.axhline(y=test_loss_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz veszteség')  # LSTM teszt loss
plt.axhline(y=test_loss_gru, color='red', linestyle='--', label='GRU teszthalmaz veszteség')  # GRU teszt loss
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Ttanulási, validációs és teszthalmaz precízió ábrázolása
if 'accuracy' in lstm_history_trainable.history and 'accuracy' in history_gru_trainable.history:
    plt.subplot(1, 2, 2)
    plt.plot(lstm_history_trainable.history['accuracy'], label='LSTM tanulási pontosság', color='blue')
    plt.plot(lstm_history_trainable.history['val_accuracy'], label='LSTM validációs pontosság', color='#7fcdbb')
    plt.plot(history_gru_trainable.history['accuracy'], label='GRU tanulási pontosság', color='red')
    plt.plot(history_gru_trainable.history['val_accuracy'], label='GRU validációs pontosság', color='orange')
    plt.axhline(y=test_accuracy_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz pontosság')  # LSTM teszt accuracy
    plt.axhline(y=test_accuracy_gru, color='red', linestyle='--', label='GRU teszthalmaz pontosság')  # GRU teszt accuracy
    plt.xlabel('Epizód')
    plt.ylabel('Pontosság')
    plt.legend()
    plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.tight_layout()
plt.show()
