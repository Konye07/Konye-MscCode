# %% [markdown]
# # **Csomagok behívása**

# %%
#Szükséges csomagok és adatbázis importálása
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Concatenate
import numpy as np
import tensorflow as tf
import spacy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fájlok behívása, ellenőrzése és felkészítése

# %%
# Betölteni padded sequences, tokenizer, és számokat
padded_train = np.load('/content/padded_train03.npy')
padded_test = np.load('/content/padded_independent03.npy')

# Tokenizer visszatöltése
with open('/content/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Címkék betöltése (real = 1, fake = 0)
train_file = '/content/train_harmadik.csv'
test_file = '/content/indep_harmadik.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

labels_train = df_train['label'].values
labels_test = df_test['label'].values

# Betölteni embedding mátrixot
embedding_matrix = np.load('/content/embedding_matrix.npy')

# Ellenőrzés
print(f"Train padded sequences shape: {padded_train.shape}")
print(f"Test padded sequences shape: {padded_test.shape}")
print(f"Train labels shape: {labels_train.shape}")
print(f"Test labels shape: {labels_test.shape}")
# Out:
# Train padded sequences shape: (59520, 600)
# Test padded sequences shape: (14304, 600)
# Train labels shape: (59520,)
# Test labels shape: (14304,)

# %%
# Max szókincs és szekvencia hossz
MAX_VOCAB_SIZE = 25000
MAX_LENGTH = 600
EMBEDDING_DIM = 300  # GloVe 300d

# input shape
MAX_SEQUENCE_LENGTH = padded_train.shape[1]

# Szöveges input (LSTM/GRU bemenet)
text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
embedding_layer = Embedding(
    input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
    output_dim=embedding_matrix.shape[1],
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)(text_input)

model_output = embedding_layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
MAX_SEQUENCE_LENGTH = padded_train.shape[1]  # Train hossz
EMBEDDING_DIM = embedding_matrix.shape[1]  # GloVe embeddings

# 10%-os validációs halmaz leválasztása a tanító adatokból
padded_train_final, padded_val, y_train_final, y_val = train_test_split(
    padded_train, labels_train, test_size=0.1, random_state=42
)
# Float32-re konvertálás TensorFlow kompatibilitás miatt
padded_train_final = np.array(padded_train_final, dtype=np.float32)
padded_val = np.array(padded_val, dtype=np.float32)
padded_test = np.array(padded_test, dtype=np.float32)
y_train_final = np.array(y_train_final, dtype=np.float32)
y_val = np.array(y_val, dtype=np.float32)
y_test = np.array(labels_test, dtype=np.float32)

# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# # LSTM MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ## Modell lefuttatása

# %%
# LSTM modell, trainable, non-trainable embedding

def create_lstm_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings
    )(text_input)

    # LSTM rétegek
    lstm_out = LSTM(128, return_sequences=True, dropout=0.3)(text_embedding)
    lstm_out = Dropout(0.3)(lstm_out)  # Dropout réteg az első LSTM után
    lstm_out = LSTM(64,return_sequences=True, dropout=0.3)(lstm_out)
    lstm_out = Dropout(0.3)(lstm_out) # Dropout réteg az második LSTM után
    lstm_out = LSTM(32, dropout=0.3)(lstm_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(lstm_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása
lstm_trainable = create_lstm_model(trainable_embeddings=True)  # Trainable embedding

lstm_trainable.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_1 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 600, 128)            │         219,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 600, 64)             │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,781,505 (29.68 MB)
#  Trainable params: 7,781,505 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Modell tanítása a validációs adatok figyelésével
lstm_history_trainable = lstm_trainable.fit(
    padded_train_final, y_train_final,
    validation_data=(padded_val, y_val),  # Validációs halmaz
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság: {test_accuracy:.4f}, Teszthalmaz veszteség: {test_loss:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 77s 83ms/step - accuracy: 0.8563 - loss: 0.3460 - val_accuracy: 0.9031 - val_loss: 0.2534
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 81s 88ms/step - accuracy: 0.9406 - loss: 0.1758 - val_accuracy: 0.9340 - val_loss: 0.1986
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.9583 - loss: 0.1255 - val_accuracy: 0.9325 - val_loss: 0.1842
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9552 - loss: 0.1278 - val_accuracy: 0.9425 - val_loss: 0.1527
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9779 - loss: 0.0681 - val_accuracy: 0.9503 - val_loss: 0.1500
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 87ms/step - accuracy: 0.9843 - loss: 0.0513 - val_accuracy: 0.9525 - val_loss: 0.1421
# Epoch 7/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 80s 84ms/step - accuracy: 0.9893 - loss: 0.0356 - val_accuracy: 0.9545 - val_loss: 0.1406
# Epoch 8/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9930 - loss: 0.0243 - val_accuracy: 0.9516 - val_loss: 0.1670
# Epoch 9/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9941 - loss: 0.0210 - val_accuracy: 0.9556 - val_loss: 0.1469
# Epoch 10/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 87ms/step - accuracy: 0.9677 - loss: 0.1053 - val_accuracy: 0.9528 - val_loss: 0.1777
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.7232 - loss: 1.3290
# Teszthalmaz pontosság: 0.7186, Teszthalmaz veszteség: 1.3573

# %%
# Valószínűség becslése
lstm_y_prob = lstm_trainable.predict(padded_test)

lstm_y_pred = (lstm_y_prob > 0.5).astype(int)

lstm_accuracy = accuracy_score(y_test, lstm_y_pred)
lstm_precision = precision_score(y_test, lstm_y_pred)
lstm_recall = recall_score(y_test, lstm_y_pred)
lstm_f1 = f1_score(y_test, lstm_y_pred)

print(f"Accuracy: {lstm_accuracy:.4f}")
print(f"Precision: {lstm_precision:.4f}")
print(f"Recall: {lstm_recall:.4f}")
print(f"F1-score: {lstm_f1:.4f}")
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
# Accuracy: 0.7189
# Precision: 0.9143
# Recall: 0.4831
# F1-score: 0.6321

# %% [markdown]
# ## LSTM Modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(lstm_history_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(lstm_history_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 15s 34ms/step - accuracy: 0.7233 - loss: 1.3357

# %%
# Confusion Matrix
cm_lstm = confusion_matrix(y_test, lstm_y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm_lstm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix LSTM Modellre')
plt.show()

print(classification_report(y_test, lstm_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.95      0.77      7152
#          1.0       0.91      0.48      0.63      7152
#
#     accuracy                           0.72     14304
#    macro avg       0.78      0.72      0.70     14304
# weighted avg       0.78      0.72      0.70     14304

# %%
# Flatten
y_true = y_test.flatten()
y_pred = lstm_y_pred.flatten()
y_prob = lstm_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás besorolás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás besorolás) LSTM Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": lstm_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = lstm_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_lstm.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#            Hiba típusa  Valódi címke  Prediktált címke  \
# 4   Hamis negatív (FN)           1.0                 0
# 8   Hamis negatív (FN)           1.0                 0
# 10  Hamis negatív (FN)           1.0                 0
# 12  Hamis negatív (FN)           1.0                 0
# 15  Hamis negatív (FN)           1.0                 0
# 23  Hamis negatív (FN)           1.0                 0
# 24  Hamis negatív (FN)           1.0                 0
# 38  Hamis negatív (FN)           1.0                 0
# 50  Hamis negatív (FN)           1.0                 0
# 51  Hamis negatív (FN)           1.0                 0
# 57  Hamis negatív (FN)           1.0                 0
# 59  Hamis negatív (FN)           1.0                 0
# 60  Hamis negatív (FN)           1.0                 0
# 70  Hamis negatív (FN)           1.0                 0
# 71  Hamis negatív (FN)           1.0                 0
# 77  Hamis negatív (FN)           1.0                 0
# 79  Hamis negatív (FN)           1.0                 0
# 82  Hamis negatív (FN)           1.0                 0
# 86  Hamis negatív (FN)           1.0                 0
# 90  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   'department' 'transportation' 'ask' 'understanding' 'metro' 'manila' 'land'  ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'geneva' 'world' 'health' 'organization' 'say' 'wednesday' 'early' 'lift' 'alert' 'crisis' 'pandemic' 'remain' 'global' 'health' 'emergency' 'despite' 'recent' 'progress' 'emergency' 'committee' 'meet' 'week' 'conclude' 'pandemic' 'constitutes' 'public' 'health' 'emergency' 'international' 'concern' 'status' 'declare' 'january' 'chief' 'tedros' 'tell' 'reporter' 'wednesday' 'agree' 'committee' 'advice' 'committee' 'emphasize' 'need'  ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 50  'culture' 'war' 'percolate' 'beneath' 'surface' 'presidential' 'politics' 'push' 'surface' 'early' 'cycle' 'indianas' 'religious' 'freedom' 'restoration' 'act' 'republican' 'gov' 'mike' 'penny' 'consider' 'run' 'president' 'sign' 'law' 'week' 'cause' 'firestorm' 'criticism' 'law' 'lead' 'discrimination' 'gay' 'lesbians' 'include' 'business' 'like' 'apple' 'list' 'ncaa' 'host' 'men' 'college' 'basketball' 'final' 'indianapolis' 'state' 'like' 'connecticut' 'ban' 'travel' 'indiana' 'penny' 'surprise' 'backlash' 'difficulty' 'explain' 'position' 'potential' 'candidate' 'leap' 'defense' 'like' 'florida' 'sen' 'marco' 'rubio' 'go' 'indiana' 'governor' 'supporter' 'indianas' 'law' 'similar' 'federal' 'religious' 'freedom' 'restoration' 'act' 'pass' 'case' 'controversy' 'facts' 'muddle' 'conflate' 'fact' 'law' 'different' 'politics' 'side' 'shape' 'response' 'seek' 'clarification' 'fix' 'contender' 'weigh' 'tuesday' 'penny' 'say' 'misunderstanding' 'confusion' 'law' 'say' 'seek' 'clarification' 'fix' 'law' 'legislation' 'make' 'clear' 'law' 'business' 'right' 'deny' 'service' 'monday' 'law' 'presidential' 'campaign' 'republican' 'presidential' 'candidate' 'weigh' 'sunday' 'performance' 'penny' 'raise' 'question' 'penny' 'sidestep' 'half' 'dozen' 'specific' 'question' 'law' 'lead' 'discrimination' 'gay' 'lesbian' 'florida' 'gov' 'jeb' 'bush' 'contend' 'fact' 'establish' 'people' 'go' 'discriminatory' 'wisconsin' 'gov' 'scott' 'walker' 'back' 'law' 'say' 'spokesman' 'right' 'american' 'exercise' 'religion' 'act' 'conscience' 'texas' 'sen' 'ted' 'cruz' 'say' 'law' 'give' 'voice' 'million' 'courageous' 'conservative' 'rubio' 'candidate' 'directly' 'addressed' 'charge' 'business' 'discriminate' 'gay' 'lesbian' 'couple' 'advocate' 'example' 'gay' 'lesbian' 'couple' 'want' 'flower' 'arrangement' 'cake' 'reception' 'florist' 'lawfully' 'choose' 'fill' 'order' 'religious' 'objection' 'rubio' 'say' 'thinks' 'business' 'right' 'issue' 'talk' 'provide' 'professional' 'service' 'punish' 'law' 'refuse' 'provide' 'professional' 'service' 'ceremony' 'believe' 'violation' 'faith' 'say' 'fox' 'news' 'monday' 'think' 'people' 'right' 'live' 'religious' 'faith' 'life' 'conservative' 'include' 'penny' 'address' 'charge' 'headon' 'instead' 'law' 'unfairly' 'malign' 'state' 'similar' 'law' 'democrat' 'bill' 'clinton' 'sign' 'federal' 'religious' 'freedom' 'restoration' 'act' 'law' 'president' 'hillary' 'clinton' 'record' 'tweet' 'sad' 'new' 'indiana' 'law' 'happen' 'america' 'today' 'discriminate' 'people' 'love' 'white' 'house' 'tuesday' 'blast' 'penny' 'falsely' 'suggest' 'law' 'indianas' 'federal' 'true' 'white' 'house' 'press' 'secretary' 'josh' 'earnest' 'say' 'white' 'house' 'daily' 'briefing' 'cite' 'spirit' 'law' 'text' 'say' 'law' 'effort' 'protect' 'religious' 'liberty' 'religious' 'minority' 'base' 'action' 'take' 'federal' 'government' 'hand' 'indiana' 'law' 'broader' 'earnest' 'continue' 'apply' 'individual' 'religious' 'minority' 'applies' 'quote' 'partnership' 'limit' 'liability' 'company' 'corporation' 'company' 'firm' 'society' 'joint' 'stock' 'company' 'association' 'obviously' 'significant' 'expansion' 'law' 'term' 'way' 'apply' 'openended' 'piece' 'legislation' 'reasonably' 'try' 'justify' 'discriminate' 'somebody' 'love' 'let' 'start' 'law' 'come' 'federal' 'law' 'stem' 'oregon' 'native' 'american' 'man' 'lose' 'job' 'test' 'positive' 'drug' 'religious' 'ritual' 'fix' 'problem' 'federal' 'introduce' 'soontobe' 'senate' 'minority' 'leader' 'chuck' 'schumer' 'house' 'member' 'new' 'york' 'companion' 'bill' 'pass' 'senate' 'introduce' 'late' 'sen' 'ted' 'kennedy' 'nineteen' 'state' 'addition' 'indiana' 'enact' 'atlantic' 'note' 'south' 'carolina' 'texas' 'similar' 'variation' 'indianas' 'far' 'indiana' 'vs' 'federal' 'law' 'federal' 'state' 'government' 'shall' 'substantially' 'burden' 'person' 'exercise' 'religion' 'burden' 'result' 'rule' 'general' 'indiana' 'law' 'state' 'governmental' 'entity' 'substantially' 'burden' 'person' 'ex ...
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# ...
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 86                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'monday' 'sentence' 'mayor' 'islam' 'year' 'prison' 'multiple' 'count' 'graft' 'antigraft' 'court' 'division' 'find' 'guilty' 'reasonable' 'doubt' 'count' 'graft' 'count' 'complex' 'crime' 'falsification' 'public' 'document' 'appear' 'million' 'worth' 'government' 'fund' 'buy' 'food' 'supply' 'brown' 'sugar' 'dry' 'fish' 'different' 'supplier' 'purchase' 'governor' 'crime' 'commit' 'perpetually' 'run' 'occupy' 'public' 'office' 'order' 'pay' 'million' 'sentenced' 'year' 'jail' 'time' 'count' 'graft' 'sentence' 'year' 'jail' 'time' 'count' 'get' 'year' 'jail' 'sentence' 'fourth' 'count' 'find' 'guilty' 'offense' 'ali' 'provincial' 'budget' 'officer' 'member' 'province' 'bid' 'award' 'committee' 'attend' 'virtually' 'currently' 'municipal' 'council' 'member' 'review' 'voluminous' 'documentary' 'exhibit' 'testimonial' 'evidence' 'present' 'prosecution' 'reveals' 'evident' 'bad' 'faith' 'accuse' 'say' 'piece' 'evidence' 'proven' 'doubt' 'say' 'accuse' 'deliberately' 'maliciously' 'orchestrate' 'simulated' 'purchase' 'fictitious' 'supplier' 'order' 'divert' 'public' 'fund' 'benefit' 'say' 'page' 'decision' 'absence' 'public' 'bidding' 'resort' 'negotiate' 'procurement' 'legal' 'accuse' 'breach' 'swear' 'duty' 'public' 'official' 'fraudulent' 'malevolent' 'intent' 'steal' 'public' 'fund' 'antigraft' 'court' 'add' 'say' 'defy' 'safeguard' 'provide' 'procurement' 'law' 'republic' 'act' 'implement' 'rule' 'regulation' 'resort' 'alternative' 'method' 'procurement' 'justification' 'base' 'section' 'ra' 'procure' 'entity' 'purchase' 'food' 'supply' 'negotiate' 'procurement' 'harp' 'purported' 'natural' 'manmade' 'calamity' 'reason' 'negotiate' 'procurement' 'evidence' 'present' 'prove' 'emergency' 'case' 'say' 'accuse' 'local' 'chief' 'executive' 'completely' 'accomplish' 'portion' 'po' 'purchase' 'order' 'necessitate' 'certification' 'secretary' 'negotiate' 'procurement' 'approve' 'pursuant' 'resolution' 'declare' 'state' 'emergency' 'add' 'likewise' 'stress' 'fictitious' 'nature' 'supplier' 'merchandise' 'enterprise' 'merchandise' 'n' 'merchandise' 'general' 'merchandise' 'undeniable' 'department' 'trade' 'industry' 'security' 'exchange' 'commission' 'business' 'permit' 'license' 'section' 'attest' 'supplier' 'register' 'issue' 'permit' 'conduct' 'business' 'letter' 'certification' 'commission' 'election' 'social' 'security' 'system' 'government' 'service' 'insurance' 'system' 'philippine' 'statistic' 'authority' 'bureau' 'internal' 'revenue' 'official' 'confirm' 'alleged' 'owner' 'thereof' 'fictitious' 'give' 'record' 'verify' 'existence' 'iota' 'evidence' 'validate' 'existence' 'say' 'commission' 'audit' 'special' 'audit' 'eventual' 'issuance' 'notice' 'accuse' 'get' 'away' 'ghost' 'pr ...
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'department' 'education' 'finaliz ...
#
#     Predikció valószínűsége
# 4                    0.0052
# 8                    0.0005
# 10                   0.1599
# 12                   0.0640
# 15                   0.0008
# 23                   0.0176
# 24                   0.3546
# 38                   0.0086
# 50                   0.0723
# 51                   0.0041
# 57                   0.0021
# 59                   0.0659
# 60                   0.0073
# 70                   0.0621
# 71                   0.0015
# 77                   0.0018
# 79                   0.0032
# 82                   0.0008
# 86                   0.0697
# 90                   0.0041

# %% [markdown]
# # GRU MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ### Modell lefuttatása

# %%
# GRU Modell

def create_gru_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),  # Ensure within vocab limit
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings  # Toggle trainability
    )(text_input)

    # GRU rétegek
    gru_out = GRU(128, return_sequences=True, dropout=0.3)(text_embedding)
    gru_out = Dropout(0.3)(gru_out)  # Dropout réteg az első GRU után
    gru_out = GRU(64,return_sequences=True, dropout=0.3)(gru_out)
    gru_out = Dropout(0.3)(gru_out)
    gru_out = GRU(32, dropout=0.3)(gru_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(gru_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása (Trainable)
gru_trainable = create_gru_model(trainable_embeddings=True)

gru_trainable.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_2 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 600, 128)            │         165,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 600, 64)             │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,711,809 (29.42 MB)
#  Trainable params: 7,711,809 (29.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# GRU modell tanítása a validációs adatok figyelésével
history_gru_trainable = gru_trainable.fit(
    padded_train_final, y_train_final,  # Ugyanaz a tanító adathalmaz, mint az LSTM-nél
    validation_data=(padded_val, y_val),  # Ugyanaz a validációs halmaz, mint az LSTM-nél
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság (GRU): {test_accuracy_gru:.4f}, Teszthalmaz veszteség (GRU): {test_loss_gru:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 72s 83ms/step - accuracy: 0.8610 - loss: 0.3161 - val_accuracy: 0.9498 - val_loss: 0.1381
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 78s 79ms/step - accuracy: 0.9663 - loss: 0.1001 - val_accuracy: 0.9745 - val_loss: 0.0751
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 79ms/step - accuracy: 0.9893 - loss: 0.0365 - val_accuracy: 0.9745 - val_loss: 0.0773
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 66s 78ms/step - accuracy: 0.9943 - loss: 0.0198 - val_accuracy: 0.9701 - val_loss: 0.0982
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 66s 78ms/step - accuracy: 0.9733 - loss: 0.0627 - val_accuracy: 0.9639 - val_loss: 0.1087
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7897 - loss: 0.6711
# Teszthalmaz pontosság (GRU): 0.7874, Teszthalmaz veszteség (GRU): 0.6814

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Valószínűség becslése
gru_y_prob = gru_trainable.predict(padded_test)

gru_y_pred = (gru_y_prob > 0.5).astype(int)

accuracy = accuracy_score(y_test, gru_y_pred)
precision = precision_score(y_test, gru_y_pred)
recall = recall_score(y_test, gru_y_pred)
f1 = f1_score(y_test, gru_y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step
# Accuracy: 0.7882
# Precision: 0.9556
# Recall: 0.6046
# F1-score: 0.7406

# %% [markdown]
# ## GRU modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_gru_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(history_gru_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(history_gru_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(history_gru_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.7234 - loss: 1.3307

# %%
# Confusion Matrix
cm_gru = confusion_matrix(y_test, gru_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_gru, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix GRU Modellre')
plt.show()

print(classification_report(y_test, gru_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.97      0.82      7152
#          1.0       0.96      0.60      0.74      7152
#
#     accuracy                           0.79     14304
#    macro avg       0.83      0.79      0.78     14304
# weighted avg       0.83      0.79      0.78     14304

# %%
# Flatten
y_true = y_test.flatten()
y_pred = gru_y_pred.flatten()
y_prob = gru_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás) GRU Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": gru_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = gru_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_gru.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 8    Hamis negatív (FN)           1.0                 0
# 15   Hamis negatív (FN)           1.0                 0
# 23   Hamis negatív (FN)           1.0                 0
# 32   Hamis negatív (FN)           1.0                 0
# 34   Hamis negatív (FN)           1.0                 0
# 51   Hamis negatív (FN)           1.0                 0
# 57   Hamis negatív (FN)           1.0                 0
# 59   Hamis negatív (FN)           1.0                 0
# 60   Hamis negatív (FN)           1.0                 0
# 70   Hamis negatív (FN)           1.0                 0
# 77   Hamis negatív (FN)           1.0                 0
# 79   Hamis negatív (FN)           1.0                 0
# 82   Hamis negatív (FN)           1.0                 0
# 84   Hamis pozitív (FP)           0.0                 1
# 91   Hamis negatív (FN)           1.0                 0
# 109  Hamis negatív (FN)           1.0                 0
# 111  Hamis negatív (FN)           1.0                 0
# 115  Hamis negatív (FN)           1.0                 0
# 134  Hamis negatív (FN)           1.0                 0
# 137  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'official' 'philippine' 'national' 'police' 'pnp' 'drug' 'enforcement' 'group' 'special' ...
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   'past' 'perceive' 'gaffe' 'romneys' 'percent' 'comment' 'drawn' 'far' 'attention' 'medium' 'voter' 'mind' 'candidate' 'way' 'leave' 'becky' 'love' 'kathy' 'political' 'statement' 'town' 'hall' 'gathering' 'host' 'trump' 'supporter' 'house' 'speaker' 'newt' 'gingrich' 'state' 'university' 'monday' 'sept' 'ga' 'hillary' 'clinton' 'weekend' 'comment' 'half' 'donald' 'trumps' 'supporter' 'racist' 'sexist' 'basket' 'deplorables' 'roil' 'presidential' 'race' 'begin' 'lot' 'pundit' 'compare' 'mitt' 'romneys' 'famous' 'percent' 'statement' 'say' 'nearly' 'half' 'american' 'voter' 'write' 'welfare' 'moocher' 'lose' 'discussion' 'comparison' 'fact' 'romneys' 'percent' 'word' 'reveal' 'secret' 'source' 'leak' 'tape' 'fundraiser' 'mother' 'jones' 'magazine' 'affect' 'outcome' 'probably' 'poll' 'political' 'reality' 'moment' 'mrs' 'clinton' 'deplorables' 'romneys' 'percent' 'voter' 'usually' 'mind' 'day' 'news' 'coverage' 'true' 'voter' 'saw' 'romneys' 'perceive' 'gaffe' 'negative' 'term' 'sure' 'like' 'negative' 'repercussion' 'harsh' 'word' 'seemingly' 'deliver' 'secret' 'opponent' 'supporter' 'important' 'typical' 'political' 'slip' 'tongue' 'term' 'people' 'plan' 'vote' 'consistent' 'evidence' 'change' 'wake' 'tape' 'release' 'write' 'political' 'scientist' 'john' 'side' 'george' 'university' 'lynn' 'ucla' 'history' 'election' 'gamble' 'gallup' 'poll' 'data' 'show' 'president' 'obamas' 'lead' 'romney' 'actually' 'shrink' 'percentage' 'point' 'week' 'percent' 'public' 'rasmussen' 'poll' 'stay' 'average' 'public' 'poll' 'stable' 'wake' 'controversy' 'accord' 'side' 'word' 'people' 'opinion' 'race' 'alter' 'contrast' 'debate' 'hold' 'october' 'poll' 'medium'  ...
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'house' 'committee' 'appropriation' 'wednesday' 'terminate' 'hearing' 'propose' 'billion' 'budget' 'department' 'justice' 'doj' 'attach' 'agency' 'year' 'representative' 'initially' 'move' 'terminate' 'de ...
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'number' 'dengue' 'case' 'continue' 'increase' 'philippine' 'region' 'department' 'health' 'officer' 'charge' 'ma' 'rosario' 'say' 'friday' 'statement' 'saturday' 'doh' 'say' 'region' 'recently' 'exceed' 'threshold' 'past' 'week' 'valley' 'central' 'western' 'central' 'peninsula' 'administrative' 'region' 'national' 'capital' 'region' 'accord' 'country' 'log' 'dengue' 'case' 'base' ' ...
# 60                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'department' 'environment' 'natural' 'resource' 'monday ...
# 70   'los' 'angeles' 'usa' 'return' 'table' 'international' 'ballroom' 'beverly' 'hilton' 'lisa' 'marie' 'priscilla' 'arrive' 'red' 'carpet' 'medium' 'line' 'golden' 'globe' 'award' 'january' 'ballroom' 'pack' 'woman' 'stop' 'traffic' 'pause' 'stair' 'lead' 'pit' 'level' 'near' 'stage' 'lady' 'sit' 'table' 'elvis' 'star' 'austin' 'butler' 'director' 'austin' 'win' 'best' 'actor' 'motion' 'picture' 'drama' 'play' 'rock' 'roll' 'legend' 'die' 'thanked' 'lisa' 'marie' 'hand' 'face' 'austin' 'eerily' 'speak' 'voice' 'accent' 'king' 'say' 'want' 'thank' 'incredible' 'producer' 'warner' 'brother' 'family' 'thank' 'guy' 'thank' 'open' 'heart' 'memory' 'home' 'lisa' 'marie' 'priscilla' 'love' 'forever' 'play' 'suspicious' 'mind' 'lastly' 'elvis' 'icon' 'rebel' 'love' 'thank' 'remember' 'forget' 'backstage' 'press' 'austin' 'ask' 'advice' 'get' 'prepare' 'role' 'answer' 'advice' 'feeling' 'bless' 'meant' 'imagine' 'shock' 'read' 'online' 'daughter' 'elvis' 'priscilla' 'die' 'cardiac' 'arrest' 'day' 'attend' 'globe' 'lisa' 'marie' 'career' 'news' 'story' 'report' 'lisa' 'marie' 'appear' 'frail' 'interview' 'extra' 'host' 'billy' 'bush' 'carpet' 'point' 'tell' 'jerry' 'schilling' 'friend' 'manager' 'go' 'grab' 'arm' 'riley' 'lisa' 'mary' 'daughter' 'exhusband' 'danny' 'eldest' 'grandchild' 'elvis' 'priscilla' 'golden' 'globe' 'best' 'actress' 'limited' 'series' 'series' 'television' 'motion' 'picture' 'nominee' 'girlfriend' 'experience' 'riley' 'feature' 'direct' 'debut' 'gina' 'war' 'pony' 'win' 'cannes' 'film' 'festival' 'golden' 'camera' 'prize' 'new' 'york' 'time' 'write' 'day' 'pass' 'away' 'lisa' 'marie' 'go' 'elvis' 'famed' 'mansion' 'inherit' 'commemorate' 'dad' 'birthday' 'representative' 'say' 'lisa' 'marie' 'bury' 'alongside' 'son' 'benjamin' 'die' 'ground' 'elvis' 'family' 'member' 'bury' 'lisa' 'mary' 'pass' 'sad' 'note' 'golden' 'globe' 'mark' 'return' 'year' 'inperson' 'ceremony' 'award' 'present' 'hollywood' 'foreign' 'press' 'association' 'honor' 'excellence' 'film' 'television' 'follow' 'ramble' 'note' 'highlight' 'red' 'carpet' 'inside' 'ballroom' 'despite' 'prediction' 'rain' 'pelt' 'california' 'day' 'sky' 'clear' 'january' 'film' 'director' 'cue' 'red' 'carpet' 'actually' 'gray' 'keep' 'motif' 'show' 'producer' 'pick' 'open' 'dolly' 'de' 'leon' 'entrance' 'carpet' 'filipino' 'best' 'support' 'actress' 'nominee' 'triangle' 'sadness' 'year' 'history' 'limo' 'end' 'carpet' 'line' 'stay' 'hilton' 'entered' 'gray' 'carpet' 'lobby' 'interview' 'janet' 'gma' 'yong' 'chavez' 'pose' 'photo' 'filipino' 'guest' 'designer' 'david' 'geoffrey' 'jimenez' 'baker' 'benjamin' 'cabrera' 'actress' 'way' 'carpet' 'line' 'despite' 'carpet' 'medium' 'line' 'frenzy' 'dolly' 'fellow' 'nominee' 'star' 'talent' 'get' 'pose' 'hunter' 'abrams' 'stun' 'portrait' 'take' 'room' 'plush' 'drape' 'wall' 'dolly' 'good' 'company' 'portrait' 'take' 'eddie' 'wife' 'hannah' 'viola' 'davis' 'jamie' 'lee' 'curtis' 'michelle' 'matt' 'michelle' 'williams' 'jenna' 'ortega' 'rodriguez' 'filmmaker' 'tim' 'burton' 'ryan' 'james' 'cameron' 'walk' 'carpet' 'bring' 'reporter' 'occupational' 'hazard' 'step' 'long' 'train' 'talent' 'year' 'star' 'voluminous' 'skirt' 'extra' 'careful' 'l' 'step' 'train' 'include' 'billy' 'porter' 'lily' 'jam' 'jenna' 'ortega' 'james' 'cameron' 'steven' 'spielberg' 'chat' 'pose' 'photos' 'talent' 'walk' 'long' 'carpet' 'line' 'previous' 'year' 'rush' 'red' 'carpet' 'minute' 'begin' 'time' 'get' 'sit' 'table' 'dinner' 'plate' 'clear' 'away' 'ballroom' 'ready' 'nbc' 'stream' 'year' 'year' 'lucky' 'dessert' 'plate' 'usually' 'left' 'table' 'hurriedly' 'begin' 'year' 'finally' 'luxury' 'sit' 'enjoy' 'menu' 'prepare' 'matthew' 'morgan' 'bev' 'executive' 'chef' 'get' 'savor' 'course' 'salad' 'follow' 'icelandic' 'salmon' 'vegan' 'alternative' 'squash' 'dome' 'dessert' 'table' 'magnum' 'bottle' 'grand' 'vintage' 'plus' 'bottle' 'red' 'white' 'wine' 'star' 'usually' 'arrive' 'time' 'oftentimes' 'chocolate' 'champagne' 'know' 'aware' 'guest' 'st ...
# ...
# 115                                                                                                                                                                                                                                                                                                                                                                                                                        'kyiv' 'ukraine' 'ukrainian' 'president' 'volodymyr' 'urge' 'eu' 'leader' 'talk' 'kyiv' 'thursday' 'february' 'slap' 'sanction' 'russia' 'moscow' 'force' 'press' 'offensive' 'eastern' 'ukraine' 'fire' 'missile' 'city' 'near' 'line' 'missile' 'destroy' 'apartment' 'building' 'late' 'wednesday' 'kill' 'people' 'wound' 'police' 'say' 'russia' 'say' 'thursday' 'strike' 'usmade' 'rocket' 'launcher' 'area' 'head' 'european' 'commission' 'pledge' 'eu' 'aid' 'ukraine' 'arrive' 'kyiv' 'train' 'dozen' 'senior' 'eu' 'official' 'day' 'talk' 'see' 'key' 'ukraine' 'hope' 'day' 'join' 'bloc' 'russia' 'pay' 'heavy' 'price' 'war' 'sanction' 'erode' 'economy' 'throw' 'generation' 'turn' 'pressure' 'ursula' 'von' 'der' 'leyen' 'later' 'tell' 'joint' 'news' 'conference' 'west' 'impose' 'sweeping' 'sanction' 'russia' 'invasion' 'ukraine' 'february' 'year' 'aim' 'cripple' 'ability' 'wage' 'war' 'devastate' 'ukrainian' 'city' 'town' 'kill' 'ten' 'thousand' 'people' 'force' 'million' 'flee' 'home' 'call' 'sanction' 'say' 'pace' 'slightly' 'slow' 'late' 'moscow' 'adapt' 'joint' 'european' 'task' 'reduce' 'russias' 'ability' 'evade' 'sanction' 'faster' 'well' 'task' 'accomplish' 'closer' 'defeat' 'aggression' 'russian' 'federation' 'say' 'von' 'der' 'leyen' 'say' 'eu' 'new' 'package' 'sanction' 'place' 'anniversary' 'war' 'big' 'arm' 'conflict' 'europe' 'world' 'war' 'avoid' 'commitment' 'fasttrack' 'ukraine' 'eu' 'membership' 'bid' 'expect' 'year' 'team' 'brussels' 'discuss' 'send' 'arm' 'money' 'ukraine' 'increase' 'access' 'ukrainian' 'product' 'eu' 'help' 'kyiv' 'cover' 'energy' 'need' 'strengthen' 'sanction' 'russia' 'prosecute' 'russian' 'leader' 'war' 'earlier' 'give' 'bleak' 'assessment' 'battlefield' 'situation' 'eastern' 'ukraine' 'russian' 'force' 'make' 'incremental' 'gain' 'anniversary' 'moscow' 'invasion' 'loom' 'russian' 'tactical' 'missile' 'strike' 'pm' 'gmt' 'wednesday' 'police' 'say' 'apartment' 'building' 'damage' 'completely' 'destroy' 'say' 'facebook' 'post' 'people' 'remain' 'rubble' 'daily' 'update' 'russia' 'defense' 'ministry' 'say' 'thursday' 'destroy' 'usmade' 'himars' 'launch' 'pad' 'attack' 'region' 'reference' 'strike' 'residential' 'building' 'km' 'mile' 'northwest' 'currently' 'main' 'focus' 'fight' 'eastern' 'ukraine' 'russia' 'determine' 'progress' 'ukraine' 'receives' 'newly' 'promise' 'western' 'battle' 'tank' 'armour' 'vehicle' 'pick' 'momentum' 'battlefield' 'announce' 'advance' 'north' 'south' 'suffer' 'persistent' 'russian' 'bombardment' 'month' 'enemy' 'try' 'achieve' 'russia' 'chance' 'anniversary' 'invasion' 'say' 'video' 'address' 'late' 'wednesday' 'town' 'village' 'come' 'russian' 'fire' 'ukrainian' 'military' 'say' 'russian' 'force' 'push' 'north' 'south' 'encircle' 'superior' 'troop' 'number' 'try' 'cut' 'resupply' 'force' 'ukrainian' 'ukrainian' 'military' 'analyst' 'say' 'enemy' 'able' 'use' 'sole' 'resource' 'excess' 'men' 'tell' 'tv' 'describe' 'landscape' 'northeast' 'literally' 'cover' 'corps' 'ukraine' 'western' 'ally' 'moscow' 'take' 'huge' 'loss' 'send' 'wave' 'poorly' 'equip' 'troop' 'include' 'thousand' 'convict' 'recruit' 'prison' 'mercenary' 'commander' 'russia' 'wagner' 'mercenary' 'group' 'flee' 'norway' 'january' 'tell' 'want' 'apologise' 'fight' 'ukraine' 'speak' 'bring' 'perpetrator' 'atrocity' 'justice' 'repeatedly' 'like' 'apologise' 'say' 'yearold' 'andrei' 'medvedev' 'ukraine' 'secure' 'pledge' 'weapon' 'west' 'offer' 'new' 'capability' 'late' 'expect' 'week' 'include' 'rocket' 'united' 'state' 'nearly' 'double' 'range' 'ukrainian' 'force' 'focused' 'provide' 'ukraine' 'capabilit ...
# 134                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'senator' 'thursday' 'claim' 'company' 'ask' 'p5' 'million' 'million' 'fast' 'track' 'renewal' 'certificate' 'product' 'registration' 'food' 'drug' 'administration' 'fda' 'raise' 'allegation' 'senate' 'plenary' 'deliberation' 'department' 'health' 'budget' 'cite' 'complaint' 'pharmaceutical' 'firm' 'wait' 'year' 'renewal' 'say' 'ask' 'price' 'fast' 'track' 'process' 'range' 'p5' 'million' 'million' 'product' 'fda' 'director' 'general' 'samuel' 'appoint' 'post' 'august' 'say' 'claim' 'dismay' 'yan' 'po' 'po' 'yan' 'actually' 'po' 'tolerate' 'agency' 'say' 'mention' 'conversation' 'director' 'general' 'agency' 'supposedly' 'admit' 'fda' 'admit' 'na' 'agency' 'admit' 'p5' 'million' 'million' 'say' 'go' 'stop' 'practice' 'na' 'say' 'wag' 'kang' 'wag' 'na' 'accept' 'fact' 'na' 'sa' 'fda' 'yan' 'add' 'response' 'admit' 'hear' 'story' 'allege' 'corruption' 'agency' 'proof' 'pursue' 'investigation' 'po' 'problem' 'lead' 'say' 'ko' 'po' 'want' 'coordinate' 'people' 'knowledge ...
# 137                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
#
#      Predikció valószínűsége
# 8                     0.0037
# 15                    0.0244
# 23                    0.0115
# 32                    0.2891
# 34                    0.3776
# 51                    0.0050
# 57                    0.0052
# 59                    0.4710
# 60                    0.3515
# 70                    0.0381
# 77                    0.2744
# 79                    0.0012
# 82                    0.0033
# 84                    0.9454
# 91                    0.1794
# 109                   0.0271
# 111                   0.0134
# 115                   0.0963
# 134                   0.2187
# 137                   0.0656

# %% [markdown]
# # Tanulás-validáció-teszt összehasonlítása két modellnél

# %%
test_loss_lstm, test_accuracy_lstm = lstm_trainable.evaluate(padded_test, y_test, verbose=0)
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test, verbose=0)

# Ábra létrehozása két alábrával
plt.figure(figsize=(12, 5))

# Tanulási, validációs és teszthalmaz veszteség ábrázolása
plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='LSTM tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='LSTM validációs veszteség', color='#7fcdbb')
plt.plot(history_gru_trainable.history['loss'], label='GRU tanulási veszteség', color='red')
plt.plot(history_gru_trainable.history['val_loss'], label='GRU validációs veszteség', color='orange')
plt.axhline(y=test_loss_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz veszteség')  # LSTM teszt loss
plt.axhline(y=test_loss_gru, color='red', linestyle='--', label='GRU teszthalmaz veszteség')  # GRU teszt loss
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Ttanulási, validációs és teszthalmaz precízió ábrázolása
if 'accuracy' in lstm_history_trainable.history and 'accuracy' in history_gru_trainable.history:
    plt.subplot(1, 2, 2)
    plt.plot(lstm_history_trainable.history['accuracy'], label='LSTM tanulási pontosság', color='blue')
    plt.plot(lstm_history_trainable.history['val_accuracy'], label='LSTM validációs pontosság', color='#7fcdbb')
    plt.plot(history_gru_trainable.history['accuracy'], label='GRU tanulási pontosság', color='red')
    plt.plot(history_gru_trainable.history['val_accuracy'], label='GRU validációs pontosság', color='orange')
    plt.axhline(y=test_accuracy_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz pontosság')  # LSTM teszt accuracy
    plt.axhline(y=test_accuracy_gru, color='red', linestyle='--', label='GRU teszthalmaz pontosság')  # GRU teszt accuracy
    plt.xlabel('Epizód')
    plt.ylabel('Pontosság')
    plt.legend()
    plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.tight_layout()
plt.show()
