# %% [markdown]
# # **Csomagok behívása**

# %%
#Szükséges csomagok és adatbázis importálása
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Concatenate
import numpy as np
import tensorflow as tf
import spacy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fájlok behívása, ellenőrzése és felkészítése

# %%
# Betölteni padded sequences, tokenizer, és számokat
padded_train = np.load('/content/padded_train05.npy')
padded_test = np.load('/content/padded_independent05.npy')

# Tokenizer visszatöltése
with open('/content/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Címkék betöltése (real = 1, fake = 0)
train_file = '/content/train_otodik.csv'
test_file = '/content/indep_otodik.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

labels_train = df_train['label'].values
labels_test = df_test['label'].values

# Betölteni embedding mátrixot
embedding_matrix = np.load('/content/embedding_matrix.npy')

# Ellenőrzés
print(f"Train padded sequences shape: {padded_train.shape}")
print(f"Test padded sequences shape: {padded_test.shape}")
print(f"Train labels shape: {labels_train.shape}")
print(f"Test labels shape: {labels_test.shape}")
# Out:
# Train padded sequences shape: (59520, 600)
# Test padded sequences shape: (14304, 600)
# Train labels shape: (59520,)
# Test labels shape: (14304,)

# %%
# Max szókincs és szekvencia hossz
MAX_VOCAB_SIZE = 25000
MAX_LENGTH = 600
EMBEDDING_DIM = 300  # GloVe 300d

# input shape
MAX_SEQUENCE_LENGTH = padded_train.shape[1]

# Szöveges input (LSTM/GRU bemenet)
text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
embedding_layer = Embedding(
    input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
    output_dim=embedding_matrix.shape[1],
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)(text_input)

model_output = embedding_layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
MAX_SEQUENCE_LENGTH = padded_train.shape[1]  # Train hossz
EMBEDDING_DIM = embedding_matrix.shape[1]  # GloVe embeddings

# 10%-os validációs halmaz leválasztása a tanító adatokból
padded_train_final, padded_val, y_train_final, y_val = train_test_split(
    padded_train, labels_train, test_size=0.1, random_state=42
)
# Float32-re konvertálás TensorFlow kompatibilitás miatt
padded_train_final = np.array(padded_train_final, dtype=np.float32)
padded_val = np.array(padded_val, dtype=np.float32)
padded_test = np.array(padded_test, dtype=np.float32)
y_train_final = np.array(y_train_final, dtype=np.float32)
y_val = np.array(y_val, dtype=np.float32)
y_test = np.array(labels_test, dtype=np.float32)

# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# # LSTM MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ## Modell lefuttatása

# %%
# LSTM modell, trainable, non-trainable embedding

def create_lstm_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings
    )(text_input)

    # LSTM rétegek
    lstm_out = LSTM(128, return_sequences=True, dropout=0.3)(text_embedding)
    lstm_out = Dropout(0.3)(lstm_out)  # Dropout réteg az első LSTM után
    lstm_out = LSTM(64,return_sequences=True, dropout=0.3)(lstm_out)
    lstm_out = Dropout(0.3)(lstm_out) # Dropout réteg az második LSTM után
    lstm_out = LSTM(32, dropout=0.3)(lstm_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(lstm_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása
lstm_trainable = create_lstm_model(trainable_embeddings=True)  # Trainable embedding

lstm_trainable.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_1 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 600, 128)            │         219,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 600, 64)             │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,781,505 (29.68 MB)
#  Trainable params: 7,781,505 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Modell tanítása a validációs adatok figyelésével
lstm_history_trainable = lstm_trainable.fit(
    padded_train_final, y_train_final,
    validation_data=(padded_val, y_val),  # Validációs halmaz
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság: {test_accuracy:.4f}, Teszthalmaz veszteség: {test_loss:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 78s 85ms/step - accuracy: 0.8249 - loss: 0.4005 - val_accuracy: 0.8978 - val_loss: 0.2764
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 70s 83ms/step - accuracy: 0.9038 - loss: 0.2361 - val_accuracy: 0.9404 - val_loss: 0.1555
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 72s 87ms/step - accuracy: 0.9525 - loss: 0.1285 - val_accuracy: 0.9541 - val_loss: 0.1299
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9655 - loss: 0.1009 - val_accuracy: 0.9558 - val_loss: 0.1166
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9785 - loss: 0.0654 - val_accuracy: 0.9523 - val_loss: 0.1309
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9829 - loss: 0.0505 - val_accuracy: 0.9645 - val_loss: 0.1105
# Epoch 7/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.9877 - loss: 0.0363 - val_accuracy: 0.9614 - val_loss: 0.1270
# Epoch 8/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 70s 84ms/step - accuracy: 0.9895 - loss: 0.0342 - val_accuracy: 0.9647 - val_loss: 0.1151
# Epoch 9/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 85s 87ms/step - accuracy: 0.9920 - loss: 0.0259 - val_accuracy: 0.9654 - val_loss: 0.1127
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.8604 - loss: 0.4366
# Teszthalmaz pontosság: 0.8582, Teszthalmaz veszteség: 0.4559

# %%
# Valószínűség becslése
lstm_y_prob = lstm_trainable.predict(padded_test)

lstm_y_pred = (lstm_y_prob > 0.5).astype(int)

lstm_accuracy = accuracy_score(y_test, lstm_y_pred)
lstm_precision = precision_score(y_test, lstm_y_pred)
lstm_recall = recall_score(y_test, lstm_y_pred)
lstm_f1 = f1_score(y_test, lstm_y_pred)

print(f"Accuracy: {lstm_accuracy:.4f}")
print(f"Precision: {lstm_precision:.4f}")
print(f"Recall: {lstm_recall:.4f}")
print(f"F1-score: {lstm_f1:.4f}")
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step
# Accuracy: 0.8588
# Precision: 0.9219
# Recall: 0.7840
# F1-score: 0.8474

# %% [markdown]
# ## LSTM Modell ábrák

# %%
import matplotlib.pyplot as plt

# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(lstm_history_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(lstm_history_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.8625 - loss: 0.4368

# %%
# Confusion Matrix
cm_lstm = confusion_matrix(y_test, lstm_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_lstm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix LSTM Modellre')
plt.show()

print(classification_report(y_test, lstm_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.93      0.87      7152
#          1.0       0.92      0.78      0.85      7152
#
#     accuracy                           0.86     14304
#    macro avg       0.87      0.86      0.86     14304
# weighted avg       0.87      0.86      0.86     14304

# %%
# Flatten
y_true = y_test.flatten()
y_pred = lstm_y_pred.flatten()
y_prob = lstm_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás besorolás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás besorolás) LSTM Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": lstm_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = lstm_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_lstm.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 4    Hamis negatív (FN)           1.0                 0
# 8    Hamis negatív (FN)           1.0                 0
# 9    Hamis pozitív (FP)           0.0                 1
# 10   Hamis negatív (FN)           1.0                 0
# 15   Hamis negatív (FN)           1.0                 0
# 27   Hamis pozitív (FP)           0.0                 1
# 51   Hamis negatív (FN)           1.0                 0
# 78   Hamis pozitív (FP)           0.0                 1
# 82   Hamis negatív (FN)           1.0                 0
# 95   Hamis pozitív (FP)           0.0                 1
# 111  Hamis negatív (FN)           1.0                 0
# 117  Hamis negatív (FN)           1.0                 0
# 128  Hamis negatív (FN)           1.0                 0
# 134  Hamis negatív (FN)           1.0                 0
# 137  Hamis negatív (FN)           1.0                 0
# 161  Hamis negatív (FN)           1.0                 0
# 162  Hamis negatív (FN)           1.0                 0
# 169  Hamis pozitív (FP)           0.0                 1
# 175  Hamis pozitív (FP)           0.0                 1
# 180  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    'the' 'department' 'of' 'transportation' 'have' 'ask' 'for' 'understand' 'after' 'metro' 'manila' 'land' 'near' 'the' 'bottom' 'of' 'a' 'global' 'urban' 'mobility' 'rank' 'say' 'that' 'it' 'be' 'work' 'on' 'several' 'project' 'to' 'improve' 'mobility' 'and' 'public' 'transportation' 'in' 'the' 'national' 'capital' 'region' 'the' 'two' 'thousand' 'and' 'twentytwo' 'urban' 'mobility' 'readiness' 'index' 'compile' 'by' 'the' 'oliver' 'forum' 'and' 'the' 'university' 'of' 'california' 'at' 'berkeley' 'rank' 'sixty' 'global' 'city' 'on' 'metro' 'manila' 'land' 'in' 'place' 'with' 'only' 'nairobi' 'and' 'fare' 'worse' 'in' 'the' 'study' 'in' 'the' 'public' 'transport' 'use' 'some' 'of' 'the' 'metric' 'above' 'include' 'transit' 'commute' 'speed' 'public' 'transit' 'affordability' 'rail' 'network' 'public' 'transit' 'station' 'density' 'transit' 'estimate' 'time' 'of' 'arrival' 'and' 'share' 'of' 'time' 'in' 'public' 'philippine' 'be' 'in' 'place' 'the' 'study' 'note' 'that' 'in' 'the' 'national' 'capital' 'region' 'sustainable' 'mobility' 'be' 'less' 'of' 'a' 'priority' 'and' 'vehicle' 'be' 'likely' 'to' 'remain' 'the' 'most' 'common' 'transit' 'option' 'ask' 'for' 'understand' 'report' 'on' 'twentyfour' 'on' 'monday' 'note' 'that' 'commuter' 'pedestrian' 'motorist' 'and' 'transport' 'worker' 'face' 'long' 'line' 'crowd' 'heavy' 'road' 'congestion' 'transport' 'malfunction' 'and' 'other' 'problem' 'every' 'day' 'the' 'result' 'for' 'many' 'filipino' 'be' 'a' 'large' 'chunk' 'of' 'their' 'day' 'and' 'their' 'energy' 'devote' 'to' 'travel' 'to' 'and' 'from' 'work' 'and' 'school' 'the' 'say' 'that' 'it' 'accept' 'the' 'report' 'finding' 'we' 'be' 'address' 'current' 'commuter' 'travail' 'with' 'permanent' 'solution' 'transportation' 'secretary' 'jaime' 'say' 'in' 'a' 'statement' 'i' 'personally' 'ask' 'for' 'the' 'public' 'under ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'more' 'than' 'a' 'week' 'before' 'several' 'family' 'have' 'start' 'go' 'to' 'the' 'manila' 'north' 'cemetery' 'to' 'clean' 'the' 'resting' 'place' 'of' 'their' 'love' 'one' 'accord' 'to'  ...
# 9                                                                                                                                                                                                                                                                                                                                                                                                                          'load' 'post' 'on' 'november' 'three' 'two' 'thousand' 'and' 'sixteen' 'go' 'away' 'you' 'should' 'not' 'be' 'here' 'do' 'not' 'come' 'back' 'the' 'corner' 'of' 'that' 'have' 'almost' 'no' 'white' 'resident' 'sue' 'reid' 'daily' 'mail' 'november' 'three' 'two' 'thousand' 'and' 'sixteen' 'from' 'the' 'window' 'of' 'her' 'flat' 'overlook' 'the' 'canal' 'path' 'in' 'a' 'suburb' 'of' 'in' 'a' 'blonde' 'woman' 'watch' 'two' 'female' 'figure' 'walk' 'past' 'a' 'they' 'chatter' 'in' 'a' 'foreign' 'tongue' 'both' 'the' 'passersby' 'be' 'cover' 'in' 'black' 'islamic' 'gown' 'only' 'a' 'glimpse' 'of' 'their' 'eye' 'show' 'from' 'in' 'the' 'two' 'gap' 'in' 'the' 'veil' 'across' 'their' 'face' 'they' 'like' 'many' 'muslim' 'woman' 'who' 'live' 'here' 'speak' 'little' 'or' 'no' 'english' 'lot' 'of' 'them' 'will' 'have' 'no' 'contact' 'with' 'any' 'person' 'from' 'another' 'religion' 'or' 'culture' 'almost' 'all' 'have' 'be' 'bring' 'to' 'the' 'uk' 'to' 'wed' 'the' 'british' 'men' 'of' 'south' 'asian' 'heritage' 'who' 'have' 'make' 'this' 'area' 'their' 'home' 'the' 'wife' 'have' 'restrict' 'life' 'bring' 'up' 'child' 'cook' 'for' 'family' 'or' 'go' 'to' 'event' 'at' 'the' 'huge' 'local' 'mosque' 'run' 'by' 'the' 'a' 'powerful' 'sect' 'of' 'islam' 'whose' 'most' 'outspoken' 'preacher' 'have' 'urge' 'follower' 'not' 'to' 'mix' 'with' 'christian' 'jew' 'or' 'hindu' 'we' 'be' 'in' 'town' 'one' 'of' 'the' 'most' 'racially' 'homogeneous' 'part' 'of' 'britain' 'not' 'because' 'everyone' 'be' 'an' 'indigenous' 'man' 'or' 'woman' 'but' 'exactly' 'the' 'opposite' 'in' 'fact' 'there' 'be' 'almost' 'no' 'white' 'resident' 'to' 'be' 'find' 'in' 'town' 'astonishingly' 'a' 'detailed' 'breakdown' 'of' 'the' 'last' 'census' 'of' 'two' 'thousand' 'and' 'eleven' 'record' 'that' 'only' 'fortyeight' 'of' 'the' 'people' 'live' 'here' 'be' 'white' 'british' 'this' 'would' 'not' 'surprise' 'the' 'blonde' 'lorraine' 'matthew' 'look' 'out' 'at' 'the' 'lady' 'in' 'burka' 'from' 'her' 'window' 'she' 'be' 'a' 'fiftythreeyearold' 'dentist' 'receptionist' 'one' 'of' 'the' 'handful' 'of' 'white' 'briton' 'leave' 'in' 'town' 'grid' 'of' 'terrace' 'street' 'almost' 'all' 'the' 'other' 'resident' 'accord' 'to' 'that' 'census' 'have' 'pakistani' 'or' 'indian' 'background' 'their' 'be' 'entice' 'to' 'town' 'a' 'cheap' 'labour' 'for' 'job' 'in' 'the' 'mill' 'which' 'have' 'make' 'a' 'renowned' 'textile' 'town' 'these' 'hardworking' 'newcomer' 'buy' 'their' 'own' 'home' 'and' 'open' 'corner' 'shop' 'that' 'sell' 'prayer' 'mat' 'and' 'perfume' 'that' 'contain' 'no' 'alcohol' 'in' 'line' 'with' 'the' 'of' 'the' 'koran' 'soon' 'the' 'new' 'arrival' 'have' 'build' 'the' 'mosque' 'which' 'be' 'design' 'to' 'accommodate' 'fourzero' 'worshipper' 'today' 'a' 'sharia' 'court' 'in' 'a' 'house' 'of' 'lord' 'report' 'for' 'discriminate' 'against' 'woman' 'in' 'divorce' 'and' 'brisk' 'business' 'espouse' 'the' 'strict' 'islamic' 'justice' 'code' 'even' 'the' 'lady' 'selling' 'ice' 'cream' 'from' 'a' 'van' 'during' 'the' 'summer' 'wear' 'a' 'burka' 'and' 'the' 'mobile' 'butcher' 'go' 'round' 'the' 'street' 'offer' 'only' 'halal' 'goat' 'lamb' 'and' 'stand' 'in' 'town' 'a' 'i' 'have' 'and' 'you' 'will' 'see' 'score' 'of' 'boy' 'in' 'islamic' 'robe' 'walk' 'to' 'and' 'from' 'lesson' 'at' 'the' 'mosque' 'school' 'where' 'for' 'hour' 'at' 'a' 'time' 'they' 'the' 'koran' 'by' 'heart' 'and' 'every' 'girl' 'i' 'those' 'of' 'six' 'and' 'seven' 'playing' 'in' 'the' 'wrap' 'up' 'in' 'a' 'hijab' 'and' 'l' 'a' 'man' 'glimpse' 'her' 'flesh' 'eight' 'of' 'the' 'nine' 'pub' 'in' 'the' 'area' 'have' 'shu ...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'geneva' 'the' 'world' 'health' 'organization' 'say' 'wednesday' 'it' 'be' 'too' 'early' 'to' 'lift' 'the' 'alert' 'for' 'the' 'crisis' 'with' 'the' 'pandemic' 'remain' 'a' 'global' 'health' 'emergency' 'despite' 'recent' 'progress' 'the' 'who' 'be' 'emergency' 'committee' 'on' 'meet' 'last' 'week' 'and' 'conclude' 'that' 'the' 'pandemic' 'still' 'constitute' 'a' 'public' 'health' 'emergency' 'of' 'international' 'concern' 'a' 'status' 'it' 'declare' 'back' 'in' 'january' 'two' 'thousand' 'and' 'twenty' 'who' 'chief' 'tedros' 'tell' 'reporter' 'wednesday' 'that' 'he' 'agree' 'with' 'the' 'committee' 'advice' 'the' 'committee' 'emphasize' 'the' 'need' 'to' 'strengthen' 'surveillance' 'and' 'expand' 'access' 'to' 'test' 'treatment' 'and' 'vaccine' 'for' 'those' 'most' 'at' 'risk' 'he' 'say' 'speak' 'from' 'the' 'un' 'health' 'agency' 'headquarters' 'in' 'geneva' 'the' 'who' 'first' 'declare' 'the' 'outbreak' 'a' 'on' 'january' 'thirty' 'two' 'thousand' 'and' 'twenty' 'when' 'outside' 'of' 'china' 'few' 'than' 'one' 'hundred' 'case' 'and' 'no' 'death' 'have' 'be' 'report' 'though' 'it' 'be' 'the' 'mechanism' 'for' 'trigger' 'an' 'international' 'response' 'to' 'such' 'outbreak' 'it' 'be' 'only' 'in' 'march' 'when' 'tedros' 'describe' 'the' 'worsen' 'situation' 'a' 'a' 'pandemic' 'that' 'many' 'country' 'wake' 'up' 'to' 'the' 'danger' 'since' 'the' 'start' 'of' 'the' 'pandemic' 'more' 'than' 'six' 'hundred' 'and' 'twentytwo' 'million' 'confirm' 'case' 'have' 'be' 'report' 'to' 'who' 'and' 'more' 'than' 'sixfive' 'million' 'death' 'although' 'those' 'number' 'be' 'believe' 'to' 'be' 'significant' 'underestimate' 'accord' 'to' 'who' 'be' 'global' 'dashboard' 'of' 'the' 'situation' 'two' 'hundred' 'and' 'new' 'case' 'be' 'report' 'in' 'the' 'previous' 'twentyfour' 'hour' 'while' 'eight' 'hundred' 'and' 'fiftysix' 'new' 'death' 'have' 'be' 'report' 'in' 'the' 'past' 'week' 'tedros' 'acknowledge' 'wednesday' 'that' 'the' 'global' 'situation' 'have' 'obviously' 'improve' 'since' 'the' 'pandemic' 'begin' 'but' 'he' 'warn' 'that' 'the' 'virus' 'continue' 'to' 'change' 'and' 'there' 'remain' 'many' 'risk' 'and' 'uncertainty' 'the' 'pandemic' 'have' 'surprise' 'u' 'before' 'and' 'very' 'well' 'could' 'again' 'he' 'warn' 'surveillance' 'have' 'decline' 'maria' 'van' 'the' 'who' 'be' 'technical' 'lead' 'agree' 'warn' 'that' 'there' 'be' 'still' 'million' 'of' 'case' 'be' 'report' 'each' 'week' 'but' 'our' 'surveillance' 'have' 'decline' 'this' 'be' 'make' 'it' 'difficult' 'to' 'get' 'a' 'full' 'overview' 'of' 'the' 'situation' 'and' 'especially' 'of' 'how' 'the' 'virus' 'be' 'she' 'stress' 'that' 'the' 'more' 'this' 'virus' 'circulate' 'the' 'more' 'opportunity' 'it' 'have' 'to' 'change' 'the' 'variant' 'account' 'for' 'basically' 'all' 'virus' 'sample' 'that' 'be' 'sequence' 'with' 'more' 'than' 'three' 'hundred' 'of' 'that' 'variant' 'record' 'all' 'of' 'the' 'of' 'be' 'show' 'incre ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    'interior' 'and' 'local' 'government' 'secretary' 'on' 'wednesday' 'order' 'an' 'investigation' 'into' 'the' 'death' 'of' 'a' 'student' 'who' 'be' 'find' 'in' 'a' 'shallow' 'grave' 'in' 'to' 'at' 'ano' 'circumstance' 'any' 'form' 'of' 'violence' 'na' 'he' 'tell' 'reporter' 'in' 'an' 'ambush' 'interview' 'we' 'will' 'investigate' 'it' 'immediately' 'and' 'look' 'into' 'the' 'circumstance' 'here' 'any' 'form' 'of' 'violence' 'that' 'lead' 'to' 'death' 'should' 'be' 'investigate' 'immediately' 'on' 'tuesday' 'the' 'body' 'of' 'john' 'matthew' 'a' 'student' 'at' 'university' 'in' 'manila' 'be' 'find' 'more' 'than' 'a' 'week' 'afte ...
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'unidentified' 'muslim' 'on' 'the' 'run' 'after' 'stab' 'four' 'people' 'at' 'a' 'frankfurt' 'train' 'station' 'the' 'attack' 'this' 'afternoon' 'occur' 'at' 'station' 'and' 'police' 'have' 'say' 'there' 'be' 'four' 'victim' 'at' 'this' 'stage' 'the' 'motive' 'for' 'the' 'stabbings' 'be' 'not' 'clear' 'it' 'will' 'become' 'crystal' 'clear' 'once' 'you' 'identify' 'the' 'attacker' 'a' 'a' 'muslim' 'uk' 'daily' 'mail' 'ht' 'the' 'local' 'police' 'force' 'confirm' 'the' 'attack' 'by' 'tweet' 'there' 'be' 'a' 'knife' 'assault' 'at' 'the' 'in' 'frankfurt' 'that' 'be' 'why' 'so' 'many' 'colleague' 'police' 'officer' 'and' 'rescue' 'worker' 'there' 'frankfurt' 'police' 'confirm' 'all' 'four' 'victim' 'be' 'still' 'in' 'hospital' 'a' 'video' 'of' 'the' 'bloody' 'aftermath' 'be' 'capture' 'on' 'what' 'be' 'understood' 'to' 'be' 'level' 'b' 'of' 'the' 'station' 'the' 'incident' 'be' 'at' 'local' 'time' 'accord' 'to' 'who' 'report' 'the' 'stabbings' 'come' 'after' 'a' 'group' 'be' 'quarrel' 'a' 'dispute' 'have' 'start' 'on' 'one' 'platform' 'and' 'spill' 'over' 'onto' 'another' 'one' 'there' 'be' 'more' 'bloodshed' 'in' 'a' 'separate' 'incident' 'at' 'the' 'station' 'understood' 'to' 'be' 'on' 'a' 'passenger' 'train' 'between' 'and' 'a' 'dispute' 'between' 'two' 'passenger' 'break' 'out' 'into' 'a' 'fight' 'accord' 'to' 'which' 'lead' 'to' 'glass' 'be' 'break' 'and' 'people' 'suffer' 'cut' 'frankfurt' 'police' 'look' 'to' 'reassure' 'the' 'public' 'by' 'tweet' 'if' 'we' 'recognize' 'a' 'threat' 'to' 'the' 'local' 'population' 'we' 'would' 'communicate' 'this' 'no' 'you' 'would' 'not' 'the' 'stabbings' 'will' 'still' 'raise' 'fear' 'the' 'attack' 'be' 'islamic' 'after' 'a' 'string' 'of' 'incident' 'across' 'europe' 'over' 'recent' 'month' 'germany' 'have' 'be' 'rock' 'by' 'islamic' 'terror' 'attack' 'this' 'year' 'heap' 'pressure' 'on' 'chancellor' 'angela' 'merkels' 'opendoor' 'muslim' 'immigration' 'policy' 'a' 'bloody' 'week' 'of' 'violence' 'that' 'rock' 'germany' 'begin' 'on' 'july' 'eighteen' 'when' 'pakistani' 'muslim' 'teenager' 'khan' 'seventeen' 'pose' 'a' 'an' 'afghan' 'refugee' 'hack' 'at' 'passenger' 'on' 'a' 'train' 'in' 'with' 'an' 'axe' 'wound' 'five' 'four' 'day' 'later' 'a' 'muslim' 'teenager' 'ali' 'shot' 'nine' 'people' 'dead' 'during' 'a ...
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    'the' 'bureau' 'of' 'immigration' 'bi' 'arrest' 'and' 'set' 'to' 'deport' 'a' 'chinese' 'national' 'who' 'be' 'be' 'search' 'by' 'authority' 'for' 'allegedly' 'misrepresent' 'himself' 'a' 'a' 'filipino' 'suspect' 'tai' 'sixty' 'be' 'nab' 'in' 'manila' 'on' 'tuesday' 'may' 'sixteen' 'after' 'a' 'warrant' 'of' 'deportation' 'be' 'issue' 'against' 'him' 'in' 'july' 'last' 'year' 'for' 'be' 'an' 'undesirable' 'alien' 'tai' 'allegedly' 'assume' 'the' 'name' 'of' 'one' 'albert' 'torres' 'and' 'have' 'be' 'use' 'the' 'fictitious' 'identity' 'in' 'file' 'incorporation' 'paper' 'acquire' 'a' 'driver' 'license' 'register ...
# 78                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'share' 'on' 'twitter' 'la' 'vega' 'nevada' 'politician' 'often' 'try' 'to' 'relate' 'to' 'the' 'common' 'man' 'and' 'fail' 'miserably' 'however' 'in' 'a' 'moment' 'of' 'blunt' 'candor' 'and' 'honesty' 'libertarian' 'candidate' 'for' 'president' 'gary' 'johnson' 'speak' 'for' 'all' 'of' 'u' 'when' 'he' 'openly' 'mourn' 'the' 'loss' 'of' 'majestic' 'harambe' 'why' 'do' 'they' 'have' 'to' 'kill' 'the' 'gorilla' 'johnson' 'lament' 'in' 'an' 'exclusive' 'interview' 'with' 'independent' 'journal' 'review' 'the' 'former' 'new' 'mexico' 'governor' 'and' 'nature' 'enthusiast' 'be' 'visibly' 'move' 'when' 'ask' 'about' 'his' 'feeling' 'on' 'harambe' 'a' 'celebrated' 'western' 'gorilla' 'live' 'peacefully' 'in' 'the' 'cincinnati' 'zoo' 'before' 'he' 'be' 'cut' 'down' 'in' 'the' 'prime' 'of' 'his' 'life' 'after' 'a' 'child' 'fell' 'into' 'his' 'enclosure' 'this' 'past' 'may' 'i' 'be' 'sure' 'it' 'be' 'a' 'difficult' 'decision' 'for' 'everyone' 'involve' 'johnson' 'say' 'before' 'ultimately' 'bemoan' 'the' 'cruel' 'fate' 'of' 'the' 'endanger' 'peaceful' 'animal' 'legacy' 'have' 'become' 'a' 'cultural' 'and' 'even' 'political' 'phenomenon' 'green' 'party' 'candidate' 'jill' 'stein' 'have' 'tweet' 'her' 'defense' 'of' 'sweet' 'harambe' 'and' 'there' 'be' 'now' 'an' 'official' 'harambe' 'super' 'pac' 'register' 'with' 'the' 'fec' 'call' 'justice' 'for' 'harambe' 'the' 'super' 'pac' 'creator' 'ryan' 'hall' 'spoke' 'with' 'ijr' 'last' 'month' 'describe' 'what' 'his' 'pac' 'will' 'be' 'commit' 'to' 'do' 'we' 'will' 'endorse' 'any' 'candidate' 'who' 'be' 'willing' 'to' 'honor' 'legacy' 'harambe' 'represent' 'all' ' ...
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'a' 'family' 'in' 'be' 'shock' 'to' 'see' 'that' 'their' 'electricity' 'bill' 'have' 'reach' 'million' 'in' 'a' 'report' 'by' 'gma' 'regional' 'tv' 'one' 'north' 'central' 'antonio' 'say' 'that' 'from' 'their' 'average' 'monthly' 'bill' 'of' 'around' 'hundred' 'they' 'now' 'to' 'pay' 'hundred' 'and' 'hundred' 'and' 'seventythree' 'reaction' 'ko' 'din' 'ng' 'tao' 'lang' 'po' 'mo' 'she' 'say' 'din' 'po' 'number' 'po' 'm ...
# 95                                                                              'country' 'south' 'korea' 'we' 'be' 'continue' 'to' 'inform' 'our' 'reader' 'on' 'the' 'scandal' 'around' 'choi' 'confidante' 'of' 'president' 'park' 'geunhye' 'a' 'the' 'crisis' 'cause' 'by' 'her' 'interference' 'in' 'the' 'affair' 'of' 'the' 'state' 'and' 'link' 'to' 'corruption' 'continue' 'to' 'roll' 'on' 'to' 'recap' 'choi' 'have' 'no' 'official' 'right' 'to' 'do' 'so' 'but' 'have' 'access' 'to' 'and' 'read' 'official' 'material' 'correct' 'the' 'president' 'though' 'there' 'be' 'still' 'no' 'evidence' 'of' 'an' 'ideological' 'rather' 'than' 'nature' 'of' 'the' 'correction' 'and' 'be' 'suspect' 'to' 'have' 'raise' 'fund' 'from' 'major' 'company' 'include' 'lotte' 'and' 'group' 'for' 'mir' 'and' 'foundation' 'related' 'to' 'her' 'on' 'november' 'four' 'two' 'thousand' 'and' 'sixteen' 'the' 'south' 'korean' 'president' 'appear' 'on' 'live' 'tv' 'and' 'apologize' 'admit' 'that' 'on' 'choi' 'have' 'blind' 'my' 'objectivity' 'and' 'allow' 'my' 'guard' 'to' 'drop' 'she' 'speak' 'with' 'great' 'emotion' 'which' 'be' 'unusual' 'for' 'her' 'take' 'full' 'responsibility' 'for' 'the' 'scandal' 'and' 'say' 'that' 'she' 'be' 'very' 'sorry' 'that' 'she' 'have' 'disappoint' 'the' 'people' 'who' 'have' 'entrust' 'her' 'with' 'the' 'right' 'to' 'rule' 'the' 'state' 'park' 'say' 'that' 'she' 'have' 'be' 'work' 'on' 'improve' 'the' 'economy' 'and' 'living' 'standard' 'but' 'some' 'individual' 'have' 'be' 'act' 'illegally' 'in' 'their' 'own' 'interest' 'about' 'which' 'she' 'be' 'deeply' 'concerned' 'her' 'emotional' 'reaction' 'be' 'reasonable' 'look' 'into' 'her' 'biography' 'after' 'her' 'parent' 'death' 'and' 'against' 'the' 'background' 'of' 'very' 'difficult' 'relationship' 'with' 'her' 'family' 'choi' 'the' 'daughter' 'of' 'her' 'spiritual' 'advisor' 'be' 'her' 'close' 'friend' 'and' 'a' 'for' 'a' 'very' 'long' 'time' 'the' 'president' 'emphasize' 'that' 'she' 'be' 'ready' 'to' 'accept' 'all' 'the' 'demand' 'of' 'the' 'population' 'and' 'the' 'national' 'assembly' 'in' 'the' 'course' 'of' 'perform' 'her' 'duty' 'this' 'include' 'if' 'necessary' 'render' 'assistance' 'to' 'the' 'prosecutor' 'office' 'investigation' 'and' 'take' 'part' 'in' 'the' 'special' 'investigation' 'although' 'formally' 'she' 'could' 'legitimately' 'refuse' 'to' 'do' 'so' 'however' 'park' 'geunhye' 'note' 'that' 'the' 'countrys' 'security' 'and' 'economics' 'be' 'currently' 'under' 'great' 'threat' 'therefore' 'it' 'be' 'for' 'the' 'implementation' 'of' 'state' 'policy' 'to' 'be' 'halt' 'however' 'the' 'president' 'apology' 'have' 'not' 'go' 'down' 'well' 'with' 'everyone' 'the' 'incumbent' 'party' 'receive' 'the' 'president' 'speech' 'quite' 'positively' 'state' 'that' 'the' 'president' 'have' 'agree' 'with' 'all' 'the' 'public' 'demand' 'and' 'have' 'express' 'a' 'firm' 'commitment' 'to' 'clarify' 'all' 'the' 'detail' 'of' 'the' 'scandal' 'and' 'prevent' 'similar' 'situation' 'in' 'the' 'future' 'the' 'head' 'of' 'the' 'opposition' 'democratic' 'party' 'on' 'the' 'contrary' 'say' 'that' 'the' 'apology' 'of' 'park' 'geunhye' 'do' 'not' 'provide' 'any' 'answer' 'which' 'the' 'outraged' 'people' 'be' 'wait' 'for' 'and' 'call' 'the' 'president' 'speech' 'mere' 'disingenuous' 'apology' 'the' 'chairman' 'of' 'the' 'interim' 'committee' 'of' 'the' 'people' 'party' 'pak' 'point' 'out' 'the' 'of' 'park' 'statement' 'that' 'the' 'choi' 'matter' 'have' 'it' 'root' 'in' 'action' 'aim' 'at' 'improve' 'the' 'economy' 'and' 'living' 'standard' 'of' 'the' 'population' 'but' 'praise' 'the' 'willingness' 'of' 'park' 'geunhye' 'to' 'cooperate' 'with' 'the' 'prosecutor' 'office' 'in' 'the' 'investigation' 'a' 'a' 'result' 'the' 'opposition' 'only' 'increase' 'it' 'pressure' 'and' 'actually' 'present' 'an' 'ultimatum' 'to' 'the' 'president' 'either' 'the' 'parliament' 'initiate' 'impeachment' 'or' 'park' 'step' 'down' 'from' 'domestic' 'politics' 'and' 'remove' 'the' 'prime' 'minister' 'newly' 'appoint' ...
# ...
# 169                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 175  'fox' 'news' 'the' 'fbi' 'have' 'reopen' 'it' 'investigation' 'into' 'hillary' 'clinton' 'use' 'of' 'a' 'private' 'server' 'while' 'secretary' 'of' 'state' 'after' 'discover' 'new' 'email' 'in' 'a' 'stunning' 'turn' 'of' 'event' 'just' 'day' 'before' 'the' 'presidential' 'election' 'fbi' 'director' 'james' 'comey' 'write' 'in' 'a' 'letter' 'to' 'top' 'member' 'of' 'congress' 'friday' 'that' 'the' 'bureau' 'have' 'learn' 'of' 'the' 'existence' 'of' 'email' 'that' 'appear' 'to' 'be' 'pertinent' 'to' 'the' 'investigation' 'click' 'here' 'to' 'read' 'the' 'letter' 'comey' 'do' 'not' 'detail' 'those' 'email' 'say' 'only' 'that' 'they' 'surface' 'in' 'connection' 'with' 'an' 'unrelated' 'case' 'he' 'tell' 'lawmaker' 'the' 'investigative' 'team' 'brief' 'him' 'on' 'the' 'information' 'a' 'day' 'earlier' 'and' 'i' 'agree' 'that' 'the' 'fbi' 'should' 'take' 'appropriate' 'investigative' 'step' 'design' 'to' 'allow' 'investigator' 'to' 'review' 'these' 'email' 'to' 'determine' 'whether' 'they' 'contain' 'classified' 'information' 'as' 'well' 'a' 'to' 'assess' 'their' 'importance' 'to' 'our' 'investigation' 'he' 'say' 'the' 'fbi' 'could' 'not' 'yet' 'assess' 'whether' 'the' 'new' 'material' 'be' 'significant' 'and' 'he' 'could' 'not' 'predict' 'how' 'long' 'it' 'will' 'take' 'to' 'complete' 'this' 'additional' 'work' 'a' 'senior' 'law' 'enforcement' 'official' 'separately' 'tell' 'fox' 'news' 'the' 'fbi' 'decision' 'be' 'not' 'link' 'to' 'wikileaks' 'message' 'or' 'any' 'hack' 'and' 'the' 'newly' 'discover' 'email' 'do' 'not' 'come' 'from' 'the' 'clinton' 'server' 'but' 'from' 'another' 'device' 'from' 'another' 'government' 'official' 'the' 'move' 'come' 'after' 'comey' 'and' 'the' 'justice' 'department' 'decide' 'in' 'july' 'not' 'to' 'pursue' 'charge' 'over' 'clinton' 'email' 'practice' 'say' 'at' 'the' 'time' 'that' 'the' 'investigation' 'be' 'finish' 'comey' 'have' 'since' 'come' 'under' 'criticism' 'from' 'donald' 'trump' 'lawmaker' 'and' 'others' 'who' 'claim' 'the' 'investigation' 'downplay' 'the' 'mishandling' 'of' 'classified' 'information' 'during' 'clinton' 'tenure' 'trump' 'speaking' 'to' 'cheer' 'supporter' 'friday' 'afternoon' 'in' 'manchester' 'nh' 'praise' 'the' 'fbi' 'for' 'have' 'the' 'courage' 'to' 'right' 'the' 'horrible' 'mistake' 'that' 'they' 'make' 'say' 'he' 'hop' 'that' 'be' 'correct' 'hillary' 'clinton' 'corruption' 'be' 'on' 'a' 'scale' 'we' 'have' 'never' 'see' 'before' 'trump' 'say' 'we' 'must' 'not' 'let' 'her' 'take' 'her' 'criminal' 'scheme' 'into' 'the' 'oval' 'office' 'in' 'a' 'nod' 'to' 'the' 'significance' 'of' 'the' 'fbis' 'announcement' 'trump' 'quip' 'the' 'rest' 'of' 'my' 'speech' 'be' 'go' 'to' 'be' 'so' 'boring' 'other' 'gop' 'lawmaker' 'also' 'weigh' 'in' 'urge' 'the' 'bureau' 'to' 'pursue' 'a' 'thorough' 'new' 'probe' 'the' 'fbis' 'decision' 'to' 'reopen' 'it' 'investigation' 'into' 'secretary' 'clinton' 'reinforce' 'what' 'the' 'house' 'judiciary' 'committee' 'have' 'be' 'say' 'for' 'month' 'the' 'more' 'we' 'learn' 'about' 'secretary' 'clinton' 'use' 'of' 'a' 'private' 'email' 'server' 'the' 'clearer' 'it' 'become' 'that' 'she' 'and' 'her' 'associate' 'commit' 'wrongdoing' 'and' 'national' 'security' 'house' 'judiciary' 'committee' 'chairman' 'bob' 'goodlatte' 'say' 'in' 'a' 'statement' 'republican' 'national' 'committee' 'chairman' 'reince' 'priebus' 'say' 'the' 'discovery' 'must' 'be' 'serious' 'for' 'the' 'bureau' 'to' 'investigate' 'this' 'close' 'to' 'the' 'election' 'clinton' 'do' 'not' 'respond' 'to' 'question' 'from' 'reporter' 'about' 'the' 'development' 'a' 'she' 'land' 'in' 'cedar' 'rapid' 'iowa' 'and' 'do' 'not' 'address' 'the' 'matter' 'while' 'speak' 'to' 'supporter' 'in' 'the' 'same' 'city' 'the' 'development' 'come' 'eleven' 'day' 'before' 'the' 'general' 'election' 'and' 'be' 'the' 'late' 'to' 'hit' 'the' 'race' 'clinton' 'have' 'be' 'gain' 'in' 'the' 'poll' 'over' 'trump' 'in' 'the' 'wake' 'of' 'the' 'release' 'of' 'footage' 'show' 'trump' 'talk' 'about' 'grope' 'woma ...
# 180                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'the' 'department' 'of' 'environment' 'and' 'natural' 'resource' 'have' 'form' 'a' 'task' 'force' 'to' 'secure' 'the' 'marine' 'protect' 'area' 'that' 'may' 'be' 'affect' 'by' 'the' 'possible' 'oil' 'spill' 'from' 'the' 'motor' 'tanker' 'carry' 'eight' 'hundredzero' 'liter' 'of' 'industrial' 'fuel' 'oil' 'that' 'sink' 'off' 'oriental' 'on' 'tuesday' 'in' 'a' 'statement' 'the' 'say' 'task' 'force' 'oil' 'spill' 'be' 'create' 'after' 'it' 'conduct' 'an' 'emergency' 'meeting' 'with' 'the' 'philippine' 'coast' 'guard' 'oriental' 'governor' 'and' 'mayor' 'henry' 'joel' 'undersecretary' 'and' 'chief' 'of' 'staff' 'who' 'serve' 'a' 'the' 'corporate' 'ground' 'response' 'coordinator' 'during' 'the' 'oil' 'spill' 'in' 'two' 'thousand' 'and' 'six' 'be' 'appoint' 'a' 'task' 'force' 'commander' 'philippine' 'coast' 'guard' 'spokesperson' 'rear' 'admiral' 'say' 'wednesday' 'that' 'it' 'be' 'monitor' 'for' 'possible' 'oil' 'spill' 'from' 'mt' 'princess' 'empress' 'which' 'have' 'now' 'totally' 'sink' 'accord' 'to' 'the' 'an' 'oil' 'spill' 'six' 'kilometer' 'long' 'and' 'four' 'kilometer' 'wide' 'be' 'spot' 'in' 'the' 'area' 'where' 'the' 'tanker' 'sink' 'a' 'report' 'state' 'that' 'on' 'a' 'maximum' 'of' 'radius' 'from' 'east' 'of' 'port' 'twentyone' 'marine' 'protect' 'area' 'can' 'be' 'potentially' 'affected' 'due' 'to' 'oil' 'it' 'have' 'map' 'potential' 'risk' 'area' 'include' 'bed' 'and' 'pathway' 'for' 'fish' 'the' 'say' 'in' 'a' 'statement' 'this' 'be' 'determine' 'after' 'conduct' 'a' 'water' 'sample' 'in' 'the' 'municipality' 'of' 'and' 'the' 'agency' 'say' 'marine' 'environmental' 'protection' 'command' 'would' 'be' 'the' 'lead' 'agency' 'task' 'with' 'the' 'response' 'operation' 'in' 'the' 'affected' 'area' 'say' 'they' 'have' 'deploy' ' ...
#
#      Predikció valószínűsége
# 4                     0.0758
# 8                     0.0702
# 9                     0.6874
# 10                    0.3157
# 15                    0.2832
# 27                    0.9713
# 51                    0.4617
# 78                    0.9534
# 82                    0.1813
# 95                    0.9877
# 111                   0.0849
# 117                   0.3179
# 128                   0.0010
# 134                   0.0126
# 137                   0.1536
# 161                   0.4390
# 162                   0.0028
# 169                   0.9112
# 175                   0.7954
# 180                   0.0091

# %% [markdown]
# # GRU MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ### Modell lefuttatása

# %%
# GRU modell

def create_gru_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),  # Ensure within vocab limit
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings  # Toggle trainability
    )(text_input)

    # GRU rétegek
    gru_out = GRU(128, return_sequences=True, dropout=0.3)(text_embedding)
    gru_out = Dropout(0.3)(gru_out)  # Dropout réteg az első GRU után
    gru_out = GRU(64,return_sequences=True, dropout=0.3)(gru_out)
    gru_out = Dropout(0.3)(gru_out)
    gru_out = GRU(32, dropout=0.3)(gru_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(gru_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása (Trainable)
gru_trainable = create_gru_model(trainable_embeddings=True)  # Trainable

gru_trainable.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_2 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 600, 128)            │         165,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 600, 64)             │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,711,809 (29.42 MB)
#  Trainable params: 7,711,809 (29.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# GRU modell tanítása a validációs adatok figyelésével
history_gru_trainable = gru_trainable.fit(
    padded_train_final, y_train_final,  # Ugyanaz a tanító adathalmaz, mint az LSTM-nél
    validation_data=(padded_val, y_val),  # Ugyanaz a validációs halmaz, mint az LSTM-nél
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság (GRU): {test_accuracy_gru:.4f}, Teszthalmaz veszteség (GRU): {test_loss_gru:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 72s 83ms/step - accuracy: 0.8437 - loss: 0.3468 - val_accuracy: 0.9331 - val_loss: 0.1649
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 81s 82ms/step - accuracy: 0.9595 - loss: 0.1108 - val_accuracy: 0.9719 - val_loss: 0.0863
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 68s 81ms/step - accuracy: 0.9854 - loss: 0.0463 - val_accuracy: 0.9704 - val_loss: 0.0834
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 78ms/step - accuracy: 0.9932 - loss: 0.0228 - val_accuracy: 0.9736 - val_loss: 0.0869
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 79ms/step - accuracy: 0.9943 - loss: 0.0173 - val_accuracy: 0.9750 - val_loss: 0.0975
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 81ms/step - accuracy: 0.9687 - loss: 0.0848 - val_accuracy: 0.9657 - val_loss: 0.1006
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8628 - loss: 0.4407
# Teszthalmaz pontosság (GRU): 0.8623, Teszthalmaz veszteség (GRU): 0.4474

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Valószínűség becslése
gru_y_prob = gru_trainable.predict(padded_test)

gru_y_pred = (gru_y_prob > 0.5).astype(int)

accuracy = accuracy_score(y_test, gru_y_pred)
precision = precision_score(y_test, gru_y_pred)
recall = recall_score(y_test, gru_y_pred)
f1 = f1_score(y_test, gru_y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step
# Accuracy: 0.8638
# Precision: 0.9425
# Recall: 0.7749
# F1-score: 0.8505

# %% [markdown]
# ## GRU modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = gru_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_gru_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(history_gru_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(history_gru_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(history_gru_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.8642 - loss: 0.4437

# %%
# Confusion Matrix
cm_gru = confusion_matrix(y_test, gru_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_gru, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix GRU Modellre')
plt.show()

print(classification_report(y_test, gru_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.95      0.87      7152
#          1.0       0.94      0.77      0.85      7152
#
#     accuracy                           0.86     14304
#    macro avg       0.88      0.86      0.86     14304
# weighted avg       0.88      0.86      0.86     14304

# %%
# Flatten
y_true = y_test.flatten()
y_pred = gru_y_pred.flatten()
y_prob = gru_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás) GRU Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": gru_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = gru_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_gru.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 8    Hamis negatív (FN)           1.0                 0
# 15   Hamis negatív (FN)           1.0                 0
# 23   Hamis negatív (FN)           1.0                 0
# 24   Hamis negatív (FN)           1.0                 0
# 46   Hamis negatív (FN)           1.0                 0
# 57   Hamis negatív (FN)           1.0                 0
# 77   Hamis negatív (FN)           1.0                 0
# 79   Hamis negatív (FN)           1.0                 0
# 82   Hamis negatív (FN)           1.0                 0
# 95   Hamis pozitív (FP)           0.0                 1
# 109  Hamis negatív (FN)           1.0                 0
# 111  Hamis negatív (FN)           1.0                 0
# 120  Hamis pozitív (FP)           0.0                 1
# 128  Hamis negatív (FN)           1.0                 0
# 134  Hamis negatív (FN)           1.0                 0
# 157  Hamis negatív (FN)           1.0                 0
# 162  Hamis negatív (FN)           1.0                 0
# 180  Hamis negatív (FN)           1.0                 0
# 192  Hamis negatív (FN)           1.0                 0
# 194  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'more' 'than' 'a' 'week' 'before' 'several' 'family' 'have' 'start' 'go' 'to' 'the' 'manila' 'north' 'cemetery' 'to' 'clean' 'the' 'resting' 'place' 'of' 'their' 'love' 'one' 'accord' 'to' 'a' 'report' 'on' 'twentyfour' 'staff' 'expect' 'more' 'people' 'to' 'the'  ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'interior' 'and' 'local' 'government' 'secretary' 'on' 'wednesday' 'order' 'an' 'investigation' 'into' 'the' 'death' 'of' 'a' 'student' 'who' 'be' 'find' 'in' 'a' 'shallow' 'grave' 'in' 'to' 'at' 'ano' 'circumstance' 'any' 'form' 'of' 'violence' 'na' 'he' 'tell' 'reporter' 'in' 'an' 'ambush' 'interview' 'we' 'will' 'investigate' 'it' 'immediately' 'and' 'look' 'into' 'the' 'circumstance' 'here' 'any' 'form' 'of' 'violence' 'that' 'lead' 'to' 'death' 'should' 'be' 'investigate' 'immediately' 'on' 'tuesday' 'the' 'body' 'of' 'john' 'matthew' 'a' 'student' 'at' 'university' 'in' 'manila' 'be' 'find' 'more' 'than' 'a' 'week' 'after' 'he' 'be' 'last' 'see' 'alive' 'police' 'say' 'suspect' 'whom' 'they' 'i ...
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'six' 'official' 'of' 'the' 'philippine' 'national' 'police' 'pnp' 'drug' 'enforcement' 'group' 'special' 'operation' 'unit' 'be' 'relieve' 'from' 'their' 'post' 'in' 'the' 'official' 'be' 'face' 'allegation' 'of' 'kidnapping' 'and' 'torture' 'accord' 'to' 'jun' 'twentyfour' 'report' 'on' 'wednesday' 'yun' 'relieve' 'ni' 'director' 'yun' 'in' 'fairness' 'to' 'them' 'allegation' 'yun' 'police' 'colonel' 'martinez' 'deputy' 'director' 'for' 'administration' 'say' 'base' 'on' 'the' 'report' 'the' 'complainant' 'say' 'that' 'they' 'be' 'force' 'to' 'ride' 'the' 'operative' 'vehicle' 'and' 'be' 'take' 'to' 'the' 'headquarters' 'of' 'the' 'where' 'they' 'be' 'allegedly' 'tortured' 'pnp' 'chief' 'police' 'general' 'benjamin' 'jr' 'maintain' 'that' 'misconduct' 'will' 'not' 'be' 'tolerate' 'under' 'his' 'leadership' 'he' 'also' 'urge' 'the' 'public' 'that' 'there' 'b ...
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'president' 'ferdinand' 'marcos' 'jr' 'have' 'reconstitute' 'the' 'sugar' 'regulatory' 'administration' 'govern' 'body' 'with' 'three' 'new' 'appointee' 'the' 'appointment' 'be' 'make' 'on' 'the' 'heel' 'of' 'the' 'controversial' 'order' 'authorize' 'the' 'importation' 'of' 'three' 'hundredzero' 'metric' 'ton' 'of' 'sugar' 'which' 'be' 'later' 'on' 'declare' 'illegal' 'and' 'thumb' 'down' 'by' 'the' 'chief' 'executive' 'marcos' 'appoint' 'david' 'john' 'p' 'a' 'act' 'administrator' 'of' 'the' 'accord' 'to' 'a' 'report' 'on' 'staterun' 'replace' 'former' 'administrator' 'who' 'resign' 'from' 'his' 'post' 'amid' 'the' 'controversy' 'involve' 'sugar' 'order' 'no' 'four' 'so' 'four' 'the' 'say' 'order' 'be' 'deem' 'illegal' 'a' 'the' 'sugar' 'regulatory' 'board' 'convene' 'and' 'issue' 'a' 'resolution' 'without' 'the' 'approval' 'of' 'marcos' 'who' 'a' 'the' 'concurrent' 'secretary' 'of' 'the' 'department' 'of' 'agriculture' 'be' 'chairman' 'of' 'the' 'sugar' 'board' 'meanwhile' 'other' 'sugar' 'regulatory' 'board' 'member' 'be' 'pablo' 'luis' 's' 'replace' 'sugar' 'planter' 'representative' 'gerardo' 'jr' 'and' 'ma' 'v' 'replace' 'sugar' 'miller' 'representative' 'atty' 'roland' 'who' 'resign' 'for' 'health' 'reason' 'the' 'be' 'a' 'governmentowned' 'and' 'controlled' 'corporation' 'attach' 'to' 'the' 'da' 'establish' 'in' 'one' 'thousand' 'nine' 'hundred' 'and' 'eightysix' 'by' 'virtue' 'of' ...
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'u' 'secret' 'service' 'officer' 'fatally' 'shoot' 'an' 'intruder' 'at' 'the' 'peruvian' 'ambassador' 'residence' 'in' 'dc' 'after' 'a' 'confrontation' 'on' 'wednesday' 'morning' 'follow' 'a' 'report' 'burglary' 'attempt' 'authority' 'say' 'the' 'ambassador' 'de' 'and' 'his' 'family' 'be' 'at' 'home' 'at' 'the' 'time' 'but' 'neither' 'they' 'nor' 'their' 'staff' 'be' 'injure' 'say' 'the' 'peruvian' 'embassy' 'press' 'counselor' 'uniformed' 'secret' 'service' 'officer' 'respond' 'to' 'a' 'report' 'of' 'a' 'burglary' 'in' 'progress' 'shortly' 'before' 'eight' 'be' 'edt' 'one' 'thousand' 'two' 'hundred' 'gmt' 'police' 'chief' 'robert' 'say' 'they' 'find' 'a' 'man' 'in' 'his' '20' 'or' '30' 'carry' 'a' 'metal' 'stake' 'at' 'the' 'rear' 'of' 'the' 'house' 'where' 'several' 'window' 'have' 'be' 'smash' 'officer' 'initially' 'try' 'to' 'stop' 'the' 'man' 'with' 'tasers' 'but' 'when' 'he' 'approach' 'the' 'officer' 'with' 'the' 'metal' 'stake' 'they' 'begin' 'fire' 'shot' 'say' 'two' 'officer' 'fire' 'their' 'weapon' 'he' 'say' 'the' 'peruvian' 'embassy' 'confirm' 'there' 'be' 'damage' 'do' 'to' 'the' 'property' 'but' 'offer' 'no' 'detail' 'beyond' 'the' 'police' 'account' 'the' 'man' 'be' 'not' 'identify' 'and' 'it' 'be' 'u ...
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'a' 'family' 'of' 'five' 'after' 'a' 'fire' 'hit' 'their' 'residence' 'in' 'on' 'monday' 'accord' 'to' 'claire' 'report' 'on' 'gma'  ...
# 77                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   'personal' 'belonging' 'of' 'the' 'miss' 'twentytwoyearold' 'be' 'find' 'among' 'skeletal' 'remains' 'before' 'dawn' 'in' 'in' 'puerto' 'on' 'tuesday' 'accord' 'to' 'report' 'on' 'super'  ...
# 79                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'two' 'minor' 'be' 'prostitute' 'be' 'rescue' 'by' 'operative' 'in' 'a' 'sting' 'operation' 'which' 'lead' 'to' 'the' 'arrest' 'of' 'one' 'of' 'their' 'pimp' 'during' 'the' 'operation' 'the' 'pimp' 'bring' 'along' 'with' 'her' 'two' 'minor' 'female' 'age' 'thirteen' 'and' 'a' 'vehicle' 'where' 'two' 'undercover' 'operative' 'be' 'seat' 'the' 'transaction' 'take' 'place' 'inside' 'the' 'vehicle' 'where' 'the' 'operative' 'bargain' 'for' 'a' 'cheap' 'price' 'a' 'they' 'earlier' 'agree' 'to' 'pay' 'for' 'three' 'female' 'but' 'only' 'two' 'arrive' 'the' 'pimp' 'be' 'arrest' 'a' 'she' 'exit' 'the' 'vehicle' 'accord' 'to' 'city' 'police' 'district' 'station' 'fourteen' 'investigation' 'chief' 'anthony' 'the' 'suspect' 'be' 'part' 'of' 'a' 'group' 'that' 'prostitute' 'child' 'transaction' 'be' 'online' 'group' 'group' 'chat' 'sa' 'ng' 'prostitution' 'sa' 'minor' 'he' 'say' 'in' 'a' 'report' 'on' 'twentyfour' 'weekend' 'on' 'sunday' 'their' 'transaction' 'be' 'do' 'online' 'they' 'have' 'a' 'group' 'a' 'group' 'chat' 'for' 'the' 'transaction' 'where' 'they' 'prostitute' 'minor' 'one' 'of' 'the' 'father' 'of' 'the' 'minor' 'say' 'the' 'child' 'tell' 'him' 'she' 'be' 'go' 'to' 'attend' 'a' 'birthday' 'party' 'and' 'he' 'do' 'not' 'know' 'that' 'she' 'be' 'instead' 'be' 'prostitute' 'ko' 'po' 'na' 'po' 'po' 'nasa' 'din' 'po' 'eh' 'ko' 'lang' 'din' 'po' 'din' 'na' 'na' 'he' 'say' 'i' 'do' 'not' 'know' 'that' 'that' 'be' 'what' 'happen' 'i' 'be' 'always' 'in' 'work' 'and' 'i' 'just' 'knew' 'of' ' ...
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'a' 'family' 'in' 'be' 'shock' 'to' 'see' 'that' 'their' 'electricity' 'bill' 'have' 'reach' 'million' 'in' 'a' 'report' 'by' 'gma' 'regional' 'tv' 'one' 'north' 'central' 'antonio' 'say' 'that' 'from' 'their' 'average' 'monthly' 'bill' 'of' 'around' 'hundred' 'they' 'now' 'to' 'pay' 'hundred' 'and' 'hundred' 'and' 'seventythree' 'reaction' 'ko' 'din' 'ng' 'tao' 'lang' 'po' 'mo' 'she' 'say' 'din' 'po' 'number' 'po' 'million' 'po' 'she' 'add' 'antonio' 'immediately' 'go' 'to' 'the' 'central'  ...
# 95   'country' 'south' 'korea' 'we' 'be' 'continue' 'to' 'inform' 'our' 'reader' 'on' 'the' 'scandal' 'around' 'choi' 'confidante' 'of' 'president' 'park' 'geunhye' 'a' 'the' 'crisis' 'cause' 'by' 'her' 'interference' 'in' 'the' 'affair' 'of' 'the' 'state' 'and' 'link' 'to' 'corruption' 'continue' 'to' 'roll' 'on' 'to' 'recap' 'choi' 'have' 'no' 'official' 'right' 'to' 'do' 'so' 'but' 'have' 'access' 'to' 'and' 'read' 'official' 'material' 'correct' 'the' 'president' 'though' 'there' 'be' 'still' 'no' 'evidence' 'of' 'an' 'ideological' 'rather' 'than' 'nature' 'of' 'the' 'correction' 'and' 'be' 'suspect' 'to' 'have' 'raise' 'fund' 'from' 'major' 'company' 'include' 'lotte' 'and' 'group' 'for' 'mir' 'and' 'foundation' 'related' 'to' 'her' 'on' 'november' 'four' 'two' 'thousand' 'and' 'sixteen' 'the' 'south' 'korean' 'president' 'appear' 'on' 'live' 'tv' 'and' 'apologize' 'admit' 'that' 'on' 'choi' 'have' 'blind' 'my' 'objectivity' 'and' 'allow' 'my' 'guard' 'to' 'drop' 'she' 'speak' 'with' 'great' 'emotion' 'which' 'be' 'unusual' 'for' 'her' 'take' 'full' 'responsibility' 'for' 'the' 'scandal' 'and' 'say' 'that' 'she' 'be' 'very' 'sorry' 'that' 'she' 'have' 'disappoint' 'the' 'people' 'who' 'have' 'entrust' 'her' 'with' 'the' 'right' 'to' 'rule' 'the' 'state' 'park' 'say' 'that' 'she' 'have' 'be' 'work' 'on' 'improve' 'the' 'economy' 'and' 'living' 'standard' 'but' 'some' 'individual' 'have' 'be' 'act' 'illegally' 'in' 'their' 'own' 'interest' 'about' 'which' 'she' 'be' 'deeply' 'concerned' 'her' 'emotional' 'reaction' 'be' 'reasonable' 'look' 'into' 'her' 'biography' 'after' 'her' 'parent' 'death' 'and' 'against' 'the' 'background' 'of' 'very' 'difficult' 'relationship' 'with' 'her' 'family' 'choi' 'the' 'daughter' 'of' 'her' 'spiritual' 'advisor' 'be' 'her' 'close' 'friend' 'and' 'a' 'for' 'a' 'very' 'long' 'time' 'the' 'president' 'emphasize' 'that' 'she' 'be' 'ready' 'to' 'accept' 'all' 'the' 'demand' 'of' 'the' 'population' 'and' 'the' 'national' 'assembly' 'in' 'the' 'course' 'of' 'perform' 'her' 'duty' 'this' 'include' 'if' 'necessary' 'render' 'assistance' 'to' 'the' 'prosecutor' 'office' 'investigation' 'and' 'take' 'part' 'in' 'the' 'special' 'investigation' 'although' 'formally' 'she' 'could' 'legitimately' 'refuse' 'to' 'do' 'so' 'however' 'park' 'geunhye' 'note' 'that' 'the' 'countrys' 'security' 'and' 'economics' 'be' 'currently' 'under' 'great' 'threat' 'therefore' 'it' 'be' 'for' 'the' 'implementation' 'of' 'state' 'policy' 'to' 'be' 'halt' 'however' 'the' 'president' 'apology' 'have' 'not' 'go' 'down' 'well' 'with' 'everyone' 'the' 'incumbent' 'party' 'receive' 'the' 'president' 'speech' 'quite' 'positively' 'state' 'that' 'the' 'president' 'have' 'agree' 'with' 'all' 'the' 'public' 'demand' 'and' 'have' 'express' 'a' 'firm' 'commitment' 'to' 'clarify' 'all' 'the' 'detail' 'of' 'the' 'scandal' 'and' 'prevent' 'similar' 'situation' 'in' 'the' 'future' 'the' 'head' 'of' 'the' 'opposition' 'democratic' 'party' 'on' 'the' 'contrary' 'say' 'that' 'the' 'apology' 'of' 'park' 'geunhye' 'do' 'not' 'provide' 'any' 'answer' 'which' 'the' 'outraged' 'people' 'be' 'wait' 'for' 'and' 'call' 'the' 'president' 'speech' 'mere' 'disingenuous' 'apology' 'the' 'chairman' 'of' 'the' 'interim' 'committee' 'of' 'the' 'people' 'party' 'pak' 'point' 'out' 'the' 'of' 'park' 'statement' 'that' 'the' 'choi' 'matter' 'have' 'it' 'root' 'in' 'action' 'aim' 'at' 'improve' 'the' 'economy' 'and' 'living' 'standard' 'of' 'the' 'population' 'but' 'praise' 'the' 'willingness' 'of' 'park' 'geunhye' 'to' 'cooperate' 'with' 'the' 'prosecutor' 'office' 'in' 'the' 'investigation' 'a' 'a' 'result' 'the' 'opposition' 'only' 'increase' 'it' 'pressure' 'and' 'actually' 'present' 'an' 'ultimatum' 'to' 'the' 'president' 'either' 'the' 'parliament' 'initiate' 'impeachment' 'or' 'park' 'step' 'down' 'from' 'domestic' 'politics' 'and' 'remove' 'the' 'prime' 'minister' 'newly' 'appoint' 'by' 'her' 'he' 'be' 'a' 'representative' 'of' 'the' 'left' 'but' 'not' 't ...
# ...
# 180                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'the' 'department' 'of' 'environment' 'and' 'natural' 'resource' 'have' 'form' 'a' 'task' 'force' 'to' 'secure' 'the' 'marine' 'protect' 'area' 'that' 'may' 'be' 'affect' 'by' 'the' 'possible' 'oil' 'spill' 'from' 'the' 'motor' 'tanker' 'carry' 'eight' 'hundredzero' 'liter' 'of' 'industrial' 'fuel' 'oil' 'that' 'sink' 'off' 'oriental' 'on' 'tuesday' 'in' 'a' 'statement' 'the' 'say' 'task' 'force' 'oil' 'spill' 'be' 'create' 'after' 'it' 'conduct' 'an' 'emergency' 'meeting' 'with' 'the' 'philippine' 'coast' 'guard' 'oriental' 'governor' 'and' 'mayor' 'henry' 'joel' 'undersecretary' 'and' 'chief' 'of' 'staff' 'who' 'serve' 'a' 'the' 'corporate' 'ground' 'response' 'coordinator' 'during' 'the' 'oil' 'spill' 'in' 'two' 'thousand' 'and' 'six' 'be' 'appoint' 'a' 'task' 'force' 'commander' 'philippine' 'coast' 'guard' 'spokesperson' 'rear' 'admiral' 'say' 'wednesday' 'that' 'it' 'be' 'monitor' 'for' 'possible' 'oil' 'spill' 'from' 'mt' 'princess' 'empress' 'which' 'have' 'now' 'totally' 'sink' 'accord' 'to' 'the' 'an' 'oil' 'spill' 'six' 'kilometer' 'long' 'and' 'four' 'kilometer' 'wide' 'be' 'spot' 'in' 'the' 'area' 'where' 'the' 'tanker' 'sink' 'a' 'report' 'state' 'that' 'on' 'a' 'maximum' 'of' 'radius' 'from' 'east' 'of' 'port' 'twentyone' 'marine' 'protect' 'area' 'can' 'be' 'potentially' 'affected' 'due' 'to' 'oil' 'it' 'have' 'map' 'potential' 'risk' 'area' 'include' 'bed' 'and' 'pathway' 'for' 'fish' 'the' 'say' 'in' 'a' 'statement' 'this' 'be' 'determine' 'after' 'conduct' 'a' 'water' 'sample' 'in' 'the' 'municipality' 'of' 'and' 'the' 'agency' 'say' 'marine' 'environmental' 'protection' 'command' 'would' 'be' 'the' 'lead' 'agency' 'task' 'with' 'the' 'response' 'operation' 'in' 'the' 'affected' 'area' 'say' 'they' 'have' 'deploy' 'one' 'of' 'their' 'vessel' 'aquino' 'to' 'the' 'area' 'to' 'conduct' 'the'  ...
# 192                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'the' 'land' 'transportation' 'and' 'regulatory' 'board' 'announce' 'on' 'thursday' 'the' 'commencement' 'of' 'three' 'route' 'for' 'operator' 'of' 'public' 'utility' 'and' 'modern' 'help' 'commuter' 'affect' 'by' 'the' 'closure' 'of' 'certain' 'philippine' 'national' 'railway' 'station' 'the' 'closure' 'be' 'necessary' 'for' 'the' 'construction' 'of' 'the' 'commuter' 'railway' 'to' 'mitigate' 'the' 'impact' 'of' 'the' 'closure' 'on' 'commuter' 'we' 'have' 'establish' 'these' 'route' 'we' 'be' 'grateful' 'to' 'the' 'for' 'assist' 'in' 'identify' 'these' 'route' 'chairman' 'say' 'once' 'the' 'be' 'complete' 'it' 'advantage' 'in' 'term' 'of' 'passenger' 'mobility' 'along' 'our' 'railway' 'which' 'be' 'know' 'a' 'one' 'of' 'the' 'most' 'convenient' 'and' 'affordable' 'mean' 'of' 'public' 'transportation' 'in' 'the' 'country' 'will' 'be' 'truly' 'worth' 'it' 'he' 'add' 'earlier' 'this' 'month' 'the' 'announce' 'that' 'daily' 'trip' 'on' 'the' 'to' 'route' 'would' 'cease' 'start' 'july' 'two' 'due' 'to' 'construction' 'the' 'affected' 'station' 'include' 'san' 'pedro' 'main' 'gate' 'golden' 'city' 'rosa' 'and' 'accord' 'to' 'memorandum' 'circular' 'no' 'two' 'thousand' 'and' 'the' 'in' 'collaboration' 'with' 'the' 'have' 'identify' 'three' 'route' 'to' 'serve' 'the' 'affected' 'station' 'these' 'route' 'have' 'be' 'open' 'for' 'the' 'qualification' 'process' 'the' 'have' 'specify' 'three' 'route' 'via' 'east' 'service' 'road' 'and' 'and' 'via' 'the' 'south' 'expressway' 'for' 'public' 'utility' 'bus' 'and' 'which' 'will' 'be' 'service' 'by' 'modern' 'public' 'utility' 'the' 'agency' 'have' 'allocate' 'thirty' 'pub' 'unit' 'for' 'the' 'route' 'twentyfive' 'pub' 'for' 'and' 'five' 'for' 'the' 'number' 'of' 'unit' 'may' 'be' 'adjust' 'base' 'on' 'passenger' 'demand' 'a' 'determine' 'by' 'the' 'the' 'follow' 'memorandum' 'circular' 'no' 'two' 'thousand' 'and' 'title' 'consolidated' 'guideline' 'on' 'the' 'process' 'of' 'issuance' 'of' 'certificate' 'of' 'public' 'convenience' 'and' 'provisional' 'authority' 'permit' 'sp' 'under' 'the' 'omnibus' 'guideline' 'and' 'public' 'utility' 'vehicle' 'modernization' 'program' 'for' 'select' 'operator' 'a' 'per' 'the' 'memorandum' 'authorize' 'unit' 'should' 'not' 'exceed' 'five' 'year' 'base' 'on' 'the' 'vehicle' 'certificate' 'of' ' ...
# 194                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'a' 'graduate' 'of' 'southwestern' 'university' 'be' 'the' 'top' 'in' 'the' 'examination' 'give' 'last' 'month' 'accord' 'to' 'the' 'professional' 'regulation' 'commission' 'one' 'hundred' 'and' 'seventynine' 'out' 'of' 'two' 'hundred' 'and' 'eightyfive' 'test' 'taker' 'pass' 'the' 'examination' 'give' 'by' 'the' 'board' 'of' 'in' 'manila' 'last' 'month' 'roy' 'take' 'the' 'top' 'spot' 'with' 'a' 'score' 'of' 'while' 'his' 'alma' 'mater' 'southwestern' 'be' 'also' 'the' 'top' 'performing' ' ...
#
#      Predikció valószínűsége
# 8                     0.0268
# 15                    0.0570
# 23                    0.3467
# 24                    0.0131
# 46                    0.2582
# 57                    0.0643
# 77                    0.0641
# 79                    0.0777
# 82                    0.0203
# 95                    0.8296
# 109                   0.4280
# 111                   0.0053
# 120                   0.6454
# 128                   0.3525
# 134                   0.1880
# 157                   0.0595
# 162                   0.3793
# 180                   0.3365
# 192                   0.0050
# 194                   0.2975

# %% [markdown]
# # Tanulás-validáció-teszt összehasonlítása két modellnél

# %%
test_loss_lstm, test_accuracy_lstm = lstm_trainable.evaluate(padded_test, y_test, verbose=0)
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test, verbose=0)

# Ábra létrehozása két alábrával
plt.figure(figsize=(12, 5))

# Tanulási, validációs és teszthalmaz veszteség ábrázolása
plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='LSTM tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='LSTM validációs veszteség', color='#7fcdbb')
plt.plot(history_gru_trainable.history['loss'], label='GRU tanulási veszteség', color='red')
plt.plot(history_gru_trainable.history['val_loss'], label='GRU validációs veszteség', color='orange')
plt.axhline(y=test_loss_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz veszteség')  # LSTM teszt loss
plt.axhline(y=test_loss_gru, color='red', linestyle='--', label='GRU teszthalmaz veszteség')  # GRU teszt loss
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Ttanulási, validációs és teszthalmaz precízió ábrázolása
if 'accuracy' in lstm_history_trainable.history and 'accuracy' in history_gru_trainable.history:
    plt.subplot(1, 2, 2)
    plt.plot(lstm_history_trainable.history['accuracy'], label='LSTM tanulási pontosság', color='blue')
    plt.plot(lstm_history_trainable.history['val_accuracy'], label='LSTM validációs pontosság', color='#7fcdbb')
    plt.plot(history_gru_trainable.history['accuracy'], label='GRU tanulási pontosság', color='red')
    plt.plot(history_gru_trainable.history['val_accuracy'], label='GRU validációs pontosság', color='orange')
    plt.axhline(y=test_accuracy_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz pontosság')  # LSTM teszt accuracy
    plt.axhline(y=test_accuracy_gru, color='red', linestyle='--', label='GRU teszthalmaz pontosság')  # GRU teszt accuracy
    plt.xlabel('Epizód')
    plt.ylabel('Pontosság')
    plt.legend()
    plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.tight_layout()
plt.show()
