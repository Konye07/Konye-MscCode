# %% [markdown]
# # **Csomagok behívása**

# %%
#Szükséges csomagok és adatbázis importálása
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Concatenate
import numpy as np
import tensorflow as tf
import spacy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fájlok behívása, ellenőrzése és felkészítése

# %%
# Betölteni padded sequences, tokenizer, és számokat
padded_train = np.load('/content/padded_train04.npy')
padded_test = np.load('/content/padded_independent04.npy')

# Tokenizer visszatöltése
with open('/content/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Címkék betöltése (real = 1, fake = 0)
train_file = '/content/train_negyedik.csv'
test_file = '/content/indep_negyedik.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

labels_train = df_train['label'].values
labels_test = df_test['label'].values

# Betölteni embedding mátrixot
embedding_matrix = np.load('/content/embedding_matrix.npy')

# Ellenőrzés
print(f"Train padded sequences shape: {padded_train.shape}")
print(f"Test padded sequences shape: {padded_test.shape}")
print(f"Train labels shape: {labels_train.shape}")
print(f"Test labels shape: {labels_test.shape}")
# Out:
# Train padded sequences shape: (59520, 600)
# Test padded sequences shape: (14304, 600)
# Train labels shape: (59520,)
# Test labels shape: (14304,)

# %%
# Max szókincs és szekvencia hossz
MAX_VOCAB_SIZE = 25000
MAX_LENGTH = 600
EMBEDDING_DIM = 300  # GloVe 300d

# input shape
MAX_SEQUENCE_LENGTH = padded_train.shape[1]

# Szöveges input (LSTM/GRU bemenet)
text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
embedding_layer = Embedding(
    input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
    output_dim=embedding_matrix.shape[1],
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)(text_input)

model_output = embedding_layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
MAX_SEQUENCE_LENGTH = padded_train.shape[1]  # Train hossz
EMBEDDING_DIM = embedding_matrix.shape[1]  # GloVe embeddings

# 10%-os validációs halmaz leválasztása a tanító adatokból
padded_train_final, padded_val, y_train_final, y_val = train_test_split(
    padded_train, labels_train, test_size=0.1, random_state=42
)
# Float32-re konvertálás TensorFlow kompatibilitás miatt
padded_train_final = np.array(padded_train_final, dtype=np.float32)
padded_val = np.array(padded_val, dtype=np.float32)
padded_test = np.array(padded_test, dtype=np.float32)
y_train_final = np.array(y_train_final, dtype=np.float32)
y_val = np.array(y_val, dtype=np.float32)
y_test = np.array(labels_test, dtype=np.float32)

# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# # LSTM MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ## Modell lefuttatása

# %%
# LSTM modell, trainable, non-trainable embedding

def create_lstm_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings
    )(text_input)

    # LSTM rétegek
    lstm_out = LSTM(128, return_sequences=True, dropout=0.3)(text_embedding)
    lstm_out = Dropout(0.3)(lstm_out)  # Dropout réteg az első LSTM után
    lstm_out = LSTM(64,return_sequences=True, dropout=0.3)(lstm_out)
    lstm_out = Dropout(0.3)(lstm_out) # Dropout réteg az második LSTM után
    lstm_out = LSTM(32, dropout=0.3)(lstm_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(lstm_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása
lstm_trainable = create_lstm_model(trainable_embeddings=True)  # Trainable embedding

lstm_trainable.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_1 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 600, 128)            │         219,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 600, 64)             │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,781,505 (29.68 MB)
#  Trainable params: 7,781,505 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Modell tanítása a validációs adatok figyelésével
lstm_history_trainable = lstm_trainable.fit(
    padded_train_final, y_train_final,
    validation_data=(padded_val, y_val),  # Validációs halmaz
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság: {test_accuracy:.4f}, Teszthalmaz veszteség: {test_loss:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.6988 - loss: 0.5520 - val_accuracy: 0.7969 - val_loss: 0.4414
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 80s 80ms/step - accuracy: 0.8851 - loss: 0.2913 - val_accuracy: 0.9409 - val_loss: 0.1568
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 85s 83ms/step - accuracy: 0.9478 - loss: 0.1448 - val_accuracy: 0.9521 - val_loss: 0.1369
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 80ms/step - accuracy: 0.9658 - loss: 0.1011 - val_accuracy: 0.9667 - val_loss: 0.0989
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 85s 83ms/step - accuracy: 0.9779 - loss: 0.0661 - val_accuracy: 0.9718 - val_loss: 0.0845
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 80ms/step - accuracy: 0.9874 - loss: 0.0394 - val_accuracy: 0.9721 - val_loss: 0.0994
# Epoch 7/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 83ms/step - accuracy: 0.9909 - loss: 0.0301 - val_accuracy: 0.9689 - val_loss: 0.1129
# Epoch 8/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 83ms/step - accuracy: 0.9928 - loss: 0.0234 - val_accuracy: 0.9733 - val_loss: 0.0999
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.8306 - loss: 0.5067
# Teszthalmaz pontosság: 0.8260, Teszthalmaz veszteség: 0.5207

# %%
# Valószínűség becslése
lstm_y_prob = lstm_trainable.predict(padded_test)

lstm_y_pred = (lstm_y_prob > 0.5).astype(int)

lstm_accuracy = accuracy_score(y_test, lstm_y_pred)
lstm_precision = precision_score(y_test, lstm_y_pred)
lstm_recall = recall_score(y_test, lstm_y_pred)
lstm_f1 = f1_score(y_test, lstm_y_pred)

print(f"Accuracy: {lstm_accuracy:.4f}")
print(f"Precision: {lstm_precision:.4f}")
print(f"Recall: {lstm_recall:.4f}")
print(f"F1-score: {lstm_f1:.4f}")
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step
# Accuracy: 0.8259
# Precision: 0.9433
# Recall: 0.6934
# F1-score: 0.7993

# %% [markdown]
# ## LSTM Modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(lstm_history_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(lstm_history_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 0.8282 - loss: 0.5178

# %%
# Confusion Matrix
cm_lstm = confusion_matrix(y_test, lstm_y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm_lstm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix LSTM Modellre')
plt.show()

print(classification_report(y_test, lstm_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.96      0.85      7152
#          1.0       0.94      0.69      0.80      7152
#
#     accuracy                           0.83     14304
#    macro avg       0.85      0.83      0.82     14304
# weighted avg       0.85      0.83      0.82     14304

# %%
# Flatten
y_true = y_test.flatten()
y_pred = lstm_y_pred.flatten()
y_prob = lstm_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás besorolás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás besorolás) LSTM Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": lstm_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = lstm_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_lstm.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 8    Hamis negatív (FN)           1.0                 0
# 15   Hamis negatív (FN)           1.0                 0
# 24   Hamis negatív (FN)           1.0                 0
# 27   Hamis pozitív (FP)           0.0                 1
# 51   Hamis negatív (FN)           1.0                 0
# 57   Hamis negatív (FN)           1.0                 0
# 77   Hamis negatív (FN)           1.0                 0
# 79   Hamis negatív (FN)           1.0                 0
# 82   Hamis negatív (FN)           1.0                 0
# 90   Hamis negatív (FN)           1.0                 0
# 95   Hamis pozitív (FP)           0.0                 1
# 109  Hamis negatív (FN)           1.0                 0
# 111  Hamis negatív (FN)           1.0                 0
# 112  Hamis pozitív (FP)           0.0                 1
# 121  Hamis pozitív (FP)           0.0                 1
# 128  Hamis negatív (FN)           1.0                 0
# 162  Hamis negatív (FN)           1.0                 0
# 169  Hamis pozitív (FP)           0.0                 1
# 180  Hamis negatív (FN)           1.0                 0
# 192  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'more' 'than' 'a' 'week' 'befor' 'sever' 'famili' 'have' 'start' 'go' 'to' 'the' 'manila' 'north' 'cemeteri' 'to' 'clean' 'the' 'rest' 'place' 'of' 'their' 'love' 'one' 'accord' 'to' 'a' 'report' 'on' 'staff' 'expect' 'more' 'peopl' 'to' 'the' 'cemeteri' 'over' 'the' 'holiday' 'thi' 'year' 'cemeteri' 'were' 'clos ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'interior' 'and' 'local' 'govern' 'secretari' 'on' 'wednesday' 'order' 'an' 'investig' 'into' 'the' 'death' 'of' 'a' 'student' 'who' 'wa' 'found' 'in' 'a' 'shallow' 'grave' 'in' 'imu' 'to' 'at' 'kung' 'ano' 'ang' 'circumst' 'ani' 'form' 'of' 'violenc' 'na' 'ang' 'ito' 'he' 'told' 'report' 'in' 'an' 'ambush' 'interview' 'we' 'will' 'investig' 'it' 'immedi' 'and' 'look' 'into' 'the' 'circumst' 'here' 'ani' 'form' 'of' 'violenc' 'that' 'lead' 'to' 'death' 'should' 'be' 'investig' 'immedi' 'on' 'tuesday' 'the' 'bodi' 'of' 'john' 'matthew' 'a' 'student' 'at' 'univers' 'in' 'manila' 'wa' 'found' 'more' 'than' 'a' 'week' 'after' 'he' 'wa' 'last' 'seen' 'aliv' 'polic' 'said' 'suspect' 'whom' 'they' 'invit' 'for' 'investig' 'point' 'to' 'where' 'had' 'been' 'buri' 'bodi' 'show' 'sign' 'of' 'haze' 'accord' 'to' 'polic' 'act' 'chief' 'polic' 'lieuten' 'colonel' 'sa ...
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'presid' 'ferdinand' 'marco' 'jr' 'ha' 'reconstitut' 'the' 'sugar' 'regulatori' 'administr' 'govern' 'bodi' 'with' 'three' 'new' 'appointe' 'the' 'appoint' 'were' 'made' 'on' 'the' 'heel' 'of' 'the' 'controversi' 'order' 'author' 'the' 'import' 'of' 'metric' 'ton' 'of' 'sugar' 'which' 'wa' 'later' 'on' 'declar' 'illeg' 'and' 'thumb' 'down' 'by' 'the' 'chief' 'execut' 'marco' 'appoint' 'david' 'john' 'p' 'as' 'act' 'administr' 'of' 'the' 'accord' 'to' 'a' 'report' 'on' 'staterun' 'replac' 'former' 'administr' 'who' 'resign' 'from' 'hi' 'post' 'amid' 'the' 'controversi' 'involv' 'sugar' 'order' 'no' 'so' 'the' 'said' 'order' 'wa' 'deem' 'illeg' 'as' 'the' 'sugar' 'regulatori' 'board' 'conven' 'and' 'issu' 'a' 'resolut' 'without' 'the' 'approv' 'of' 'marco' 'who' 'as' 'the' 'concurr' 'secretari' 'of' 'the' 'depart' 'of' 'agricultur' 'is' 'chairman' 'of' 'the' 'sugar' 'board' 'meanwhil' 'other' 'sugar' 'regulatori' 'board' 'member' 'are' 'pablo' 'lui' 's' 'replac' 'sugar' 'planter' 'repres' 'gerardo' 'jr' 'and' 'ma' 'v' 'replac' 'sugar' 'miller' 'repres' 'atti' 'roland' 'who' 'resign' 'for' 'health' 'reason' 'the' 'is' 'a' 'governmentown' 'and' 'control' 'corpor' 'attach' 'to' 'the' 'da' 'establish' 'in' 'by' 'virtu' 'of' 'execut' 'order' 'no' 'it' 'is' 'mandat' 'to' 'promot' 'the' 'growth' 'and' 'develop' 'of' 'the' 'sugar' 'industri' 'through'  ...
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'unidentifi' 'muslim' 'on' 'the' 'run' 'after' 'stab' 'four' 'peopl' 'at' 'a' 'frankfurt' 'train' 'station' 'the' 'attack' 'thi' 'afternoon' 'occur' 'at' 'station' 'and' 'polic' 'have' 'said' 'there' 'are' 'four' 'victim' 'at' 'thi' 'stage' 'the' 'motiv' 'for' 'the' 'stab' 'is' 'not' 'clear' 'it' 'will' 'becom' 'crystal' 'clear' 'onc' 'you' 'identifi' 'the' 'attack' 'as' 'a' 'muslim' 'uk' 'daili' 'mail' 'ht' 'the' 'local' 'polic' 'forc' 'confirm' 'the' 'attack' 'by' 'tweet' 'there' 'wa' 'a' 'knife' 'assault' 'at' 'the' 'in' 'frankfurt' 'that' 'is' 'whi' 'so' 'mani' 'colleagu' 'polic' 'offic' 'and' 'rescu' 'worker' 'there' 'frankfurt' 'polic' 'confirm' 'all' 'four' 'victim' 'were' 'still' 'in' 'hospit' 'a' 'video' 'of' 'the' 'bloodi' 'aftermath' 'wa' 'captur' 'on' 'what' 'is' 'understood' 'to' 'be' 'level' 'b' 'of' 'the' 'station' 'the' 'incid' 'wa' 'at' '30pm' 'local' 'time' 'accord' 'to' 'who' 'report' 'the' 'stab' 'came' 'after' 'a' 'group' 'were' 'quarrel' 'a' 'disput' 'had' 'start' 'on' 'one' 'platform' 'and' 'spill' 'over' 'onto' 'anoth' 'one' 'there' 'wa' 'more' 'bloodsh' 'in' 'a' 'separ' 'incid' 'at' 'the' 'station' 'understood' 'to' 'be' 'on' 'a' 'passeng' 'train' 'between' 'and' 'a' 'disput' 'between' 'two' 'passeng' 'broke' 'out' 'into' 'a' 'fight' 'accord' 'to' 'which' 'led' 'to' 'glass' 'be' 'broken' 'and' 'peopl' 'suffer' 'cut' 'frankfurt' 'polic' 'look' 'to' 'reassur' 'the' 'public' 'by' 'tweet' 'if' 'we' 'recogn' 'a' 'threat' 'to' 'the' 'local' 'popul' 'we' 'would' 'commun' 'thi' 'no' 'you' 'would' 'not' 'the' 'stab' 'will' 'still' 'rais' 'fear' 'the' 'attack' 'wa' 'islam' 'after' 'a' 'string' 'of' 'incid' 'across' 'europ' 'over' 'recent' 'month' 'germani' 'ha' 'been' 'rock' 'by' 'islam' 'terror' 'attack' 'thi' 'year' 'heap' 'pressur' 'on' 'chancellor' 'angela' 'merkel' 'opendoor' 'muslim' 'immigr' 'polici' 'a' 'bloodi' 'week' 'of' 'violenc' 'that' 'rock' 'germani' 'began' 'on' 'juli' 'when' 'pakistani' 'muslim' 'teenag' 'khan' 'pose' 'as' 'an' 'afghan' 'refuge' 'hack' 'at' 'passeng' 'on' 'a' 'train' 'in' 'with' 'an' 'axe' 'wound' 'five' 'four' 'day' 'later' 'a' 'muslim' 'teenag' 'ali' 'shot' 'nine' 'peopl' 'dead' 'dure' 'a' 'rampag' 'through' 'a' 'shop' 'centr' 'in' 'munich' 'befor' 'take' 'hi' 'own' 'life' 'pour' 'le' 'lien' 'amaq' 'de' 'l' 'diffus' 'video' 'de' 'du' 't ...
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               'the' 'bureau' 'of' 'immigr' 'bi' 'arrest' 'and' 'set' 'to' 'deport' 'a' 'chines' 'nation' 'who' 'wa' 'be' 'search' 'by' 'author' 'for' 'allegedli' 'misrepres' 'himself' 'as' 'a' 'filipino' 'suspect' 'tai' 'wa' 'nab' 'in' 'manila' 'on' 'tuesday' 'may' 'after' 'a' 'warrant' 'of' 'deport' 'wa' 'issu' 'against' 'him' 'in' 'juli' 'last' 'year' 'for' 'be' 'an' 'undesir' 'alien' 'tai' 'allegedli' 'assum' 'the' 'name' 'of' 'one' 'albert' 'torr' 'and' 'ha' 'been' 'use' 'the' 'fictiti' 'ident' 'in' 'file' 'incorpor' 'paper' 'acquir' 'a' 'driver' 'licens' 'regist' 'hi' 'busi' 'as' 'well' 'as' 'in' 'other' 'public' 'document' 'accord' 'to' 'the' 'immigr' 'bureau' 'the' 'suspect' 'is' 'current' 'detain' 'at' 'the' 'bi' 'facil' 'in' 'pend' 'hi' 'deport' 'he' 'will' 'als ...
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'a' 'famili' 'of' 'five' 'die' 'after' 'a' 'fire' 'hit' 'their' 'resid' 'in' 'on' 'monday' 'accord' 'to' 'clair' 'report' 'on' 'gma' 'region' 'tv' 'one' 'north' 'central' 'the' 'fire' 'spread' 'to' 'three' 'hous' 'in' 'the' 'fire' 'reach' 'the' 'second' 'alarm' 'and' 'last' 'for' 'over' 'two' 'hour'  ...
# 77                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'person' 'belong' 'of' 'the' 'miss' 'yearold' 'were' 'found' 'among' 'skelet' 'remain' 'befor' 'dawn' 'in' 'in' 'puerto' 'on' 'tuesday' 'accord' 'to' 'report' 'on' 'super' 'recov' 'among' 'the' 'remain' 'were' 'black' 'bag' 'cellphon' 'and' 'some' 'identif' 'card' 'her' 'love' 'one' 'have' 'confirm' 'that' 'the' 'item' 'belong ...
# 79                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'two' 'minor' 'be' 'prostitut' 'were' 'rescu' 'by' 'oper' 'in' 'a' 'sting' 'oper' 'which' 'led' 'to' 'the' 'arrest' 'of' 'one' 'of' 'their' 'pimp' 'dure' 'the' 'oper' 'the' 'pimp' 'brought' 'along' 'with' 'her' 'two' 'minor' 'femal' 'age' 'and' 'to' 'a' 'vehicl' 'where' 'two' 'undercov' 'oper' 'were' 'seat' 'the' 'transact' 'took' 'place' 'insid' 'the' 'vehicl' 'where' 'the' 'oper' 'bargain' 'for' 'a' 'cheaper' 'price' 'as' 'they' 'earlier' 'agre' 'to' 'pay' 'for' 'three' 'femal' 'but' 'onli' 'two' 'arriv' 'the' 'pimp' 'wa' 'arrest' 'as' 'she' 'exit' 'the' 'vehicl' 'accord' 'to' 'citi' 'polic' 'district' 'station' 'investig' 'chief' 'anthoni' 'the' 'suspect' 'is' 'part' 'of' 'a' 'group' 'that' 'prostitut' 'children' 'ang' 'transact' 'is' 'onlin' 'group' 'group' 'chat' 'para' 'sa' 'ng' 'prostitut' 'sa' 'minor' 'he' 'said' 'in' 'a' 'report' 'on' 'gma' 'weekend' 'on' 'sunday' 'their' 'transact' 'are' 'done' 'onlin' 'they' 'have' 'a' 'group' 'a' 'group' 'chat' 'for' 'the' 'transact' 'where' 'they' 'prostitut' 'minor' 'one' 'of' 'the' 'father' 'of' 'the' 'minor' 'said' 'the' 'child' 'told' 'him' 'she' 'wa' 'go' 'to' 'attend' 'a' 'birthday' 'parti' 'and' 'he' 'did' 'not' 'know' 'that' 'she' 'wa' 'instead' 'be' 'prostitut' 'hindi' 'ko' 'po' 'na' 'po' 'ang' 'rin' 'po' 'nasa' 'din' 'po' 'eh' 'ko' 'lang' 'din' 'po' 'din' 'na' 'na' 'he' 'said' 'i' 'did' 'not' 'know' 'that' 'that' 'is' 'what' 'happen' 'i' 'am' 'alway' 'in' 'work' 'and' 'i' 'just' 'knew' 'of' 'thi' 'now' 'that' 'she' 'is' 'be' 'prostitut' 'the' 'oper' 'also' 'nab' 'the' 'driver' 'of' 'the' 'use' 'by' 'the' 'pimp' 'and' 'oper' 'who' 'deni' 'ani' 'k ...
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   'a' 'famili' 'in' 'wa' 'shock' 'to' 'see' 'that' 'their' 'electr' 'bill' 'ha' 'reach' 'million' 'in' 'a' 'report' 'by' 'gma' 'region' 'tv' 'one' 'north' 'central' 'antonio' 'said' 'that' 'from' 'their' 'averag' 'monthli' 'bill' 'of' 'around' 'they' 'now' 'to' 'pay' 'reaction' 'ko' 'din' 'ng' 'tao' 'lang' 'po' 'mo' 'she' 'said' 'din' 'po' 'ang' 'number' 'po' 'million' 'po' 'she' 'ad' 'antonio' 'immedi' 'went' 'to' 'the' 'central' 'electr' 'cooper' 'offic' 'to' 'complain' 'about' 'the' 'bill' 'clarifi' 'that' 'there' 'an' 'error' 'in' 'the' 'meter' 'read' 'it' 'apolog' 'to' 'the' 'famili' 'and' 'sa ...
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'the' 'depart' 'of' 'educ' 'is' 'final' 'the' 'guidelin' 'for' 'the' 'start' 'of' 'a' 'nation' 'learn' 'camp' 'on' 'juli' 'spokesperson' 'michael' 'said' 'friday' 'we' 'are' 'hope' 'to' 'releas' 'those' 'guidelin' 'as' 'soon' 'as' 'possibl' 'sad' 'in' 'an' 'interview' 'on' 'b' 'tv' 'the' 'nation' 'learn' 'camp' 'is' 'a' 'part' 'of' 'nation' 'learn' 'recoveri' 'program' 'that' 'aim' 'to' 'help' 'the' 'student' 'catch' 'up' 'with' 'the' 'learn' 'loss' 'dure' 'the' 'height' 'of' 'the' 'pandem' 'where' 'school' 'are' 'close' 'down' 'thi' 'camp' 'featur' 'intervent' 'enrich' 'and' 'remedi' 'he' 'ad' 'come' 'out' 'of' 'the' 'learn' 'loss' 'learn' 'gap' 'ang' 'po' 'sa' 'summer' 'class' 'hindi' 'lang' 'ito' 'para' 'sa' 'o' 'para' 'sa' 'ang' 'grade' 'po' 'na' 'sa' 'ate' 'learn' 'camp' 'said' 'voluntari' 'the' 'offici' 'emphas' 'that' 'the' 'nation' 'learn' 'camp' 'is' 'voluntari' 'for' 'student' 'and' 'teacher' 'as' 'well' 'while' 'it' 'is' 'voluntari' 'said' 'student' 'who' 'have' 'low' 'grade' 'are' 'highli' 'encourag' 'to' 'particip' 'as' 'thi' 'might' 'affect' 'their' 'promot' 'to' 'the' 'next' 'grade' 'level' 'for' 'teacher' 'who' 'will' 'volunt' 'in' 'the' 'program' 'said' 'they' 'will' 'be' 'given' 'addit' 'leav' 'credit' 'these' 'leav' 'credit' 'will' 'be' 'count' 'even' 'if' 'their' 'servic' 'credit' 'is' 'limit' 'to' 'day' 'may' 'rule' 'ang' 'way' 'back' 'in' 'na' 'may' 'limit' 'na' 'day' 'lang' 'ang' 'na' 'servic' 'credit' 'ng' 'ate' 'ito' 'pong' 'sa' 'learn' 'camp' 'is' 'over' 'and' 'abov' 'limit' 'na' 'so' 'hindi' 'po' 'na' 'day' 'he' 'said' 'apart' 'from' 'thi' 'said' 'the' 'is' 'eye' 'to' 'give' 'free' 'meal' 'for' 'teacher' 'who' 'will' 'volunt' 'in' 'the' 'said' 'camp' 'mass' 'promot' 'in' 'the' 'same' 'interview' 'said' 'the' 'ha' 'no' 'polici' 'on' 'alleg' 'mass' 'promot' 'of' 'student' 'ho' 'polici' 'sa' 'there' 'is' 'no' 'issuanc' 'that' 'even' 'allow' 'mass' 'promot' 'but' 'we' 'do' 'understand' 'na' 'sa' 'field' 'and' 'that' 'is' 'whi' 'that' 'is' 'someth' 'that' 'we' 'are' 'look' 'into' 'in' 'term' 'of' 'ano' 'ba' 'he' 'said' 'one' 'of' 'the' 'thing' 'that' 'they' 'are ...
# ...
# 169                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               'new' 'topic' 'the' 'abov' 'top' 'secret' 'web ...
# 180                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'the' 'depart' 'of' 'environ' 'and' 'natur' 'resourc' 'ha' 'form' 'a' 'task' 'forc' 'to' 'secur' 'the' 'marin' 'protect' 'area' 'that' 'may' 'be' 'affect' 'by' 'the' 'possibl' 'oil' 'spill' 'from' 'the' 'motor' 'tanker' 'carri' 'liter' 'of' 'industri' 'fuel' 'oil' 'that' 'sank' 'off' 'orient' 'on' 'tuesday' 'in' 'a' 'statement' 'the' 'said' 'task' 'forc' 'oil' 'spill' 'wa' 'creat' 'after' 'it' 'conduct' 'an' 'emerg' 'meet' 'with' 'the' 'philippin' 'coast' 'guard' 'orient' 'governor' 'and' 'mayor' 'henri' 'joel' 'undersecretari' 'and' 'chief' 'of' 'staff' 'erni' 'who' 'serv' 'as' 'the' 'corpor' 'ground' 'respons' 'coordin' 'dure' 'the' 'oil' 'spill' 'in' 'wa' 'appoint' 'as' 'task' 'forc' 'command' 'philippin' 'coast' 'guard' 'spokesperson' 'rear' 'admir' 'said' 'wednesday' 'that' 'it' 'is' 'monitor' 'for' 'possibl' 'oil' 'spill' 'from' 'mt' 'princess' 'empress' 'which' 'ha' 'now' 'total' 'sunk' 'accord' 'to' 'the' 'an' 'oil' 'spill' 'six' 'kilomet' 'long' 'and' 'four' 'kilomet' 'wide' 'wa' 'spot' 'in' 'the' 'area' 'where' 'the' 'tanker' 'sank' 'a' 'report' 'state' 'that' 'on' 'a' 'maximum' 'of' 'kilomet' 'radiu' 'from' 'east' 'of' 'port' 'marin' 'protect' 'area' 'can' 'be' 'potenti' 'affect' 'due' 'to' 'oil' 'it' 'ha' 'map' 'potenti' 'risk' 'area' 'includ' 'bed' 'and' 'dispers' 'pathway' 'for' 'spawn' 'fish' 'larva' 'the' 'said' 'in' 'a' 'statement' 'thi' 'wa' 'determin' 'after' 'conduct' 'a' 'water' 'sampl' 'in' 'the' 'municip' 'of' 'and' 'the' 'agenc' 'said' 'marin' 'environment' 'protect' 'command' 'would' 'be' 'the' 'lead' 'agenc' 'task' 'with' 'the' 'respons' 'oper' 'in' 'the' 'affect' 'area' 'said' 'they' 'have' 'deploy' 'one' 'of' 'their' 'vessel' 'aquino' 'to' 'the' 'area' 'to' 'conduct' 'the' 'monitor' 'it' 'is' 'carri' 'spill' 'boom' 'readi' 'to' 'conduct' 'proper' 'procedur' 'in' 'case' 'of' 'an' 'oil' 'spill' 'the' 'said' 'the' 'ta ...
# 192                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'the' 'land' 'transport' 'franchis' 'and' 'regulatori' 'board' 'announc' 'on' 'thursday' 'the' 'commenc' 'of' 'three' 'rout' 'for' 'oper' 'of' 'public' 'util' 'and' 'modern' 'help' 'commut' 'affect' 'by' 'the' 'closur' 'of' 'certain' 'philippin' 'nation' 'railway' 'station' 'the' 'closur' 'is' 'necessari' 'for' 'the' 'construct' 'of' 'the' 'commut' 'railway' 'to' 'mitig' 'the' 'impact' 'of' 'the' 'closur' 'on' 'commut' 'we' 'have' 'establish' 'these' 'rout' 'we' 'are' 'grate' 'to' 'the' 'for' 'assist' 'in' 'identifi' 'these' 'rout' 'chairman' 'said' 'onc' 'the' 'is' 'complet' 'it' 'advantag' 'in' 'term' 'of' 'passeng' 'mobil' 'along' 'our' 'railway' 'which' 'is' 'known' 'as' 'one' 'of' 'the' 'most' 'conveni' 'and' 'afford' 'mean' 'of' 'public' 'transport' 'in' 'the' 'countri' 'will' 'be' 'truli' 'worth' 'it' 'he' 'ad' 'earlier' 'thi' 'month' 'the' 'announc' 'that' 'daili' 'trip' 'on' 'the' 'to' 'rout' 'would' 'ceas' 'start' 'juli' 'due' 'to' 'construct' 'the' 'affect' 'station' 'includ' 'san' 'pedro' 'main' 'gate' 'golden' 'citi' 'rosa' 'and' 'accord' 'to' 'memorandum' 'circular' 'no' 'the' 'in' 'collabor' 'with' 'the' 'ha' 'identifi' 'three' 'rout' 'to' 'serv' 'the' 'affect' 'station' 'these' 'rout' 'have' 'been' 'open' 'for' 'the' 'qualif' 'process' 'the' 'ha' 'specifi' 'three' 'rout' 'via' 'east' 'servic' 'road' 'and' 'and' 'via' 'the' 'south' 'expressway' 'for' 'public' 'util' 'buse' 'pub' 'and' 'which' 'will' 'be' 'servic' 'by' 'modern' 'public' 'util' 'the' 'agenc' 'ha' 'alloc' 'pub' 'unit' 'for' 'the' 'rout' 'pub' 'for' 'and' 'five' 'for' 'the' 'number' 'of' 'unit' 'may' 'be' 'adjust' 'base' 'on' 'passeng' 'demand' 'as' 'determin' 'by' 'the' 'the' 'follow' 'memorandum' 'circular' 'no' 'titl' 'consolid' 'guidelin' 'on' 'the' 'process' 'of' 'issuanc' 'of' 'certif' 'of' 'public' 'conveni' 'and' 'provision' 'author' 'permit' 'sp' 'under' 'the' 'omnibu' 'franchis' 'guidelin' 'and' 'public' 'util' 'vehicl' 'modern' 'program' 'for' 'select' 'oper' 'as' 'per' 'the' 'memorandum' 'author' 'unit' 'should' 'not' 'exceed' 'five' 'year' 'base' 'on' 'the' 'vehicl' 'certif' 'of' 'registr' 'with' 'the' 'land' 'transport' 'offic' 'they' 'should' 'oper' 'under' 'an ...
#
#      Predikció valószínűsége
# 8                     0.0275
# 15                    0.4417
# 24                    0.2864
# 27                    0.8440
# 51                    0.1862
# 57                    0.2266
# 77                    0.1213
# 79                    0.0051
# 82                    0.0033
# 90                    0.3356
# 95                    0.7265
# 109                   0.3180
# 111                   0.0033
# 112                   0.5447
# 121                   0.6589
# 128                   0.0223
# 162                   0.0778
# 169                   0.7273
# 180                   0.2806
# 192                   0.0017

# %% [markdown]
# # GRU MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ### Modell lefuttatása

# %%
# GRU Modell

def create_gru_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),  # Ensure within vocab limit
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings  # Toggle trainability
    )(text_input)

    # GRU rétegek
    gru_out = GRU(128, return_sequences=True, dropout=0.3)(text_embedding)
    gru_out = Dropout(0.3)(gru_out)  # Dropout réteg az első GRU után
    gru_out = GRU(64,return_sequences=True, dropout=0.3)(gru_out)
    gru_out = Dropout(0.3)(gru_out)
    gru_out = GRU(32, dropout=0.3)(gru_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(gru_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása (Trainable)
gru_trainable = create_gru_model(trainable_embeddings=True)

gru_trainable.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_2 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 600, 128)            │         165,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 600, 64)             │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,711,809 (29.42 MB)
#  Trainable params: 7,711,809 (29.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# GRU modell tanítása a validációs adatok figyelésével
history_gru_trainable = gru_trainable.fit(
    padded_train_final, y_train_final,  # Ugyanaz a tanító adathalmaz, mint az LSTM-nél
    validation_data=(padded_val, y_val),  # Ugyanaz a validációs halmaz, mint az LSTM-nél
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság (GRU): {test_accuracy_gru:.4f}, Teszthalmaz veszteség (GRU): {test_loss_gru:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 66s 76ms/step - accuracy: 0.8292 - loss: 0.3723 - val_accuracy: 0.9189 - val_loss: 0.1845
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 64s 76ms/step - accuracy: 0.9390 - loss: 0.1622 - val_accuracy: 0.9143 - val_loss: 0.2154
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 79ms/step - accuracy: 0.9701 - loss: 0.0874 - val_accuracy: 0.9345 - val_loss: 0.1806
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 76ms/step - accuracy: 0.9851 - loss: 0.0462 - val_accuracy: 0.9661 - val_loss: 0.1044
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.9940 - loss: 0.0201 - val_accuracy: 0.9721 - val_loss: 0.0988
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 63s 76ms/step - accuracy: 0.9952 - loss: 0.0156 - val_accuracy: 0.9669 - val_loss: 0.1284
# Epoch 7/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.9976 - loss: 0.0080 - val_accuracy: 0.9731 - val_loss: 0.1045
# Epoch 8/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 63s 76ms/step - accuracy: 0.9838 - loss: 0.0492 - val_accuracy: 0.9691 - val_loss: 0.1038
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7450 - loss: 1.1943
# Teszthalmaz pontosság (GRU): 0.7416, Teszthalmaz veszteség (GRU): 1.2057

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Valószínűség becslése
gru_y_prob = gru_trainable.predict(padded_test)

gru_y_pred = (gru_y_prob > 0.5).astype(int)

accuracy = accuracy_score(y_test, gru_y_pred)
precision = precision_score(y_test, gru_y_pred)
recall = recall_score(y_test, gru_y_pred)
f1 = f1_score(y_test, gru_y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step
# Accuracy: 0.7408
# Precision: 0.9362
# Recall: 0.5169
# F1-score: 0.6661

# %% [markdown]
# ## GRU modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_gru_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(history_gru_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(history_gru_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(history_gru_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.8316 - loss: 0.5142

# %%
# Confusion Matrix
cm_gru = confusion_matrix(y_test, gru_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_gru, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix GRU Modellre')
plt.show()

print(classification_report(y_test, gru_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.96      0.79      7152
#          1.0       0.94      0.52      0.67      7152
#
#     accuracy                           0.74     14304
#    macro avg       0.80      0.74      0.73     14304
# weighted avg       0.80      0.74      0.73     14304

# %%
# Flatten
y_true = y_test.flatten()
y_pred = gru_y_pred.flatten()
y_prob = gru_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás) GRU Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": gru_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = gru_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_gru.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 4    Hamis negatív (FN)           1.0                 0
# 8    Hamis negatív (FN)           1.0                 0
# 10   Hamis negatív (FN)           1.0                 0
# 12   Hamis negatív (FN)           1.0                 0
# 15   Hamis negatív (FN)           1.0                 0
# 23   Hamis negatív (FN)           1.0                 0
# 24   Hamis negatív (FN)           1.0                 0
# 34   Hamis negatív (FN)           1.0                 0
# 38   Hamis negatív (FN)           1.0                 0
# 46   Hamis negatív (FN)           1.0                 0
# 51   Hamis negatív (FN)           1.0                 0
# 57   Hamis negatív (FN)           1.0                 0
# 59   Hamis negatív (FN)           1.0                 0
# 71   Hamis negatív (FN)           1.0                 0
# 77   Hamis negatív (FN)           1.0                 0
# 78   Hamis pozitív (FP)           0.0                 1
# 79   Hamis negatív (FN)           1.0                 0
# 82   Hamis negatív (FN)           1.0                 0
# 90   Hamis negatív (FN)           1.0                 0
# 100  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Szöveg  \
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'the' 'depart' 'of' 'transport' 'ha' 'ask' 'for' 'understand' 'after' 'metro' 'manila' 'land' 'near' 'the' 'bottom' 'of' 'a' 'global' 'urban' 'mobil' 'rank' 'say' 'that' 'it' 'is' 'work' 'on' 'sever' 'project' 'to' 'improv' 'mobil' 'and' 'public' 'transport' 'in' 'the' 'nation' 'capit' 'region' 'the' 'urban' 'mobil' 'readi' 'index' 'compil' 'by' 'the' 'oliv' 'forum' 'and' 'the' 'univers' 'of' 'california' 'at' 'berkeley' 'rank' 'global' 'citi' 'on' 'metro' 'manila' 'land' 'in' 'place' 'with' 'onli' 'nairobi' 'and' 'lago' 'fare' 'wors' 'in' 'the' 'studi' 'in' 'the' 'public' 'transport' 'use' 'some' 'of' 'the' 'metric' 'abov' 'includ' 'transit' 'commut' 'speed' 'public' 'transit' 'afford' 'rail' 'network' 'public' 'transit' 'station' 'densiti' 'transit' 'estim' 'time' 'of' 'arriv' 'and' 'share' 'of' 'time' 'in' 'public' 'philippin' 'wa' 'in' 'place' 'the' 'studi' 'note' 'that' 'in' 'the' 'nation' 'capit' 'region' 'sustain' 'mobil' 'is' 'less' 'of' 'a' 'prioriti' 'and' 'motor' 'vehicl' 'are' 'like' 'to' 'remain' 'the' 'most' 'common' 'transit' 'option' 'ask' 'for' 'understand' 'report' 'on' 'on' 'monday' 'note' 'that' 'commut' 'pedestrian' 'motorist' 'and' 'transport' 'worker' 'face' 'long' 'line' 'crowd' 'heavi' 'road' 'congest' 'transport' 'malfunct' 'and' 'other' 'problem' 'everi' 'day' 'the' 'result' 'for' 'mani' 'filipino' 'is' 'a' 'larg' 'chunk' 'of' 'their' 'day' 'and' 'their' 'energi' 'devot' 'to' 'travel' 'to' 'and' 'from' 'work' 'and' 'school' 'the' 'said' 'that' 'it' 'accept' 'the' 'report' 'find' 'we' 'are' 'address' 'current' 'commut' 'travail' 'with' 'perman' 'solut' 'transport' 'secretari' 'jaim' 'bautista' 'said' 'in' 'a' 'statement' 'i' 'person' 'ask' 'for' 'the' 'public' 'understand' 'to' 'give' 'us' 'more' 'time' 'to' 'complet' 'our' 'project' 'we' 'are' 'fasttrack' 'variou' 'transport' 'project' 'carri' 'over' 'from' 'the' 'past' 'administr' 'despit' 'financi' 'and' 'bureaucrat' 'challeng' 'we' 'are' 'redesign' 'the' 'framework' 'of' 'undertak' 'transport' 'project' 'though' 'effect' 'to' 'the' 'ride' 'public' 'may' 'take' 'time' 'becaus' 'we' 'are' 'look' 'longterm' 'he' 'ad' 'construct' 'of' 'the' 'metro' 'manila' 'subway' 'is' 'underway' 'with' 'the' 'countri' 'first' 'underground' 'rail' 'system' 'expect' 'to' 'be' 'complet' 'by' 'or' 'gma' 'integr' 'news'
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'more' 'than' 'a' 'week' 'befor' 'sever' 'famili' 'have' 'start' 'go' 'to' 'the' 'manila' 'north' 'cemeteri' 'to' 'clean' 'the' 'rest' 'place' 'of' 'their' 'love' 'one' 'accord' 'to' 'a' 'report' 'on' 'staff' 'expect' 'more' 'peopl' 'to' 'the' 'cemeteri' 'over' 'the' 'holiday' 'thi' 'year' 'cemeteri' 'were' 'close' 'over' 'in' 'and' 'due' 'to' 'the' 'pandem' 'po' 'po' 'up' 'to' 'to' 'million' 'novemb' 'po' 'said' 'a' 'cemeteri' 'staff' 'the' 'manila' 'intern' 'airport' 'author' 'is' 'also' 'prepar' 'for' 'the' 'possibl' 'influx' 'of' 'passeng' 'go' 'home' 'to' 'their' 'provinc' 'thi' 'season' 'the' 'remind' 'the' 'public' 'to' 'follow' 'health' 'protocol' 'and' 'contact' 'the' 'airlin' 'regard' 'entri' 'requir' 'gma' 'news'
# 10   'geneva' 'the' 'world' 'health' 'organ' 'said' 'wednesday' 'it' 'is' 'too' 'earli' 'to' 'lift' 'the' 'highestlevel' 'alert' 'for' 'the' 'crisi' 'with' 'the' 'pandem' 'remain' 'a' 'global' 'health' 'emerg' 'despit' 'recent' 'progress' 'the' 'who' 'is' 'emerg' 'committe' 'on' 'met' 'last' 'week' 'and' 'conclud' 'that' 'the' 'pandem' 'still' 'constitut' 'a' 'public' 'health' 'emerg' 'of' 'intern' 'concern' 'a' 'statu' 'it' 'declar' 'back' 'in' 'januari' 'who' 'chief' 'tedro' 'told' 'report' 'wednesday' 'that' 'he' 'agre' 'with' 'the' 'committe' 'advic' 'the' 'committe' 'emphas' 'the' 'need' 'to' 'strengthen' 'surveil' 'and' 'expand' 'access' 'to' 'test' 'treatment' 'and' 'vaccin' 'for' 'those' 'most' 'at' 'risk' 'he' 'said' 'speak' 'from' 'the' 'un' 'health' 'agenc' 'headquart' 'in' 'geneva' 'the' 'who' 'first' 'declar' 'the' 'outbreak' 'a' 'on' 'januari' 'when' 'outsid' 'of' 'china' 'fewer' 'than' 'case' 'and' 'no' 'death' 'had' 'been' 'report' 'though' 'it' 'is' 'the' 'mechan' 'for' 'trigger' 'an' 'intern' 'respons' 'to' 'such' 'outbreak' 'it' 'wa' 'onli' 'in' 'march' 'when' 'tedro' 'describ' 'the' 'worsen' 'situat' 'as' 'a' 'pandem' 'that' 'mani' 'countri' 'woke' 'up' 'to' 'the' 'danger' 'sinc' 'the' 'start' 'of' 'the' 'pandem' 'more' 'than' 'million' 'confirm' 'case' 'have' 'been' 'report' 'to' 'who' 'and' 'more' 'than' 'million' 'death' 'although' 'those' 'number' 'are' 'believ' 'to' 'be' 'signific' 'underestim' 'accord' 'to' 'who' 'is' 'global' 'dashboard' 'of' 'the' 'situat' 'new' 'case' 'were' 'report' 'in' 'the' 'previou' 'hour' 'while' 'new' 'death' 'had' 'been' 'report' 'in' 'the' 'past' 'week' 'tedro' 'acknowledg' 'wednesday' 'that' 'the' 'global' 'situat' 'ha' 'obvious' 'improv' 'sinc' 'the' 'pandem' 'began' 'but' 'he' 'warn' 'that' 'the' 'viru' 'continu' 'to' 'chang' 'and' 'there' 'remain' 'mani' 'risk' 'and' 'uncertainti' 'the' 'pandem' 'ha' 'surpris' 'us' 'befor' 'and' 'veri' 'well' 'could' 'again' 'he' 'warn' 'surveil' 'ha' 'declin' 'maria' 'van' 'the' 'who' 'is' 'technic' 'lead' 'agre' 'warn' 'that' 'there' 'were' 'still' 'million' 'of' 'case' 'be' 'report' 'each' 'week' 'but' 'our' 'surveil' 'ha' 'declin' 'thi' 'is' 'make' 'it' 'difficult' 'to' 'get' 'a' 'full' 'overview' 'of' 'the' 'situat' 'and' 'especi' 'of' 'how' 'the' 'viru' 'is' 'mutat' 'she' 'stress' 'that' 'the' 'more' 'thi' 'viru' 'circul' 'the' 'more' 'opportun' 'it' 'ha' 'to' 'chang' 'the' 'variant' 'account' 'for' 'basic' 'all' 'viru' 'sampl' 'that' 'are' 'sequenc' 'with' 'more' 'than' 'of' 'that' 'variant' 'record' 'all' 'of' 'the' 'of' 'are' 'show' 'increas' 'transmiss' 'and' 'properti' 'of' 'immun' 'escap' 'van' 'said' 'ad' 'that' 'one' 'new' 'combin' 'of' 'two' 'differ' 'wa' 'show' 'signific' 'immun' 'evas' 'thi' 'is' 'a' 'concern' 'for' 'us' 'becaus' 'we' 'need' 'to' 'ensur' 'that' 'the' 'vaccin' 'that' 'are' 'in' 'use' 'worldwid' 'remain' 'effect' 'at' 'prevent' 'sever' 'diseas' 'and' 'death' 'she' 'said' 'in' 'light' 'of' 'the' 'broad' 'spread' 'of' 'new' 'van' 'stress' 'that' 'countri' 'need' 'to' 'be' 'in' 'a' 'posit' 'to' 'conduct' 'surveil' 'to' 'deal' 'with' 'increas' 'in' 'case' 'and' 'perhap' 'deal' 'with' 'increas' 'in' 'hospit' 'we' 'have' 'to' 'remain' 'vigil' 'afp'
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'citi' 'philippin' 'heavili' 'arm' 'men' 'brutal' 'kill' 'a' 'villag' 'chief' 'and' 'four' 'of' 'hi' 'love' 'one' 'in' 'a' 'coldblood' 'ambush' 'in' 'del' 'nort' 'provinc' 'on' 'thursday' 'afternoon' 'januari' 'the' 'attack' 'which' 'also' 'left' 'two' 'other' 'wound' 'took' 'place' 'in' 'the' 'remot' 'villag' 'of' 'locat' 'approxim' 'kilomet' 'southwest' 'of' 'citi' 'as' 'fear' 'and' 'uncertainti' 'spread' 'throughout' 'the' 'commun' 'militari' 'and' 'polic' 'forc' 'were' 'swiftli' 'deploy' 'to' 'the' 'predominantli' 'muslim' 'town' 'of' 'in' 'del' 'nort' '3rd' 'district' 'in' 'a' 'bid' 'to' 'prevent' 'ani' 'further' 'act' 'of' 'violenc' 'or' 'retali' 'accord' 'to' 'polic' 'report' 'the' 'arm' 'group' 'target' 'chairman' 'ali' 'and' 'hi' 'famili' 'member' 'in' 'a' 'ruthless' 'assault' 'that' 'shook' 'the' 'commun' 'to' 'it' 'core' 'the' 'villag' 'chief' 'alongsid' 'hi' 'wife' 'ani' 'and' 'were' 'brutal' 'kill' 'in' 'the' 'attack' 'colonel' 'glenn' 'command' 'of' 'the' 'del' 'nort' 'polic' 'provinci' 'command' 'said' 'two' 'other' 'in' 'the' 'chairman' 'group' 'and' 'norman' 'surviv' 'the' 'ambush' 'the' 'victim' 'were' 'travel' 'in' 'a' 'pickup' 'truck' 'that' 'wa' 'riddl' 'with' 'bullet' 'on' 'a' 'road' 'in' 'indic' 'that' 'the' 'attack' 'use' 'highpow' 'firearm' 'and' 'plan' 'to' 'kill' 'everyon' 'insid' 'said' 'investig' 'have' 'theoriz' 'that' 'the' 'ambush' 'wa' 'carri' 'out' 'by' 'a' 'group' 'with' 'an' 'old' 'grudg' 'against' 'the' 'villag' 'chief' 'of' 'nearbi' 'in' 'the' 'tragic' 'incid' 'prompt' 'a' 'rapid' 'respons' 'from' 'troop' 'from' 'the' 'armi' '42nd' 'infantri' 'battalion' 'the' 'philippin' 'nation' 'polic' 'region' 'mobil' 'forc' 'battalion' 'and' 'the' 'town' 'polic' 'who' 'step' 'up' 'secur' 'measur' 'in' 'the' 'town' 'and' 'launch' 'pursuit' 'oper' 'to' 'track' 'down' 'the' 'perpetr' 'of' 'thi' 'heinou' 'crime'
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'interior' 'and' 'local' 'govern' 'secretari' 'on' 'wednesday' 'order' 'an' 'investig' 'into' 'the' 'death' 'of' 'a' 'student' 'who' 'wa' 'found' 'in' 'a' 'shallow' 'grave' 'in' 'imu' 'to' 'at' 'kung' 'ano' 'ang' 'circumst' 'ani' 'form' 'of' 'violenc' 'na' 'ang' 'ito' 'he' 'told' 'report' 'in' 'an' 'ambush' 'interview' 'we' 'will' 'investig' 'it' 'immedi' 'and' 'look' 'into' 'the' 'circumst' 'here' 'ani' 'form' 'of' 'violenc' 'that' 'lead' 'to' 'death' 'should' 'be' 'investig' 'immedi' 'on' 'tuesday' 'the' 'bodi' 'of' 'john' 'matthew' 'a' 'student' 'at' 'univers' 'in' 'manila' 'wa' 'found' 'more' 'than' 'a' 'week' 'after' 'he' 'wa' 'last' 'seen' 'aliv' 'polic' 'said' 'suspect' 'whom' 'they' 'invit' 'for' 'investig' 'point' 'to' 'where' 'had' 'been' 'buri' 'bodi' 'show' 'sign' 'of' 'haze' 'accord' 'to' 'polic' 'act' 'chief' 'polic' 'lieuten' 'colonel' 'sa' 'statement' 'ng' 'ate' 'wit' 'ng' 'ang' 'sa' 'he' 'said' 'asid' 'from' 'the' 'statement' 'of' 'our' 'wit' 'we' 'saw' 'that' 'the' 'victim' 'had' 'bruis' 'on' 'hi' 'leg' 'howev' 'polic' 'are' 'still' 'await' 'the' 'result' 'of' 'the' 'autopsi' 'examin' 'fifteen' 'person' 'of' 'interest' 'are' 'be' 'investig' 'seven' 'of' 'whom' 'took' 'part' 'in' 'the' 'gamma' 'initi' 'rite' 'for' 'said' 'val' 'gma' 'integr' 'news'
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               'six' 'offici' 'of' 'the' 'philippin' 'nation' 'polic' 'pnp' 'drug' 'enforc' 'group' 'special' 'oper' 'unit' 'were' 'reliev' 'from' 'their' 'post' 'in' 'the' 'offici' 'were' 'face' 'alleg' 'of' 'kidnap' 'and' 'tortur' 'accord' 'to' 'jun' 'report' 'on' 'wednesday' 'yun' 'reliev' 'ni' 'director' 'yun' 'in' 'fair' 'to' 'them' 'alleg' 'yun' 'polic' 'colonel' 'martinez' 'deputi' 'director' 'for' 'administr' 'said' 'base' 'on' 'the' 'report' 'the' 'complain' 'said' 'that' 'they' 'were' 'forc' 'to' 'ride' 'the' 'oper' 'vehicl' 'and' 'were' 'taken' 'to' 'the' 'headquart' 'of' 'the' 'where' 'they' 'were' 'allegedli' 'tortur' 'pnp' 'chief' 'polic' 'gener' 'benjamin' 'jr' 'maintain' 'that' 'misconduct' 'will' 'not' 'be' 'toler' 'under' 'hi' 'leadership' 'he' 'also' 'urg' 'the' 'public' 'that' 'there' 'is' 'no' 'reason' 'for' 'them' 'to' 'be' 'afraid' 'to' 'report' 'ani' 'misconduct' 'to' 'the' 'polic' 'thi' 'kind' 'of' 'case' 'is' 'just' 'a' 'manifest' 'na' 'ate' 'will' 'and' 'kung' 'ano' 'ang' 'he' 'said' 'at' 'least' 'offici' 'have' 'been' 'reliev' 'from' 'their' 'post' 'due' 'to' 'drug' 'raid' 'in' 'manila' 'indepth' 'background' 'investig' 'were' 'conduct' 'among' 'the' 'agenc' 'over' 'personnel' 'kung' 'may' 'ka' 'sa' 'background' 'investig' 'na' 'continu' 'then' 'you' 'will' 'be' 'reliev' 'from' 'with' 'the' 'purpos' 'of' 'na' 'ang' 'martinez' 'gma' 'integr' 'news'
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'presid' 'ferdinand' 'marco' 'jr' 'ha' 'reconstitut' 'the' 'sugar' 'regulatori' 'administr' 'govern' 'bodi' 'with' 'three' 'new' 'appointe' 'the' 'appoint' 'were' 'made' 'on' 'the' 'heel' 'of' 'the' 'controversi' 'order' 'author' 'the' 'import' 'of' 'metric' 'ton' 'of' 'sugar' 'which' 'wa' 'later' 'on' 'declar' 'illeg' 'and' 'thumb' 'down' 'by' 'the' 'chief' 'execut' 'marco' 'appoint' 'david' 'john' 'p' 'as' 'act' 'administr' 'of' 'the' 'accord' 'to' 'a' 'report' 'on' 'staterun' 'replac' 'former' 'administr' 'who' 'resign' 'from' 'hi' 'post' 'amid' 'the' 'controversi' 'involv' 'sugar' 'order' 'no' 'so' 'the' 'said' 'order' 'wa' 'deem' 'illeg' 'as' 'the' 'sugar' 'regulatori' 'board' 'conven' 'and' 'issu' 'a' 'resolut' 'without' 'the' 'approv' 'of' 'marco' 'who' 'as' 'the' 'concurr' 'secretari' 'of' 'the' 'depart' 'of' 'agricultur' 'is' 'chairman' 'of' 'the' 'sugar' 'board' 'meanwhil' 'other' 'sugar' 'regulatori' 'board' 'member' 'are' 'pablo' 'lui' 's' 'replac' 'sugar' 'planter' 'repres' 'gerardo' 'jr' 'and' 'ma' 'v' 'replac' 'sugar' 'miller' 'repres' 'atti' 'roland' 'who' 'resign' 'for' 'health' 'reason' 'the' 'is' 'a' 'governmentown' 'and' 'control' 'corpor' 'attach' 'to' 'the' 'da' 'establish' 'in' 'by' 'virtu' 'of' 'execut' 'order' 'no' 'it' 'is' 'mandat' 'to' 'promot' 'the' 'growth' 'and' 'develop' 'of' 'the' 'sugar' 'industri' 'through' 'greater' 'and' 'signific' 'particip' 'of' 'the' 'privat' 'sector' 'and' 'to' 'improv' 'the' 'work' 'condit' 'of' 'labor' 'the' 'agenc' 'concentr' 'it' 'effort' 'on' 'effect' 'discharg' 'regulatori' 'research' 'and' 'develop' 'rd' 'and' 'socioeconom' 'activ' 'such' 'as' 'the' 'livelihood' 'program' 'for' 'the' 'sugar' 'worker' 'the' 'sugar' 'regulatori' 'board' 'is' 'the' 'govern' 'bodi' 'of' 'the' 'kg' 'gma' 'news'
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'the' 'hous' 'committe' 'on' 'appropri' 'on' 'wednesday' 'termin' 'the' 'hear' 'for' 'the' 'propos' 'billion' 'budget' 'of' 'the' 'depart' 'of' 'justic' 'doj' 'and' 'it' 'attach' 'agenc' 'for' 'the' 'year' 'repres' 'initi' 'move' 'to' 'termin' 'the' 'deliber' 'without' 'ani' 'say' 'member' 'may' 'ask' 'their' 'question' 'dure' 'the' 'plenari' 'deliber' 'howev' 'the' 'hear' 'wa' 'onli' 'termin' 'after' 'act' 'teacher' 'repres' 'franc' 'castro' 'question' 'and' 'ask' 'the' 'doj' 'for' 'updat' 'on' 'the' 'bloodi' 'sunday' 'and' 'extrajudici' 'kill' 'the' 'doj' 'and' 'it' 'attach' 'agenc' 'ask' 'for' 'a' 'billion' 'budget' 'lower' 'than' 'it' 'budget' 'under' 'the' 'gener' 'appropri' 'act' 'of' 'billion' 'doj' 'financi' 'servic' 'director' 'maria' 'said' 'the' 'propos' 'budget' 'of' 'the' 'doj' 'is' 'onli' 'or' 'half' 'of' 'the' 'total' 'nation' 'budget' 'of' 'p5' 'trillion' 'said' 'of' 'the' 'budget' 'would' 'go' 'to' 'person' 'servic' 'includ' 'salari' 'and' 'other' 'compens' 'for' 'employe' 'will' 'go' 'to' 'mainten' 'and' 'oper' 'expens' 'and' 'will' 'go' 'to' 'capit' 'outlay' 'meanwhil' 'accord' 'to' 'justic' 'undersecretari' 'three' 'of' 'the' 'top' 'agenc' 'in' 'the' 'countri' 'are' 'under' 'the' 'doj' 'these' 'are' 'the' 'land' 'registr' 'author' 'which' 'contribut' 'to' 'the' 'coffer' 'of' 'govern' 'approxim' 'billion' 'the' 'bureau' 'of' 'immigr' 'which' 'contribut' 'around' 'billion' 'and' 'the' 'which' 'contribut' 'million' 'the' 'million' 'he' 'said' 'gma' 'news'
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   'presid' 'ferdinand' 'marco' 'jr' 'vow' 'to' 'provid' 'hous' 'for' 'soldier' 'and' 'policemen' 'accord' 'to' 'the' 'presidenti' 'commun' 'offic' 'on' 'tuesday' 'we' 'have' 'begun' 'to' 'craft' 'the' 'program' 'for' 'the' 'hous' 'of' 'the' 'uniform' 'personnel' 'the' 'policemen' 'and' 'the' 'militari' 'we' 'have' 'to' 'develop' 'the' 'concept' 'further' 'but' 'i' 'am' 'determin' 'to' 'provid' 'the' 'hous' 'for' 'our' 'uniform' 'personnel' 'we' 'will' 'not' 'stop' 'until' 'we' 'are' 'abl' 'to' 'do' 'that' 'marco' 'said' 'the' 'presid' 'said' 'there' 'is' 'avail' 'land' 'for' 'the' 'program' 'and' 'the' 'govern' 'ha' 'just' 'to' 'work' 'on' 'a' 'scheme' 'to' 'get' 'other' 'onboard' 'marco' 'issu' 'the' 'remark' 'after' 'hi' 'meet' 'with' 'philippin' 'nation' 'polic' 'pnp' 'chief' 'polic' 'gener' 'jr' 'arm' 'forc' 'of' 'the' 'philippin' 'afp' 'chief' 'of' 'staff' 'gener' 'andr' 'human' 'settlement' 'secretari' 'jose' 'and' 'governor' 'at' 'the' 'palac' 'marco' 'earlier' 'led' 'site' 'inspect' 'and' 'launch' 'differ' 'hous' 'project' 'in' 'metro' 'manila' 'and' 'other' 'provinc' 'hi' 'administr' 'hous' 'program' 'aim' 'to' 'address' 'the' 'hous' 'backlog' 'in' 'the' 'countri' 'at' 'more' 'than' 'million' 'unit' 'the' 'said' 'val' 'gma' 'integr' 'news'
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'us' 'secret' 'servic' 'offic' 'fatal' 'shot' 'an' 'intrud' 'at' 'the' 'peruvian' 'ambassador' 'resid' 'in' 'dc' 'after' 'a' 'confront' 'on' 'wednesday' 'morn' 'follow' 'a' 'report' 'burglari' 'attempt' 'author' 'said' 'the' 'ambassador' 'de' 'and' 'hi' 'famili' 'were' 'at' 'home' 'at' 'the' 'time' 'but' 'neither' 'they' 'nor' 'their' 'staff' 'were' 'injur' 'said' 'the' 'peruvian' 'embassi' 'press' 'counselor' 'uniform' 'secret' 'servic' 'offic' 'respond' 'to' 'a' 'report' 'of' 'a' 'burglari' 'in' 'progress' 'shortli' 'befor' 'am' 'edt' 'gmt' 'polic' 'chief' 'robert' 'said' 'they' 'found' 'a' 'man' 'in' 'hi' '20' 'or' '30' 'carri' 'a' 'metal' 'stake' 'at' 'the' 'rear' 'of' 'the' 'hous' 'where' 'sever' 'window' 'had' 'been' 'smash' 'offic' 'initi' 'tri' 'to' 'stop' 'the' 'man' 'with' 'taser' 'but' 'when' 'he' 'approach' 'the' 'offic' 'with' 'the' 'metal' 'stake' 'they' 'began' 'fire' 'shot' 'said' 'two' 'offic' 'fire' 'their' 'weapon' 'he' 'said' 'the' 'peruvian' 'embassi' 'confirm' 'there' 'wa' 'damag' 'done' 'to' 'the' 'properti' 'but' 'offer' 'no' 'detail' 'beyond' 'the' 'polic' 'account' 'the' 'man' 'wa' 'not' 'identifi' 'and' 'it' 'wa' 'unclear' 'whether' 'he' 'knew' 'the' 'home' 'belong' 'to' 'a' 'foreign' 'diplomat' 'polic' 'are' 'investig' 'who' 'the' 'intrud' 'wa' 'and' 'whi' 'the' 'ambassador' 'home' 'wa' 'target' 'said' 'there' 'wa' 'no' 'indic' 'he' 'wa' 'known' 'to' 'law' 'enforc' 'violenc' 'at' 'embassi' 'is' 'rare' 'in' 'we' 'do' 'not' 'see' 'these' 'type' 'of' 'incid' 'around' 'here' 'said' 'thi' 'is' 'total' 'out' 'of' 'the' 'ordinari' 'offic' 'with' 'the' 'secret' 'servic' 'uniform' 'divis' 'protect' 'more' 'than' 'foreign' 'diplomat' 'mission' 'in' 'the' 'us' 'capit' 'reuter'
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   'the' 'bureau' 'of' 'immigr' 'bi' 'arrest' 'and' 'set' 'to' 'deport' 'a' 'chines' 'nation' 'who' 'wa' 'be' 'search' 'by' 'author' 'for' 'allegedli' 'misrepres' 'himself' 'as' 'a' 'filipino' 'suspect' 'tai' 'wa' 'nab' 'in' 'manila' 'on' 'tuesday' 'may' 'after' 'a' 'warrant' 'of' 'deport' 'wa' 'issu' 'against' 'him' 'in' 'juli' 'last' 'year' 'for' 'be' 'an' 'undesir' 'alien' 'tai' 'allegedli' 'assum' 'the' 'name' 'of' 'one' 'albert' 'torr' 'and' 'ha' 'been' 'use' 'the' 'fictiti' 'ident' 'in' 'file' 'incorpor' 'paper' 'acquir' 'a' 'driver' 'licens' 'regist' 'hi' 'busi' 'as' 'well' 'as' 'in' 'other' 'public' 'document' 'accord' 'to' 'the' 'immigr' 'bureau' 'the' 'suspect' 'is' 'current' 'detain' 'at' 'the' 'bi' 'facil' 'in' 'pend' 'hi' 'deport' 'he' 'will' 'also' 'be' 'includ' 'in' 'the' 'countri' 'immigr' 'blacklist' 'which' 'will' 'perpetu' 'ban' 'him' 'from' 'enter' 'the' 'philippin' 'alien' 'who' 'flaunt' 'and' 'make' 'a' 'mockeri' 'of' 'our' 'immigr' 'and' 'citizenship' 'law' 'do' 'not' 'deserv' 'the' 'privileg' 'to' 'stay' 'here' 'they' 'should' 'be' 'expel' 'and' 'ban' 'from' 'reenter' 'the' 'countri' 'bi' 'commission' 'norman' 'said' 'in' 'a' 'gma' 'integr' 'news'
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'a' 'famili' 'of' 'five' 'die' 'after' 'a' 'fire' 'hit' 'their' 'resid' 'in' 'on' 'monday' 'accord' 'to' 'clair' 'report' 'on' 'gma' 'region' 'tv' 'one' 'north' 'central' 'the' 'fire' 'spread' 'to' 'three' 'hous' 'in' 'the' 'fire' 'reach' 'the' 'second' 'alarm' 'and' 'last' 'for' 'over' 'two' 'hour' 'the' 'famili' 'trap' 'in' 'the' 'fire' 'includ' 'the' 'coupl' 'and' 'their' 'children' 'age' 'six' 'three' 'and' 'one' 'origin' 'at' 'becaus' 'of' 'fire' 'kung' 'sa' 'electr' 'said' 'randi' 'fire' 'station' 'marshal' 'the' 'estim' 'damag' 'of' 'the' 'fire' 'amount' 'to' 'million' 'the' 'said' 'it' 'is' 'still' 'conduct' 'an' 'indepth' 'investig' 'to' 'determin' 'the' 'becaus' 'of' 'the' 'fire' 'gma' 'integr' 'news'
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'the' 'number' 'of' 'dengu' 'case' 'continu' 'to' 'increas' 'in' 'nine' 'out' 'of' 'the' 'philippin' 'region' 'depart' 'of' 'health' 'offic' 'in' 'charg' 'ma' 'rosario' 'said' 'on' 'friday' 'in' 'a' 'statement' 'on' 'saturday' 'the' 'doh' 'said' 'the' 'nine' 'region' 'that' 'have' 'recent' 'exceed' 'the' 'threshold' 'in' 'the' 'past' 'four' 'week' 'are' 'valley' 'central' 'western' 'central' 'peninsula' 'administr' 'region' 'and' 'nation' 'capit' 'region' 'accord' 'to' 'the' 'countri' 'log' 'dengu' 'case' 'base' 'on' 'report' 'from' 'juli' 'to' 'juli' 'she' 'said' 'or' 'of' 'the' 'dengu' 'case' 'had' 'been' 'hospit' 'kaya' 'sa' 'ate' 'said' 'po' 'sa' 'strategi' 'seek' 'earli' 'consult' 'kung' 'po' 'ang' 'ng' 'dengu' 'hindi' 'po' 'ma' 'ang' 'tao' 'may' 'dengu' 'she' 'ad' 'that' 'is' 'whi' 'we' 'are' 'remind' 'the' 'public' 'seek' 'earli' 'consult' 'is' 'part' 'of' 'the' 'strategi' 'so' 'we' 'can' 'address' 'the' 'symptom' 'of' 'dengu' 'you' 'do' 'not' 'need' 'to' 'get' 'hospit' 'becaus' 'of' 'dengu' 'the' 'strategi' 'is' 'to' 'search' 'and' 'destroy' 'breed' 'place' 'secur' 'seek' 'earli' 'consult' 'and' 'support' 'in' 'hotspot' 'area' 'she' 'urg' 'the' 'public' 'to' 'consult' 'health' 'center' 'immedi' 'upon' 'experienc' 'dengu' 'symptom' 'such' 'as' 'a' 'fever' 'for' 'two' 'day' 'or' 'more' 'libr' 'po' 'ang' 'dengu' 'test' 'kit' 'sa' 'ate' 'facil' 'para' 'lang' 'na' 'said' 'dengu' 'test' 'kit' 'are' 'free' 'in' 'our' 'facil' 'so' 'we' 'can' 'ensur' 'that' 'we' 'do' 'not' 'have' 'them' 'further' 'she' 'said' 'the' 'agenc' 'ha' 'download' 'fund' 'to' 'hospit' 'for' 'addit' 'resourc' 'in' 'case' 'of' 'an' 'increas' 'in' 'dengu' 'admiss' 'the' 'doh' 'previous' 'said' 'it' 'record' 'a' 'total' 'of' 'dengu' 'case' 'from' 'januari' 'to' 'juli' 'which' 'is' 'higher' 'than' 'those' 'record' 'dure' 'the' 'same' 'period' 'in' 'gma' 'news'
# ...
# 79                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'two' 'minor' 'be' 'prostitut' 'were' 'rescu' 'by' 'oper' 'in' 'a' 'sting' 'oper' 'which' 'led' 'to' 'the' 'arrest' 'of' 'one' 'of' 'their' 'pimp' 'dure' 'the' 'oper' 'the' 'pimp' 'brought' 'along' 'with' 'her' 'two' 'minor' 'femal' 'age' 'and' 'to' 'a' 'vehicl' 'where' 'two' 'undercov' 'oper' 'were' 'seat' 'the' 'transact' 'took' 'place' 'insid' 'the' 'vehicl' 'where' 'the' 'oper' 'bargain' 'for' 'a' 'cheaper' 'price' 'as' 'they' 'earlier' 'agre' 'to' 'pay' 'for' 'three' 'femal' 'but' 'onli' 'two' 'arriv' 'the' 'pimp' 'wa' 'arrest' 'as' 'she' 'exit' 'the' 'vehicl' 'accord' 'to' 'citi' 'polic' 'district' 'station' 'investig' 'chief' 'anthoni' 'the' 'suspect' 'is' 'part' 'of' 'a' 'group' 'that' 'prostitut' 'children' 'ang' 'transact' 'is' 'onlin' 'group' 'group' 'chat' 'para' 'sa' 'ng' 'prostitut' 'sa' 'minor' 'he' 'said' 'in' 'a' 'report' 'on' 'gma' 'weekend' 'on' 'sunday' 'their' 'transact' 'are' 'done' 'onlin' 'they' 'have' 'a' 'group' 'a' 'group' 'chat' 'for' 'the' 'transact' 'where' 'they' 'prostitut' 'minor' 'one' 'of' 'the' 'father' 'of' 'the' 'minor' 'said' 'the' 'child' 'told' 'him' 'she' 'wa' 'go' 'to' 'attend' 'a' 'birthday' 'parti' 'and' 'he' 'did' 'not' 'know' 'that' 'she' 'wa' 'instead' 'be' 'prostitut' 'hindi' 'ko' 'po' 'na' 'po' 'ang' 'rin' 'po' 'nasa' 'din' 'po' 'eh' 'ko' 'lang' 'din' 'po' 'din' 'na' 'na' 'he' 'said' 'i' 'did' 'not' 'know' 'that' 'that' 'is' 'what' 'happen' 'i' 'am' 'alway' 'in' 'work' 'and' 'i' 'just' 'knew' 'of' 'thi' 'now' 'that' 'she' 'is' 'be' 'prostitut' 'the' 'oper' 'also' 'nab' 'the' 'driver' 'of' 'the' 'use' 'by' 'the' 'pimp' 'and' 'oper' 'who' 'deni' 'ani' 'knowledg' 'in' 'the' 'activ' 'servic' 'ko' 'lang' 'po' 'yan' 'sir' 'lang' 'po' 'yan' 'sa' 'akin' 'sir' 'he' 'said' 'that' 'wa' 'just' 'a' 'servic' 'they' 'just' 'hire' 'my' 'the' 'suspect' 'will' 'face' 'charg' 'of' 'child' 'traffick' 'and' 'child' 'abus' 'for' 'hi' 'part' 'urg' 'parent' 'to' 'keep' 'an' 'eye' 'on' 'their' 'children' 'and' 'monitor' 'their' 'activ' 'on' 'their' 'devic' 'jon' 'viktor' 'd' 'gma' 'news'
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'a' 'famili' 'in' 'wa' 'shock' 'to' 'see' 'that' 'their' 'electr' 'bill' 'ha' 'reach' 'million' 'in' 'a' 'report' 'by' 'gma' 'region' 'tv' 'one' 'north' 'central' 'antonio' 'said' 'that' 'from' 'their' 'averag' 'monthli' 'bill' 'of' 'around' 'they' 'now' 'to' 'pay' 'reaction' 'ko' 'din' 'ng' 'tao' 'lang' 'po' 'mo' 'she' 'said' 'din' 'po' 'ang' 'number' 'po' 'million' 'po' 'she' 'ad' 'antonio' 'immedi' 'went' 'to' 'the' 'central' 'electr' 'cooper' 'offic' 'to' 'complain' 'about' 'the' 'bill' 'clarifi' 'that' 'there' 'an' 'error' 'in' 'the' 'meter' 'read' 'it' 'apolog' 'to' 'the' 'famili' 'and' 'said' 'it' 'would' 'conduct' 'anoth' 'read' 'to' 'updat' 'the' 'famili' 'electr' 'bill' 'hindi' 'o' 'hindi' 'meter' 'reader' 'na' 'ng' 'error' 'sa' 'ng' 'number' 'ng' 'gener' 'manag' 'rod' 'said' 'howev' 'accord' 'to' 'antonio' 'recent' 'post' 'she' 'discov' 'that' 'the' 'meter' 'read' 'went' 'wrong' 'again' 'antonio' 'appeal' 'to' 'to' 'fix' 'the' 'read' 'and' 'bill' 'befor' 'distribut' 'the' 'bill' 'to' 'gma' 'news'
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'the' 'depart' 'of' 'educ' 'is' 'final' 'the' 'guidelin' 'for' 'the' 'start' 'of' 'a' 'nation' 'learn' 'camp' 'on' 'juli' 'spokesperson' 'michael' 'said' 'friday' 'we' 'are' 'hope' 'to' 'releas' 'those' 'guidelin' 'as' 'soon' 'as' 'possibl' 'sad' 'in' 'an' 'interview' 'on' 'b' 'tv' 'the' 'nation' 'learn' 'camp' 'is' 'a' 'part' 'of' 'nation' 'learn' 'recoveri' 'program' 'that' 'aim' 'to' 'help' 'the' 'student' 'catch' 'up' 'with' 'the' 'learn' 'loss' 'dure' 'the' 'height' 'of' 'the' 'pandem' 'where' 'school' 'are' 'close' 'down' 'thi' 'camp' 'featur' 'intervent' 'enrich' 'and' 'remedi' 'he' 'ad' 'come' 'out' 'of' 'the' 'learn' 'loss' 'learn' 'gap' 'ang' 'po' 'sa' 'summer' 'class' 'hindi' 'lang' 'ito' 'para' 'sa' 'o' 'para' 'sa' 'ang' 'grade' 'po' 'na' 'sa' 'ate' 'learn' 'camp' 'said' 'voluntari' 'the' 'offici' 'emphas' 'that' 'the' 'nation' 'learn' 'camp' 'is' 'voluntari' 'for' 'student' 'and' 'teacher' 'as' 'well' 'while' 'it' 'is' 'voluntari' 'said' 'student' 'who' 'have' 'low' 'grade' 'are' 'highli' 'encourag' 'to' 'particip' 'as' 'thi' 'might' 'affect' 'their' 'promot' 'to' 'the' 'next' 'grade' 'level' 'for' 'teacher' 'who' 'will' 'volunt' 'in' 'the' 'program' 'said' 'they' 'will' 'be' 'given' 'addit' 'leav' 'credit' 'these' 'leav' 'credit' 'will' 'be' 'count' 'even' 'if' 'their' 'servic' 'credit' 'is' 'limit' 'to' 'day' 'may' 'rule' 'ang' 'way' 'back' 'in' 'na' 'may' 'limit' 'na' 'day' 'lang' 'ang' 'na' 'servic' 'credit' 'ng' 'ate' 'ito' 'pong' 'sa' 'learn' 'camp' 'is' 'over' 'and' 'abov' 'limit' 'na' 'so' 'hindi' 'po' 'na' 'day' 'he' 'said' 'apart' 'from' 'thi' 'said' 'the' 'is' 'eye' 'to' 'give' 'free' 'meal' 'for' 'teacher' 'who' 'will' 'volunt' 'in' 'the' 'said' 'camp' 'mass' 'promot' 'in' 'the' 'same' 'interview' 'said' 'the' 'ha' 'no' 'polici' 'on' 'alleg' 'mass' 'promot' 'of' 'student' 'ho' 'polici' 'sa' 'there' 'is' 'no' 'issuanc' 'that' 'even' 'allow' 'mass' 'promot' 'but' 'we' 'do' 'understand' 'na' 'sa' 'field' 'and' 'that' 'is' 'whi' 'that' 'is' 'someth' 'that' 'we' 'are' 'look' 'into' 'in' 'term' 'of' 'ano' 'ba' 'he' 'said' 'one' 'of' 'the' 'thing' 'that' 'they' 'are' 'look' 'at' 'is' 'how' 'thi' 'mass' 'promot' 'is' 'tie' 'to' 'the' 'teacher' 'perform' 'rate' 'he' 'said' 'we' 'are' 'check' 'if' 'ito' 'tie' 'sa' 'let' 'us' 'say' 'perform' 'rate' 'ng' 'teacher' 'kaya' 'ng' 'na' 'na' 'lang' 'kung' 'hindi' 'ang' 'perform' 'rate' 'and' 'these' 'are' 'thing' 'that' 'we' 'want' 'to' 'revis' 'he' 'said' 'said' 'mass' 'promot' 'is' 'detriment' 'to' 'the' 'learner' 'gma' 'integr' 'news'
# 100                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'onlin' 'channel' 'of' 'the' 'social' 'secur' 'system' 'were' 'temporarili' 'unavail' 'as' 'of' 'monday' 'follow' 'a' 'fire' 'that' 'hit' 'the' 'agenc' 'facil' 'over' 'the' 'weekend' 'in' 'an' 'advisori' 'the' 'said' 'it' 'onlin' 'platform' 'it' 'offici' 'websit' 'the' 'mobil' 'applic' 'and' 'the' 'portal' 'were' 'unavail' 'as' 'oper' 'were' 'affect' 'by' 'the' 'recent' 'fire' 'fire' 'broke' 'out' 'at' 'the' 'electr' 'room' 'of' 'the' 'main' 'offic' 'build' 'of' 'the' 'along' 'east' 'avenu' 'in' 'citi' 'earli' 'sunday' 'morn' 'it' 'hit' 'the' 'first' 'alarm' 'befor' 'a' 'call' 'wa' 'declar' 'the' 'fire' 'start' 'at' 'am' 'on' 'sunday' 'august' 'firefight' 'declar' 'the' 'fire' 'under' 'control' 'at' 'am' 'and' 'wa' 'put' 'out' 'about' 'am' 'stakehold' 'are' 'assur' 'that' 'all' 'member' 'data' 'record' 'were' 'not' 'affect' 'by' 'the' 'incid' 'the' 'advisori' 'read' 'the' 'ask' 'for' 'their' 'patienc' 'and' 'understand' 'while' 'all' 'effort' 'are' 'be' 'made' 'to' 'restor' 'the' 'avail' 'of' 'it' 'onlin' 'servic' 'as' 'soon' 'as' 'possibl' 'it' 'ad' 'the' 'did' 'not' 'elabor' 'on' 'the' 'timelin' 'for' 'the' 'interrupt' 'but' 'said' 'that' 'a' 'separ' 'advisori' 'will' 'be' 'releas' 'onc' 'oper' 'resum' 'urgent' 'queri' 'and' 'concern' 'may' 'be' 'sent' 'to' 'the' 'offici' 'email' 'and' 'social' 'account' 'in' 'the' 'meantim' 'the' 'agenc' 'is' 'mandat' 'to' 'provid' 'social' 'justic' 'and' 'provid' 'protect' 'to' 'member' 'and' 'their' 'famili' 'against' 'the' 'hazard' 'of' 'disabl' 'sick' 'matern' 'old' 'age' 'death' 'and' 'other' 'conting' 'result' 'in' 'loss' 'of' 'incom' 'or' 'financi' 'burden' 'gma' 'news'
#
#      Predikció valószínűsége
# 4                     0.2824
# 8                     0.0002
# 10                    0.2295
# 12                    0.0915
# 15                    0.0251
# 23                    0.0215
# 24                    0.0040
# 34                    0.0696
# 38                    0.0201
# 46                    0.0008
# 51                    0.0034
# 57                    0.0008
# 59                    0.0317
# 71                    0.0006
# 77                    0.0103
# 78                    0.9620
# 79                    0.0015
# 82                    0.0002
# 90                    0.0009
# 100                   0.0039

# %% [markdown]
# # Tanulás-validáció-teszt összehasonlítása két modellnél

# %%
test_loss_lstm, test_accuracy_lstm = lstm_trainable.evaluate(padded_test, y_test, verbose=0)
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test, verbose=0)

# Ábra létrehozása két alábrával
plt.figure(figsize=(12, 5))

# Tanulási, validációs és teszthalmaz veszteség ábrázolása
plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='LSTM tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='LSTM validációs veszteség', color='#7fcdbb')
plt.plot(history_gru_trainable.history['loss'], label='GRU tanulási veszteség', color='red')
plt.plot(history_gru_trainable.history['val_loss'], label='GRU validációs veszteség', color='orange')
plt.axhline(y=test_loss_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz veszteség')  # LSTM teszt loss
plt.axhline(y=test_loss_gru, color='red', linestyle='--', label='GRU teszthalmaz veszteség')  # GRU teszt loss
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Ttanulási, validációs és teszthalmaz precízió ábrázolása
if 'accuracy' in lstm_history_trainable.history and 'accuracy' in history_gru_trainable.history:
    plt.subplot(1, 2, 2)
    plt.plot(lstm_history_trainable.history['accuracy'], label='LSTM tanulási pontosság', color='blue')
    plt.plot(lstm_history_trainable.history['val_accuracy'], label='LSTM validációs pontosság', color='#7fcdbb')
    plt.plot(history_gru_trainable.history['accuracy'], label='GRU tanulási pontosság', color='red')
    plt.plot(history_gru_trainable.history['val_accuracy'], label='GRU validációs pontosság', color='orange')
    plt.axhline(y=test_accuracy_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz pontosság')  # LSTM teszt accuracy
    plt.axhline(y=test_accuracy_gru, color='red', linestyle='--', label='GRU teszthalmaz pontosság')  # GRU teszt accuracy
    plt.xlabel('Epizód')
    plt.ylabel('Pontosság')
    plt.legend()
    plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.tight_layout()
plt.show()
