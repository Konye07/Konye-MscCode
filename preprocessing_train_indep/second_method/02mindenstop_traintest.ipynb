# %% [markdown]
# # **Csomagok behívása**

# %%
#Szükséges csomagok és adatbázis importálása
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Concatenate
import numpy as np
import tensorflow as tf
import spacy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fájlok behívása, ellenőrzése és felkészítése

# %%
# Betölteni padded sequences, tokenizer, és számokat
padded_train = np.load('/content/padded_train02.npy')
padded_test = np.load('/content/padded_test02.npy')

# Tokenizer visszatöltése
with open('/content/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Címkék betöltése (real = 1, fake = 0)
train_file = '/content/train_masodik.csv'
test_file = '/content/teszt_masodik.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

labels_train = df_train['label'].values
labels_test = df_test['label'].values

# Betölteni embedding mátrixot
embedding_matrix = np.load('/content/embedding_matrix.npy')

# Ellenőrzés
print(f"Train padded sequences shape: {padded_train.shape}")
print(f"Test padded sequences shape: {padded_test.shape}")
print(f"Train labels shape: {labels_train.shape}")
print(f"Test labels shape: {labels_test.shape}")
# Out:
# Train padded sequences shape: (59520, 600)
# Test padded sequences shape: (14880, 600)
# Train labels shape: (59520,)
# Test labels shape: (14880,)

# %%
# Max szókincs és szekvencia hossz
MAX_VOCAB_SIZE = 25000
MAX_LENGTH = 600
EMBEDDING_DIM = 300  # GloVe 300d

# input shape
MAX_SEQUENCE_LENGTH = padded_train.shape[1]

# Szöveges input (LSTM/GRU bemenet)
text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
embedding_layer = Embedding(
    input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
    output_dim=embedding_matrix.shape[1],
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)(text_input)

model_output = embedding_layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
MAX_SEQUENCE_LENGTH = padded_train.shape[1]  # Train hossz
EMBEDDING_DIM = embedding_matrix.shape[1]  # GloVe embeddings

# 10%-os validációs halmaz leválasztása a tanító adatokból
padded_train_final, padded_val, y_train_final, y_val = train_test_split(
    padded_train, labels_train, test_size=0.1, random_state=42
)
# Float32-re konvertálás TensorFlow kompatibilitás miatt
padded_train_final = np.array(padded_train_final, dtype=np.float32)
padded_val = np.array(padded_val, dtype=np.float32)
padded_test = np.array(padded_test, dtype=np.float32)
y_train_final = np.array(y_train_final, dtype=np.float32)
y_val = np.array(y_val, dtype=np.float32)
y_test = np.array(labels_test, dtype=np.float32)

# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# # LSTM MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ## Modell lefuttatása

# %%
# LSTM modell, trainable, non-trainable embedding

def create_lstm_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings
    )(text_input)

    # LSTM rétegek
    lstm_out = LSTM(128, return_sequences=True, dropout=0.3)(text_embedding)
    lstm_out = Dropout(0.3)(lstm_out)  # Dropout réteg az első LSTM után
    lstm_out = LSTM(64,return_sequences=True, dropout=0.3)(lstm_out)
    lstm_out = Dropout(0.3)(lstm_out) # Dropout réteg az második LSTM után
    lstm_out = LSTM(32, dropout=0.3)(lstm_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(lstm_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása
lstm_trainable = create_lstm_model(trainable_embeddings=True)  # Trainable embedding

lstm_trainable.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_1 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 600, 128)            │         219,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 600, 64)             │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,781,505 (29.68 MB)
#  Trainable params: 7,781,505 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Modell tanítása a validációs adatok figyelésével
lstm_history_trainable = lstm_trainable.fit(
    padded_train_final, y_train_final,
    validation_data=(padded_val, y_val),  # Validációs halmaz
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság: {test_accuracy:.4f}, Teszthalmaz veszteség: {test_loss:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 75s 81ms/step - accuracy: 0.7769 - loss: 0.4735 - val_accuracy: 0.9051 - val_loss: 0.2946
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 80s 83ms/step - accuracy: 0.8978 - loss: 0.2786 - val_accuracy: 0.9274 - val_loss: 0.1896
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 85s 87ms/step - accuracy: 0.8997 - loss: 0.2647 - val_accuracy: 0.9363 - val_loss: 0.1834
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9538 - loss: 0.1370 - val_accuracy: 0.9540 - val_loss: 0.1411
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 83ms/step - accuracy: 0.9680 - loss: 0.0981 - val_accuracy: 0.9637 - val_loss: 0.1074
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 86ms/step - accuracy: 0.9801 - loss: 0.0626 - val_accuracy: 0.9603 - val_loss: 0.1374
# Epoch 7/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9838 - loss: 0.0517 - val_accuracy: 0.9661 - val_loss: 0.1154
# Epoch 8/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9929 - loss: 0.0276 - val_accuracy: 0.9709 - val_loss: 0.1052
# Epoch 9/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.9946 - loss: 0.0193 - val_accuracy: 0.9578 - val_loss: 0.1174
# Epoch 10/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 69s 83ms/step - accuracy: 0.9936 - loss: 0.0230 - val_accuracy: 0.9689 - val_loss: 0.1258
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9711 - loss: 0.1046
# Teszthalmaz pontosság: 0.9690, Teszthalmaz veszteség: 0.1125

# %%
# Valószínűség becslése
lstm_y_prob = lstm_trainable.predict(padded_test)

lstm_y_pred = (lstm_y_prob > 0.5).astype(int)

lstm_accuracy = accuracy_score(y_test, lstm_y_pred)
lstm_precision = precision_score(y_test, lstm_y_pred)
lstm_recall = recall_score(y_test, lstm_y_pred)
lstm_f1 = f1_score(y_test, lstm_y_pred)

print(f"Accuracy: {lstm_accuracy:.4f}")
print(f"Precision: {lstm_precision:.4f}")
print(f"Recall: {lstm_recall:.4f}")
print(f"F1-score: {lstm_f1:.4f}")
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
# Accuracy: 0.9694
# Precision: 0.9733
# Recall: 0.9652
# F1-score: 0.9692

# %% [markdown]
# ## LSTM Modell ábrák

# %%
import matplotlib.pyplot as plt

# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(lstm_history_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(lstm_history_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9695 - loss: 0.1058

# %%
# Confusion Matrix
cm_lstm = confusion_matrix(y_test, lstm_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_lstm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix LSTM Modellre')
plt.show()

print(classification_report(y_test, lstm_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97      7440
#          1.0       0.97      0.97      0.97      7440
#
#     accuracy                           0.97     14880
#    macro avg       0.97      0.97      0.97     14880
# weighted avg       0.97      0.97      0.97     14880

# %%
# Flatten
y_true = y_test.flatten()
y_pred = lstm_y_pred.flatten()
y_prob = lstm_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás besorolás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás besorolás) LSTM Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": lstm_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = lstm_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_lstm.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 3    Hamis negatív (FN)           1.0                 0
# 41   Hamis negatív (FN)           1.0                 0
# 53   Hamis negatív (FN)           1.0                 0
# 151  Hamis pozitív (FP)           0.0                 1
# 168  Hamis negatív (FN)           1.0                 0
# 217  Hamis negatív (FN)           1.0                 0
# 235  Hamis pozitív (FP)           0.0                 1
# 244  Hamis negatív (FN)           1.0                 0
# 259  Hamis pozitív (FP)           0.0                 1
# 275  Hamis negatív (FN)           1.0                 0
# 290  Hamis pozitív (FP)           0.0                 1
# 297  Hamis pozitív (FP)           0.0                 1
# 338  Hamis negatív (FN)           1.0                 0
# 408  Hamis negatív (FN)           1.0                 0
# 464  Hamis pozitív (FP)           0.0                 1
# 505  Hamis negatív (FN)           1.0                 0
# 507  Hamis pozitív (FP)           0.0                 1
# 601  Hamis negatív (FN)           1.0                 0
# 618  Hamis negatív (FN)           1.0                 0
# 642  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 3                                                                                                              'the' 'australian' 'government' 'have' 'take' 'the' 'lead' 'from' 'president' 'donald' 'trump' 'in' 'the' 'race' 'to' 'improve' 'vetting' 'of' 'immigrant' 'who' 'may' 'hold' 'hostile' 'islamic' 'attitude' 'and' 'to' 'reform' 'program' 'like' 'the' 'outsourcing' 'visa' 'we' 'be' 'define' 'by' 'a' 'commitment' 'to' 'common' 'value' 'political' 'value' 'the' 'rule' 'of' 'law' 'democracy' 'freedom' 'mutual' 'respect' 'equality' 'for' 'men' 'and' 'woman' 'prime' 'minister' 'malcolm' 'turnbull' 'tell' 'the' 'medium' 'on' 'thursday' 'where' 'he' 'describe' 'the' 'vetting' 'process' 'our' 'citizenship' 'process' 'should' 'reflect' 'that' 'so' 'today' 'we' 'be' 'announce' 'change' 'to' 'strengthen' 'citizenship' 'to' 'make' 'for' 'a' 'strong' 'australia' 'strong' 'citizenship' 'strong' 'citizen' 'before' 'you' 'apply' 'to' 'be' 'a' 'citizen' 'you' 'will' 'need' 'to' 'have' 'competent' 'english' 'that' 'be' 'a' 'vital' 'requirement' 'also' 'we' 'need' 'to' 'ensure' 'that' 'our' 'citizenship' 'test' 'enable' 'applicant' 'to' 'demonstrate' 'how' 'they' 'have' 'integrate' 'into' 'and' 'engage' 'with' 'our' 'australian' 'community' 'so' 'that' 'they' 'be' 'part' 'of' 'the' 'community' 'they' 'have' 'live' 'here' 'a' 'a' 'permanent' 'resident' 'for' 'four' 'year' 'they' 'speak' 'english' 'share' 'our' 'value' 'be' 'integrate' 'those' 'be' 'critically' 'important' 'element' 'i' 'believe' 'that' 'they' 'will' 'be' 'empower' 'for' 'applicant' 'this' 'will' 'be' 'good' 'for' 'the' 'applicant' 'good' 'for' 'the' 'nation' 'underline' 'our' 'australian' 'value' 'at' 'the' 'very' 'heart' 'of' 'australian' 'citizenship' 'australian' 'citizenship' 'be' 'the' 'foundation' 'of' 'our' 'democracy' 'these' 'political' 'value' 'be' 'what' 'bind' 'u' 'together' 'that' 'be' 'what' 'keep' 'u' 'together' 'in' 'the' 'midst' 'of' 'our' 'diversity' 'the' 'new' 'australian' 'push' 'be' 'a' 'from' 'when' 'trump' 'champion' 'immigration' 'reform' 'in' 'the' 'united' 'state' 'while' 'turnbull' 'seek' 'to' 'stabilize' 'his' 'government' 'after' 'he' 'stag' 'an' 'internal' 'party' 'vote' 'in' 'september' 'to' 'take' 'the' 'prime' 'minister' 'job' 'from' 'his' 'own' 'partys' 'leader' 'tony' 'abbott' 'an' 'immigration' 'hawk' 'who' 'entirely' 'block' 'and' 'stop' 'a' 'wave' 'of' 'immigrant' 'from' 'reach' 'australia' 'to' 'some' 'extent' 'flip' 'towards' 'position' 'be' 'design' 'to' 'help' 'his' 'wing' 'of' 'the' 'party' 'from' 'wing' 'of' 'the' 'party' 'and' 'from' 'the' 'grow' 'support' 'be' 'give' 'to' 'nationalist' 'one' 'nation' 'party' 'which' 'be' 'skeptical' 'about' 'ability' 'to' 'integrate' 'into' 'australian' 'society' 'in' 'and' 'before' 'turnbull' 'repeatedly' 'endorse' 'immigration' 'invite' 'additional' 'refugee' 'and' 'tell' 'the' 'parliament' 'in' 'october' 'that' 'everyone' 'sit' 'in' 'this' 'chamber' 'and' 'every' 'australian' 'be' 'a' 'beneficiary' 'of' 'the' 'diversity' 'that' 'be' 'at' 'the' 'heart' 'of' 'our' 'nation' 'the' 'most' 'effective' 'weapon' 'against' 'the' 'muslim' 'terrorist' 'be' 'an' 'inclusive' 'nation' 'amid' 'rise' 'violence' 'and' 'welfare' 'use' 'among' 'immigrant' 'muslim' 'a' 'september' 'poll' 'show' 'that' 'half' 'of' 'all' 'australian' 'want' 'to' 'block' 'muslim' 'immigration' 'which' 'be' 'strongly' 'support' 'by' 'business' 'group' 'which' 'profit' 'from' 'the' 'inflow' 'of' 'extra' 'consumer' 'and' 'worker' 'minister' 'for' 'immigration' 'and' 'border' 'protection' 'peter' 'dutton' 'tell' 'reporter' 'at' 'the' 'press' 'conference' 'that' 'immigrant' 'will' 'have' 'to' 'take' 'an' 'write' 'test' 'there' 'will' 'be' 'further' 'test' 'further' 'question' 'place' 'in' 'the' 'test' 'a' 'it' 'currently' 'operate' 'and' 'there' 'will' 'be' 'the' 'opportunity' 'for' 'people' 'to' 'comment' 'on' 'some' 'of' 'these' 'change' 'over' 'the' 'course' 'of' 'the' 'next' 'over' 'the' 'course' 'of' 'the' 'period' 'between' 'now'  ...
# 41                                                                                                                                                                                                                                                                                                                                                                'editor' 'note' 'the' 'following' 'column' 'originally' 'appear' 'on' 'the' 'website' 'u' 'defense' 'watch' 'it' 'be' 'reprint' 'with' 'permission' 'i' 'like' 'million' 'of' 'american' 'saw' 'your' 'speech' 'at' 'the' 'dnc' 'on' 'thursday' 'night' 'i' 'wish' 'to' 'offer' 'my' 'sympathy' 'for' 'the' 'death' 'of' 'your' 'son' 'captain' 'humayun' 'khan' 'who' 'be' 'kill' 'in' 'action' 'in' 'iraq' 'a' 'a' 'former' 'u' 'army' 'officer' 'and' 'a' 'veteran' 'of' 'the' 'gulf' 'war' 'i' 'can' 'certainly' 'understand' 'the' 'pain' 'and' 'anguish' 'that' 'you' 'and' 'your' 'wife' 'endure' 'every' 'day' 'your' 'son' 'die' 'save' 'the' 'life' 'of' 'his' 'fellow' 'soldier' 'a' 'jesus' 'tell' 'his' 'disciple' 'accord' 'to' 'the' 'gospel' 'of' 'john' 'great' 'love' 'no' 'man' 'than' 'this' 'that' 'a' 'man' 'lay' 'down' 'his' 'life' 'for' 'his' 'friend' 'captain' 'khan' 'be' 'a' 'hero' 'i' 'be' 'sure' 'the' 'soldier' 'he' 'serve' 'with' 'regard' 'him' 'a' 'one' 'i' 'know' 'you' 'and' 'your' 'wife' 'do' 'rest' 'assure' 'that' 'million' 'of' 'veteran' 'regard' 'your' 'son' 'a' 'a' 'hero' 'as' 'well' 'to' 'paraphrase' 'from' 'the' 'book' 'of' 'your' 'son' 'name' 'for' 'your' 'son' 'make' 'the' 'ultimate' 'sacrifice' 'for' 'his' 'country' 'a' 'country' 'that' 'be' 'new' 'to' 'you' 'and' 'your' 'family' 'and' 'one' 'which' 'you' 'openly' 'embrace' 'and' 'certainly' 'love' 'when' 'you' 'and' 'your' 'family' 'arrive' 'to' 'america' 'from' 'pakistan' 'you' 'assimilate' 'into' 'our' 'country' 'you' 'adopt' 'american' 'way' 'learn' 'our' 'history' 'and' 'apparently' 'you' 'even' 'acquire' 'a' 'pocket' 'constitution' 'along' 'the' 'way' 'good' 'for' 'you' 'sir' 'but' 'there' 'be' 'many' 'muslim' 'in' 'america' 'who' 'not' 'only' 'have' 'no' 'desire' 'to' 'assimilate' 'but' 'wish' 'to' 'live' 'under' 'sharia' 'law' 'that' 'be' 'unacceptable' 'to' 'american' 'there' 'be' 'only' 'one' 'law' 'of' 'the' 'land' 'that' 'be' 'the' 'yous' 'constitution' 'a' 'you' 'well' 'know' 'mr' 'khan' 'we' 'live' 'in' 'violent' 'time' 'dangerous' 'time' 'muslim' 'madman' 'from' 'isi' 'and' 'other' 'radical' 'jihadi' 'group' 'be' 'on' 'a' 'murder' 'and' 'terror' 'spree' 'across' 'the' 'globe' 'your' 'religion' 'of' 'peace' 'islam' 'be' 'anything' 'but' 'that' 'in' 'that' 'be' 'a' 'fact' 'that' 'be' 'confirm' 'every' 'time' 'a' 'muslim' 'shoot' 'bomb' 'and' 'torture' 'innocent' 'men' 'woman' 'and' 'child' 'this' 'do' 'not' 'mean' 'that' 'every' 'muslim' 'be' 'a' 'terrorist' 'but' 'most' 'terrorist' 'sir' 'be' 'indeed' 'muslim' 'a' 'muslim' 'terrorist' 'attack' 'have' 'become' 'the' 'sign' 'of' 'the' 'time' 'regardless' 'of' 'what' 'the' 'feckless' 'nave' 'leftist' 'ideologue' 'barack' 'obama' 'and' 'his' 'colleague' 'john' 'kerry' 'francois' 'hollande' 'and' 'angela' 'merkel' 'state' 'the' 'united' 'state' 'and' 'the' 'west' 'be' 'at' 'war' 'with' 'radical' 'islam' 'it' 'be' 'the' 'job' 'of' 'the' 'president' 'of' 'the' 'united' 'state' 'to' 'protect' 'his' 'nation' 'from' 'all' 'enemy' 'foreign' 'and' 'domestic' 'unfortunately' 'mr' 'obama' 'islam' 'and' 'refuse' 'to' 'accept' 'reality' 'which' 'have' 'result' 'in' 'the' 'death' 'of' 'thousand' 'of' 'innocent' 'people' 'across' 'the' 'world' 'group' 'like' 'isi' 'and' 'al' 'qaeda' 'have' 'one' 'goal' 'the' 'complete' 'destruction' 'of' 'the' 'judeochristian' 'culture' 'our' 'religion' 'and' 'our' 'way' 'of' 'life' 'many' 'american' 'have' 'family' 'that' 'have' 'be' 'here' 'for' 'decade' 'even' 'century' 'many' 'family' 'like' 'mine' 'have' 'relative' 'who' 'fight' 'in' 'the' 'civil' 'war' 'wwii' 'korea' 'vietnam' 'and' 'desert' 'storm' 'some' 'family' 'have' 'relative' 'who' 'fi ...
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'far' 'from' 'weaken' 'the' 'environmental' 'protection' 'agency' 'donald' 'trump' 'need' 'to' 'beef' 'it' 'up' 'or' 'so' 'say' 'a' 'guy' 'in' 'the' 'new' 'york' 'time' 'by' 'the' 'name' 'of' 'william' 'd' 'in' 'a' 'march' 'in' 'the' 'time' 'write' 'a' 'strong' 'and' 'credible' 'regulatory' 'regime' 'be' 'essential' 'to' 'the' 'smooth' 'functioning' 'of' 'our' 'economy' 'interest' 'use' 'of' 'the' 'word' 'credible' 'there' 'from' 'the' 'worthless' 'bureaucrat' 'who' 'perhaps' 'more' 'than' 'anyone' 'what' 'be' 'so' 'very' 'wrong' 'with' 'the' 'epa' 'and' 'why' 'it' 'so' 'urgently' 'need' 'to' 'be' 'reform' 'let' 'it' 'never' 'be' 'forget' 'be' 'the' 'epa' 'administrator' 'responsible' 'for' 'probably' 'the' 'black' 'moment' 'in' 'the' 'institution' 'history' 'the' 'man' 'who' 'ban' 'in' 'the' 'you' 's' 'with' 'consequence' 'which' 'result' 'in' 'million' 'of' 'unnecessary' 'death' 'around' 'the' 'world' 'from' 'malaria' 'sure' 'do' 'not' 'deliberately' 'murder' 'all' 'those' 'people' 'but' 'the' 'fact' 'remain' 'that' 'be' 'still' 'be' 'one' 'of' 'the' 'most' 'effective' 'killer' 'of' 'the' 'mosquito' 'and' 'that' 'by' 'ban' 'it' 'in' 'the' 'you' 's' 'help' 'create' 'a' 'regulatory' 'effect' 'which' 'deprive' 'the' 'world' 'of' 'one' 'it' 'best' 'defence' 'against' 'one' 'of' 'it' 'big' 'health' 'problem' 'i' 'tell' 'the' 'story' 'a' 'few' 'month' 'back' 'but' 'it' 'be' 'worth' 'repeat' 'and' 'should' 'be' 'repeat' 'every' 'time' 'this' 'dreadful' 'man' 'pop' 'up' 'again' 'and' 'to' 'assume' 'the' 'mantle' 'of' 'an' 'authority' 'he' 'simply' 'have' 'not' 'earn' 'a' 'i' 'note' 'then' 'a' 'lawyer' 'by' 'train' 'not' 'a' 'scientist' 'be' 'the' 'man' 'responsible' 'for' 'institute' 'the' 'ban' 'on' 'he' 'do' 'this' 'on' 'no' 'scientific' 'basis' 'whatsoever' 'in' 'fact' 'judge' 'edmund' 'sweeney' 'have' 'preside' 'over' 'a' 'epa' 'hearing' 'examine' 'more' 'than' 'page' 'of' 'expert' 'testimony' 'and' 'conclude' 'be' 'not' 'a' 'carcinogenic' 'hazard' 'to' 'man' 'be' 'not' 'a' 'or' 'hazard' 'to' 'man' 'the' 'use' 'of' 'under' 'the' 'regulation' 'involve' 'here' 'do' 'not' 'have' 'a' 'effect' 'on' 'freshwater' 'fish' 'organism' 'wild' 'bird' 'or' 'other' 'wildlife' 'who' 'have' 'not' 'attend' 'the' 'hearing' 'or' 'read' 'the' 'report' 'overrule' 'him' 'which' 'probably' 'make' 'not' 'much' 'difference' 'in' 'the' 'united' 'state' 'but' 'the' 'effect' 'of' 'the' 'near' 'worldwide' 'ban' 'that' 'follow' 'meant' 'that' 'could' 'no' 'longer' 'be' 'use' 'to' 'control' 'mosquito' 'population' 'which' 'in' 'turn' 'lead' 'to' 'an' 'explosion' 'in' 'malaria' 'cause' 'the' 'death' 'of' 'million' 'subsequently' 'have' 'distinguish' 'himself' 'by' 'endorse' 'barack' 'obama' 'for' 'you' 's' 'president' 'in' 'and' 'most' 'recently' 'by' 'head' 'the' 'blue' 'ribbon' 'panel' 'on' 'ocean' 'ocean' 'of' 'course' 'be' 'yet' 'another' 'scientifically' 'dubious' 'scare' 'story' 'design' 'mainly' 'to' 'prop' 'up' 'the' 'lucrative' 'global' 'industry' 'i' 'do' 'not' 'doubt' 'a' 'claim' 'in' 'his' 'new' 'york' 'time' 'article' 'that' 'the' 'public' 'whatever' 'their' 'politics' 'be' 'keen' 'to' 'have' 'clean' 'water' 'and' 'clean' 'air' 'but' 'the' 'way' 'he' 'put' 'it' 'smack' 'of' 'the' 'dishonest' 'rhetoric' 'of' 'the' 'd' 'c' 'establishment' 'use' 'emotive' 'cheap' 'trick' 'to' 'try' 'to' 'protect' 'their' 'power' 'base' 'and' 'their' 'revenue' 'stream' 'write' 'voter' 'may' 'have' 'support ...
# 151                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'november' 'gop' 'senator' 'warn' 'negotiator' 'u' 'climate' 'goal' 'might' 'not' 'last' 'a' 'group' 'of' 'republican' 'senator' 'on' 'thursday' 'advise' 'american' 'negotiator' 'to' 'warn' 'their' 'international' 'counterpart' 'that' 'president' 'obamas' 'climate' 'goal' 'might' 'not' 'survive' 'the' 'next' 'administration' 'in' 'a' 'letter' 'to' 'secretary' 'of' 'state' 'john' 'kerry' 'the' 'senator' 'lead' 'by' 'environment' 'and' 'public' 'work' 'comm ...
# 168                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'los' 'angeles' 'democratic' 'presidential' 'nominee' 'hillary' 'clinton' 'play' 'it' 'strictly' 'while' 'parry' 'decidedly' 'question' 'from' 'comedian' 'zach' 'on' 'his' 'online' 'parody' 'talk' 'show' 'between' 'two' 'release' 'on' 'thursday' 'star' 'of' 'the' 'hangover' 'film' 'be' 'know' 'for' 'his' 'banter' 'on' 'the' 'web' 'program' 'ask' 'subject' 'awkward' 'question' 'past' 'interview' 'subject' 'include' 'brad' 'pitt' 'bradley' 'cooper' 'and' 'president' 'barack' 'obama' 'sit' 'between' 'two' 'plant' 'on' 'a' 'sparse' 'set' 'do' 'not' 'dial' 'back' 'his' 'trademark' 'style' 'of' 'appear' 'uninterested' 'and' 'unprepared' 'a' 'he' 'interview' 'clinton' 'riff' 'on' 'her' 'previous' 'role' 'a' 'yous' 'secretary' 'of' 'state' 'in' 'obamas' 'first' 'term' 'a' 'secretary' 'how' 'many' 'word' 'per' 'minute' 'could' 'you' 'type' 'and' 'how' 'do' 'president' 'obama' 'like' 'his' 'coffee' 'like' 'himself' 'weak' 'say' 'you' 'know' 'zach' 'those' 'be' 'really' 'question' 'you' 'need' 'to' 'get' 'out' 'more' 'clinton' 'respond' 'other' 'topic' 'bring' 'up' 'include' 'the' ' ...
# 217                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'far' 'cry' 'brings' 'shooter' 'to' 'the' 'united' 'state' 'pit' 'player' 'against' 'a' 'religious' 'doomsday' 'cult' 'that' 'have' 'take' 'over' 'the' 'remote' 'fictional' 'hope' 'county' 'in' 'montana' 'be' 'court' 'controversy' 'with' 'their' 'late' 'entry' 'in' 'the' 'series' 'which' 'seem' 'target' 'to' 'appeal' 'to' 'the' 'revenge' 'fantasy' 'of' 'the' 'crowd' 'that' 'have' 'label' 'anyone' 'who' 'have' 'not' 'declare' 'open' 'resistance' 'against' 'donald' 'trumps' 'presidency' 'a' 'a' 'deserve' 'target' 'of' 'violence' 'the' 'game' 'do'  ...
# 235                                                                                                                                                                                                                               'activist' 'post' 'a' 'the' 'yous' 'presidential' 'selection' 'circus' 'draw' 'to' 'a' 'close' 'the' 'united' 'state' 'and' 'turkey' 'have' 'announce' 'a' 'new' 'plan' 'to' 'defeat' 'isi' 'the' 'same' 'terrorist' 'organization' 'both' 'country' 'have' 'create' 'fund' 'arm' 'and' 'facilitate' 'in' 'syria' 'the' 'plan' 'revolve' 'around' 'the' 'occupation' 'and' 'governing' 'of' 'sovereign' 'syrian' 'territory' 'in' 'the' 'east' 'most' 'notably' 'raqqa' 'accord' 'to' 'the' 'yous' 'joint' 'chief' 'of' 'staff' 'gen' 'joseph' 'dunford' 'after' 'meet' 'with' 'his' 'turkish' 'counterpart' 'that' 'the' 'coalition' 'and' 'turkey' 'will' 'work' 'together' 'on' 'the' 'longterm' 'plan' 'for' 'seize' 'hold' 'and' 'govern' 'raqqa' 'the' 'statement' 'by' 'dunford' 'seem' 'to' 'confirm' 'the' 'fact' 'that' 'the' 'united' 'state' 'will' 'not' 'move' 'forward' 'in' 'it' 'campaign' 'for' 'raqqa' 'without' 'work' 'closely' 'with' 'the' 'turk' 'who' 'be' 'themselves' 'concerned' 'about' 'the' 'makeup' 'of' 'the' 'proxy' 'force' 'destine' 'to' 'hold' 'power' 'once' 'the' 'campaign' 'be' 'over' 'the' 'syrian' 'democratic' 'force' 'the' 'proxy' 'of' 'choice' 'in' 'this' 'battle' 'be' 'make' 'up' 'of' 'many' 'kurdish' 'militia' 'and' 'fighter' 'an' 'issue' 'that' 'provide' 'much' 'worry' 'on' 'the' 'part' 'of' 'the' 'turkish' 'government' 'a' 'cnn' 'report' 'but' 'dod' 'news' 'report' 'that' 'sunday' 'meet' 'reinforce' 'a' 'longstanding' 'agreement' 'that' 'the' 'usled' 'coalition' 'would' 'not' 'move' 'ahead' 'with' 'the' 'seizure' 'of' 'raqqa' 'without' 'incorporate' 'the' 'turk' 'and' 'their' 'perspective' 'into' 'our' 'plan' 'accord' 'to' 'dunford' 'the' 'turkish' 'army' 'say' 'in' 'a' 'statement' 'that' 'the' 'military' 'head' 'have' 'discuss' 'the' 'method' 'of' 'a' 'common' 'struggle' 'against' 'isi' 'in' 'iraq' 'and' 'syria' 'especially' 'in' 'al' 'bab' 'and' 'raqqa' 'in' 'coming' 'day' 'address' 'the' 'sensitivity' 'around' 'the' 'ethnic' 'makeup' 'of' 'the' 'force' 'involve' 'in' 'the' 'operation' 'dunford' 'say' 'we' 'always' 'know' 'the' 'sdf' 'be' 'not' 'the' 'solution' 'for' 'hold' 'and' 'govern' 'raqqa' 'what' 'we' 'be' 'work' 'on' 'right' 'now' 'be' 'to' 'find' 'the' 'right' 'mix' 'of' 'force' 'for' 'the' 'operation' 'he' 'say' 'the' 'u' 'would' 'work' 'with' 'turkey' 'to' 'determine' 'the' 'composition' 'of' 'the' 'force' 'that' 'would' 'seize' 'and' 'govern' 'the' 'territory' 'he' 'say' 'he' 'say' 'the' 'right' 'approach' 'be' 'for' 'local' 'to' 'lead' 'the' 'mission' 'to' 'retake' 'the' 'city' 'and' 'run' 'it' 'after' 'isi' 'be' 'drive' 'out' 'the' 'operation' 'need' 'a' 'predominantly' 'arab' 'and' 'sunni' 'arab' 'force' 'he' 'say' 'accord' 'to' 'dod' 'news' 'and' 'there' 'be' 'force' 'like' 'that' 'there' 'be' 'the' 'moderate' 'syrian' 'opposition' 'the' 'vetted' 'syrian' 'force' 'and' 'the' 'free' 'syrian' 'army' 'force' 'and' 'there' 'be' 'some' 'initial' 'outreach' 'to' 'force' 'in' 'raqqa' 'proper' 'dunford' 'say' 'the' 'sdf' 'be' 'move' 'south' 'to' 'isolate' 'isi' 'position' 'in' 'raqqa' 'and' 'the' 'surround' 'area' 'a' 'phase' 'that' 'would' 'take' 'month' 'essentially' 'the' 'united' 'state' 'and' 'turkey' 'be' 'devise' 'a' 'plan' 'by' 'which' 'to' 'control' 'raqqa' 'and' 'the' 'territory' 'surround' 'it' 'by' 'use' 'proxy' 'force' 'to' 'overthrow' 'other' 'proxy' 'force' 'in' 'other' 'word' 'the' 'fighter' 'in' 'raqqa' 'will' 'simply' 'undergo' 'another' 'name' 'change' 'be' 'replace' 'with' 'a' 'heavy' 'kurdish' 'contingent' 'and' 'act' 'a' 'a' 'carefully' 'place' 'chess' 'piece' 'by' 'which' 'to' 'prevent' 'the' 'syrian' 'or' 'russian' 'military' 'from' 'liberate' 'the' 'city' 'after' 'all' 'these' 'sdf' 'force' 'will' 'be' 'present' 'a' 'moderate' 'a' 'label' 'that' 'can' 'not' 'be' 'attach' 'to' ...
# 244                                                                                                                                                                                                                            'a' 'public' 'service' 'announcement' 'from' 'your' 'friend' 'here' 'at' 'vox' 'there' 'will' 'be' 'an' 'enormous' 'amount' 'of' 'false' 'information' 'on' 'facebook' 'the' 'internet' 'and' 'tv' 'this' 'election' 'day' 'do' 'yourself' 'and' 'the' 'country' 'a' 'favor' 'and' 'ignore' 'it' 'politician' 'have' 'always' 'play' 'fast' 'and' 'loose' 'with' 'the' 'truth' 'cable' 'news' 'network' 'have' 'always' 'get' 'story' 'wrong' 'and' 'the' 'internet' 'have' 'always' 'be' 'a' 'place' 'for' 'conspiracy' 'theory' 'and' 'mislead' 'story' 'and' 'photo' 'but' 'the' 'campaign' 'have' 'see' 'an' 'unprecedented' 'increase' 'in' 'the' 'sheer' 'number' 'of' 'false' 'news' 'story' 'be' 'share' 'on' 'facebook' 'or' 'post' 'to' 'but' 'entirely' 'fake' 'news' 'site' 'run' 'by' 'young' 'people' 'look' 'to' 'make' 'some' 'money' 'off' 'this' 'long' 'and' 'bitter' 'election' 'take' 'the' 'denver' 'guardian' 'which' 'earlier' 'this' 'month' 'run' 'a' 'story' 'with' 'the' 'headline' 'fbi' 'agent' 'suspect' 'in' 'hillary' 'email' 'leak' 'find' 'dead' 'in' 'apparent' 'the' 'article' 'ricochet' 'across' 'facebook' 'and' 'gain' 'ten' 'of' 'thousand' 'of' 'share' 'despite' 'the' 'fact' 'that' 'there' 'be' 'no' 'such' 'thing' 'a' 'the' 'denver' 'guardian' 'and' 'that' 'the' 'story' 'in' 'question' 'be' 'a' 'complete' 'fabrication' 'it' 'be' 'a' 'dynamic' 'that' 'deeply' 'concern' 'president' 'barack' 'obama' 'arguably' 'the' 'user' 'of' 'social' 'medium' 'in' 'american' 'political' 'history' 'and' 'the' 'politician' 'who' 'have' 'be' 'target' 'in' 'the' 'majority' 'of' 'facebooks' 'most' 'paranoid' 'and' 'outright' 'racist' 'viral' 'post' 'as' 'long' 'a' 'it' 'be' 'on' 'start' 'believe' 'it' 'he' 'say' 'during' 'a' 'campaign' 'stop' 'in' 'ann' 'arbor' 'michigan' 'on' 'monday' 'it' 'create' 'this' 'dust' 'cloud' 'of' 'nonsense' 'to' 'make' 'matter' 'even' 'many' 'current' 'and' 'former' 'u' 'official' 'believe' 'that' 'russia' 'may' 'try' 'to' 'deliberately' 'spread' 'false' 'information' 'on' 'election' 'day' 'to' 'make' 'wouldbe' 'hillary' 'clinton' 'voter' 'stay' 'home' 'or' 'simply' 'to' 'shake' 'overall' 'confidence' 'in' 'the' 'american' 'political' 'system' 'all' 'of' 'which' 'mean' 'that' 'if' 'you' 'see' 'or' 'read' 'something' 'on' 'election' 'day' 'that' 'appear' 'too' 'dramatic' 'to' 'be' 'true' 'there' 'be' 'probably' 'a' 'good' 'and' 'simple' 'reason' 'it' 'be' 'not' 'in' 'november' 'fox' 'news' 'air' 'a' 'video' 'clip' 'show' 'a' 'member' 'of' 'the' 'black' 'panther' 'stand' 'outside' 'a' 'polling' 'station' 'in' 'philadelphia' 'it' 'be' 'a' 'single' 'person' 'at' 'a' 'single' 'polling' 'station' 'in' 'a' 'heavily' 'black' 'heavily' 'democratic' 'area' 'but' 'fox' 'anchor' 'strongly' 'suggest' 'that' 'it' 'be' 'part' 'of' 'a' 'broad' 'pattern' 'of' 'voter' 'intimidation' 'by' 'militant' 'determine' 'to' 'stop' 'nominee' 'mitt' 'romney' 'the' 'segment' 'be' 'frequently' 'throughout' 'the' 'day' 'four' 'year' 'it' 'be' 'certainly' 'possible' 'that' 'fox' 'news' 'or' 'a' 'leftleaning' 'station' 'like' 'msnbc' 'will' 'find' 'a' 'similar' 'type' 'of' 'clip' 'and' 'present' 'it' 'in' 'a' 'way' 'that' 'be' 'deliberately' 'misleading' 'amazingly' 'though' 'that' 'could' 'literally' 'be' 'the' 'least' 'of' 'our' 'problem' 'a' 'much' 'big' 'concern' 'be' 'the' 'proliferation' 'of' 'entirely' 'fake' 'news' 'site' 'with' 'entirely' 'fake' 'story' 'often' 'operate' 'by' 'entrepreneur' 'live' 'overseas' 'a' 'buzzfeed' 'article' 'earlier' 'this' 'month' 'find' 'that' 'young' 'people' 'in' 'the' 'macedonian' 'town' 'of' 'population' 'have' 'create' 'more' 'than' 'protrump' 'news' 'site' 'run' 'post' 'every' 'day' 'that' 'be' 'aggregate' 'or' 'completely' 'plagiarize' 'from' 'fringe' 'and' 'rightwing' 'site' 'in' 'the' 'u' 'to' 'take' 'on ...
# 259                                                                                                                                                                                                                                                                                                         'iraq' 'and' 'turkey' 'be' 'threaten' 'to' 'go' 'to' 'war' 'with' 'each' 'other' 'over' 'who' 'should' 'hold' 'power' 'in' 'mosul' 'and' 'the' 'surround' 'region' 'after' 'the' 'defeat' 'of' 'isi' 'turkish' 'tank' 'and' 'artillery' 'have' 'deploy' 'along' 'the' 'border' 'and' 'iraqi' 'prime' 'minister' 'haider' 'alabadi' 'have' 'say' 'that' 'while' 'iraq' 'do' 'not' 'want' 'war' 'with' 'turkey' 'it' 'be' 'ready' 'to' 'fight' 'one' 'if' 'necessary' 'the' 'confrontation' 'be' 'sharpen' 'a' 'the' 'iraqi' 'army' 'enters' 'eastern' 'mosul' 'and' 'shia' 'militia' 'know' 'a' 'the' 'hashd' 'alshaabi' 'advance' 'towards' 'the' 'town' 'of' 'tal' 'afar' 'threaten' 'to' 'cut' 'isiss' 'last' 'escape' 'route' 'from' 'mosul' 'to' 'syria' 'turkey' 'see' 'itself' 'a' 'the' 'protector' 'of' 'the' 'sunni' 'arab' 'of' 'mosul' 'and' 'northern' 'iraq' 'a' 'community' 'leave' 'vulnerable' 'by' 'the' 'likely' 'defeat' 'of' 'isi' 'by' 'shia' 'and' 'kurdish' 'force' 'back' 'by' 'usled' 'the' 'dependence' 'of' 'the' 'antiisis' 'force' 'on' 'air' 'strike' 'and' 'drone' 'be' 'underline' 'on' 'wednesday' 'when' 'iraqi' 'special' 'force' 'delay' 'their' 'advance' 'into' 'east' 'mosul' 'because' 'high' 'humidity' 'and' 'cloud' 'make' 'it' 'difficult' 'for' 'aircraft' 'to' 'identify' 'and' 'attack' 'target' 'on' 'the' 'ground' 'they' 'have' 'enter' 'the' 'industrial' 'suburb' 'of' 'on' 'tuesday' 'and' 'be' 'wednesday' 'go' 'from' 'house' 'to' 'house' 'look' 'for' 'improvised' 'explosive' 'device' 'ied' 'and' 'booby' 'trap' 'the' 'population' 'of' 'mosul' 'east' 'of' 'the' 'tigris' 'river' 'which' 'divide' 'the' 'city' 'in' 'half' 'have' 'in' 'the' 'past' 'consist' 'largely' 'of' 'welleducated' 'professional' 'people' 'such' 'a' 'doctor' 'and' 'engineer' 'few' 'of' 'whom' 'be' 'likely' 'to' 'be' 'sympathetic' 'to' 'isis' 'resident' 'in' 'the' 'east' 'say' 'they' 'expect' 'isi' 'to' 'withdraw' 'to' 'the' 'western' 'side' 'of' 'mosul' 'which' 'be' 'more' 'sympathetic' 'to' 'them' 'cross' 'the' 'five' 'bridge' 'span' 'the' 'tigris' 'which' 'the' 'resident' 'say' 'have' 'be' 'rig' 'with' 'demolition' 'charge' 'the' 'iraqi' 'government' 'react' 'angrily' 'to' 'the' 'possibility' 'of' 'turkish' 'intervention' 'the' 'invasion' 'of' 'iraq' 'will' 'lead' 'to' 'turkey' 'be' 'dismantle' 'say' 'mr' 'abadi' 'at' 'a' 'news' 'conference' 'in' 'baghdad' 'on' 'tuesday' 'we' 'do' 'not' 'want' 'war' 'with' 'turkey' 'and' 'we' 'do' 'not' 'want' 'a' 'confrontation' 'with' 'turkey' 'but' 'if' 'a' 'confrontation' 'happen' 'we' 'be' 'ready' 'for' 'it' 'he' 'add' 'that' 'iraq' 'would' 'consider' 'turkey' 'a' 'an' 'enemy' 'and' 'would' 'deal' 'with' 'it' 'a' 'an' 'enemy' 'the' 'exchange' 'of' 'abuse' 'between' 'ankara' 'and' 'baghdad' 'continue' 'on' 'wednesday' 'when' 'turkish' 'foreign' 'minister' 'mevlut' 'cavusoglu' 'denounce' 'mr' 'abadi' 'a' 'weak' 'ask' 'if' 'you' 'have' 'the' 'strength' 'why' 'do' 'you' 'surrender' 'mosul' 'to' 'terror' 'organisation' 'if' 'you' 'be' 'so' 'strong' 'why' 'have' 'the' 'pkk' 'occupy' 'your' 'land' 'for' 'year' 'earlier' 'turkey' 'deputy' 'prime' 'minister' 'have' 'try' 'to' 'lower' 'the' 'temperature' 'by' 'say' 'that' 'the' 'military' 'buildup' 'be' 'a' 'precaution' 'and' 'not' 'a' 'threat' 'iraqi' 'leader' 'in' 'baghdad' 'have' 'long' 'privately' 'blame' 'turkey' 'for' 'aid' 'or' 'tolerate' 'movement' 'like' 'isi' 'which' 'operate' 'in' 'iraq' 'but' 'the' 'be' 'now' 'become' 'more' 'public' 'on' 'both' 'side' 'on' 'october' 'president' 'recep' 'tayyip' 'erdogan' 'launch' 'a' 'furious' 'tirade' 'against' 'mr' 'abadi' 'say' 'he' 'insult' 'me' 'you' 'be' 'not' 'on' 'the' 'same' 'level' 'a' 'me' 'you' 'be' 'not' 'my' 'equal' 'scream' 'all' 'you' 'want' 'f ...
# 275                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# ...
# 601                                                                                                                                                                                                                                      'sherman' 'dale' 'penn' 'while' 'donald' 'trump' 'often' 'rail' 'against' 'a' 'rigged' 'election' 'on' 'twitter' 'and' 'at' 'rally' 'nationwide' 'he' 'go' 'a' 'few' 'step' 'far' 'in' 'pennsylvania' 'a' 'state' 'crucial' 'to' 'the' 'republican' 'fading' 'chance' 'to' 'win' 'the' 'white' 'house' 'here' 'he' 'have' 'make' 'direct' 'appeal' 'since' 'august' 'to' 'recruit' 'voter' 'a' 'poll' 'monitor' 'on' 'election' 'day' 'and' 'have' 'point' 'specifically' 'at' 'philadelphia' 'a' 'a' 'city' 'beset' 'by' 'voter' 'fraud' 'despite' 'offer' 'little' 'evidence' 'for' 'any' 'of' 'his' 'claim' 'his' 'rigged' 'election' 'message' 'be' 'resonate' 'with' 'his' 'follower' 'in' 'this' 'traditional' 'battleground' 'state' 'where' 'democratic' 'rival' 'hillary' 'clinton' 'have' 'open' 'up' 'a' 'wide' 'lead' 'but' 'his' 'call' 'for' 'poll' 'watcher' 'on' 'november' 'be' 'draw' 'a' 'mix' 'of' 'confusion' 'concern' 'and' 'tepid' 'support' 'in' 'some' 'case' 'trump' 'talk' 'of' 'fraud' 'appear' 'to' 'have' 'make' 'some' 'of' 'his' 'own' 'follower' 'more' 'resign' 'to' 'an' 'election' 'loss' 'even' 'though' 'independent' 'study' 'show' 'yous' 'vote' 'be' 'exceptionally' 'rare' 'and' 'certainly' 'never' 'on' 'a' 'national' 'scale' 'since' 'august' 'when' 'trump' 'first' 'urge' 'supporter' 'in' 'the' 'state' 'to' 'watch' 'other' 'poll' 'place' 'and' 'make' 'sure' 'that' 'it' 'be' 'percent' 'fine' 'civil' 'right' 'group' 'have' 'express' 'fear' 'that' 'some' 'supporter' 'will' 'take' 'the' 'idea' 'too' 'far' 'by' 'form' 'roam' 'crowd' 'intimidate' 'voter' 'trump' 'supporter' 'mark' 'bowman' 'say' 'he' 'be' 'not' 'the' 'type' 'to' 'attend' 'a' 'political' 'rally' 'or' 'put' 'campaign' 'sticker' 'on' 'his' 'car' 'and' 'he' 'be' 'not' 'confident' 'the' 'election' 'result' 'will' 'be' 'correct' 'i' 'hate' 'to' 'say' 'it' 'but' 'i' 'do' 'not' 'have' 'a' 'lot' 'of' 'faith' 'bowman' 'say' 'voter' 'fraud' 'be' 'rampant' 'especially' 'in' 'the' 'city' 'but' 'in' 'a' 'comment' 'echo' 'by' 'nearly' 'two' 'dozen' 'trump' 'supporter' 'in' 'the' 'state' 'reliably' 'republican' 'central' 'region' 'he' 'say' 'he' 'think' 'nothing' 'can' 'be' 'do' 'to' 'stop' 'it' 'and' 'that' 'become' 'an' 'amateur' 'poll' 'watcher' 'be' 'a' 'step' 'too' 'far' 'what' 'authority' 'do' 'i' 'have' 'to' 'confront' 'someone' 'say' 'the' 'resident' 'of' 'sherman' 'dale' 'a' 'rural' 'community' 'of' 'about' 'people' 'your' 'average' 'citizen' 'you' 'be' 'go' 'to' 'end' 'up' 'in' 'a' 'confrontation' 'with' 'someone' 'you' 'be' 'go' 'to' 'end' 'up' 'in' 'a' 'bad' 'situation' 'there' 'be' 'official' 'channel' 'to' 'monitor' 'election' 'pennsylvania' 'have' 'a' 'system' 'that' 'allow' 'campaign' 'and' 'political' 'party' 'to' 'designate' 'official' 'poll' 'monitor' 'who' 'be' 'allow' 'into' 'the' 'polling' 'place' 'and' 'can' 'register' 'official' 'complaint' 'if' 'they' 'think' 'someone' 'be' 'not' 'a' 'valid' 'voter' 'a' 'form' 'on' 'the' 'trump' 'campaign' 'website' 'asks' 'voter' 'to' 'help' 'trump' 'stop' 'crook' 'hillary' 'from' 'rig' 'this' 'election' 'by' 'become' 'a' 'volunteer' 'trump' 'election' 'observer' 'but' 'in' 'an' 'example' 'of' 'the' 'trump' 'campaign' 'near' 'nonexistent' 'effort' 'to' 'organize' 'field' 'operation' 'in' 'key' 'swing' 'state' 'there' 'be' 'little' 'evidence' 'that' 'the' 'recruitment' 'drive' 'be' 'translate' 'into' 'legion' 'of' 'officially' 'sanction' 'volunteer' 'repeat' 'inquiry' 'from' 'about' 'effort' 'to' 'staff' 'polling' 'place' 'go' 'unanswered' 'by' 'his' 'campaign' 'the' 'rule' 'allow' 'each' 'candidate' 'and' 'the' 'state' 'party' 'to' 'name' 'monitor' 'with' 'federal' 'and' 'local' 'candidate' 'both' 'on' 'the' 'november' 'ballot' 'there' 'could' 'be' 'dozen' 'of' 'watcher' 'in' 'a' 'single' 'precinct' 'but' 'those ...
# 618                                                                                                                                                                                                                                                                                                                                                                                                                            'scott' 'host' 'of' 'cbs' 'news' 'minute' 'embarrass' 'himself' 'in' 'a' 'sunday' 'segment' 'about' 'fake' 'news' 'despite' 'have' 'the' 'final' 'cut' 'on' 'a' 'hostile' 'interview' 'with' 'a' 'activist' 'mike' 'cernovich' 'a' 'lawyer' 'independent' 'and' 'a' 'dominant' 'voice' 'on' 'twitter' 'build' 'up' 'significant' 'buzz' 'for' 'minute' 'by' 'reveal' 'on' 'thursday' 'he' 'have' 'grant' 'a' 'interview' 'in' 'the' 'hour' 'before' 'the' 'live' 'broadcast' 'cernovich' 'anticipate' 'that' 'the' 'conversation' 'would' 'be' 'selectively' 'edit' 'and' 'publish' 'a' 'partial' 'transcript' 'that' 'concern' 'be' 'base' 'on' 'a' 'long' 'history' 'of' 'network' 'news' 'program' 'use' 'mislead' 'or' 'downright' 'comical' 'editing' 'to' 'put' 'conservative' 'in' 'the' 'bad' 'possible' 'light' 'a' 'the' 'segment' 'air' 'open' 'statement' 'make' 'it' 'clear' 'this' 'story' 'be' 'a' 'smear' 'job' 'in' 'this' 'last' 'election' 'the' 'nation' 'be' 'assault' 'by' 'masquerade' 'a' 'reporter' 'they' 'poison' 'the' 'conversation' 'with' 'lie' 'on' 'the' 'left' 'and' 'on' 'the' 'right' 'many' 'do' 'it' 'to' 'influence' 'the' 'outcome' 'others' 'just' 'to' 'make' 'a' 'buck' 'the' 'president' 'use' 'the' 'term' 'fake' 'news' 'to' 'discredit' 'responsible' 'reporting' 'that' 'he' 'do' 'not' 'like' 'but' 'we' 'be' 'go' 'to' 'show' 'you' 'how' 'con' 'artist' 'insert' 'truly' 'fake' 'news' 'into' 'the' 'national' 'conversation' 'with' 'fraudulent' 'software' 'that' 'scam' 'your' 'social' 'medium' 'account' 'the' 'story' 'be' 'fake' 'but' 'the' 'consequence' 'be' 'real' 'emphasis' 'add' 'later' 'on' 'introduce' 'cernovich' 'with' 'depict' 'him' 'rather' 'like' 'a' 'little' 'boy' 'hunch' 'over' 'his' 'laptop' 'call' 'him' 'a' 'magnet' 'for' 'reader' 'with' 'a' 'taste' 'for' 'story' 'with' 'no' 'basis' 'in' 'fact' 'even' 'with' 'this' 'setup' 'end' 'up' 'humiliate' 'himself' 'not' 'his' 'target' 'watch' 'the' 'key' 'exchange' 'that' 'story' 'get' 'so' 'much' 'traction' 'it' 'have' 'to' 'be' 'deny' 'not' 'only' 'by' 'clinton' 'doctor' 'but' 'by' 'the' 'national' 'parkinson' 'foundation' 'pic' 'twitter' 'minute' 'march' 'bring' 'up' 'an' 'article' 'on' 'website' 'where' 'a' 'physician' 'who' 'later' 'out' 'himself' 'a' 'orlando' 'dr' 'ted' 'noel' 'argue' 'that' 'an' 'explanation' 'for' 'clinton' 'bizarre' 'physical' 'tic' 'could' 'be' 'parkinson' 'disease' 'while' 'confront' 'cernovich' 'about' 'the' 'headline' 'hillary' 'clinton' 'have' 'parkinson' 'disease' 'physician' 'confirm' 'expose' 'his' 'own' 'belief' 'in' 'an' 'unproven' 'claim' 'cernovich' 'she' 'have' 'a' 'seizure' 'and' 'freeze' 'up' 'walk' 'into' 'her' 'motorcade' 'that' 'day' 'september' 'well' 'she' 'have' 'pneumonia' 'i' 'mean' 'cernovich' 'how' 'do' 'you' 'know' 'who' 'tell' 'you' 'that' 'well' 'the' 'campaign' 'tell' 'u' 'that' 'cernovich' 'why' 'would' 'you' 'trust' 'the' 'campaign' 'the' 'point' 'be' 'you' 'do' 'not' 'talk' 'to' 'anybody' 'who' 'would' 'ever' 'examine' 'hillary' 'clinton' 'cernovich' 'i' 'do' 'not' 'take' 'anything' 'hillary' 'clinton' 'be' 'go' 'to' 'say' 'at' 'all' 'a' 'true' 'i' 'be' 'not' 'go' 'to' 'take' 'her' 'on' 'her' 'word' 'the' 'medium' 'say' 'we' 'be' 'not' 'go' 'to' 'take' 'donald' 'trump' 'on' 'his' 'word' 'and' 'that' 'be' 'why' 'we' 'be' 'in' 'these' 'different' 'universe' 'have' 'no' 'answer' 'for' 'those' 'six' 'word' 'why' 'would' 'you' 'trust' 'the' 'campaign' 'a' 'his' 'entire' 'profession' 'go' 'with' 'fact' 'check' 'for' 'every' 'tweet' 'from' 'president' 'trump' 'also' 'seem' 'to' 'forget' 'the' 'fakery' 'that' 'clinton' 'world' 'attempt' ' ...
# 642                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
#
#      Predikció valószínűsége
# 3                     0.1502
# 41                    0.0992
# 53                    0.3578
# 151                   0.9991
# 168                   0.0325
# 217                   0.1818
# 235                   0.9567
# 244                   0.0034
# 259                   0.8340
# 275                   0.2310
# 290                   0.7687
# 297                   0.8401
# 338                   0.0569
# 408                   0.0202
# 464                   0.9849
# 505                   0.0074
# 507                   0.5270
# 601                   0.0376
# 618                   0.4536
# 642                   0.0119

# %% [markdown]
# # GRU MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ### Modell lefuttatása

# %%
# GRU modell

def create_gru_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),  # Ensure within vocab limit
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings  # Toggle trainability
    )(text_input)

    # GRU rétegek
    gru_out = GRU(128, return_sequences=True, dropout=0.3)(text_embedding)
    gru_out = Dropout(0.3)(gru_out)  # Dropout réteg az első GRU után
    gru_out = GRU(64,return_sequences=True, dropout=0.3)(gru_out)
    gru_out = Dropout(0.3)(gru_out)
    gru_out = GRU(32, dropout=0.3)(gru_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(gru_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása (Trainable)
gru_trainable = create_gru_model(trainable_embeddings=True)  # Trainable

gru_trainable.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_2 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 600, 128)            │         165,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 600, 64)             │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,711,809 (29.42 MB)
#  Trainable params: 7,711,809 (29.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# GRU modell tanítása a validációs adatok figyelésével
history_gru_trainable = gru_trainable.fit(
    padded_train_final, y_train_final,  # Ugyanaz a tanító adathalmaz, mint az LSTM-nél
    validation_data=(padded_val, y_val),  # Ugyanaz a validációs halmaz, mint az LSTM-nél
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság (GRU): {test_accuracy_gru:.4f}, Teszthalmaz veszteség (GRU): {test_loss_gru:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 69s 79ms/step - accuracy: 0.8328 - loss: 0.3649 - val_accuracy: 0.9454 - val_loss: 0.1452
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 67s 81ms/step - accuracy: 0.9640 - loss: 0.1019 - val_accuracy: 0.9735 - val_loss: 0.0789
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 80s 79ms/step - accuracy: 0.9843 - loss: 0.0489 - val_accuracy: 0.9681 - val_loss: 0.0928
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 68s 81ms/step - accuracy: 0.9913 - loss: 0.0292 - val_accuracy: 0.9662 - val_loss: 0.1152
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 80s 78ms/step - accuracy: 0.9957 - loss: 0.0158 - val_accuracy: 0.9654 - val_loss: 0.1495
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9726 - loss: 0.0811
# Teszthalmaz pontosság (GRU): 0.9696, Teszthalmaz veszteség (GRU): 0.0903

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Valószínűség becslése
gru_y_prob = gru_trainable.predict(padded_test)

gru_y_pred = (gru_y_prob > 0.5).astype(int)

accuracy = accuracy_score(y_test, gru_y_pred)
precision = precision_score(y_test, gru_y_pred)
recall = recall_score(y_test, gru_y_pred)
f1 = f1_score(y_test, gru_y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
# Accuracy: 0.9680
# Precision: 0.9664
# Recall: 0.9698
# F1-score: 0.9681

# %% [markdown]
# ## GRU modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = gru_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_gru_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(history_gru_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(history_gru_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(history_gru_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9723 - loss: 0.0804

# %%
# Confusion Matrix
cm_gru = confusion_matrix(y_test, gru_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_gru, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix GRU Modellre')
plt.show()

print(classification_report(y_test, gru_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97      7440
#          1.0       0.97      0.97      0.97      7440
#
#     accuracy                           0.97     14880
#    macro avg       0.97      0.97      0.97     14880
# weighted avg       0.97      0.97      0.97     14880

# %%
# Flatten
y_true = y_test.flatten()
y_pred = gru_y_pred.flatten()
y_prob = gru_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás) GRU Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": gru_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = gru_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_gru.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 17   Hamis negatív (FN)           1.0                 0
# 151  Hamis pozitív (FP)           0.0                 1
# 162  Hamis pozitív (FP)           0.0                 1
# 235  Hamis pozitív (FP)           0.0                 1
# 244  Hamis negatív (FN)           1.0                 0
# 269  Hamis pozitív (FP)           0.0                 1
# 275  Hamis negatív (FN)           1.0                 0
# 293  Hamis pozitív (FP)           0.0                 1
# 297  Hamis pozitív (FP)           0.0                 1
# 391  Hamis pozitív (FP)           0.0                 1
# 404  Hamis pozitív (FP)           0.0                 1
# 408  Hamis negatív (FN)           1.0                 0
# 454  Hamis pozitív (FP)           0.0                 1
# 464  Hamis pozitív (FP)           0.0                 1
# 490  Hamis pozitív (FP)           0.0                 1
# 497  Hamis negatív (FN)           1.0                 0
# 508  Hamis negatív (FN)           1.0                 0
# 639  Hamis pozitív (FP)           0.0                 1
# 642  Hamis negatív (FN)           1.0                 0
# 707  Hamis pozitív (FP)           0.0                 1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'minsk' 'belarus' 's' 'kgb' 'state' 'security' 'service' 'say' 'on' 'monday' 'it' 'have' 'uncover' 'a' 'spy' 'ring' 'work' 'for' 'the' 'ukrainian' 'defence' 'ministry' 'that' 'have' 'be' 'set' 'up' 'by' 'a' 'detained' 'ukrainian' 'radio' 'correspondent' 'journalist' 'be' 'arrest' 'in' 'october' 'and' 'charge' 'with' 'be' 'an' 'undercover' 'intelligence' 'officer' 'kgb' 'spokesman' 'dmitry' 'say' 'in' 'a' 'briefing' 'in' 'belarus' 'build' 'a' 'network' 'of' 'agent' 'make' 'up' 'of' 'belarussian' 'citizen' 'who' 'carry' 'out' 'his' 'assignment' 'for' 'monetary' 'compensation' 'say' 'an' 'adviser' 'to' 'the' 'embassy' 'in' 'minsk' 'ukrainian' 'have' 'be' 'declare' 'persona' 'non' 'grata' 'ban' 'from' 'the' 'country' 'a' 'he' 'be' 'believe' 'to' 'be' 's' 'handler' 'say' 'the' 'ukrainian' 'defence' 'ministry' 'deny' 'the' 'allegation' 'against' 'who' 'it' 'say' 'have' 'work' 'a' 'a' 'spokesman' 'for' 'the' 'ministry' 'before' 'switch' 'to' 'journa ...
# 151                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'november' 'gop' 'senator' 'warn' 'negotiator' 'u' 'climate' 'goal' 'might' 'not' 'last' 'a' 'group' 'of' 'republican' 'senator' 'on' 'thursday' 'advise' 'american' 'negotiator' 'to' 'warn' 'their' 'international' 'counterpart' 'that' 'president' 'obamas' 'climate' 'goal' 'might' 'not' 'survive' 'the' 'next' 'administration' 'in' 'a' 'letter' 'to' 'secretary' 'of' 'state' 'john' 'kerry' 'the' 'senator' 'lead' 'by' 'environment' 'and' 'public' 'work' 'committee' 'chairman' 'jam' 'inhofe' 'note' 'that' 'american' 'commitment' 'to' 'the' 'i ...
# 162                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 235                                                                                                                                           'activist' 'post' 'a' 'the' 'yous' 'presidential' 'selection' 'circus' 'draw' 'to' 'a' 'close' 'the' 'united' 'state' 'and' 'turkey' 'have' 'announce' 'a' 'new' 'plan' 'to' 'defeat' 'isi' 'the' 'same' 'terrorist' 'organization' 'both' 'country' 'have' 'create' 'fund' 'arm' 'and' 'facilitate' 'in' 'syria' 'the' 'plan' 'revolve' 'around' 'the' 'occupation' 'and' 'governing' 'of' 'sovereign' 'syrian' 'territory' 'in' 'the' 'east' 'most' 'notably' 'raqqa' 'accord' 'to' 'the' 'yous' 'joint' 'chief' 'of' 'staff' 'gen' 'joseph' 'dunford' 'after' 'meet' 'with' 'his' 'turkish' 'counterpart' 'that' 'the' 'coalition' 'and' 'turkey' 'will' 'work' 'together' 'on' 'the' 'longterm' 'plan' 'for' 'seize' 'hold' 'and' 'govern' 'raqqa' 'the' 'statement' 'by' 'dunford' 'seem' 'to' 'confirm' 'the' 'fact' 'that' 'the' 'united' 'state' 'will' 'not' 'move' 'forward' 'in' 'it' 'campaign' 'for' 'raqqa' 'without' 'work' 'closely' 'with' 'the' 'turk' 'who' 'be' 'themselves' 'concerned' 'about' 'the' 'makeup' 'of' 'the' 'proxy' 'force' 'destine' 'to' 'hold' 'power' 'once' 'the' 'campaign' 'be' 'over' 'the' 'syrian' 'democratic' 'force' 'the' 'proxy' 'of' 'choice' 'in' 'this' 'battle' 'be' 'make' 'up' 'of' 'many' 'kurdish' 'militia' 'and' 'fighter' 'an' 'issue' 'that' 'provide' 'much' 'worry' 'on' 'the' 'part' 'of' 'the' 'turkish' 'government' 'a' 'cnn' 'report' 'but' 'dod' 'news' 'report' 'that' 'sunday' 'meet' 'reinforce' 'a' 'longstanding' 'agreement' 'that' 'the' 'usled' 'coalition' 'would' 'not' 'move' 'ahead' 'with' 'the' 'seizure' 'of' 'raqqa' 'without' 'incorporate' 'the' 'turk' 'and' 'their' 'perspective' 'into' 'our' 'plan' 'accord' 'to' 'dunford' 'the' 'turkish' 'army' 'say' 'in' 'a' 'statement' 'that' 'the' 'military' 'head' 'have' 'discuss' 'the' 'method' 'of' 'a' 'common' 'struggle' 'against' 'isi' 'in' 'iraq' 'and' 'syria' 'especially' 'in' 'al' 'bab' 'and' 'raqqa' 'in' 'coming' 'day' 'address' 'the' 'sensitivity' 'around' 'the' 'ethnic' 'makeup' 'of' 'the' 'force' 'involve' 'in' 'the' 'operation' 'dunford' 'say' 'we' 'always' 'know' 'the' 'sdf' 'be' 'not' 'the' 'solution' 'for' 'hold' 'and' 'govern' 'raqqa' 'what' 'we' 'be' 'work' 'on' 'right' 'now' 'be' 'to' 'find' 'the' 'right' 'mix' 'of' 'force' 'for' 'the' 'operation' 'he' 'say' 'the' 'u' 'would' 'work' 'with' 'turkey' 'to' 'determine' 'the' 'composition' 'of' 'the' 'force' 'that' 'would' 'seize' 'and' 'govern' 'the' 'territory' 'he' 'say' 'he' 'say' 'the' 'right' 'approach' 'be' 'for' 'local' 'to' 'lead' 'the' 'mission' 'to' 'retake' 'the' 'city' 'and' 'run' 'it' 'after' 'isi' 'be' 'drive' 'out' 'the' 'operation' 'need' 'a' 'predominantly' 'arab' 'and' 'sunni' 'arab' 'force' 'he' 'say' 'accord' 'to' 'dod' 'news' 'and' 'there' 'be' 'force' 'like' 'that' 'there' 'be' 'the' 'moderate' 'syrian' 'opposition' 'the' 'vetted' 'syrian' 'force' 'and' 'the' 'free' 'syrian' 'army' 'force' 'and' 'there' 'be' 'some' 'initial' 'outreach' 'to' 'force' 'in' 'raqqa' 'proper' 'dunford' 'say' 'the' 'sdf' 'be' 'move' 'south' 'to' 'isolate' 'isi' 'position' 'in' 'raqqa' 'and' 'the' 'surround' 'area' 'a' 'phase' 'that' 'would' 'take' 'month' 'essentially' 'the' 'united' 'state' 'and' 'turkey' 'be' 'devise' 'a' 'plan' 'by' 'which' 'to' 'control' 'raqqa' 'and' 'the' 'territory' 'surround' 'it' 'by' 'use' 'proxy' 'force' 'to' 'overthrow' 'other' 'proxy' 'force' 'in' 'other' 'word' 'the' 'fighter' 'in' 'raqqa' 'will' 'simply' 'undergo' 'another' 'name' 'change' 'be' 'replace' 'with' 'a' 'heavy' 'kurdish' 'contingent' 'and' 'act' 'a' 'a' 'carefully' 'place' 'chess' 'piece' 'by' 'which' 'to' 'prevent' 'the' 'syrian' 'or' 'russian' 'military' 'from' 'liberate' 'the' 'city' 'after' 'all' 'these' 'sdf' 'force' 'will' 'be' 'present' 'a' 'moderate' 'a' 'label' 'that' 'can' 'not' 'be' 'attach' 'to' 'the' 'isi' 'fighter' 'currently' 'inhabit' 'raqqa' 'raqqa' 'have' 'act' 'a' 'the'  ...
# 244                                                                                                                                        'a' 'public' 'service' 'announcement' 'from' 'your' 'friend' 'here' 'at' 'vox' 'there' 'will' 'be' 'an' 'enormous' 'amount' 'of' 'false' 'information' 'on' 'facebook' 'the' 'internet' 'and' 'tv' 'this' 'election' 'day' 'do' 'yourself' 'and' 'the' 'country' 'a' 'favor' 'and' 'ignore' 'it' 'politician' 'have' 'always' 'play' 'fast' 'and' 'loose' 'with' 'the' 'truth' 'cable' 'news' 'network' 'have' 'always' 'get' 'story' 'wrong' 'and' 'the' 'internet' 'have' 'always' 'be' 'a' 'place' 'for' 'conspiracy' 'theory' 'and' 'mislead' 'story' 'and' 'photo' 'but' 'the' 'campaign' 'have' 'see' 'an' 'unprecedented' 'increase' 'in' 'the' 'sheer' 'number' 'of' 'false' 'news' 'story' 'be' 'share' 'on' 'facebook' 'or' 'post' 'to' 'but' 'entirely' 'fake' 'news' 'site' 'run' 'by' 'young' 'people' 'look' 'to' 'make' 'some' 'money' 'off' 'this' 'long' 'and' 'bitter' 'election' 'take' 'the' 'denver' 'guardian' 'which' 'earlier' 'this' 'month' 'run' 'a' 'story' 'with' 'the' 'headline' 'fbi' 'agent' 'suspect' 'in' 'hillary' 'email' 'leak' 'find' 'dead' 'in' 'apparent' 'the' 'article' 'ricochet' 'across' 'facebook' 'and' 'gain' 'ten' 'of' 'thousand' 'of' 'share' 'despite' 'the' 'fact' 'that' 'there' 'be' 'no' 'such' 'thing' 'a' 'the' 'denver' 'guardian' 'and' 'that' 'the' 'story' 'in' 'question' 'be' 'a' 'complete' 'fabrication' 'it' 'be' 'a' 'dynamic' 'that' 'deeply' 'concern' 'president' 'barack' 'obama' 'arguably' 'the' 'user' 'of' 'social' 'medium' 'in' 'american' 'political' 'history' 'and' 'the' 'politician' 'who' 'have' 'be' 'target' 'in' 'the' 'majority' 'of' 'facebooks' 'most' 'paranoid' 'and' 'outright' 'racist' 'viral' 'post' 'as' 'long' 'a' 'it' 'be' 'on' 'start' 'believe' 'it' 'he' 'say' 'during' 'a' 'campaign' 'stop' 'in' 'ann' 'arbor' 'michigan' 'on' 'monday' 'it' 'create' 'this' 'dust' 'cloud' 'of' 'nonsense' 'to' 'make' 'matter' 'even' 'many' 'current' 'and' 'former' 'u' 'official' 'believe' 'that' 'russia' 'may' 'try' 'to' 'deliberately' 'spread' 'false' 'information' 'on' 'election' 'day' 'to' 'make' 'wouldbe' 'hillary' 'clinton' 'voter' 'stay' 'home' 'or' 'simply' 'to' 'shake' 'overall' 'confidence' 'in' 'the' 'american' 'political' 'system' 'all' 'of' 'which' 'mean' 'that' 'if' 'you' 'see' 'or' 'read' 'something' 'on' 'election' 'day' 'that' 'appear' 'too' 'dramatic' 'to' 'be' 'true' 'there' 'be' 'probably' 'a' 'good' 'and' 'simple' 'reason' 'it' 'be' 'not' 'in' 'november' 'fox' 'news' 'air' 'a' 'video' 'clip' 'show' 'a' 'member' 'of' 'the' 'black' 'panther' 'stand' 'outside' 'a' 'polling' 'station' 'in' 'philadelphia' 'it' 'be' 'a' 'single' 'person' 'at' 'a' 'single' 'polling' 'station' 'in' 'a' 'heavily' 'black' 'heavily' 'democratic' 'area' 'but' 'fox' 'anchor' 'strongly' 'suggest' 'that' 'it' 'be' 'part' 'of' 'a' 'broad' 'pattern' 'of' 'voter' 'intimidation' 'by' 'militant' 'determine' 'to' 'stop' 'nominee' 'mitt' 'romney' 'the' 'segment' 'be' 'frequently' 'throughout' 'the' 'day' 'four' 'year' 'it' 'be' 'certainly' 'possible' 'that' 'fox' 'news' 'or' 'a' 'leftleaning' 'station' 'like' 'msnbc' 'will' 'find' 'a' 'similar' 'type' 'of' 'clip' 'and' 'present' 'it' 'in' 'a' 'way' 'that' 'be' 'deliberately' 'misleading' 'amazingly' 'though' 'that' 'could' 'literally' 'be' 'the' 'least' 'of' 'our' 'problem' 'a' 'much' 'big' 'concern' 'be' 'the' 'proliferation' 'of' 'entirely' 'fake' 'news' 'site' 'with' 'entirely' 'fake' 'story' 'often' 'operate' 'by' 'entrepreneur' 'live' 'overseas' 'a' 'buzzfeed' 'article' 'earlier' 'this' 'month' 'find' 'that' 'young' 'people' 'in' 'the' 'macedonian' 'town' 'of' 'population' 'have' 'create' 'more' 'than' 'protrump' 'news' 'site' 'run' 'post' 'every' 'day' 'that' 'be' 'aggregate' 'or' 'completely' 'plagiarize' 'from' 'fringe' 'and' 'rightwing' 'site' 'in' 'the' 'u' 'to' 'take' 'one' 'example' 'from' 'the' 'story' 'a' 'website' 'call' 'post' 'an' 'article' 'with'  ...
# 269                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 275                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'michael ...
# 293  'federal' 'prosecutor' 'warn' 'yous' 'district' 'judge' 'gregory' 'that' 'gang' 'member' 'and' 'radical' 'muslim' 'marcus' 'dwayne' 'robertson' 'be' 'dangerous' 'and' 'be' 'recruit' 'inmate' 'for' 'terrorism' 'yet' 'the' 'judge' 'release' 'him' 'the' 'gunman' 'who' 'murder' 'at' 'least' 'people' 'in' 'a' 'florida' 'nightclub' 'early' 'sunday' 'morning' 'be' 'a' 'follower' 'of' 'a' 'controversial' 'gang' 'robber' 'who' 'be' 'release' 'from' 'prison' 'last' 'year' 'despite' 'warning' 'from' 'prosecutor' 'that' 'he' 'would' 'recruit' 'people' 'to' 'carry' 'out' 'violent' 'act' 'source' 'tell' 'mateen' 'whose' 'bloody' 'siege' 'inside' 'a' 'packed' 'orlando' 'gay' 'nightclub' 'end' 'when' 'swat' 'team' 'storm' 'the' 'building' 'and' 'kill' 'him' 'be' 'a' 'radical' 'muslim' 'who' 'follow' 'marcus' 'dwayne' 'robertson' 'a' 'law' 'enforcement' 'source' 'say' 'it' 'be' 'no' 'coincidence' 'that' 'this' 'happen' 'in' 'orlando' 'say' 'a' 'law' 'enforcement' 'source' 'familiar' 'with' 'robertson' 's' 'history' 'of' 'recruit' 'terrorist' 'and' 'incite' 'violence' 'mateen' 'be' 'enrol' 'in' 'robertson' 's' 'online' 'fundamental' 'islamic' 'knowledge' 'seminary' 'robertson' 'and' 'several' 'associate' 'be' 'round' 'up' 'for' 'question' 'early' 'sunday' 'accord' 'to' 'law' 'enforcement' 'source' 'a' 'development' 'his' 'attorney' 'refuse' 'to' 'confirm' 'or' 's' 'school' 'may' 'not' 'have' 'be' 'the' 'only' 'source' 'of' 'mateen' 's' 'spiritual' 'guidance' 'the' 'gunman' 'be' 'at' 'the' 'islamic' 'center' 'of' 'fort' 'pierce' 'with' 'imam' 'rahman' 'two' 'day' 'before' 'the' 'nightclub' 'attack' 'accord' 'to' 'the' 'post' 'that' 'mosque' 'be' 'frequent' 'by' 'americanborn' 'suicide' 'bomber' 'abu' 'who' 'blow' 'himself' 'up' 'in' 'syria' 'in' 'and' 'the' 'two' 'knew' 'each' 'other' 'accord' 'to' 'official' 'mateen' 's' 'association' 'with' 'lead' 'the' 'fbi' 'to' 'interview' 'him' 'in' 'rep' 'michael' 'mccaul' 'chairman' 'of' 'the' 'house' 'homeland' 'security' 'committee' 'mike' 'mccaul' 'tell' 'fox' 'news' 'law' 'enforcement' 'determine' 'at' 'the' 'time' 'their' 'contact' 'be' 'minimal' 'foxnewscom' 'have' 'report' 'extensively' 'on' 'robertson' 'a' 'former' 'yous' 'marine' 'who' 'serve' 'a' 'a' 'bodyguard' 'to' 'the' 'blind' 'sheik' 'involve' 'in' 'the' 'world' 'trade' 'center' 'attack' 'and' 'lead' 'a' 'gang' 'of' 'new' 'york' 'bank' 'robber' 'call' 'ali' 'baba' 'and' 'the' 'thief' 'before' 'resurface' 'in' 'orlando' 'where' 'he' 'start' 'an' 'islamic' 'school' 'recently' 'rename' 'the' 'seminary' 'be' 'operate' 'by' 'robertson' 'a' 'yearold' 'firebrand' 'know' 'to' 'his' 'thousand' 'of' 'follower' 'a' 'abu' 'who' 'recently' 'spend' 'four' 'year' 'in' 'prison' 'in' 'florida' 'on' 'illegal' 'weapon' 'and' 'tax' 'fraud' 'charge' 'before' 'be' 'release' 'by' 'a' 'florida' 'judge' 'one' 'year' 'ago' 'have' 'openly' 'and' 'enthusiastically' 'preach' 'against' 'homosexuality' 'the' 'target' 'of' 'mateen' 's' 'bloody' 'rampage' 'be' 'member' 'of' 'the' 'gay' 'community' 'of' 'orlando' 'mile' 'from' 'the' 'yearold' 's' 'home' 'in' 'fort' 'say' 'wiretap' 'from' 'prove' 'robertson' 'instruct' 'one' 'of' 'his' 'student' 'jonathan' 'paul' 'jimenez' 'to' 'file' 'false' 'tax' 'return' 'to' 'obtain' 'a' 'tax' 'refund' 'to' 'pay' 'for' 'travel' 'to' 'mauritania' 'for' 'terror' 'study' 'with' 'robertson' 'for' 'a' 'year' 'in' 'preparation' 'for' 'his' 'travel' 'to' 'mauritania' 'where' 'he' 'would' 'study' 'and' 'further' 'his' 'training' 'in' 'kill' 'suicide' 'bombing' 'and' 'and' 'murder' 'yous' 'military' 'personnel' 'he' 'plead' 'guilty' 'in' 'to' 'lie' 'to' 'authority' 'and' 'conspire' 'to' 'defraud' 'the' 'irs' 'and' 'be' 'sentence' 'to' 'year' 'in' 'federal' 'be' 'arrest' 'on' 'a' 'firearms' 'charge' 'in' 'and' 'plead' 'guilty' 'in' 'january' 'on' 'march' 'federal' 'authority' 'charge' 'him' 'with' 'conspire' 'to' 'defraud' 'the' 'irs' 'which' 'he' 'be' 'convict' 'of' 'in' 'december' 'while' 'in' 'the' 'john' 'e' 'polk' 'correctional' 'facili ...
# 297                                                                                                                                                                                                                                                                      'after' 'nearly' 'a' 'year' 'of' 'cause' 'hysteria' 'mass' 'travel' 'cancellation' 'and' 'unnecessary' 'abortion' 'it' 'finally' 'daunt' 'to' 'journalist' 'and' 'expert' 'that' 'the' 'zika' 'virus' 'be' 'harmless' 'it' 'can' 'cause' 'a' 'very' 'minor' 'two' 'day' 'of' 'a' 'low' 'fever' 'and' 'uncomfortable' 'feeling' 'for' 'a' 'quarter' 'of' 'those' 'infect' 'that' 'be' 'all' 'it' 'do' 'not' 'because' 'a' 'be' 'claim' 'by' 'in' 'the' 'medium' 'and' 'various' 'selfserving' 'scientist' 'birth' 'defect' 'like' 'microcephaly' 'we' 'tell' 'you' 'so' 'in' 'february' 'we' 'write' 'the' 'zika' 'virus' 'be' 'harmless' 'who' 'then' 'benefit' 'from' 'this' 'medium' 'panic' 'the' 'piece' 'to' 'a' 'congressional' 'research' 'service' 'report' 'and' 'various' 'sound' 'scientific' 'paper' 'it' 'conclude' 'there' 'be' 'absolutely' 'no' 'sane' 'reason' 'for' 'the' 'scary' 'headline' 'and' 'the' 'panic' 'they' 'virus' 'be' 'harmless' 'it' 'be' 'possible' 'but' 'seem' 'for' 'now' 'very' 'unlikely' 'that' 'it' 'affect' 'some' 'unborn' 'child' 'there' 'be' 'absolutely' 'no' 'reason' 'to' 'be' 'concern' 'about' 'it' 'the' 'artificial' 'medium' 'panic' 'continue' 'and' 'huge' 'amount' 'of' 'money' 'be' 'pour' 'into' 'dangerous' 'to' 'kill' 'mosquito' 'and' 'important' 'pollinator' 'that' 'do' 'not' 'do' 'any' 'harm' 'indeed' 'generous' 'use' 'of' 'some' 'of' 'these' 'likely' 'be' 'the' 'very' 'because' 'of' 'a' 'blip' 'in' 'case' 'in' 'northeastern' 'brazil' 'in' 'march' 'we' 'write' 'read' 'about' 'zika' 'may' 'hurt' 'your' 'brain' 'we' 'list' 'sensational' 'news' 'headline' 'about' 'potential' 'catastrophe' 'relate' 'to' 'a' 'zika' 'epidemic' 'the' 'common' 'factor' 'of' 'those' 'panic' 'create' 'medium' 'wave' 'all' 'those' 'headline' 'include' 'the' 'miraculous' 'little' 'word' 'may' 'the' 'piece' 'be' 'pure' 'speculation' 'with' 'some' 'quote' 'this' 'or' 'that' 'expert' 'who' 'be' 'hunt' 'for' 'research' 'fund' 'or' 'lobbying' 'for' 'some' 'pharmaceutical' 'or' 'pesticide' 'conglomerate' 'in' 'june' 'we' 'add' 'zika' 'virus' 'do' 'not' 'because' 'birth' 'defect' 'fight' 'it' 'probably' 'do' 'new' 'serious' 'research' 'find' 'what' 'some' 'people' 'in' 'brazil' 'have' 'suspect' 'from' 'the' 'very' 'start' 'of' 'the' 'small' 'and' 'strictly' 'locally' 'limited' 'jump' 'in' 'case' 'in' 'brazil' 'doctor' 'in' 'the' 'zika' 'affect' 'area' 'in' 'brazil' 'point' 'out' 'that' 'the' 'real' 'because' 'of' 'somewhat' 'increased' 'microcephaly' 'in' 'the' 'region' 'be' 'probably' 'the' 'use' 'to' 'kill' 'mosquito' 'in' 'drinking' 'water' 'the' 'brazilian' 'doctor' 'note' 'that' 'the' 'area' 'of' 'northeast' 'brazil' 'that' 'have' 'witness' 'the' 'great' 'number' 'of' 'microcephaly' 'case' 'match' 'with' 'area' 'where' 'be' 'add' 'to' 'drink' 'water' 'in' 'an' 'effort' 'to' 'combat' 'mosquito' 'be' 'report' 'to' 'cause' 'in' 'mosquito' 'and' 'have' 'be' 'add' 'to' 'drink' 'water' 'in' 'the' 'region' 'for' 'the' 'past' 'month' 'be' 'produce' 'by' 'a' 'chemical' 'an' 'important' 'japanese' 'poison' 'giant' 'it' 'be' 'therefore' 'unsurprising' 'that' 'the' 'new' 'york' 'time' 'and' 'others' 'call' 'the' 'brazilian' 'doctor' 'report' 'a' 'conspiracy' 'theory' 'and' 'trot' 'out' 'some' 'expert' 'to' 'debunk' 'it' 'but' 'scientist' 'at' 'the' 'new' 'england' 'complex' 'system' 'institute' 'also' 'research' 'the' 'thesis' 'they' 'find' 'be' 'an' 'analog' 'of' 'juvenile' 'hormone' 'which' 'correspond' 'in' 'mammal' 'to' 'regulatory' 'molecule' 'include' 'acid' 'a' 'vitamin' 'a' 'with' 'which' 'it' 'have' 'and' 'whose' 'application' 'during' 'development' 'cause' 'microcephaly' 'test' 'of' 'by' 'the' 'manufacturer' 'widely' 'quote' 'a' 'give' 'no' 'evidence' 'for' 'developmental' 'toxicity' 'actually' 'fi ...
# 391                                                                                                                                                                                                                                                                                                                   'a' 'everyone' 'embrace' 'the' 'power' 'of' 'publicity' 'industry' 'leader' 'annie' 'jennings' 'founder' 'of' 'the' 'national' 'firm' 'annie' 'jennings' 'pr' 'share' 'the' 'new' 'way' 'to' 'think' 'of' 'publicity' 'and' 'avoid' 'the' 'many' 'pitfall' 'that' 'stand' 'in' 'your' 'way' 'with' 'so' 'many' 'people' 'sell' 'service' 'without' 'a' 'track' 'record' 'of' 'success' 'for' 'their' 'client' 'you' 'have' 'to' 'protect' 'yourself' 'and' 'ask' 'the' 'right' 'question' 'what' 'be' 'in' 'it' 'for' 'me' 'this' 'be' 'the' 'first' 'question' 'you' 'should' 'be' 'ask' 'about' 'your' 'publicity' 'strategy' 'in' 'addition' 'the' 'first' 'of' 'a' 'new' 'pr' 'mindset' 'for' 'success' 'the' 'other' 'two' 'understand' 'the' 'power' 'of' 'be' 'socially' 'relevant' 'and' 'thinking' 'of' 'your' 'medium' 'booking' 'a' 'asset' 'to' 'be' 'leverage' 'over' 'the' 'long' 'haul' 'come' 'into' 'play' 'a' 'you' 'start' 'build' 'your' 'ascent' 'to' 'the' 'top' 'to' 'be' 'sure' 'you' 'be' 'align' 'with' 'the' 'right' 'approach' 'to' 'your' 'publicity' 'that' 'will' 'elevate' 'your' 'credibility' 'exposure' 'and' 'business' 'you' 'must' 'ask' 'what' 'be' 'in' 'it' 'for' 'me' 'this' 'question' 'be' 'design' 'to' 'make' 'sure' 'you' 'be' 'buy' 'deliverable' 'this' 'mean' 'secure' 'pr' 'medium' 'placement' 'that' 'actually' 'occur' 'and' 'be' 'design' 'to' 'propel' 'your' 'personal' 'and' 'business' 'growth' 'forward' 'ask' 'this' 'question' 'make' 'sure' 'you' 'be' 'work' 'with' 'a' 'publicist' 'who' 'specialize' 'in' 'your' 'particular' 'growth' 'area' 'and' 'can' 'answer' 'the' 'question' 'a' 'it' 'pertain' 'to' 'your' 'goal' 'this' 'one' 'piece' 'of' 'advice' 'be' 'precious' 'ask' 'this' 'question' 'will' 'help' 'you' 'avoid' 'waste' 'your' 'money' 'and' 'instead' 'lead' 'to' 'you' 'invest' 'your' 'money' 'in' 'a' 'targeted' 'medium' 'strategy' 'with' 'specific' 'outcome' 'in' 'mind' 'that' 'serve' 'to' 'advance' 'your' 'level' 'of' 'achievement' 'and' 'stand' 'in' 'your' 'industry' 'when' 'you' 'simply' 'spend' 'your' 'marketing' 'money' 'without' 'a' 'plan' 'that' 'support' 'once' 'you' 'buy' 'the' 'service' 'the' 'money' 'be' 'go' 'however' 'when' 'you' 'know' 'what' 'be' 'in' 'it' 'for' 'you' 'and' 'invest' 'accordingly' 'you' 'can' 'expect' 'to' 'get' 'a' 'return' 'on' 'your' 'investment' 'now' 'this' 'be' 'how' 'a' 'great' 'pr' 'firm' 'work' 'they' 'be' 'always' 'ask' 'the' 'question' 'what' 'be' 'in' 'it' 'for' 'my' 'client' 'it' 'be' 'go' 'time' 'once' 'you' 'have' 'your' 'pr' 'strategy' 'in' 'place' 'it' 'be' 'time' 'to' 'go' 'after' 'the' 'medium' 'placement' 'it' 'be' 'time' 'to' 'decide' 'how' 'you' 'your' 'message' 'your' 'book' 'andor' 'area' 'of' 'expertise' 'to' 'society' 'today' 'many' 'people' 'will' 'try' 'to' 'force' 'a' 'topic' 'through' 'to' 'the' 'medium' 'this' 'be' 'a' 'mistake' 'it' 'be' 'so' 'much' 'good' 'to' 'go' 'with' 'the' 'medium' 'flow' 'that' 'be' 'the' 'issue' 'of' 'the' 'day' 'than' 'try' 'to' 'push' 'a' 'concept' 'or' 'conversation' 'that' 'have' 'no' 'social' 'relevance' 'at' 'the' 'time' 'define' 'what' 'it' 'be' 'you' 'want' 'to' 'say' 'and' 'understand' 'where' 'you' 'fit' 'into' 'the' 'national' 'conversation' 'on' 'topic' 'within' 'your' 'area' 'of' 'expertise' 'when' 'you' 'can' 'address' 'an' 'issue' 'people' 'be' 'talk' 'about' 'right' 'now' 'and' 'be' 'qualify' 'to' 'discuss' 'it' 'the' 'booker' 'can' 'say' 'yes' 'to' 'you' 'that' 'be' 'what' 'we' 'call' 'the' 'triple' 'win' 'the' 'show' 'keep' 'it' 'listener' 'or' 'viewer' 'glue' 'to' 'the' 'program' 'the' 'audience' 'be' 'fascinate' 'and' 'the' 'guest' 'you' 'be' 'very' 'happy' 'a' 'you' 'get' 'a' 'chance' 'to' 'share' 'your' 'message' 'promote' 'y ...
# ...
# 639                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'trump' 'campaign' 'be' 'sue' 'for' 'humiliate' 'skittle' 'candy' 'by' 'compare' 'it' 'to' 'syrian' 'muslim' 'it' 'be' 'a' 'campaign' 'ad' 'that' 'ignite' 'a' 'firestorm' 'donald' 'trump' 'jr' 'tweet' 'a' 'photo' 'of' 'a' 'bowl' 'of' 'skittle' 'and' 'compare' 'the' 'colorful' 'candy' 'to' 'syrian' 'jihadist' 'pose' 'a' 'refugee' 'now' 'the' 'man' 'who' 'take' 'the' 'photo' 'be' 'sue' 'donald' 'trump' 'donald' 'trump' 'jr' 'and' 'vicepresidential' 'nominee' 'mike' 'penny' 'for' 'copyright' 'infringement' 'liberal' 'accuse' 'the' 'tweet' 'of' 'be' 'racist' 'and' 'a' 'which' 'force' 'them' 'to' 'seek' 'shelter' 'in' 'the' 'near' 'safe' 'room' 'cbc' 'david' 'an' 'expert' 'photographer' 'and' 'former' 'cypriot' 'refugee' 'say' 'he' 'never' 'give' 'permission' 'and' 'never' 'would' 'give' 'permission' 'for' 'his' 'photo' 'to' 'be' 'use' 'in' 'the' 'ad' 'the' 'image' 'the' 'way' 'it' 'be' 'use' 'be' 'reprehensible' 'say' 'from' 'his' 'home' 'in' 'england' 'in' 'an' 'interview' 'with' 'cbc' 'news' 'it' 'be' 'ignore' 'the' 'plight' 'of' 'the' 'refugee' 'and' 'it' 'be' 'completely' 'unacceptable' 'that' 'someone' 'who' 'be' 'bear' 'into' 'privilege' 'would' 'steal' 'my' 'picture' 'and' 'use' 'it' 'to' 'make' 'this' 'political' 'point' 'say' 'when' 'he' 'first' 'saw' 'the' 'tweet' 'he' 'be' 'in' 'shock' 'he' 'explain' 'he' 'take' 'the' 'photo' 'in' 'a' 'an' 'experiment' 'use' 'artificial' 'lighting' 'and' 'post' 'it' 'on' 'flickr' 'i' 'just' 'could' 'not' 'believe' 'my' 'humble' 'picture' 'of' 'some' 'skittle' 'would' 'just' 'be' 'use' 'by' 'someone' 'so' 'powerful' 'say' 'his' 'lawyer' 'reach' 'out' 'to' 'the' 'trump' 'campaign' 'to' 'discuss' 'the' 'matter' 'but' 'get' 'no' 'response' 'so' 'he' 'report' 'a' 'copyright' 'violation' 'to' 'twitter' 'and' 'about' 'a' 'week' 'after' 'it' 'be' 'post' 'his' 'skittle' 'photo' 'be' 'remove' 'from' 'trump' 'jr' 'tweet' 'even' 'though' 'his' 'photo' 'be' 'no' 'longer' 'connect' 'to' 'the' 'ad' 'decide' 'to' 'file' 'a' 'lawsuit' 'at' 'a' 'federal' 'court' 'in' 'illinois' 'he' 'say' 'he' 'want' 'to' 'ensure' 'the' 'trump' 'campaign' 'never' 'use' 'the' 'work' 'again' 'as' 'well' 'he' 'want' 'to' 'spread' 'the' 'message' 'that' 'they' 'can' 'not' 'go' 'around' 'steal' 'from' 'author' 'like' 'myself' 'they' 'be' 'not' 'above' 'the' 'law' 'the' 'trump' 'campaign' 'tell' 'cbc' 'news' 'it' 'be' 'not' 'comment' 'on' 'the' 'case' 'at' 'this' 'time' 'back' 'in' 'september' 'trump' 'jr' 'defend' 'the' 'tweet' 'i' 'be' 'surprise' 'by' 'the' 'reaction' 'simply' 'because' 'it' 'be' 'a' 'metaphor' 'for' 'risk' 'he' 'say' 'at' 'a' 'campaign' 'stop' 'in' 'boise' 'idaho' 'trumps' 'election' 'campaign' 'have' 'call' 'for' 'extreme' 'vetting' 'of' 'immigrant' 'to' 'the' 'yous' 'especially' 'muslims' 'to' 'help' 'weed' 'out' 'anyone' 'who' 'could' 'be' 'a' 'danger' 'to' 'american' 'citizen' 'while' 'trumps' 'position' 'be' 'popular' 'with' 'some' 'american' 'his' 'eldest' 'son' 'tweet' 'outrage' 'on' 'social' 'medium' 'sorry' 'kid' 'for' 'all' 'we' 'know' 'you' 'could' 'be' 'a' 'poisonous' 'skittle' 'someone' 'tweet' 'along' 'with' 'a' ' ...
# 642                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 707                                                                                                                                                                                                                                                                                                'douglas' 'murray' 'author' 'of' 'the' 'strange' 'death' 'of' 'europe' 'immigration' 'identity' 'islam' 'give' 'a' 'stunning' 'account' 'of' 'the' 'self' 'murder' 'or' 'europe' 'in' 'the' 'death' 'of' 'europe' 'article' 'publish' 'by' 'have' 'travel' 'to' 'the' 'place' 'where' 'migrant' 'continue' 'to' 'land' 'and' 'the' 'place' 'where' 'they' 'keep' 'end' 'up' 'everywhere' 'i' 'have' 'go' 'i' 'have' 'come' 'to' 'the' 'same' 'conclusion' 'our' 'continent' 'be' 'in' 'the' 'process' 'of' 'the' 'daytoday' 'distraction' 'of' 'life' 'and' 'politics' 'it' 'be' 'easy' 'to' 'forget' 'this' 'big' 'event' 'of' 'our' 'time' 'all' 'pale' 'into' 'besides' 'the' 'story' 'of' 'the' 'loss' 'by' 'european' 'of' 'the' 'only' 'place' 'we' 'have' 'to' 'call' 'this' 'country' 'do' 'have' 'a' 'debate' 'about' 'immigration' 'it' 'be' 'minuscule' 'it' 'tend' 'to' 'focus' 'on' 'calais' 'the' 'british' 'public' 'see' 'footage' 'of' 'people' 'sit' 'in' 'makeshift' 'tent' 'or' 'hurl' 'missile' 'into' 'the' 'road' 'to' 'slow' 'the' 'truck' 'down' 'so' 'they' 'can' 'board' 'them' 'and' 'break' 'into' 'time' 'actor' 'celebrity' 'and' 'politician' 'head' 'to' 'calais' 'and' 'visit' 'the' 'camp' 'they' 'return' 'to' 'tell' 'the' 'british' 'public' 'that' 'it' 'must' 'be' 'more' 'and' 'argument' 'they' 'make' 'be' 'humane' 'it' 'be' 'an' 'understandable' 'reaction' 'to' 'human' 'misery' 'but' 'it' 'be' 'a' 'core' 'part' 'of' 'our' 'society' 's' 'suicide' 'that' 'example' 'of' 'calais' 'before' 'the' 'late' 'clearance' 'of' 'the' 'camp' 'there' 'be' 'about' 'people' 'live' 'there' 'none' 'of' 'them' 'should' 'have' 'be' 'thereby' 'be' 'there' 'they' 'have' 'already' 'break' 'every' 'one' 'of' 'the' 'rule' 'that' 'our' 'continent' 'put' 'in' 'place' 'which' 'demand' 'they' 'seek' 'asylum' 'in' 'the' 'first' 'country' 'of' 'arrival' 'almost' 'nobody' 'arrive' 'into' 'france' 'these' 'people' 'have' 'land' 'in' 'greece' 'or' 'italy' 'and' 'make' 'their' 'way' 'yet' 'still' 'the' 'celebrity' 'and' 'others' 'pick' 'at' 'our' 'conscience' 'can' 'we' 'not' 'be' 'generous' 'and' 'at' 'least' 'let' 'in' 'the' 'people' 'who' 'be' 'there' 'it' 'be' 'wholly' 'understandable' 'and' 'also' 'illinformed' 'this' 'year' 's' 'easter' 'weekend' 'alone' 'about' 'people' 'be' 'pick' 'up' 'between' 'the' 'coast' 'of' 'north' 'africa' 'and' 'the' 'south' 'of' 'be' 'describe' 'a' 'everyone' 'always' 'be' 'a' 'be' 'rescue' 'in' 'fact' 'what' 'happen' 'what' 'have' 'be' 'happen' 'for' 'year' 'be' 'that' 'each' 'day' 'boat' 'fill' 'with' 'migrant' 'set' 'out' 'from' 'north' 'the' 'height' 'of' 'the' 'migration' 'crisis' 'of' 'when' 'germany' 's' 'chancellor' 'angela' 'merkel' 'open' 'up' 'the' 'door' 'of' 'europe' 'to' 'the' 'world' 'the' 'whole' 'continent' 'begin' 'to' 'in' 'reality' 'that' 'flood' 'of' 'million' 'into' 'europe' 'only' 'speed' 'up' 'a' 'process' 'that' 'have' 'be' 'under' 'way' 'for' 'year' 'ever' 'since' 'the' 'postwar' 'period' 'european' 'government' 'have' 'encourage' 'migrant' 'worker' 'to' 'come' 'first' 'a' 'chancellor' 'merkel' 'herself' 'admit' 'in' 'a' 'speech' 'in' 'they' 'expect' 'the' 'worker' 'to' 'return' 'home' 'but' 'they' 'didn' 't' 'they' 'stay' 'a' 'do' 'the' 'flow' 'after' 'that' 'and' 'the' 'one' 'for' 'decade' 'after' 'thatthe' 'government' 'of' 'country' 'such' 'a' 'ours' 'fail' 'to' 'get' 'anything' 'right' 'all' 'their' 'prediction' 'be' 'wrong' 'for' 'decade' 'they' 'be' 'wrong' 'that' 'people' 'would' 'stay' 'for' 'only' 'a' 'short' 'time' 'wrong' 'to' 'think' 'that' 'they' 'would' 'not' 'continue' 'to' 'come' 'in' 'large' 'that' 'they' 'might' 'not' 'want' 'to' 'bring' 'their' 'extended' 'family' 'to' 'join' 'them' 'and' 'wrong' 'to' 'think' 'that' 'once' ...
#
#      Predikció valószínűsége
# 17                    0.2297
# 151                   0.9872
# 162                   0.7992
# 235                   0.9436
# 244                   0.4518
# 269                   0.9910
# 275                   0.0642
# 293                   0.7466
# 297                   0.5140
# 391                   0.6067
# 404                   0.8983
# 408                   0.2027
# 454                   0.7492
# 464                   0.9806
# 490                   0.6553
# 497                   0.0471
# 508                   0.2271
# 639                   0.7954
# 642                   0.0048
# 707                   0.7548

# %% [markdown]
# # Tanulás-validáció-teszt összehasonlítása két modellnél

# %%
test_loss_lstm, test_accuracy_lstm = lstm_trainable.evaluate(padded_test, y_test, verbose=0)
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test, verbose=0)

# Ábra létrehozása két alábrával
plt.figure(figsize=(12, 5))

# Tanulási, validációs és teszthalmaz veszteség ábrázolása
plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='LSTM tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='LSTM validációs veszteség', color='#7fcdbb')
plt.plot(history_gru_trainable.history['loss'], label='GRU tanulási veszteség', color='red')
plt.plot(history_gru_trainable.history['val_loss'], label='GRU validációs veszteség', color='orange')
plt.axhline(y=test_loss_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz veszteség')  # LSTM teszt loss
plt.axhline(y=test_loss_gru, color='red', linestyle='--', label='GRU teszthalmaz veszteség')  # GRU teszt loss
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Ttanulási, validációs és teszthalmaz precízió ábrázolása
if 'accuracy' in lstm_history_trainable.history and 'accuracy' in history_gru_trainable.history:
    plt.subplot(1, 2, 2)
    plt.plot(lstm_history_trainable.history['accuracy'], label='LSTM tanulási pontosság', color='blue')
    plt.plot(lstm_history_trainable.history['val_accuracy'], label='LSTM validációs pontosság', color='#7fcdbb')
    plt.plot(history_gru_trainable.history['accuracy'], label='GRU tanulási pontosság', color='red')
    plt.plot(history_gru_trainable.history['val_accuracy'], label='GRU validációs pontosság', color='orange')
    plt.axhline(y=test_accuracy_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz pontosság')  # LSTM teszt accuracy
    plt.axhline(y=test_accuracy_gru, color='red', linestyle='--', label='GRU teszthalmaz pontosság')  # GRU teszt accuracy
    plt.xlabel('Epizód')
    plt.ylabel('Pontosság')
    plt.legend()
    plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.tight_layout()
plt.show()
