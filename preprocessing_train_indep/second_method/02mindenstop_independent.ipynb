# %% [markdown]
# # **Csomagok behívása**

# %%
#Szükséges csomagok és adatbázis importálása
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Concatenate
import numpy as np
import tensorflow as tf
import spacy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fájlok behívása, ellenőrzése és felkészítése

# %%
# Betölteni padded sequences, tokenizer, és számokat
padded_train = np.load('/content/padded_train02.npy')
padded_test = np.load('/content/padded_independent02.npy')

# Tokenizer visszatöltése
with open('/content/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Címkék betöltése (real = 1, fake = 0)
train_file = '/content/train_masodik.csv'
test_file = '/content/indep_masodik.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

labels_train = df_train['label'].values
labels_test = df_test['label'].values

# Betölteni embedding mátrixot
embedding_matrix = np.load('/content/embedding_matrix.npy')

# Ellenőrzés
print(f"Train padded sequences shape: {padded_train.shape}")
print(f"Test padded sequences shape: {padded_test.shape}")
print(f"Train labels shape: {labels_train.shape}")
print(f"Test labels shape: {labels_test.shape}")
# Out:
# Train padded sequences shape: (59520, 600)
# Test padded sequences shape: (14304, 600)
# Train labels shape: (59520,)
# Test labels shape: (14304,)

# %%
# Max szókincs és szekvencia hossz
MAX_VOCAB_SIZE = 25000
MAX_LENGTH = 600
EMBEDDING_DIM = 300  # GloVe 300d

# input shape
MAX_SEQUENCE_LENGTH = padded_train.shape[1]

# Szöveges input (LSTM/GRU bemenet)
text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
embedding_layer = Embedding(
    input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
    output_dim=embedding_matrix.shape[1],
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)(text_input)

model_output = embedding_layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
MAX_SEQUENCE_LENGTH = padded_train.shape[1]  # Train hossz
EMBEDDING_DIM = embedding_matrix.shape[1]  # GloVe embeddings

# 10%-os validációs halmaz leválasztása a tanító adatokból
padded_train_final, padded_val, y_train_final, y_val = train_test_split(
    padded_train, labels_train, test_size=0.1, random_state=42
)
# Float32-re konvertálás TensorFlow kompatibilitás miatt
padded_train_final = np.array(padded_train_final, dtype=np.float32)
padded_val = np.array(padded_val, dtype=np.float32)
padded_test = np.array(padded_test, dtype=np.float32)
y_train_final = np.array(y_train_final, dtype=np.float32)
y_val = np.array(y_val, dtype=np.float32)
y_test = np.array(labels_test, dtype=np.float32)

# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# # LSTM MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ## Modell lefuttatása

# %%
# LSTM modell, trainable, non-trainable embedding

def create_lstm_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings
    )(text_input)

    # LSTM rétegek
    lstm_out = LSTM(128, return_sequences=True, dropout=0.3)(text_embedding)
    lstm_out = Dropout(0.3)(lstm_out)  # Dropout réteg az első LSTM után
    lstm_out = LSTM(64,return_sequences=True, dropout=0.3)(lstm_out)
    lstm_out = Dropout(0.3)(lstm_out) # Dropout réteg az második LSTM után
    lstm_out = LSTM(32, dropout=0.3)(lstm_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(lstm_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása
lstm_trainable = create_lstm_model(trainable_embeddings=True)  # Trainable embedding

lstm_trainable.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_1 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 600, 128)            │         219,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 600, 64)             │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,781,505 (29.68 MB)
#  Trainable params: 7,781,505 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Modell tanítása a validációs adatok figyelésével
lstm_history_trainable = lstm_trainable.fit(
    padded_train_final, y_train_final,
    validation_data=(padded_val, y_val),  # Validációs halmaz
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság: {test_accuracy:.4f}, Teszthalmaz veszteség: {test_loss:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 74s 81ms/step - accuracy: 0.7986 - loss: 0.4458 - val_accuracy: 0.6326 - val_loss: 0.6894
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 81s 84ms/step - accuracy: 0.8680 - loss: 0.3180 - val_accuracy: 0.8537 - val_loss: 0.3066
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9270 - loss: 0.1851 - val_accuracy: 0.9503 - val_loss: 0.1459
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 73s 87ms/step - accuracy: 0.9613 - loss: 0.1154 - val_accuracy: 0.9597 - val_loss: 0.1225
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9739 - loss: 0.0790 - val_accuracy: 0.9543 - val_loss: 0.1376
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.9742 - loss: 0.0808 - val_accuracy: 0.9609 - val_loss: 0.1247
# Epoch 7/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9854 - loss: 0.0452 - val_accuracy: 0.9634 - val_loss: 0.1167
# Epoch 8/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 73s 87ms/step - accuracy: 0.9911 - loss: 0.0307 - val_accuracy: 0.9645 - val_loss: 0.1271
# Epoch 9/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9953 - loss: 0.0199 - val_accuracy: 0.9693 - val_loss: 0.1120
# Epoch 10/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.9966 - loss: 0.0141 - val_accuracy: 0.9706 - val_loss: 0.1165
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.8722 - loss: 0.5432
# Teszthalmaz pontosság: 0.8691, Teszthalmaz veszteség: 0.5595

# %%
# Valószínűség becslése
lstm_y_prob = lstm_trainable.predict(padded_test)

lstm_y_pred = (lstm_y_prob > 0.5).astype(int)

lstm_accuracy = accuracy_score(y_test, lstm_y_pred)
lstm_precision = precision_score(y_test, lstm_y_pred)
lstm_recall = recall_score(y_test, lstm_y_pred)
lstm_f1 = f1_score(y_test, lstm_y_pred)

print(f"Accuracy: {lstm_accuracy:.4f}")
print(f"Precision: {lstm_precision:.4f}")
print(f"Recall: {lstm_recall:.4f}")
print(f"F1-score: {lstm_f1:.4f}")
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step
# Accuracy: 0.8695
# Precision: 0.9515
# Recall: 0.7788
# F1-score: 0.8565

# %% [markdown]
# ## LSTM Modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(lstm_history_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(lstm_history_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.8707 - loss: 0.5301

# %%
# Confusion Matrix
cm_lstm = confusion_matrix(y_test, lstm_y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm_lstm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix LSTM Modellre')
plt.show()

print(classification_report(y_test, lstm_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.96      0.88      7152
#          1.0       0.95      0.78      0.86      7152
#
#     accuracy                           0.87     14304
#    macro avg       0.88      0.87      0.87     14304
# weighted avg       0.88      0.87      0.87     14304

# %%
# Flatten
y_true = y_test.flatten()
y_pred = lstm_y_pred.flatten()
y_prob = lstm_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás besorolás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás besorolás) LSTM Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": lstm_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = lstm_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_lstm.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 10   Hamis negatív (FN)           1.0                 0
# 12   Hamis negatív (FN)           1.0                 0
# 13   Hamis pozitív (FP)           0.0                 1
# 23   Hamis negatív (FN)           1.0                 0
# 27   Hamis pozitív (FP)           0.0                 1
# 51   Hamis negatív (FN)           1.0                 0
# 71   Hamis negatív (FN)           1.0                 0
# 79   Hamis negatív (FN)           1.0                 0
# 111  Hamis negatív (FN)           1.0                 0
# 128  Hamis negatív (FN)           1.0                 0
# 137  Hamis negatív (FN)           1.0                 0
# 157  Hamis negatív (FN)           1.0                 0
# 192  Hamis negatív (FN)           1.0                 0
# 194  Hamis negatív (FN)           1.0                 0
# 195  Hamis negatív (FN)           1.0                 0
# 198  Hamis negatív (FN)           1.0                 0
# 199  Hamis negatív (FN)           1.0                 0
# 221  Hamis pozitív (FP)           0.0                 1
# 229  Hamis negatív (FN)           1.0                 0
# 249  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'geneva' 'the' 'world' 'health' 'organization' 'say' 'wednesday' 'it' 'be' 'too' 'early' 'to' 'lift' 'the' 'alert' 'for' 'the' 'crisis' 'with' 'the' 'pandemic' 'remain' 'a' 'global' 'health' 'emergency' 'despite' 'recent' 'progress' 'the' 'who' 'be' 'emergency' 'committee' 'on' 'meet' 'last' 'week' 'and' 'conclude' 'that' 'the' 'pandemic' 'still' 'constitute' 'a' 'public' 'health' 'emergency' 'of' 'international' 'concern' 'a' 'status' 'it' 'declare' 'back' 'in' 'january' 'who' 'chief' 'tedros' 'tell' 'reporter' 'wednesday' 'that' 'he' 'agree' 'with' 'the' 'committee' 'advice' 'the' 'committee' 'emphasize' 'the' 'need' 'to' 'strengthen' 'surveillance' 'and' 'expand' 'access' 'to' 'test' 'treatment' 'and' 'vaccine' 'for' 'those' 'most' 'at' 'risk' 'he' 'say' 'speak' 'from' 'the' 'un' 'health' 'agency' 'headquarters' 'in' 'geneva' 'the' 'who' 'first' 'declare' 'the' 'outbreak' 'a' 'on' 'january' 'when' 'outside' 'of' 'china' 'few' 'than' 'case' 'and' 'no' 'death' 'have' 'be' 'report' 'though' 'it' 'be' 'the' 'mechanism' 'for' 'trigger' 'an' 'international' 'response' 'to' 'such' 'outbreak' 'it' 'be' 'only' 'in' 'march' 'when' 'tedros' 'describe' 'the' 'worsen' 'situation' 'a' 'a' 'pandemic' 'that' 'many' 'country' 'wake' 'up' 'to' 'the' 'danger' 'since' 'the' 'start' 'of' 'the' 'pandemic' 'more' 'than' 'million' 'confirm' 'case' 'have' 'be' 'report' 'to' 'who' 'and' 'more' 'than' 'million' 'death' 'although' 'those' 'number' 'be' 'believe' 'to' 'be' 'significant' 'underestimate' 'accord' 'to' 'who' 'be' 'global' 'dashboard' 'of' 'the' 'situation' 'new' 'case' 'be' 'report' 'in' 'the' 'previous' 'hour' 'while' 'new' 'death' 'have' 'be' 'report' 'in' 'the' 'past' 'week' 'tedros' 'acknowledge' 'wednesday' 'that' 'the' 'global' 'situation' 'have' 'obviously' 'improve' 'since' 'the' 'pandemic' 'begin' 'but' 'he' 'warn' 'that' 'the' 'virus' 'continue' 'to' 'change' 'and' 'there' 'remain' 'many' 'risk' 'and' 'uncertainty' 'the' 'pandemic' 'have' 'surprise' 'u' 'before' 'and' 'very' 'well' 'could' 'again' 'he' 'warn' 'surveillance' 'have' 'decline' 'maria' 'van' 'the' 'who' 'be' 'technical' 'lead' 'agree' 'warn' 'that' 'there' 'be' 'still' 'million' 'of' 'case' 'be' 'report' 'each' 'week' 'but' 'our' 'surveillance' 'have' 'decline' 'this' 'be' 'make' 'it' 'difficult' 'to' 'get' 'a' 'full' 'overview' 'of' 'the' 'situation' 'and' 'especially' 'of' 'how' 'the' 'virus' 'be' 'she' 'stress' 'that' 'the' 'more' 'this' 'virus' 'circulate' 'the' 'more' 'opportunity' 'it' 'have' 'to' 'change' 'the' 'variant' 'account' 'for' 'basically' 'all' 'virus' 'sample' 'that' 'be' 'sequence' 'with' 'more' 'than' 'of' 'that' 'variant' 'record' 'all' 'of' 'the' 'of' 'be' 'show' 'increased' 'and' 'property' 'of' 'immune' 'escape' 'van' 'say' 'add' 'that' 'one' 'new' 'combination' ' ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'city' 'philippine' 'heavily' 'arm' 'men' 'brutally' 'kill' 'a' 'village' 'chief' 'and' 'four' 'of' 'his' 'loved' 'one' 'in' 'a' 'coldblooded' 'ambush' 'in' 'del' 'province' 'on' 'thursday' 'afternoon' 'january' 'the' 'attack' 'which' 'also' 'leave' 'two' 'others' 'wound' 'take' 'place' 'in' 'the' 'remote' 'village' 'of' 'locate' 'approximately' 'kilometer' 'southwest' 'of' 'city' 'a' 'fear' 'and' 'uncertainty' 'spread' 'throughout' 'the' 'community' 'military' 'and' 'police' 'force' 'be' 'swiftly' 'deploy' 'to' 'the' 'predominantly' 'muslim' 'town' 'of' 'in' 'del' '3rd' 'district' 'in' 'a' 'bid' 'to' 'prevent' 'any' 'further' 'act' 'of' 'violence' 'or' 'retaliation' 'accord' 'to' 'police' 'report' 'the' 'arm' 'group' 'target' 'chairman' 'ali' 'and' 'his' 'family' 'member' 'in' 'a' 'ruthless' 'assault' 'that' 'shake' 'the' 'community' 'to' 'it' 'core' 'the' 'village' 'chief' 'alongside' 'his' 'wife' 'ani' 'and' 'be' 'brutally' 'kill' 'in' 'the' 'attack' 'colonel' 'glenn' 'commander' 'of' 'the' 'del' 'police' 'provincial' 'command' 'say' 'two' 'others' 'in' 'the' 'chairman' 'group' 'and' 'norman' 'survive' 'the' 'ambush' 'the' 'victim' 'be' 'travel' 'in' 'a' 'pickup' 'truck' 'that' 'be' 'riddle' 'with' 'bullet' 'on' 'a' 'road' 'in' 'indicating' 'that' 'the' 'attacker' 'use' 'highpowered' 'firearm' 'and' 'plan' 'to' 'kill' 'everyone' 'i ...
# 13                                                 'renowned' 'harvard' 'psychologist' 'say' 'adhd' 'be' 'largely' 'a' 'fraud' 'view' 'by' 'academic' 'a' 'one' 'of' 'the' 'most' 'influential' 'psychologist' 'of' 'the' '20th' 'century' 'jerome' 'kagan' 'r' 'print' 'email' 'view' 'by' 'academic' 'a' 'one' 'of' 'the' 'most' 'influential' 'psychologist' 'of' 'the' '20th' 'century' 'jerome' 'kagan' 'rank' 'above' 'carl' 'jung' 'the' 'founder' 'of' 'analytical' 'psychology' 'and' 'ivan' 'pavlov' 'who' 'discover' 'the' 'reflex' 'in' 'a' 'american' 'psychological' 'association' 'ranking' 'of' 'the' 'eminent' 'psychologist' 'he' 'be' 'wellknown' 'for' 'his' 'pioneering' 'work' 'in' 'developmental' 'psychology' 'at' 'harvard' 'university' 'where' 'he' 'have' 'spend' 'decade' 'document' 'how' 'baby' 'and' 'small' 'child' 'grow' 'and' 'be' 'an' 'exceptional' 'and' 'it' 'may' 'be' 'surprise' 'to' 'learn' 'that' 'he' 'believe' 'the' 'diagnosis' 'of' 'adhd' 'attention' 'deficit' 'disorder' 'be' 'an' 'invention' 'and' 'only' 'benefit' 'the' 'pharmaceutical' 'industry' 'and' 'psychiatrist' 'mental' 'illness' 'that' 'be' 'the' 'history' 'of' 'humanity' 'those' 'in' 'authority' 'believe' 'they' 'be' 'do' 'the' 'right' 'thing' 'and' 'they' 'harm' 'those' 'who' 'have' 'no' 'power' 'say' 'jerome' 'an' 'interview' 'with' 'spiegel' 'kagan' 'address' 'the' 'skyrocket' 'rate' 'of' 'adhd' 'in' 'america' 'which' 'he' 'attribute' 'to' 'fuzzy' 'diagnostic' 'practice' 'he' 'illustrate' 'his' 'point' 'with' 'the' 'follow' 'fifty' 'year' 'ago' 'you' 'have' 'a' 'yearold' 'who' 'be' 'bore' 'in' 'school' 'and' 'exhibit' 'disruptive' 'behavior' 'back' 'then' 'he' 'would' 'be' 'label' 'a' 'lazy' 'but' 'today' 'that' 'same' 'child' 'be' 'say' 'to' 'suffer' 'from' 'adhd' 'that' 'be' 'why' 'we' 'have' 'see' 'such' 'a' 'dramatic' 'increase' 'in' 'the' 'child' 'who' 'be' 'have' 'problem' 'in' 'school' 'be' 'send' 'to' 'see' 'a' 'pediatrician' 'who' 'then' 'claim' 'it' 'be' 'adhd' 'and' 'in' 'fact' 'percent' 'of' 'these' 'million' 'kid' 'do' 'not' 'have' 'an' 'abnormal' 'dopamine' 'metabolism' 'the' 'problem' 'be' 'if' 'a' 'drug' 'be' 'available' 'to' 'doctor' 'they' 'will' 'make' 'the' 'corresponding' 'diagnosis' 'he' 'could' 'get' 'philosophical' 'and' 'ask' 'ourselves' 'what' 'do' 'mental' 'illness' 'mean' 'if' 'you' 'do' 'interview' 'with' 'child' 'and' 'adolescent' 'age' 'to' 'then' 'percent' 'can' 'be' 'categorize' 'a' 'anxious' 'or' 'depressed' 'but' 'if' 'you' 'take' 'a' 'close' 'look' 'and' 'ask' 'how' 'many' 'of' 'them' 'be' 'seriously' 'impair' 'by' 'this' 'the' 'number' 'shrink' 'to' 'percent' 'describe' 'every' 'child' 'who' 'be' 'depress' 'or' 'anxious' 'a' 'be' 'mentally' 'ill' 'be' 'ridiculous' 'adolescent' 'be' 'anxious' 'that' 'be' 'normal' 'they' 'do' 'not' 'know' 'what' 'college' 'to' 'go' 'to' 'their' 'boyfriend' 'or' 'girlfriend' 'just' 'stand' 'them' 'up' 'be' 'sad' 'or' 'anxious' 'be' 'just' 'as' 'much' 'a' 'part' 'of' 'life' 'a' 'anger' 'or' 'sexual' 'frustration' 'kagan' 'tell' 'be' 'the' 'implication' 'for' 'the' 'million' 'of' 'american' 'child' 'who' 'be' 'inaccurately' 'diagnose' 'a' 'mentally' 'ill' 'kagan' 'believe' 'it' 'be' 'devastate' 'because' 'they' 'think' 'there' 'be' 'something' 'fundamentally' 'wrong' 'with' 'them' 'he' 'be' 'not' 'the' 'only' 'psychologist' 'to' 'raise' 'the' 'alarm' 'about' 'this' 'trend' 'but' 'kagan' 'and' 'others' 'feel' 'they' 'be' 'up' 'against' 'an' 'enormously' 'powerful' 'alliance' 'pharmaceutical' 'company' 'that' 'be' 'make' 'billion' 'and' 'a' 'profession' 'that' 'be' 'himself' 'suffer' 'from' 'inner' 'and' 'a' 'a' 'child' 'but' 'his' 'mother' 'tell' 'him' 'there' 'be' 'nothing' 'wrong' 'with' 'you' 'your' 'mind' 'be' 'work' 'faster' 'than' 'your' 'think' 'at' 'the' 'time' 'gee' 'that' 'be' 'great' 'i' 'be' 'only' 'stutter' 'because' 'i' 'be' 'so' 'smart' 'if' 'he' 'have' 'be' 'bear' 'in' 'the' 'present' 'era' 'he' 'most' 'likely' 'would' 'have' 'be' 'classify' 'a' 'mentally' 'be' 'not' 'the' 'only'  ...
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'six' 'official' 'of' 'the' 'philippine' 'national' 'police' 'pnp' 'drug' 'enforcement' 'group' 'special' 'operation' 'unit' 'be' 'relieve' 'from' 'their' 'post' 'in' 'the' 'official' 'be' 'face' 'allegation' 'of' 'kidnapping' 'and' 'torture' 'accord' 'to' 'jun' 'report' 'on' 'wednesday' 'yun' 'relieve' 'ni' 'director' 'yun' 'in' 'fairness' 'to' 'them' 'allegation' 'yun' 'police' 'colonel' 'martinez' 'deputy' 'director' 'for' 'administration' 'say' 'base' 'on' 'the' 'report' 'the' 'complainant' 'say' 'that' 'they' 'be' 'force' 'to' 'ride' 'the' 'operative' 'vehicle' 'and' 'be' 'take' 'to' 'the' 'headquarters' 'of' 'the' 'where' 'they' 'be' 'allegedly' 'tortured' 'pnp' 'chief' 'police' 'general' 'benjamin' 'jr' 'maintain' 'that' 'misconduct' 'will' 'not' 'be' 'tolerate' 'under' 'his' 'leadership' 'he' 'also' 'urge' 'the' 'public' 'that' 'there' ' ...
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'unidentified' 'muslim' 'on' 'the' 'run' 'after' 'stab' 'four' 'people' 'at' 'a' 'frankfurt' 'train' 'station' 'the' 'attack' 'this' 'afternoon' 'occur' 'at' 'station' 'and' 'police' 'have' 'say' 'there' 'be' 'four' 'victim' 'at' 'this' 'stage' 'the' 'motive' 'for' 'the' 'stabbings' 'be' 'not' 'clear' 'it' 'will' 'become' 'crystal' 'clear' 'once' 'you' 'identify' 'the' 'attacker' 'a' 'a' 'muslim' 'uk' 'daily' 'mail' 'ht' 'the' 'local' 'police' 'force' 'confirm' 'the' 'attack' 'by' 'tweet' 'there' 'be' 'a' 'knife' 'assault' 'at' 'the' 'in' 'frankfurt' 'that' 'be' 'why' 'so' 'many' 'colleague' 'police' 'officer' 'and' 'rescue' 'worker' 'there' 'frankfurt' 'police' 'confirm' 'all' 'four' 'victim' 'be' 'still' 'in' 'hospital' 'a' 'video' 'of' 'the' 'bloody' 'aftermath' 'be' 'capture' 'on' 'what' 'be' 'understood' 'to' 'be' 'level' 'b' 'of' 'the' 'station' 'the' 'incident' 'be' 'at' '30pm' 'local' 'time' 'accord' 'to' 'who' 'report' 'the' 'stabbings' 'come' 'after' 'a' 'group' 'be' 'quarrel' 'a' 'dispute' 'have' 'start' 'on' 'one' 'platform' 'and' 'spill' 'over' 'onto' 'another' 'one' 'there' 'be' 'more' 'bloodshed' 'in' 'a' 'separate' 'incident' 'at' 'the' 'station' 'understood' 'to' 'be' 'on' 'a' 'passenger' 'train' 'between' 'and' 'a' 'dispute' 'between' 'two' 'passenger' 'break' 'out' 'into' 'a' 'fight' 'accord' 'to' 'which' 'lead' 'to' 'glass' 'be' 'break' 'and' 'people' 'suffer' 'cut' 'frankfurt' 'police' 'look' 'to' 'reassure' 'the' 'public' 'by' 'tweet' 'if' 'we' 'recognize' 'a' 'threat' 'to' 'the' 'local' 'population' 'we' 'would' 'communicate' 'this' 'no' 'you' 'would' 'not' 'the' 'stabbings' 'will' 'still' 'raise' 'fear' 'the' 'attack' 'be' 'islamic' 'after' 'a' 'string' 'of' 'incident' 'across' 'europe' 'over' 'recent' 'month' 'germany' 'have' 'be' 'rock' 'by' 'islamic' 'terror' 'attack' 'this' 'year' 'heap' 'pressure' 'on' 'chancellor' 'angela' 'merkels' 'opendoor' 'muslim' 'immigration' 'policy' 'a' 'bloody' 'week' 'of' 'violence' 'that' 'rock' 'germany' 'begin' 'on' 'july' 'when' 'pakistani' 'muslim' 'teenager' 'khan' 'pose' 'a' 'an' 'afghan' 'refugee' 'hack' 'at' 'passenger' 'on' 'a' 'train' 'in' 'with' 'an' 'axe' 'wound' 'five' 'four' 'day' 'later' 'a' 'muslim' 'teenager' 'ali' 'shot' 'nine' 'people' 'dead' 'during' 'a' 'rampage' 'throug ...
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    'the' 'bureau' 'of' 'immigration' 'bi' 'arrest' 'and' 'set' 'to' 'deport' 'a' 'chinese' 'national' 'who' 'be' 'be' 'search' 'by' 'authority' 'for' 'allegedly' 'misrepresent' 'himself' 'a' 'a' 'filipino' 'suspect' 'tai' 'be' 'nab' 'in' 'manila' 'on' 'tuesday' 'may' 'after' 'a' 'warrant' 'of' 'deportation' 'be' 'issue' 'against' 'him' 'in' 'july' 'last' 'year' 'for' 'be' 'an' 'undesirable' 'alien' 'tai' 'allegedly' 'assume' 'the' 'name' 'of' 'one' 'albert' 'torres' 'and' 'have' 'be' 'use' 'the' 'fictitious' 'identity' 'in' 'file' 'incorporation' 'paper' 'acquire' 'a' 'driver' 'license' 'register' 'his' 'business' 'as' 'well' 'a' 'in' 'other' 'public' 'document' 'accord' 'to' 'the' 'immigrati ...
# 71                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               'president' 'rodrigo' 'duterte' 'on' 'monday' 'blame' 'the' 'spread' 'of' 'false' 'information' 'on' 'vaccine' 'for' 'the' 'low' 'turnout' 'of' 'immunization' 'in' 'some' 'area' 'of' 'the' 'country' 'false' 'news' 'it' 'can' 'spread' 'immediately' 'and' 'the' 'problem' 'be' 'may' 'so' 'caveat' 'there' 'be' 'not' 'warn' 'na' 'duterte' 'say' 'during' 'the' 'weekly' 'talk' 'to' 'the' 'people' 'the' 'problem' 'be' 'false' 'news' 'it' 'can' 'spread' 'immediately' 'and' 'the' 'problem' 'be' 'some' 'people' 'believe' 'it' 'there' 'be' 'no' 'caveat' 'no' 'warn' 'as' 'long' 'a' 'they' 'read' 'it' 'i' 'hope' 'i' 'be' 'address' 'the' 'entire' 'nation' 'sa' 'he' 'say' 'i' 'hope' 'i' 'be' 'address' 'the' 'entire' 'nation' 'because' 'this' 'be' 'important' 'for' 'u' 'duterte' 'acknowledge' 'the' 'government' 'be' 'find' 'it' 'difficult' 'to' 'curb' 'the' 'proliferation' 'of' 'disinformation' 'either' 'through' 'private' 'communication' 'or' 'with' 'those' 'who' 'be' 'against' 'the' 'government' 'such' 'a' 'the' 'communist' 'party' 'of' 'the' 'people' 'army' 'there' 'be' 'no' 'way' 'we' 'can' 'really' 'go' 'up' 'against' 'the' 'panic' 'hatred' 'specially' 'ng' 'government' 'like' 'he' 'say' 'they' 'have' 'be' 'feed' 'the' 'public' 'with' 'ko' 'lang' 'po' 'sa' 'i' 'say' 'i' 'be' 'on' 'my' 'last' 'stretch' 'so' 'i' 'can' 'only' 'give' 'you' 'the' 'thing' 'that' 'can' 'make' 'this' 'country' 'well' 'for' 'everybody' 'there' 'be' 'no' 'way' 'we' 'can' 'really' 'go' 'up' 'against' 'the' 'panic' 'hatred' 'specially' 'if' 'government' 'enemy' 'like' 'the' 'they' 'have' 'be' 'feed' 'the' 'public' 'with' 'lie' 'all' 'i' 'ask' 'of' 'you' 'a' 'i' 'say' 'i' 'be' 'on' 'my' 'last' 'stretch' 'so' 'i' 'can' 'only' 'give' 'you' 'the' 'thing' 'that' 'can' 'make' 'this' 'country' 'well' 'for' 'everybody' 'the' 'president' 'do ...
# 79                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'two' 'minor' 'be' 'prostitute' 'be' 'rescue' 'by' 'operative' 'in' 'a' 'sting' 'operation' 'which' 'lead' 'to' 'the' 'arrest' 'of' 'one' 'of' 'their' 'pimp' 'during' 'the' 'operation' 'the' 'pimp' 'bring' 'along' 'with' 'her' 'two' 'minor' 'female' 'age' 'and' 'to' 'a' 'vehicle' 'where' 'two' 'undercover' 'operative' 'be' 'seat' 'the' 'transaction' 'take' 'place' 'inside' 'the' 'vehicle' 'where' 'the' 'operative' 'bargain' 'for' 'a' 'cheap' 'price' 'a' 'they' 'earlier' 'agree' 'to' 'pay' 'for' 'three' 'female' 'but' 'only' 'two' 'arrive' 'the' 'pimp' 'be' 'arrest' 'a' 'she' 'exit' 'the' 'vehicle' 'accord' 'to' 'city' 'police' 'district' 'station' 'investigation' 'chief' 'anthony' 'the' 'suspect' 'be' 'part' 'of' 'a' 'group' 'that' 'prostitute' 'child' 'transaction' 'be' 'online' 'group' 'group' 'chat' 'sa' 'ng' 'prostitution' 'sa' 'minor' 'he' 'say' 'in' 'a' 'report' 'on' 'weekend' 'on' 'sunday' 'their' 'transaction' 'be' 'do' 'online' 'they' 'have' 'a' 'group' 'a' 'group' 'chat' 'for' 'the' 'transaction' 'where' 'they' 'prostitute' 'minor' 'one' 'of' 'the' 'father' 'of' 'the' 'minor' 'say' 'the' 'child' 'tell' 'him' 'she' 'be' 'go' 'to' 'attend' 'a' 'birthday' 'party' 'and' 'he' 'do' 'not' 'know' 'that' 'she' 'be' 'instead' 'be' 'prostitute' 'ko' 'po' 'na' 'po' 'po' 'nasa' 'din' 'po' 'eh' 'ko' 'lang' 'din' 'po' 'din' 'na' 'na' 'he' 'say' 'i' 'do' 'not' 'know' 'that' 'that' 'be' 'what' 'happen' 'i' 'be' 'always' 'in' 'work' 'and' 'i' 'just' 'knew' 'of' 'this' 'now' 'that' 'she ...
# 111                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'the' 'sevenday' 'positivity' 'rate' 'in' 'the' 'national' 'capital' 'region' 'decrease' 'to' 'from' 'the' 'previous' 'independent' 'monitoring' 'group' 'research' 'say' 'monday' 'fellow' 'dr' 'guido' 'david' 'report' 'that' 'positivity' 'rate' 'go' 'down' 'to' 'on' 'october' 'from' 'it' 'peak' 'of' 'on' 'october' 'positivity' 'rate' 'refers' 'to' 'the' 'percentage' 'of' 'people' 'who' 'be' 'find' 'positive' 'for' 'among' 'the' 'total' 'number' 'of' 'individual' 'test' 'reproduction' 'number' 'meanwhile' 'also' 'slightly' 'decrease' 'from' 'on' 'september' 'to' 'on' 'october' 'reproduction' 'rate' 'refers' 'to' 'the' 'number' 'of' 'people' 'infect' 'by' 'one' 'case' 'a' 'reproduction' 'number' 'that' 'be' 'below' 'indicates' 'that' 'the' 'transmission' 'of' 'the' 'virus' 'be' 'slow' 'down' 'the' 'average' 'of' 'new' 'infection' 'in' 'the' 'region' 'also' 'drop' 'from' 'on' 'october' 'to' 'on' 'october' 'this' 'translate' 'to' 'a' 'growth' 'rate' 'of' 'average' 'daily' 'attack' 'rate' 'on' 'the' 'other' 'hand' 'also' 'decline' 'to' 'per' 'population' 'and' 'be' 'consider' 'low' 'accord' 'to' 'david' 'to' 'the' 'incidence' 'show' 'the' 'average' 'number' 'of' 'new' 'case' 'in' 'a' 'period' 'per' 'people' 'both' 'the' 'healthcare' 'for' 'in' 'and' 'it' 'intensive' 'care' 'unit' 'occupancy' 'also' 'remain' 'low' 'at' 'and' 'respectively' 'a' 'of' 'o ...
# 128                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'a' 'senate' 'bill' 'postpone' 'the' 'december' 'and' 'election' 'to' 'the' 'second' 'monday' 'of' 'december' 'be' 'sponsor' 'in' 'the' 'senate' 'on' 'wednesday' 'senate' 'electoral' 'reform' 'and' 'people' 'participation' 'committee' 'chairperson' 'marcos' 'introduce' 'senate' 'bill' 'contain' 'committee' 'report' 'no' 'during' 'the' 'chamber' 'session' 'under' 'section' 'of' 'sb' 'the' 'subsequent' 'shall' 'be' 'hold' 'on' 'the' 'second' 'monday' 'of' 'may' 'and' 'every' 'three' 'year' 'thereafter' 'and' 'official' 'who' 'will' 'be' 'elect' 'in' 'december' 'shall' 'assume' 'their' 'post' 'at' 'noon' 'of' 'january' 'meanwhile' 'the' 'term' 'of' 'office' 'of' 'official' 'elect' 'in' 'may' 'and' 'subsequently' 'thereafter' 'shall' 'start' 'at' 'noon' 'of' 'june' 'next' 'follow' 'their' 'election' 'until' 'the' 'successor' 'have' 'be' 'duly' 'elect' 'and' 'qualify' 'all' 'incumbent' 'and' 'official' 'shall' 'remain' 'in' 'office' 'unless' 'sooner' 'remove' 'or' 'suspend' 'for' 'because' 'and' 'official' 'who' 'be' 'member' 'of' 'the' 'or' 'a' 'the' 'case' 'may' 'be' 'shall' 'continue' 'to' 'serve' 'a' 'such' 'member' 'in' 'the' 'concern' 'until' 'the' 'next' 'in' 'her' 'sponsorship' 'speech' 'marcos' 'recall' 'that' 'she' 'promise' 'that' 'the' 'law' 'that' 'she' 'sponsor' 'during' 'the' '18th' 'congress' 'would' 'be' 'the' 'last' 'of' 'the' 'repeated' 'postponement' 'of' 'the' 'election' 'however' 'she' 'say' 'there' 'be' 'compel' 'reason' 'in' 'favor' 'of' 'a' 'postponement' 'of' 'the' 'poll' 'this' 'year' 'among' 'the' 'reason' 'she' 'cite' 'be' 'the' 'short' 'term' 'of' 'office' 'for' 'official' 'the' 'expense' 'that' 'be' 'incur' 'by' 'the' 'poll' 'and' 'the' 'need' 'to' 'revise' 'and' 'streamline' 'the' 'present' 'system' 'thus' 'this' 'propose' 'election' 'postponement' 'be' 'a' 'mean' 'to' 'buy' 'u' 'time' 'for' 'a' 'series' 'of' 'measure' 'that' 'the' 'committee' 'on' 'electoral' 'reform' 'and' 'people' 'participation' 'be' 'propose' 'to' 'congress' 'this' 'be' 'merely' 'a' 'preliminary' 'measure' 'to' 'give' 'u' 'time' 'to' 'study' 'and' 'debate' 'the' 'deep' 'issue' 'confront' 'the' 'and' 'system' 'under' 'our' 'present' 'law' 'she' 'say' 'marcos' 'also' 'caution' 'against' 'the' 'additional' 'funding' 'need' 'by' 'the' 'commission' 'on' 'election' 'should' 'the' 'be' 'postpone' 'accord' 'to' 'they' 'would' 'need' 'around' 'billion' 'if' 'the' 'conduct' 'of' 'the' 'be' 'postpone' 'to' 'december' 'sa' 'ko' 'ng' 'additional' 'na' 'precinct' 'na' 'na' 'teacher' 'at' 'board' 'of' 'election' 'inspector' 'at' 'na' 'supply' 'lang' 'sa' 'date' 'budget' 'na' 'billion' 'she' 'say' ...
# ...
# 221                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 229                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'gma' 'news' 'online' 'editorinchief' 'have' 'be' 'select' 'by' 'the' 'foundation' 'for' 'journalism' 'a' 'one' 'of' 'global' 'journalist' 'for' 'a' 'year' 'of' 'study' 'at' 'harvard' 'university' 'a' 'senior' 'assistant' 'vice' 'president' 'at' 'gma' 'network' 'will' 'be' 'part' 'of' 'the' 'class' 'of' 'which' 'will' 'arrive' 'on' 'campus' 'this' 'fall' 'and' 'include' 'investigative' 'reporter' 'documentary' 'filmmaker' 'an' 'researcher' 'writer' 'video' 'and' 'a' 'film' 'critic' 'a' 'television' 'news' 'producer' 'a' 'medium' 'analyst' 'and' 'senior' 'editor' 'and' 'newsroom' 'leader' 'who' 'direct' 'innovative' 'journalism' 'venture' 'he' 'will' 'study' 'audience' 'trust' 'in' 'medium' 'organization' 'and' 'what' 'newsroom' 'can' 'do' 'to' 'strengthen' 'that' 'trust' 'and' 'build' 'engagement' 'a' 'career' 'journalist' 'and' 'editor' 'be' 'also' 'one' 'of' 'the' 'philippine' 'ten' 'outstanding' 'young' 'men' 'in' 'his' 'leadership' 'of' 'gma' 'news' 'and' 'public' 'affair' 'digital' 'medium' 'lead' 'to' 'recognition' 'by' 'prestigious' 'institution' 'such' 'a' 'the' 'digital' 'medium' 'worldwide' 'and' 'digital' 'medium' 'asia' 'award' 'the' 'society' 'of' 'publisher' 'in' 'asia' 'award' 'for' 'editorial' 'excellence' 'and' 'the' 'new' 'york' 'festival' 'accord' 'to' 'the' 'fellow' 'in' 'two' 'semester' 'at' 'harvard' 'will' 'examine' 'the' 'grow' 'threat' 'to' 'democracy' 'and' 'the' 'free' 'press' 'the' 'use' 'of' 'ai' 'in' 'report' 'innovation' 'in' 'storytelling' 'political' 'polarization' 'trauma' 'climate' 'destabilization' 'scientific' 'advance' 'in' 'health' 'care' 'report' 'under' 'repressive' 'regime' 'solution' 'journalism' 'medium' 'trust' 'and' 'journalism' 'collaboration' 'these' 'inspiring' 'journalist' 'be' 'work' 'to' 'elevate' 'and' 'redefine' 'our' 'industry' 'at' 'a' 'critical' 'moment' 'say' 'ann' 'marie' 'curator' 'of' 'the' 'foundation' 'the' 'vast' 'possibility' 'offer' 'by' 'change' 'mode' 'of' 'creation' 'and' 'communication' 'invite' 'new' 'approach' 'to' 'our' 'work' 'and' 'the' 'severe' 'threat' 'against' 'journalism' 'around' 'the' 'globe' 'demand' 'them' 'i' 'be' 'excite' 'to' 'support' 'the' 'research' 'of' 'these' 'fellow' 'a' 'they' 'work'  ...
# 249                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'the' 'cooperative' 'development' 'authority' 'on' 'friday' 'encourage' 'the' 'formation' 'of' 'cooperative' 'to' 'ensure' 'that' 'farmer' 'would' 'receive' 'aid' 'from' 'the' 'government' 'individual' 'sa' 'at' 'at' 'organization' 'sa' 'ng' 'sa' 'farmer' 'assistant' 'secretary' 'say' 'at' 'the' 'public' 'briefing' 'in' 'order' 'for' 'government' 'assistance' 'to' 'reach' 'our' 'farmer' 'directly' 'we' 'be' 'transform' 'the' 'group' 'and' 'orga ...
#
#      Predikció valószínűsége
# 10                    0.0327
# 12                    0.3705
# 13                    0.7749
# 23                    0.4773
# 27                    0.8589
# 51                    0.0027
# 71                    0.4294
# 79                    0.0076
# 111                   0.0006
# 128                   0.3399
# 137                   0.1325
# 157                   0.4018
# 192                   0.0007
# 194                   0.0005
# 195                   0.4402
# 198                   0.0727
# 199                   0.0249
# 221                   0.9535
# 229                   0.0070
# 249                   0.0022

# %% [markdown]
# # GRU MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ### Modell lefuttatása

# %%
# GRU Modell

def create_gru_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),  # Ensure within vocab limit
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings  # Toggle trainability
    )(text_input)

    # GRU rétegek
    gru_out = GRU(128, return_sequences=True, dropout=0.3)(text_embedding)
    gru_out = Dropout(0.3)(gru_out)  # Dropout réteg az első GRU után
    gru_out = GRU(64,return_sequences=True, dropout=0.3)(gru_out)
    gru_out = Dropout(0.3)(gru_out)
    gru_out = GRU(32, dropout=0.3)(gru_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(gru_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása (Trainable)
gru_trainable = create_gru_model(trainable_embeddings=True)

gru_trainable.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_2 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 600, 128)            │         165,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 600, 64)             │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,711,809 (29.42 MB)
#  Trainable params: 7,711,809 (29.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# GRU modell tanítása a validációs adatok figyelésével
history_gru_trainable = gru_trainable.fit(
    padded_train_final, y_train_final,  # Ugyanaz a tanító adathalmaz, mint az LSTM-nél
    validation_data=(padded_val, y_val),  # Ugyanaz a validációs halmaz, mint az LSTM-nél
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság (GRU): {test_accuracy_gru:.4f}, Teszthalmaz veszteség (GRU): {test_loss_gru:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 70s 79ms/step - accuracy: 0.8376 - loss: 0.3579 - val_accuracy: 0.9400 - val_loss: 0.1677
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 81ms/step - accuracy: 0.9526 - loss: 0.1258 - val_accuracy: 0.9706 - val_loss: 0.0833
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 78ms/step - accuracy: 0.9855 - loss: 0.0431 - val_accuracy: 0.9659 - val_loss: 0.1050
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 81ms/step - accuracy: 0.9933 - loss: 0.0220 - val_accuracy: 0.9686 - val_loss: 0.1101
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 78ms/step - accuracy: 0.9955 - loss: 0.0150 - val_accuracy: 0.9746 - val_loss: 0.1044
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.8159 - loss: 0.5360
# Teszthalmaz pontosság (GRU): 0.8124, Teszthalmaz veszteség (GRU): 0.5431

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Valószínűség becslése
gru_y_prob = gru_trainable.predict(padded_test)

gru_y_pred = (gru_y_prob > 0.5).astype(int)

accuracy = accuracy_score(y_test, gru_y_pred)
precision = precision_score(y_test, gru_y_pred)
recall = recall_score(y_test, gru_y_pred)
f1 = f1_score(y_test, gru_y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
# Accuracy: 0.8119
# Precision: 0.9385
# Recall: 0.6676
# F1-score: 0.7802

# %% [markdown]
# ## GRU modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_gru_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(history_gru_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(history_gru_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(history_gru_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.8732 - loss: 0.5308

# %%
# Confusion Matrix
cm_gru = confusion_matrix(y_test, gru_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_gru, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix GRU Modellre')
plt.show()

print(classification_report(y_test, gru_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.96      0.84      7152
#          1.0       0.94      0.67      0.78      7152
#
#     accuracy                           0.81     14304
#    macro avg       0.84      0.81      0.81     14304
# weighted avg       0.84      0.81      0.81     14304

# %%
# Flatten
y_true = y_test.flatten()
y_pred = gru_y_pred.flatten()
y_prob = gru_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás) GRU Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": gru_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = gru_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_gru.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 5    Hamis negatív (FN)           1.0                 0
# 8    Hamis negatív (FN)           1.0                 0
# 10   Hamis negatív (FN)           1.0                 0
# 15   Hamis negatív (FN)           1.0                 0
# 23   Hamis negatív (FN)           1.0                 0
# 27   Hamis pozitív (FP)           0.0                 1
# 51   Hamis negatív (FN)           1.0                 0
# 57   Hamis negatív (FN)           1.0                 0
# 59   Hamis negatív (FN)           1.0                 0
# 60   Hamis negatív (FN)           1.0                 0
# 71   Hamis negatív (FN)           1.0                 0
# 77   Hamis negatív (FN)           1.0                 0
# 79   Hamis negatív (FN)           1.0                 0
# 82   Hamis negatív (FN)           1.0                 0
# 95   Hamis pozitív (FP)           0.0                 1
# 100  Hamis negatív (FN)           1.0                 0
# 107  Hamis pozitív (FP)           0.0                 1
# 109  Hamis negatív (FN)           1.0                 0
# 111  Hamis negatív (FN)           1.0                 0
# 128  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'oslo' 'norway' 'wealth' 'fund' 'one' 'of' 'the' 'world' 'large' 'investor' 'post' 'a' 'record' 'loss' 'of' 'trillion' 'crown' 'billion' 'for' 'bring' 'to' 'an' 'end' 'a' 'threeyear' 'run' 'of' 'soar' 'profit' 'a' 'stock' 'and' 'bond' 'be' 'hit' 'by' 'the' 'ukraine' 'war' 'and' 'inflation' 'the' 'previous' 'large' 'loss' 'be' 'billion' 'crown' 'in' 'it' 'end' 'a' 'recordbreaking' 'streak' 'for' 'the' 'fund' 'where' 'annual' 'return' 'exceed' 'trillion' 'crown' 'in' 'each' 'of' 'the' 'three' 'year' 'from' 'to' 'amount' 'to' 'more' 'than' 'trillion' 'crown' 'combine' 'we' 'be' 'invest' 'in' 'company' 'in' 'country' 'there' 'be' 'just' 'nowhere' 'to' 'hide' 'fund' 'chief' 'executive' 'tell' 'a' 'news' 'conference' 'the' 'single' 'big' 'stock' 'market' 'loss' 'come' 'from' 'the' 'fund' 'stake' 'in' 'amazon' 'which' 'decline' 'in' 'value' 'by' 'billion' 'crown' 'follow' 'by' 'a' 'loss' 'in' 'share' 'of' 'facebook' 'owner' 'platform' 'of' 'billion' 'and' 'in' 'tesla' 'with' 'billion' 'still' 'despite' 'the' 'record' 'loss' 'the' 'value' 'of' 'the' 'fund' 'rise' 'overall' 'by' 'billion' 'crown' 'or' 'billion' 'partly' 'due' 'to' 'the' 'weak' 'norwegian' 'currency' 'and' 'a' 'record' 'trillion' 'crown' 'of' 'cash' 'inflow' 'the' 'inflow' 'in' 'be' 'nearly' 'three' 'time' 'the' 'previous' 'record' 'of' 'billion' 'crown' 'set' 'in' 'the' 'fund' 'invest' 'the' 'norwegian' 'state' 'revenue' 'from' 'petroleum' 'production' 'a' 'a' 'major' 'crude' 'exporter' 'and' 'europes' 'large' 'gas' 'supplier' 'after' 'a' 'drop' 'in' 'russian' 'gas' 'flow' 'norway' 'benefit' 'from' 'high' 'energy' 'price' 'due' 'to' 'the' 'war' 'in' 'ukraine' 'we' 'have' 'to' 'be' 'very' 'conscious' 'of' 'the' 'fact' 'that' 'the' 'inflow' 'come' 'against' 'a' 'tragic' 'backdrop' 'in' 'europe' 'say' 'but' 'it' 'be' 'an' 'isolated' 'mathematical' 'fact' 'that' 'when' 'oil' 'and' 'gas' 'price' 'be' 'high' 'there' 'be' 'more' 'revenue' 'to' 'the' 'norwegian' 'government' 'and' 'more' 'inflow' 'into' 'the' 'fund' 'the' 'fund' 'own' 'on' 'average' 'of' 'all' 'listed' 'stock' 'it' 'also' 'invest' 'in' 'bond' 'real' 'estate' 'and' 'renewable' 'energy' 'pro ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'more' 'than' 'a' 'week' 'before' 'several' 'family' 'have' 'start' 'go' 'to' 'the' 'manila' 'north' 'cemetery' 'to' 'clean' 'the' 'resting' 'place' 'of' 'their' 'lov ...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'geneva' 'the' 'world' 'health' 'organization' 'say' 'wednesday' 'it' 'be' 'too' 'early' 'to' 'lift' 'the' 'alert' 'for' 'the' 'crisis' 'with' 'the' 'pandemic' 'remain' 'a' 'global' 'health' 'emergency' 'despite' 'recent' 'progress' 'the' 'who' 'be' 'emergency' 'committee' 'on' 'meet' 'last' 'week' 'and' 'conclude' 'that' 'the' 'pandemic' 'still' 'constitute' 'a' 'public' 'health' 'emergency' 'of' 'international' 'concern' 'a' 'status' 'it' 'declare' 'back' 'in' 'january' 'who' 'chief' 'tedros' 'tell' 'reporter' 'wednesday' 'that' 'he' 'agree' 'with' 'the' 'committee' 'advice' 'the' 'committee' 'emphasize' 'the' 'need' 'to' 'strengthen' 'surveillance' 'and' 'expand' 'access' 'to' 'test' 'treatment' 'and' 'vaccine' 'for' 'those' 'most' 'at' 'risk' 'he' 'say' 'speak' 'from' 'the' 'un' 'health' 'agency' 'headquarters' 'in' 'geneva' 'the' 'who' 'first' 'declare' 'the' 'outbreak' 'a' 'on' 'january' 'when' 'outside' 'of' 'china' 'few' 'than' 'case' 'and' 'no' 'death' 'have' 'be' 'report' 'though' 'it' 'be' 'the' 'mechanism' 'for' 'trigger' 'an' 'international' 'response' 'to' 'such' 'outbreak' 'it' 'be' 'only' 'in' 'march' 'when' 'tedros' 'describe' 'the' 'worsen' 'situation' 'a' 'a' 'pandemic' 'that' 'many' 'country' 'wake' 'up' 'to' 'the' 'danger' 'since' 'the' 'start' 'of' 'the' 'pandemic' 'more' 'than' 'million' 'confirm' 'case' 'have' 'be' 'report' 'to' 'who' 'and' 'more' 'than' 'million' 'death' 'although' 'those' 'number' 'be' 'believe' 'to' 'be' 'significant' 'underestimate' 'accord' 'to' 'who' 'be' 'global' 'dashboard' 'of' 'the' 'situation' 'new' 'case' 'be' 'report' 'in' 'the' 'previous' 'hour' 'while' 'new' 'death' 'have' 'be' 'report' 'in' 'the' 'past' 'week' 'tedros' 'acknowledge' 'wednesday' 'that' 'the' 'global' 'situation' 'have' 'obviously' 'improve' 'since' 'the' 'pandemic' 'begin' 'but' 'he' 'warn' 'that' 'the' 'virus' 'continue' 'to' 'change' 'and' 'there' 'remain' 'many' 'risk' 'and' 'uncertainty' 'the' 'pandemic' 'have' 'surprise' 'u' 'before' 'and' 'very' 'well' 'could' 'again' 'he' 'warn' 'surveillance' 'have' 'decline' 'maria' 'van' 'the' 'who' 'be' 'technical' 'lead' 'agree' 'warn' 'that' 'there' 'be' 'still' 'million' 'of' 'case' 'be' 'report' 'each' 'week' 'but' 'our' 'surveillance' 'have' 'decline' 'this' 'be' 'make' 'it' 'difficult' 'to' 'get' 'a' 'full' 'overview' 'of' 'the' 'situation' 'and' 'especially' 'of' 'how' 'the' 'virus' 'be' 'she' 'stress' 'that' 'the' 'more' 'this' 'virus' 'circulate' 'the' 'more' 'opportunity' 'it' 'have' 'to' 'change' 'the' 'variant' 'account' 'for' 'basically' 'all' 'virus' 'sample' 'that' 'be' 'sequence' 'with' 'more' 'than' 'of' 'that' 'variant' 'record' 'all' 'of' 'the' 'of' 'be' 'show' 'increased' 'and' 'property' 'of' 'immune' 'escape' 'van' 'say' 'add' 'that' 'one'  ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'interior' 'and' 'local' 'government' 'secretary' 'on' 'wednesday' 'order' 'an' 'investigation' 'into' 'the' 'death' 'of' 'a' 'student' 'who' 'be' 'find' 'in' 'a' 'shallow' 'grave' 'in' 'to' 'at' 'ano' 'circumstance' 'any' 'form' 'of' 'violence' 'na' 'he' 'tell' 'reporter' 'in' 'an' 'ambush' 'interview' 'we' 'will' 'investigate' 'it' 'immediately' 'and' 'look' 'into' 'the' 'circumstance' 'here' 'any' 'form' 'of' 'violence' 'that' 'lead' 'to' 'death' 'should' 'be' 'investigate' 'immediately' 'on' 'tuesday' 'the' 'body' 'of' 'john' 'matthew' 'a' 'student' 'at' 'university' 'in' 'manila' 'be' 'find' 'more' 'than' 'a' 'week' 'after' 'he' 'be' 'last' 'see' 'alive' 'police' 'say' 'suspect' 'whom' 'they' 'inv ...
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'six' 'official' 'of' 'the' 'philippine' 'national' 'police' 'pnp' 'drug' 'enforcement' 'group' 'special' 'operation' 'unit' 'be' 'relieve' 'from' 'their' 'post' 'in' 'the' 'official' 'be' 'face' 'allegation' 'of' 'kidnapping' 'and' 'torture' 'accord' 'to' 'jun' 'report' 'on' 'wednesday' 'yun' 'relieve' 'ni' 'director' 'yun' 'in' 'fairness' 'to' 'them' 'allegation' 'yun' 'police' 'colonel' 'martinez' 'deputy' 'director' 'for' 'administration' 'say' 'base' 'on' 'the' 'report' 'the' 'complainant' 'say' 'that' 'they' 'be' 'force' 'to' 'ride' 'the' 'operative' 'vehicle' 'and' 'be' 'take' 'to' 'the' 'headquarters' 'of' 'the' 'where' 'they' 'be' 'allegedly' 'tortured' 'pnp' 'chief' 'police' 'general' 'benjamin' 'jr' 'maintain' 'that' 'misconduct' 'will' 'not' 'be' 'tolerate' 'under' 'his' 'leadership' 'he' 'also' 'urge' 'the' 'pub ...
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'unidentified' 'muslim' 'on' 'the' 'run' 'after' 'stab' 'four' 'people' 'at' 'a' 'frankfurt' 'train' 'station' 'the' 'attack' 'this' 'afternoon' 'occur' 'at' 'station' 'and' 'police' 'have' 'say' 'there' 'be' 'four' 'victim' 'at' 'this' 'stage' 'the' 'motive' 'for' 'the' 'stabbings' 'be' 'not' 'clear' 'it' 'will' 'become' 'crystal' 'clear' 'once' 'you' 'identify' 'the' 'attacker' 'a' 'a' 'muslim' 'uk' 'daily' 'mail' 'ht' 'the' 'local' 'police' 'force' 'confirm' 'the' 'attack' 'by' 'tweet' 'there' 'be' 'a' 'knife' 'assault' 'at' 'the' 'in' 'frankfurt' 'that' 'be' 'why' 'so' 'many' 'colleague' 'police' 'officer' 'and' 'rescue' 'worker' 'there' 'frankfurt' 'police' 'confirm' 'all' 'four' 'victim' 'be' 'still' 'in' 'hospital' 'a' 'video' 'of' 'the' 'bloody' 'aftermath' 'be' 'capture' 'on' 'what' 'be' 'understood' 'to' 'be' 'level' 'b' 'of' 'the' 'station' 'the' 'incident' 'be' 'at' '30pm' 'local' 'time' 'accord' 'to' 'who' 'report' 'the' 'stabbings' 'come' 'after' 'a' 'group' 'be' 'quarrel' 'a' 'dispute' 'have' 'start' 'on' 'one' 'platform' 'and' 'spill' 'over' 'onto' 'another' 'one' 'there' 'be' 'more' 'bloodshed' 'in' 'a' 'separate' 'incident' 'at' 'the' 'station' 'understood' 'to' 'be' 'on' 'a' 'passenger' 'train' 'between' 'and' 'a' 'dispute' 'between' 'two' 'passenger' 'break' 'out' 'into' 'a' 'fight' 'accord' 'to' 'which' 'lead' 'to' 'glass' 'be' 'break' 'and' 'people' 'suffer' 'cut' 'frankfurt' 'police' 'look' 'to' 'reassure' 'the' 'public' 'by' 'tweet' 'if' 'we' 'recognize' 'a' 'threat' 'to' 'the' 'local' 'population' 'we' 'would' 'communicate' 'this' 'no' 'you' 'would' 'not' 'the' 'stabbings' 'will' 'still' 'raise' 'fear' 'the' 'attack' 'be' 'islamic' 'after' 'a' 'string' 'of' 'incident' 'across' 'europe' 'over' 'recent' 'month' 'germany' 'have' 'be' 'rock' 'by' 'islamic' 'terror' 'attack' 'this' 'year' 'heap' 'pressure' 'on' 'chancellor' 'angela' 'merkels' 'opendoor' 'muslim' 'immigration' 'policy' 'a' 'bloody' 'week' 'of' 'violence' 'that' 'rock' 'germany' 'begin' 'on' 'july' 'when' 'pakistani' 'muslim' 'teenager' 'khan' 'pose' 'a' 'an' 'afghan' 'refugee' 'hack' 'at' 'passenger' 'on' 'a' 'train' 'in' 'with' 'an' 'axe' 'wound' 'five' 'four' 'day' 'later' 'a' 'muslim' 'teenager' 'ali' 'shot' 'nine' 'people' 'dead' 'during'  ...
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'the' 'bureau' 'of' 'immigration' 'bi' 'arrest' 'and' 'set' 'to' 'deport' 'a' 'chinese' 'national' 'who' 'be' 'be' 'search' 'by' 'authority' 'for' 'allegedly' 'misrepresent' 'himself' 'a' 'a' 'filipino' 'suspect' 'tai' 'be' 'nab' 'in' 'manila' 'on' 'tuesday' 'may' 'after' 'a' 'warrant' 'of' 'deportation' 'be' 'issue' 'against' 'him' 'in' 'july' 'last' 'year' 'for' 'be' 'an' 'undesirable' 'alien' 'tai' 'allegedly' 'assume' 'the' 'name' 'of' 'one' 'albert' 'torres' 'and' 'have' 'be' 'use' 'the' 'fictitious' 'identity' 'in' 'file' 'incorporation' 'paper' 'acquire' 'a' 'driver' 'license' 'register' 'his' 'business' 'as' 'well' 'a' 'in' 'other' 'public' 'document' 'accord'  ...
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'a' 'family' 'of' 'five' 'died' 'after' 'a' 'fire' 'hit' 'their' 'residence' 'in' 'on' 'monday' 'accord' 'to' 'claire' 'report' 'on' 'gma' 'r ...
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'the' 'number' 'of' 'dengue' 'case' 'continue' 'to' 'increase' 'in' 'nine' 'out' 'of' 'the' 'philippine' 'region' 'department' 'of' 'health' 'officer' 'in' 'charge' 'ma' 'rosario' 'say' 'on' 'friday' 'in' 'a' 'statement' 'on' 'saturday' 'the' 'doh' 'say' 'the' 'nine' 'region' 'that' 'have' 'recently' 'exceed' 'the' 'threshold' 'in' 'the' 'past' 'four' 'week' 'be' 'valley' 'central' 'western' 'central' 'peninsula' 'administrative' 'region' 'and' 'national' 'capital' 'region' 'accord' 'to' 'the' 'country' 'log' 'dengue' 'case' 'base' 'on' 'report' 'from' 'july' 'to' 'july' 'she' 'say' 'or' 'of' 'the' 'dengue' 'case' 'have' 'be' 'hospitalize' 'kaya' 'sa' 'say' 'po' 'sa' 'strategy' 'seek' 'early' 'consult' 'po' 'ng' 'dengue' 'po' 'ma' 'tao' 'may' 'dengue' 'she' 'add' 'that' 'be' 'why' 'we' 'be' 'remind' 'the' 'public' 'seek' 'early' 'consultation' 'be' 'part' 'of' 'the' 'strategy' 'so' 'we' 'can' 'address' 'the' 'symptom' 'of' 'dengue' 'you' 'do' 'not' 'need' 'to' 'get' 'hospitalize' 'because' 'of' 'dengue' 'the' 'strategy' 'be' 'to' 'search' 'and' 'destroy' 'breeding' 'place' 'secure' 'seek' 'early' 'consultation' 'and' 'support' 'in' 'hotspot' 'area' 'she' 'urge' 'the' 'public' 'to' 'consult' 'health' 'center' 'immediately' 'upon' 'experience' 'dengue' 'sympt ...
# 60                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'the' 'department' 'of' 'environment' 'and' 'natural' 'resource' 'on' 'monday' 'conduct' 'an' 'expert' 'forum' 'target' 'to' 'the' 'review' 'and' 'enhance' 'philippine' 'policy' 'on' 'reclamation' 'the' 'expect' 'output' 'be' 'a' 'set' 'of' 'policy' 'recommendation' 'on' 'reclamation' 'that' 'will' 'inform' 'the' 'review' 'and' 'enhancement' 'of' 'the' 'country' 'policy' 'relate' 'to' 'reclamation' 'the' 'say' 'accord' 'to' 'the' 'agency' 'among' 'the' 'reclamation' 'law' 'and' 'policy' 'need' 'review' 'and' 'enhancement' 'include' 'executive' 'order' 'no' 's' 'philippine' 'reclamation' 'authority' 'administrative' 'order' 'no' 's' 'administrative' 'order' 'no' 'a ...
# ...
# 109                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'the' 'report' 'death' 'toll' 'due' 'to' 'typhoon' 'have' 'increase' 'to' 'the' 'national' 'disaster' 'risk' 'reduction' 'and' 'management' 'council' 'say' 'on' 'friday' 'in' 'it' 'report' 'the' 'say' 'the' 'fatality' 'be' 'report' 'in' 'central' 'and' 'of' 'the' 'death' 'eight' 'have' 'be' 'verify' 'so' 'far' 'meanwhile' 'the' 'report' 'on' 'the' 'following' 'fatality' 'have' 'yet' 'to' 'be' 'verify' 'accord' 'to' 'the' 'the' 'say' 'six' 'person' 'be' 'report' 'miss' 'in' 'and' 'and' 'be' 'report' 'injured' 'in' 'central' 'and' 'a' 'total' 'of' 'people' 'or' 'family' 'be' 'affect' 'by' 'in' 'in' 'central' 'and' 'the' 'say' 'it' 'add' 'that' 'person' 'or' 'family' 'be' 'stay' 'inside' 'evacuation' 'center' 'while' 'individual' 'or' 'family' 'be' 'take' 'shelter' 'in' 'other' 'place' 'due' 'to' 'the' 'typhoon' 'house' 'sustain' 'damage' 'partially' 'and' 'totally' 'in' 'central' 'and' 'a' 'total' 'of' 'worth' 'of' 'damage' 'in' 'agriculture' 'be' 'report' 'in' 'central' 'and' 'the' 'national' 'irrigation' 'administration' 'on' 'the' 'other' 'hand' 'report' 'million' 'worth' 'of' 'damage' 'in' 'and' 'for' 'infrastructure' 'the' 'say' 'worth' 'of' 'damage' 'be' 'report' 'in' 'and' 'at' 'least' 'area' 'be' 'still' 'flood' 'in' 'and' 'accord' 'to' 'the' 'a' 'landsli ...
# 111                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'the' 'sevenday' 'positivity' 'rate' 'in' 'the' 'national' 'capital' 'region' 'decrease' 'to' 'from' 'the' 'previous' 'independent' 'monitoring' 'group' 'research' 'say' 'monday' 'fellow' 'dr' 'guido' 'david' 'report' 'that' 'positivity' 'rate' 'go' 'down' 'to' 'on' 'october' 'from' 'it' 'peak' 'of' 'on' 'october' 'positivity' 'rate' 'refers' 'to' 'the' 'percentage' 'of' 'people' 'who' 'be' 'find' 'positive' 'for' 'among' 'the' 'total' 'number' 'of' 'individual' 'test' 'reproduction' 'number' 'meanwhile' 'also' 'slightly' 'decrease' 'from' 'on' 'september' 'to' 'on' 'october' 'reproduction' 'rate' 'refers' 'to' 'the' 'number' 'of' 'people' 'infect' 'by' 'one' 'case' 'a' 'reproduction' 'number' 'that' 'be' 'below' 'indicates' 'that' 'the' 'transmission' 'of' 'the' 'virus' 'be' 'slow' 'down' 'the' 'average' 'of' 'new' 'infection' 'in' 'the' 'region' 'also' 'drop' 'from' 'on' 'october' 'to' 'on' 'october' 'this' 'translate' 'to' 'a' 'growth' 'rate' 'of' 'average' 'daily' 'attack' 'rate' 'on' 'the' 'other' 'hand' 'also' 'decline' 'to' 'per' 'population' 'and' 'be' 'consider' 'low' 'accord' 'to' 'david' 'to' 'the' 'incidence' 'show' 'the' 'average' 'number' 'of' 'new' 'case' 'in' 'a' 'period' 'per' 'people' 'both' 'the' 'healthcare' 'for' 'in' 'and' 'it' 'intensive' 'care' 'unit' 'occupancy' 'also' 'remain' 'low' 'at' 'and' 'resp ...
# 128                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'a' 'senate' 'bill' 'postpone' 'the' 'december' 'and' 'election' 'to' 'the' 'second' 'monday' 'of' 'december' 'be' 'sponsor' 'in' 'the' 'senate' 'on' 'wednesday' 'senate' 'electoral' 'reform' 'and' 'people' 'participation' 'committee' 'chairperson' 'marcos' 'introduce' 'senate' 'bill' 'contain' 'committee' 'report' 'no' 'during' 'the' 'chamber' 'session' 'under' 'section' 'of' 'sb' 'the' 'subsequent' 'shall' 'be' 'hold' 'on' 'the' 'second' 'monday' 'of' 'may' 'and' 'every' 'three' 'year' 'thereafter' 'and' 'official' 'who' 'will' 'be' 'elect' 'in' 'december' 'shall' 'assume' 'their' 'post' 'at' 'noon' 'of' 'january' 'meanwhile' 'the' 'term' 'of' 'office' 'of' 'official' 'elect' 'in' 'may' 'and' 'subsequently' 'thereafter' 'shall' 'start' 'at' 'noon' 'of' 'june' 'next' 'follow' 'their' 'election' 'until' 'the' 'successor' 'have' 'be' 'duly' 'elect' 'and' 'qualify' 'all' 'incumbent' 'and' 'official' 'shall' 'remain' 'in' 'office' 'unless' 'sooner' 'remove' 'or' 'suspend' 'for' 'because' 'and' 'official' 'who' 'be' 'member' 'of' 'the' 'or' 'a' 'the' 'case' 'may' 'be' 'shall' 'continue' 'to' 'serve' 'a' 'such' 'member' 'in' 'the' 'concern' 'until' 'the' 'next' 'in' 'her' 'sponsorship' 'speech' 'marcos' 'recall' 'that' 'she' 'promise' 'that' 'the' 'law' 'that' 'she' 'sponsor' 'during' 'the' '18th' 'congress' 'would' 'be' 'the' 'last' 'of' 'the' 'repeated' 'postponement' 'of' 'the' 'election' 'however' 'she' 'say' 'there' 'be' 'compel' 'reason' 'in' 'favor' 'of' 'a' 'postponement' 'of' 'the' 'poll' 'this' 'year' 'among' 'the' 'reason' 'she' 'cite' 'be' 'the' 'short' 'term' 'of' 'office' 'for' 'official' 'the' 'expense' 'that' 'be' 'incur' 'by' 'the' 'poll' 'and' 'the' 'need' 'to' 'revise' 'and' 'streamline' 'the' 'present' 'system' 'thus' 'this' 'propose' 'election' 'postponement' 'be' 'a' 'mean' 'to' 'buy' 'u' 'time' 'for' 'a' 'series' 'of' 'measure' 'that' 'the' 'committee' 'on' 'electoral' 'reform' 'and' 'people' 'participation' 'be' 'propose' 'to' 'congress' 'this' 'be' 'merely' 'a' 'preliminary' 'measure' 'to' 'give' 'u' 'time' 'to' 'study' 'and' 'debate' 'the' 'deep' 'issue' 'confront' 'the' 'and' 'system' 'under' 'our' 'present' 'law' 'she' 'say' 'marcos' 'also' 'caution' 'against' 'the' 'additional' 'funding' 'need' 'by' 'the' 'commission' 'on' 'election' 'should' 'the' 'be' 'postpone' 'accord' 'to' 'they' 'would' 'need' 'around' 'billion' 'if' 'the' 'conduct' 'of' 'the' 'be' 'postpone' 'to' 'december' 'sa' 'ko' 'ng' 'additional' 'na' 'precinct' 'na' 'na' 'teacher' 'at' 'board' 'of' 'election' 'inspector' 'at' 'na' 'supply' 'lang' 'sa' 'date' 'budget' 'na'  ...
#
#      Predikció valószínűsége
# 5                     0.1344
# 8                     0.0055
# 10                    0.0675
# 15                    0.4892
# 23                    0.0189
# 27                    0.8656
# 51                    0.3033
# 57                    0.1631
# 59                    0.2857
# 60                    0.2103
# 71                    0.3583
# 77                    0.3353
# 79                    0.0169
# 82                    0.0324
# 95                    0.8362
# 100                   0.3401
# 107                   0.9550
# 109                   0.0370
# 111                   0.0030
# 128                   0.1403

# %% [markdown]
# # Tanulás-validáció-teszt összehasonlítása két modellnél

# %%
test_loss_lstm, test_accuracy_lstm = lstm_trainable.evaluate(padded_test, y_test, verbose=0)
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test, verbose=0)

# Ábra létrehozása két alábrával
plt.figure(figsize=(12, 5))

# Tanulási, validációs és teszthalmaz veszteség ábrázolása
plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='LSTM tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='LSTM validációs veszteség', color='#7fcdbb')
plt.plot(history_gru_trainable.history['loss'], label='GRU tanulási veszteség', color='red')
plt.plot(history_gru_trainable.history['val_loss'], label='GRU validációs veszteség', color='orange')
plt.axhline(y=test_loss_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz veszteség')  # LSTM teszt loss
plt.axhline(y=test_loss_gru, color='red', linestyle='--', label='GRU teszthalmaz veszteség')  # GRU teszt loss
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Ttanulási, validációs és teszthalmaz precízió ábrázolása
if 'accuracy' in lstm_history_trainable.history and 'accuracy' in history_gru_trainable.history:
    plt.subplot(1, 2, 2)
    plt.plot(lstm_history_trainable.history['accuracy'], label='LSTM tanulási pontosság', color='blue')
    plt.plot(lstm_history_trainable.history['val_accuracy'], label='LSTM validációs pontosság', color='#7fcdbb')
    plt.plot(history_gru_trainable.history['accuracy'], label='GRU tanulási pontosság', color='red')
    plt.plot(history_gru_trainable.history['val_accuracy'], label='GRU validációs pontosság', color='orange')
    plt.axhline(y=test_accuracy_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz pontosság')  # LSTM teszt accuracy
    plt.axhline(y=test_accuracy_gru, color='red', linestyle='--', label='GRU teszthalmaz pontosság')  # GRU teszt accuracy
    plt.xlabel('Epizód')
    plt.ylabel('Pontosság')
    plt.legend()
    plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.tight_layout()
plt.show()
