# %% [markdown]
# # **Csomagok behívása**

# %%
#Szükséges csomagok és adatbázis importálása
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Concatenate
import numpy as np
import tensorflow as tf
import spacy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fájlok behívása, ellenőrzése és felkészítése

# %%
# Betölteni padded sequences, tokenizer, és számokat
padded_train = np.load('/content/padded_train01.npy')
padded_test = np.load('/content/padded_independent01.npy')

# Tokenizer visszatöltése
with open('/content/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Címkék betöltése (real = 1, fake = 0)
train_file = '/content/train_elso.csv'
test_file = '/content/indep_elso.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

labels_train = df_train['label'].values
labels_test = df_test['label'].values

# Betölteni embedding mátrixot
embedding_matrix = np.load('/content/embedding_matrix.npy')

# Ellenőrzés
print(f"Train padded sequences shape: {padded_train.shape}")
print(f"Test padded sequences shape: {padded_test.shape}")
print(f"Train labels shape: {labels_train.shape}")
print(f"Test labels shape: {labels_test.shape}")
# Out:
# Train padded sequences shape: (59520, 600)
# Test padded sequences shape: (14304, 600)
# Train labels shape: (59520,)
# Test labels shape: (14304,)

# %%
# Max szókincs és szekvencia hossz
MAX_VOCAB_SIZE = 25000
MAX_LENGTH = 600
EMBEDDING_DIM = 300  # GloVe 300d

# input shape
MAX_SEQUENCE_LENGTH = padded_train.shape[1]

# Szöveges input (LSTM/GRU bemenet)
text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
embedding_layer = Embedding(
    input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
    output_dim=embedding_matrix.shape[1],
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)(text_input)

model_output = embedding_layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
MAX_SEQUENCE_LENGTH = padded_train.shape[1]  # Train hossz
EMBEDDING_DIM = embedding_matrix.shape[1]  # GloVe embeddings

# 10%-os validációs halmaz leválasztása a tanító adatokból
padded_train_final, padded_val, y_train_final, y_val = train_test_split(
    padded_train, labels_train, test_size=0.1, random_state=42
)
# Float32-re konvertálás TensorFlow kompatibilitás miatt
padded_train_final = np.array(padded_train_final, dtype=np.float32)
padded_val = np.array(padded_val, dtype=np.float32)
padded_test = np.array(padded_test, dtype=np.float32)
y_train_final = np.array(y_train_final, dtype=np.float32)
y_val = np.array(y_val, dtype=np.float32)
y_test = np.array(labels_test, dtype=np.float32)

# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# # LSTM MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ## Modell lefuttatása

# %%
# LSTM modell, trainable, non-trainable embedding

def create_lstm_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings
    )(text_input)

    # LSTM rétegek
    lstm_out = LSTM(128, return_sequences=True, dropout=0.3)(text_embedding)
    lstm_out = Dropout(0.3)(lstm_out)  # Dropout réteg az első LSTM után
    lstm_out = LSTM(64,return_sequences=True, dropout=0.3)(lstm_out)
    lstm_out = Dropout(0.3)(lstm_out) # Dropout réteg az második LSTM után
    lstm_out = LSTM(32, dropout=0.3)(lstm_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(lstm_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása
lstm_trainable = create_lstm_model(trainable_embeddings=True)  # Trainable embedding

lstm_trainable.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_1 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 600, 128)            │         219,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 600, 64)             │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,781,505 (29.68 MB)
#  Trainable params: 7,781,505 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Modell tanítása a validációs adatok figyelésével
lstm_history_trainable = lstm_trainable.fit(
    padded_train_final, y_train_final,
    validation_data=(padded_val, y_val),  # Validációs halmaz
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság: {test_accuracy:.4f}, Teszthalmaz veszteség: {test_loss:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 81s 89ms/step - accuracy: 0.8546 - loss: 0.3452 - val_accuracy: 0.9125 - val_loss: 0.2167
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 73s 83ms/step - accuracy: 0.9352 - loss: 0.1770 - val_accuracy: 0.9422 - val_loss: 0.1559
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 71s 85ms/step - accuracy: 0.9623 - loss: 0.1089 - val_accuracy: 0.9498 - val_loss: 0.1633
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 80s 83ms/step - accuracy: 0.9709 - loss: 0.0875 - val_accuracy: 0.9573 - val_loss: 0.1237
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 83ms/step - accuracy: 0.9765 - loss: 0.0696 - val_accuracy: 0.9491 - val_loss: 0.1503
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 86ms/step - accuracy: 0.9787 - loss: 0.0617 - val_accuracy: 0.9481 - val_loss: 0.1543
# Epoch 7/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 86ms/step - accuracy: 0.9868 - loss: 0.0437 - val_accuracy: 0.9590 - val_loss: 0.1471
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.7335 - loss: 1.0101
# Teszthalmaz pontosság: 0.7288, Teszthalmaz veszteség: 1.0208

# %%
# Valószínűség becslése
lstm_y_prob = lstm_trainable.predict(padded_test)

lstm_y_pred = (lstm_y_prob > 0.5).astype(int)

lstm_accuracy = accuracy_score(y_test, lstm_y_pred)
lstm_precision = precision_score(y_test, lstm_y_pred)
lstm_recall = recall_score(y_test, lstm_y_pred)
lstm_f1 = f1_score(y_test, lstm_y_pred)

print(f"Accuracy: {lstm_accuracy:.4f}")
print(f"Precision: {lstm_precision:.4f}")
print(f"Recall: {lstm_recall:.4f}")
print(f"F1-score: {lstm_f1:.4f}")
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
# Accuracy: 0.7286
# Precision: 0.9251
# Recall: 0.4975
# F1-score: 0.6470

# %% [markdown]
# ## LSTM Modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(lstm_history_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(lstm_history_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7334 - loss: 1.0112

# %%
# Confusion Matrix
cm_lstm = confusion_matrix(y_test, lstm_y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm_lstm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix LSTM Modellre')
plt.show()

print(classification_report(y_test, lstm_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.96      0.78      7152
#          1.0       0.93      0.50      0.65      7152
#
#     accuracy                           0.73     14304
#    macro avg       0.79      0.73      0.71     14304
# weighted avg       0.79      0.73      0.71     14304

# %%
# Flatten
y_true = y_test.flatten()
y_pred = lstm_y_pred.flatten()
y_prob = lstm_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás besorolás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás besorolás) LSTM Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": lstm_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = lstm_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_lstm.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#            Hiba típusa  Valódi címke  Prediktált címke  \
# 4   Hamis negatív (FN)           1.0                 0
# 5   Hamis negatív (FN)           1.0                 0
# 8   Hamis negatív (FN)           1.0                 0
# 12  Hamis negatív (FN)           1.0                 0
# 15  Hamis negatív (FN)           1.0                 0
# 23  Hamis negatív (FN)           1.0                 0
# 24  Hamis negatív (FN)           1.0                 0
# 34  Hamis negatív (FN)           1.0                 0
# 38  Hamis negatív (FN)           1.0                 0
# 51  Hamis negatív (FN)           1.0                 0
# 56  Hamis negatív (FN)           1.0                 0
# 57  Hamis negatív (FN)           1.0                 0
# 59  Hamis negatív (FN)           1.0                 0
# 60  Hamis negatív (FN)           1.0                 0
# 71  Hamis negatív (FN)           1.0                 0
# 77  Hamis negatív (FN)           1.0                 0
# 79  Hamis negatív (FN)           1.0                 0
# 82  Hamis negatív (FN)           1.0                 0
# 89  Hamis negatív (FN)           1.0                 0
# 90  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'the' 'department' 'transportation' 'ask' 'understanding' 'metro' 'manila' 'land' 'near' 'the' 'bottom' 'a' 'global' 'urban' 'mobility' 'rank' 'say' 'it' 'work' 'project' 'improve' 'mobility' 'public' 'transportation' 'the' 'national' 'capital' 'region' 'the' 'urban' 'mobility' 'readiness' 'index' 'compile' 'the' 'oliver' 'forum' 'the' 'university' 'california' 'berkeley' 'rank' 'global' 'city' 'metro' 'manila' 'land' 'place' 'only' 'nairobi' 'fare' 'bad' 'the' 'study' 'the' 'public' 'transport' 'some' 'the' 'metric' 'above' 'include' 'transit' 'commute' 'speed' 'public' 'transit' 'affordability' 'rail' 'network' 'public' 'transit' 'station' 'density' 'transit' 'estimate' 'time' 'arrival' 'share' 'time' 'public' 'philippine' 'place' 'the' 'study' 'note' 'the' 'national' 'capital' 'region' 'sustainable' 'mobility' 'less' 'a' 'priority' 'vehicle' 'likely' 'remain' 'the' 'most' 'common' 'transit' 'option' 'ask' 'understand' 'report' 'monday' 'note' 'commuter' 'pedestrian' 'motorist' 'transport' 'worker' 'face' 'long' 'line' 'crowd' 'heavy' 'road' ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'oslo' 'norway' 'wealth' 'fund' 'the' 'world' 'large' 'investor' 'post' 'a' 'record' 'loss' 'trillion' 'crown' 'billion' 'bring' 'an' 'end' 'a' 'threeyear' 'run' 'soar' 'profit' 'stock' 'bond' 'hit' 'the' 'ukraine' 'war' 'inflation' 'the' 'previous' 'large' 'loss' 'billion' 'crown' 'it' 'end' 'a' 'recordbreaking' 'streak' 'the' 'fund' 'annual' 'return' 'exceed' 'trillion' 'crown' 'each' 'the' 'year' 'amount' 'more' 'trillion' 'crown' 'combine' 'we' 'invest' 'company' 'country' 'there' 'just' 'nowhere' 'hide' 'fund' 'chief' 'executive' 'tell' 'a' 'news' 'conference' 'the' 'single' 'big' 'stock' 'market' 'loss' 'come' 'the' 'fund' 'stake' 'amazon' 'which' 'decline' 'value' 'billion' 'crown' 'follow' 'a' 'loss' 'share' 'facebook' 'owner' 'platform' 'billion' 'tesla' 'billion' 'still' 'despite' 'the' 'record' 'loss' 'the' 'value' 'the' 'fund' 'rise' 'overall' 'billion' 'crown' 'billion' 'partly' 'the' 'weak' 'norwegian' 'currency' 'a' 'record' 'trillion' 'crown' 'cash' 'inflow' 'the' 'inflow' 'nearly' 'times' 'the' 'previous' 'record' 'billion' 'crown' 'set' 'the' 'fund' 'invest' 'the' 'norwegian' 'state' 'revenue' 'petroleum' 'production' 'a' 'major' 'crude' 'exporter' 'europes' 'large' 'gas' 'supplier' 'a' 'drop' 'russian' 'gas' 'flow' 'norway' 'benefit' 'high' 'energy' 'price ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'city' 'philippine' 'heavily' 'arm' 'men' 'brutally' 'kill' 'a' 'village' 'chief' 'his' 'loved' 'one' 'a' 'coldblooded' 'ambush' 'del' 'province' 'thursday' 'afternoon' 'january' 'the' 'attack' 'which' 'also' 'leave' 'others' 'wound' 'take' 'place' 'the' 'remote' 'village' 'locate' 'approximately' 'kilometer' 'southwest' 'city' 'fear' 'uncertainty' 'spread' 'throughout' 'the' 'community' 'military' 'police' 'force' 'swiftly' 'deploy' 'the' 'predominantly' 'muslim' 'town' 'del' '3rd' 'district' 'a' 'bid' 'prevent' 'any' 'further' 'act' 'violence' 'retaliation' 'accord' 'police' 'report' 'the' 'arm' 'group' 'target' 'chairman' 'ali' 'his' 'family' 'member' 'a' 'ruthless' 'assault' 'shake' 'the' 'community' 'it' 'core' 'the' 'village' 'c ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'interior' 'local' 'government' 'secretary' 'wednesday' 'order' 'an' 'investigation' 'the' 'death' 'a' 'student' 'who' 'find' 'a' 'shallow' 'grave' 'ano' 'circum ...
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'official' 'the' 'philippine' 'national' 'police' 'pnp' 'drug' 'enforcement' 'group' 'special' 'operation' 'unit' 'relieve' 'their' 'post' 'the' 'official' 'face' 'allegation' 'kidnap' 'torture' 'accord' 'jun' 'report' 'wednesday' 'yun' 'relieve' 'ni' 'dir ...
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'president' 'ferdinand' 'marcos' 'jr' 'reconstitute' 'the' 'sugar' 'regulatory' 'administration' 'govern' 'body' 'new' 'appointee' 'the' 'appointment' 'the' 'heel' 'the' 'controversial' 'order' 'authorize' 'the' 'importation' 'metric' 'ton' 'sugar' 'which' 'later' 'declare' 'illegal' 'thumb' 'down' 'the' 'chief' 'executive' 'marcos' 'appoint' 'david' 'john' 'p' 'act' 'administrator' 'the' 'accord' 'a' 'report' 'staterun' 'replace' 'administrator' 'who' 'resign' 'his' 'post' 'amid' 'the' 'controversy' 'involve' 'sugar' 'order' 'so' 'the' 'say' 'order' 'deem' 'illegal' 'the' 'sugar' 'regulatory' 'board' 'convene' 'issue' 'a' 'resolution' 'the' 'approval' 'marcos' 'who' 'the' 'concurrent' 'secretary'  ...
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'the' 'house' 'committee' 'appropriation' 'wednesday' 'terminate' 'the' 'hear' 'the' 'propose' 'billion' 'budget' 'the' 'department' 'justice' 'doj' 'it' 'attached' 'agency' 'the' 'year' 'representative' 'initially' 'move' 'terminate' 'the' 'deliberation' 'any' 'say' 'member' 'ask' 'their' 'question' 'the' 'plenary' 'deliberation' 'however' 'the' 'hearing' 'only' 'terminate' 'act' 'teacher' 'representative' 'france' 'castro' 'question' 'ask' 'the' ...
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'president' 'ferdinand' 'marcos' 'jr' 'vow' 'provide' 'housing' 'soldier' 'accord' 'the' 'presidential' 'communication' 'office' 'tuesday' 'we' 'begin' 'craft' 'the' 'program' 'the' 'housing' 'the' 'uniformed' 'personnel' ...
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'the' 'bureau' 'immigration' 'bi' 'arrest' 'set' 'deport' 'a' 'chinese' 'national' 'who' 'search' 'authority' 'alleg ...
# ...
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'a' 'family' 'shock ...
# 89  'just' 'month' 'ago' 'hillary' 'clinton' 'amass' 'a' 'point' 'lead' 'over' 'donald' 'trump' 'national' 'poll' 'an' 'even' 'big' 'advantage' 'swing' 'state' 'her' 'eventual' 'victory' 'all' 'assure' 'democrat' 'so' 'confident' 'win' 'a' 'landslide' 'victory' 'even' 'like' 'a' 'possibility' 'it' 'all' 'downhill' 'clinton' 'there' 'start' 'midaugust' 'her' 'lead' 'both' 'national' 'swing' 'state' 'poll' 'begin' 'gradually' 'shrink' 'the' 'event' 'this' 'past' 'weekend' 'her' 'margin' 'narrow' 'even' 'far' 'trump' 'get' 'some' 'his' 'best' 'state' 'poll' 'the' 'entire' 'general' 'election' 'campaign' 'importantly' 'clinton' 'still' 'appear' 'narrowly' 'ahead' 'both' 'nationally' 'enough' 'state' 'win' 'the' 'recent' 'trend' 'good' 'her' 'a' 'remarkably' 'dramatic' 'contrast' 'the' 'race' 'appear' 'month' 'so' 'what' 'happen' 'this' 'race' 'get' 'so' 'close' 'all' 'a' 'sudden' 'matt' 'yglesias' 'offer' 'the' 'point' 'clinton' 'simply' 'quite' 'unpopular' 'still' 'leave' 'open' 'the' 'question' 'thing' 'change' 'so' 'quickly' 'a' 'month' 'a' 'campaign' 'a' 'complex' 'thing' 'different' 'event' 'unfold' 'either' 'concurrently' 'another' 'which' 'make' 'it' 'difficult' 'test' 'a' 'clean' 'theory' 'about' 'what' 'the' 'difference' 'some' 'combination' 'all' 'this' 'most' 'likely' 'responsible' 'the' 'shift' 'we' 'see' 'voter' 'change' 'their' 'mind' 'perhaps' 'difference' 'poll' 'response' 'rate' 'it' 'unclear' 'which' 'these' 'factor' 'most' 'important' 'what' 'clear' 'a' 'race' 'democrat' 'hop' 'a' 'landslide' 'now' 'look' 'more' 'like' 'a' 'the' 'week' 'follow' 'the' 'democratic' 'convention' 'late' 'july' 'trump' 'poll' 'stand' 'plummet' 'this' 'probably' 'partly' 'clinton' 'get' 'a' 'convention' 'bounce' 'another' 'factor' 'likely' 'trump' 'highprofile' 'attack' 'the' 'family' 'the' 'late' 'capt' 'humayun' 'khan' 'the' 'kahn' 'controversy' 'heavily' 'cover' 'the' 'press' 'earn' 'trump' 'a' 'new' 'round' 'condemnation' 'highprofile' 'republican' 'around' 'august' 'trump' 'decide' 'a' 'change' 'he' 'instal' 'a' 'new' 'campaign' 'team' 'he' 'stop' 'constant' 'tv' 'interview' 'he' 'end' 'up' 'put' 'his' 'foot' 'his' 'mouth' 'he' 'start' 'more' 'traditional' 'campaign' 'event' 'the' 'wall' 'street' 'journal' 'monica' 'writes' 'perhaps' 'most' 'importantly' 'trump' 'manage' 'avoid' 'embroil' 'himself' 'any' 'major' 'new' 'controversy' 'well' 'thursdays' 'birther' 'flap' 'which' 'yet' 'play' 'out' 'the' 'poll' 'course' 'he' 'grade' 'a' 'curve' 'here' 'matt' 'yglesias' 'writes' 'even' 'trump' 'interview' 'usually' 'contain' 'untrue' 'offensive' 'statement' 'shock' 'u' 'any' 'politician' 'involve' 'trump' 'still' 'well' 'we' 'expect' 'a' 'generic' 'republican' 'nominee' 'vox' 'election' 'forecast' 'suggest' 'he' 'win' 'percent' 'the' 'twoparty' 'vote' 'he' 'currently' 'point' 'behind' 'still' 'trump' 'generally' 'spend' 'the' 'past' 'month' 'hammer' 'home' 'his' 'critique' 'clinton' 'rather' 'dog' 'question' 'about' 'offensive' 'statement' 'another' 'help' 'bring' 'some' 'reluctant' 'republican' 'back' 'his' 'camp' 'there' 'also' 'big' 'thing' 'change' 'trump' 'this' 'time' 'period' 'he' 'finally' 'start' 'spend' 'money' 'swing' 'state' 'campaign' 'ad' 'midaugust' 'hillary' 'clinton' 'spending' 'million' 'the' 'airwave' 'essentially' 'unopposed' 'every' 'key' 'state' 'now' 'the' 'trump' 'campaign' 'invest' 'million' 'ad' 'well' 'now' 'these' 'ad' 'only' 'see' 'swing' 'state' 'voter' 'so' 'we' 'expect' 'them' 'a' 'dent' 'national' 'poll' 'trump' 'improve' 'nationally' 'so' 'they' 'the' 'heart' 'what' 'go' 'still' 'they' 'make' 'a' 'difference' 'the' 'margin' 'his' 'performance' 'the' 'swing' 'state' 'decide' 'the' 'election' 'trump' 'improve' 'his' 'operation' 'clinton' 'dog' 'a' 'series' 'negative' 'news' 'story' 'hurt' 'her' 'some' 'extent' 'september' 'the' 'fbi' 'release' 'a' 'report' 'it' 'finding' 'it' 'investigation' 'clinton' 'email' 'there' 'really' 'news' 'here' 'it' 'quite' 'understandably' 'lead' 'a' 'new' 'spate' 'news' 'st ...
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'the' 'department' 'education' 'finalize' 'the' 'guideline' 'the' 'start' 'a' 'national' 'learning' 'camp' 'july' 'spokesperson' 'michael' 'say' 'friday' 'we' 'hop' 'release' 'those' 'guideline' 'soon' 'possible' 'sad' 'an' 'interview' 'b' 'tv' 'the' 'national' 'learning' 'camp' 'a' 'part' 'national' 'learning' 'recovery' 'program' 'aim' 'help' 'the' 'student' 'catch' 'up' 'the' 'learning' 'loss' 'the' 'height' 'the' 'pandemic' 'school' 'close' 'down' 'this' 'camp' 'feature' 'intervention' 'enrichment' 'he' 'add' 'come' 'out' 'the' 'learning' 'loss' 'learn' 'gap' 'po' 'sa' 'summer' 'class' 'lang' 'sa' 'o' 'sa' 'grade' 'po' 'na' 'sa' 'learn' 'camp' 'say' 'voluntary' 'the' 'official' 'emphasize' 'the' 'national' 'learning' 'camp' 'voluntary' 'student' 'teacher' 'well' 'it' 'voluntary' 'say' 'student' 'who' 'low' 'grade' 'highly' 'encourage' 'participate' 'this' 'affect' 'their' 'promotion' 'the' 'grade' 'level' 'teacher' 'who' 'volunteer' 'the' 'program' 'say' 'they' 'give' 'additional' 'leave' 'credit' 'these' 'leave' 'credit' 'count' 'even' 'their' 'service' 'credit' 'limit' 'day' 'rule' 'way' 'back' 'n ...
#
#     Predikció valószínűsége
# 4                    0.1987
# 5                    0.1993
# 8                    0.0486
# 12                   0.0207
# 15                   0.0046
# 23                   0.3183
# 24                   0.0567
# 34                   0.2741
# 38                   0.1704
# 51                   0.0217
# 56                   0.1661
# 57                   0.0021
# 59                   0.0094
# 60                   0.0017
# 71                   0.0418
# 77                   0.0050
# 79                   0.0019
# 82                   0.0015
# 89                   0.4414
# 90                   0.0852

# %% [markdown]
# # GRU MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ### Modell lefuttatása

# %%
# GRU Modell

def create_gru_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),  # Ensure within vocab limit
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings  # Toggle trainability
    )(text_input)

    # GRU rétegek
    gru_out = GRU(128, return_sequences=True, dropout=0.3)(text_embedding)
    gru_out = Dropout(0.3)(gru_out)  # Dropout réteg az első GRU után
    gru_out = GRU(64,return_sequences=True, dropout=0.3)(gru_out)
    gru_out = Dropout(0.3)(gru_out)
    gru_out = GRU(32, dropout=0.3)(gru_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(gru_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása (Trainable)
gru_trainable = create_gru_model(trainable_embeddings=True)

gru_trainable.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_2 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 600, 128)            │         165,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 600, 64)             │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,711,809 (29.42 MB)
#  Trainable params: 7,711,809 (29.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# GRU modell tanítása a validációs adatok figyelésével
history_gru_trainable = gru_trainable.fit(
    padded_train_final, y_train_final,  # Ugyanaz a tanító adathalmaz, mint az LSTM-nél
    validation_data=(padded_val, y_val),  # Ugyanaz a validációs halmaz, mint az LSTM-nél
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság (GRU): {test_accuracy_gru:.4f}, Teszthalmaz veszteség (GRU): {test_loss_gru:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 70s 81ms/step - accuracy: 0.8284 - loss: 0.3640 - val_accuracy: 0.9587 - val_loss: 0.1174
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 65s 78ms/step - accuracy: 0.9717 - loss: 0.0833 - val_accuracy: 0.9701 - val_loss: 0.0810
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.9894 - loss: 0.0345 - val_accuracy: 0.9723 - val_loss: 0.0899
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 67s 80ms/step - accuracy: 0.9934 - loss: 0.0210 - val_accuracy: 0.9730 - val_loss: 0.0868
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 65s 78ms/step - accuracy: 0.9957 - loss: 0.0129 - val_accuracy: 0.9679 - val_loss: 0.1191
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7763 - loss: 0.7467
# Teszthalmaz pontosság (GRU): 0.7696, Teszthalmaz veszteség (GRU): 0.7643

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Valószínűség becslése
gru_y_prob = gru_trainable.predict(padded_test)

gru_y_pred = (gru_y_prob > 0.5).astype(int)

accuracy = accuracy_score(y_test, gru_y_pred)
precision = precision_score(y_test, gru_y_pred)
recall = recall_score(y_test, gru_y_pred)
f1 = f1_score(y_test, gru_y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step
# Accuracy: 0.7702
# Precision: 0.9537
# Recall: 0.5680
# F1-score: 0.7119

# %% [markdown]
# ## GRU modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_gru_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(history_gru_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(history_gru_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(history_gru_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.7315 - loss: 1.0059

# %%
# Confusion Matrix
cm_gru = confusion_matrix(y_test, gru_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_gru, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix GRU Modellre')
plt.show()

print(classification_report(y_test, gru_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.97      0.81      7152
#          1.0       0.95      0.57      0.71      7152
#
#     accuracy                           0.77     14304
#    macro avg       0.82      0.77      0.76     14304
# weighted avg       0.82      0.77      0.76     14304

# %%
# Flatten
y_true = y_test.flatten()
y_pred = gru_y_pred.flatten()
y_prob = gru_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás) GRU Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": gru_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = gru_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_gru.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 5    Hamis negatív (FN)           1.0                 0
# 8    Hamis negatív (FN)           1.0                 0
# 10   Hamis negatív (FN)           1.0                 0
# 12   Hamis negatív (FN)           1.0                 0
# 15   Hamis negatív (FN)           1.0                 0
# 23   Hamis negatív (FN)           1.0                 0
# 24   Hamis negatív (FN)           1.0                 0
# 34   Hamis negatív (FN)           1.0                 0
# 46   Hamis negatív (FN)           1.0                 0
# 51   Hamis negatív (FN)           1.0                 0
# 57   Hamis negatív (FN)           1.0                 0
# 60   Hamis negatív (FN)           1.0                 0
# 71   Hamis negatív (FN)           1.0                 0
# 79   Hamis negatív (FN)           1.0                 0
# 82   Hamis negatív (FN)           1.0                 0
# 86   Hamis negatív (FN)           1.0                 0
# 90   Hamis negatív (FN)           1.0                 0
# 101  Hamis negatív (FN)           1.0                 0
# 109  Hamis negatív (FN)           1.0                 0
# 111  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'oslo' 'norway' 'wealth' 'fund' 'the' 'world' 'large' 'investor' 'post' 'a' 'record' 'loss' 'trillion' 'crown' 'billion' 'bring' 'an' 'end' 'a' 'threeyear' 'run' 'soar' 'profit' 'stock' 'bond' 'hit' 'the' 'ukraine' 'war' 'inflation' 'the' 'previous' 'large' 'loss' 'billion' 'crown' 'it' 'end' 'a' 'recordbreaking' 'streak' 'the' 'fund' 'annual' 'return' 'exceed' 'trillion' 'crown' 'each' 'the' 'year' 'amount' 'more' 'trillion' 'crown' 'combine' 'we' 'invest' 'company' 'country' 'there' 'just' 'nowhere' 'hide' 'fund' 'chief' 'executive' 'tell' 'a' 'news' 'conference' 'the' 'single' 'big' 'stock' 'market' 'loss' 'come' 'the' 'fund' 'stake' 'amazon' 'which' 'decline' 'value' 'billion' 'crown' 'follow' 'a' 'loss' 'share' 'facebook' 'owner' 'platform' 'billion' 'tesla' 'billion' 'still' 'despite' 'the' 'record' 'loss' 'the' 'value' 'the' 'fund' 'rise' 'overall' 'billion' 'crown' 'billion' 'partly' 'the' 'weak' 'norwegian' 'currency' 'a' 'record' 'trillion' 'crown' 'cash' 'inflow' 'the' 'inflow' 'nearly' 'times' 'the' 'previous' 'record' 'billion' 'crown' 'set' 'the' 'fund' 'invest' 'the' 'norwegian' 'state' 'revenue' 'petroleum' 'production' 'a' 'major' 'crude' 'exporter' 'europes' 'large' 'gas' 'supplier' 'a' 'drop' 'russian' 'gas' 'flow' 'norway' 'benefit' 'high' 'energy' 'price' 'the' 'war' 'ukraine' 'we' 'very' 'conscious' 'the' 'fact' 'the' 'inflow' 'come' 'a' 'tragic' 'backdrop' 'europe' 'say' 'it' 'an' 'i ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'geneva' 'the' 'world' 'health' 'organization' 'say' 'wednesday' 'it' 'too' 'early' 'lift' 'the' 'alert' 'the' 'crisis' 'the' 'pandemic' 'remain' 'a' 'global' 'health' 'emergency' 'despite' 'recent' 'progress' 'the' 'who' 'emergency' 'committee' 'meet' 'week' 'conclude' 'the' 'pandemic' 'still' 'constitute' 'a' 'public' 'health' 'emergency' 'international' 'concern' 'a' 'status' 'it' 'declare' 'back' 'january' 'who' 'chief' 'tedros' 'tell' 'reporter' 'wednesday' 'he' 'agree' 'the' 'committee' 'advice' 'the' 'committee' 'emphasize' 'the' 'need' 'strengthen' 'surveillance' 'expand' 'access' 'test' 'treatment' 'vaccine' 'those' 'most' 'risk' 'he' 'say' 'speak' 'the' 'un' 'health' 'agency' 'headquarters' 'geneva' 'the' 'who' 'first' 'declare' 'the' 'outbreak' 'a' 'january' 'outside' 'china' 'few' 'case' 'death' 'report' 'it' 'the' 'mechanism' 'trigger' 'an' 'international' 'response' 'it' 'only' 'march' 'tedros' 'describe' 'the' 'worsen' 'situation' 'a' 'pandemic' 'country' 'wake' 'up' 'the' 'danger' 'the' 'start' 'the' 'pandemic' 'more' 'million' 'confirm' 'case' 'report' 'who' 'more' 'million' 'death' 'those' 'number' 'believe' 'significant' 'underestimate' 'accord' 'who' 'global' 'dashboard' 'the' 'situation' 'new' 'case' 'report' 'the' 'previous' 'hour' 'new' 'death' 'report' 'the' 'past' 'week' 'tedros' 'acknowledge' 'wednesday' 'the' 'global' 'situation' 'obviously' 'improve' 'the' 'pandemic' 'begin' 'he' 'warn' 'the' 'virus' 'continue' 'change' 'there' 'remain' 'risk' 'uncertainty' 'the' 'pandemic' 'surprise' 'u' 'very' 'well' 'again' 'he' 'warn' 'surveillance' 'decline' 'maria' 'van' 'the' 'who' 'technical' 'lead' 'agree' 'warn' 'there' 'still' 'million' 'case' 'report' 'each' 'week' 'our' 'surveillance' 'decline' 'this' 'make' 'it' 'difficult' 'a' 'overview' 'the' 'situation' 'e ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'city' 'philippine' 'heavily' 'arm' 'men' 'brutally' 'kill' 'a' 'village' 'chief' 'his' 'loved' 'one' 'a' 'coldblooded' 'ambush' 'del' 'province' 'thursday' 'afternoon' 'january' 'the' 'attack' 'which' 'also' 'leave' 'others' 'wound' 'take' 'place' 'the' 'remote' 'village' 'locate' 'approximately' 'kilometer' 'southwest' 'city' 'fear' 'uncertainty' 'spread' 'throughout' 'the' 'community' 'military' 'police' 'force' 'swiftly' 'deploy' 'the' 'predominantly' 'muslim' 'town' 'del' '3rd' 'district' 'a' 'bid' 'prevent' 'any' 'further' 'act' 'violence' 'retaliation' 'accord' 'police' 'report' 'the' 'arm' 'group' 'target' 'chairman' 'ali' 'his' 'family' 'member' 'a' 'ruthless' 'assault' 'shake' 'the' 'community' 'it' 'core' 'the' 'village' 'chief' 'alongside' 'his' 'wife' 'ani' 'brutally' 'kill' 'the' 'attack' 'colonel' 'glenn' 'commander' 'the' 'del' 'police' 'provincial'  ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'interior' 'local' 'government' 'secretary' 'wednesday' 'order' 'an' 'investigation' 'the' 'death' 'a' 'student' 'who' 'find' 'a' 'shallow' 'grave' 'ano' 'circumstance' 'any' 'form' 'violence' 'na' 'he' 'tell' 'reporter' 'an' 'ambush' 'interview' 'we' 'investigate' 'it' 'immediately' 'look' 'th ...
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'official' 'the' 'philippine' 'national' 'police' 'pnp' 'drug' 'enforcement' 'group' 'special' 'operation' 'unit' 'relieve' 'their' 'post' 'the' 'official' 'face' 'allegation' 'kidnap' 'torture' 'accord' 'jun' 'report' 'wednesday' 'yun' 'relieve' 'ni' 'director' 'yun' 'fairness' 'them' 'allegation' 'yun' 'police' 'colonel' 'martinez' 'deputy' 'director' 'administration' 'say' 'base' 'the ...
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'president' 'ferdinand' 'marcos' 'jr' 'reconstitute' 'the' 'sugar' 'regulatory' 'administration' 'govern' 'body' 'new' 'appointee' 'the' 'appointment' 'the' 'heel' 'the' 'controversial' 'order' 'authorize' 'the' 'importation' 'metric' 'ton' 'sugar' 'which' 'later' 'declare' 'illegal' 'thumb' 'down' 'the' 'chief' 'executive' 'marcos' 'appoint' 'david' 'john' 'p' 'act' 'administrator' 'the' 'accord' 'a' 'report' 'staterun' 'replace' 'administrator' 'who' 'resign' 'his' 'post' 'amid' 'the' 'controversy' 'involve' 'sugar' 'order' 'so' 'the' 'say' 'order' 'deem' 'illegal' 'the' 'sugar' 'regulatory' 'board' 'convene' 'issue' 'a' 'resolution' 'the' 'approval' 'marcos' 'who' 'the' 'concurrent' 'secretary' 'the' 'department' 'agriculture' 'chairman' 'the' 'sugar' 'board' 'meanwhile' 'sugar' 'regulatory' 'board' 'member' 'pablo' 'luis' 're ...
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'the' 'house' 'committee' 'appropriation' 'wednesday' 'terminate' 'the' 'hear' 'the' 'propose' 'billion' 'budget' 'the' 'department' 'justice' 'doj' 'it' 'attached' 'agency' 'the' 'year' 'representative' 'initially' 'move' 'terminate' 'the' 'deliberation' 'any' 'say' 'member' 'ask' 'their' 'question' 'the' 'plenary' 'deliberation' 'however' 'the' 'hearing' 'only' 'terminate' 'act' 'teacher' 'representative' 'france' 'castro' 'question' 'ask' 'the' 'doj' 'update' 'the' 'bloody' 'sunday' 'extrajudicial' 'killing' 'the' 'doj' 'it' 'attached' 'agency' 'ask' 'a' 'billion' 'budget' 'l ...
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   'u' 'secret' 'service' 'officer' 'fatally' 'shoot' 'an' 'intruder' 'the' 'peruvian' 'ambassador' 'residence' 'dc' 'a' 'confrontation' 'wednesday' 'morning' 'follow' 'a' 'report' 'burglary' 'attempt' 'authority' 'say' 'the' 'ambassador' 'de' 'his' 'family' 'home' 'the' 'time' 'they' 'their' 'staff' 'injure' 'say' 'the' 'peruvian' 'embassy' 'press' 'counselor' 'uniformed' 'secret' 'service' 'officer' 'respond' 'a' 'report' 'a' 'burglary' 'progress' 'shortly' 'edt' 'gmt' 'police' 'chief' 'robert' 'say' 'they' 'find' 'a' 'man' 'his' '20' '30' 'carry' 'a' 'metal' 'stake' 'the' 'rear' 'the' 'house' 'windows' 'smash' 'officer' 'initially' 'try' 'stop' 'the' 'man' 'tasers' 'he' 'app ...
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    'the' 'bureau' 'immigration' 'bi' 'arrest' 'set' 'deport' 'a' 'chinese' 'national' 'who' 'search' 'authority' 'allegedly' 'misrepresent' 'himself' 'a' 'filipino' 'suspect' 'tai' 'manila' 'tuesday' 'a' 'warrant' 'deportation' 'issue' 'him' 'july' 'yea ...
# ...
# 101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'manila' 'philippine' 'philippine' 'basketball' 'hot' 'prospect' 'just' 'a' 'major' 'francis' 'lebron' 'lopez' 'transfer' 'the' 'university' 'the' 'philippine' 'up' 'some' 'a' 'distraction' 'the' 'year' 'spend' 'quality' 'time' 'family' 'close' 'friends' 'the' 'holiday' 'it' 'give' 'me' 'the' 'opportunity' 'seriously' 'stock' 'my' 'life' 'well' 'the' 'option' 'available' 'my' 'future' 'both' 'my' 'education' 'basketball' 'career' 'lopez' 'say' 'a' 'statement' 'saturday' 'january' 'my' 'basketball' 'path' 'unpredictable' 'the' 'past' 'year' 'i' 'finish' 'my' 'high' 'school' 'education' 'life' 'thrown' 'a' 'distraction' 'me' 'a' 'strong' 'well' 'person' 'lopez' 'the' 'young' 'the' 'pool' 'say' 'up' 'star' 'carl' 'play' 'a' 'pivotal' 'role' 'his' 'decision' 'aside' 'his' 'discussion' 'family' 'friend' 'the' 'yearold' 'lopez' 'thank' 'his' 'teammate' 'who' 'recently' 'bid' 'up' 'farewell' 'play' 'the' ' ...
# 109                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'the' 'report' 'death' 'toll' 'typhoon' 'increase' 'the' 'national' 'disaster' 'risk' 'reduction' 'management' 'council' 'say' 'friday' 'it' 'report' 'the' 'say' 'the' 'fatality' 'report' 'central' 'the' 'death' 'verify' 'so' 'far' 'meanwhile' 'the' 'report' 'the' 'following' 'fatality' 'yet' 'verify' 'accord' 'the' 'the' 'say' 'person' 'report' 'miss' 'report' 'injured' 'central' 'a' 'total' 'people' 'family' 'affect' 'central' 'the' 'say' 'it' 'add' 'person' 'family' 'stay' 'inside' 'evacuation' 'center' 'individual' 'family' 'take' 'shelter' 'place' 'the' 'typhoon' 'house ...
# 111                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'the' 'sevenday' 'positivity' 'rate' 'the' 'national' 'capital' 'region' 'decrease' 'the' 'previous' 'independent' 'monitoring' 'group' 'research' 'say' 'monday' 'fellow' 'dr' 'guido' 'david' 'report' 'positivity' 'rate' 'go' 'down' 'october' 'it' 'peak' 'october' 'positivity' 'rate' 'refer' 'the' 'percentage' 'people' 'who' 'find' 'positive' 'the' 'total' 'number' 'individual' 'test' 'reproduction' 'number' 'meanwhile' 'also' 'slightly' 'september' 'october' 'reproduction' 'rate' 'refer' 'the' 'number' 'people' 'infect' 'case' 'a' 'reproduction' 'number' 'indicate' 'the' 'transmission' 'the' 'virus' 'slow' 'down' 'the' 'average' 'new' 'infection' 'the' 'region' 'also' 'drop' 'october' 'october' 'this' 'translate' 'a' 'growth'  ...
#
#      Predikció valószínűsége
# 5                     0.1552
# 8                     0.0078
# 10                    0.4226
# 12                    0.4065
# 15                    0.0268
# 23                    0.0248
# 24                    0.0363
# 34                    0.0151
# 46                    0.1165
# 51                    0.0265
# 57                    0.0201
# 60                    0.0266
# 71                    0.0624
# 79                    0.0063
# 82                    0.0101
# 86                    0.4548
# 90                    0.0810
# 101                   0.1246
# 109                   0.1368
# 111                   0.0009

# %% [markdown]
# # Tanulás-validáció-teszt összehasonlítása két modellnél

# %%
test_loss_lstm, test_accuracy_lstm = lstm_trainable.evaluate(padded_test, y_test, verbose=0)
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test, verbose=0)

# Ábra létrehozása két alábrával
plt.figure(figsize=(12, 5))

# Tanulási, validációs és teszthalmaz veszteség ábrázolása
plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='LSTM tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='LSTM validációs veszteség', color='#7fcdbb')
plt.plot(history_gru_trainable.history['loss'], label='GRU tanulási veszteség', color='red')
plt.plot(history_gru_trainable.history['val_loss'], label='GRU validációs veszteség', color='orange')
plt.axhline(y=test_loss_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz veszteség')  # LSTM teszt loss
plt.axhline(y=test_loss_gru, color='red', linestyle='--', label='GRU teszthalmaz veszteség')  # GRU teszt loss
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Ttanulási, validációs és teszthalmaz precízió ábrázolása
if 'accuracy' in lstm_history_trainable.history and 'accuracy' in history_gru_trainable.history:
    plt.subplot(1, 2, 2)
    plt.plot(lstm_history_trainable.history['accuracy'], label='LSTM tanulási pontosság', color='blue')
    plt.plot(lstm_history_trainable.history['val_accuracy'], label='LSTM validációs pontosság', color='#7fcdbb')
    plt.plot(history_gru_trainable.history['accuracy'], label='GRU tanulási pontosság', color='red')
    plt.plot(history_gru_trainable.history['val_accuracy'], label='GRU validációs pontosság', color='orange')
    plt.axhline(y=test_accuracy_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz pontosság')  # LSTM teszt accuracy
    plt.axhline(y=test_accuracy_gru, color='red', linestyle='--', label='GRU teszthalmaz pontosság')  # GRU teszt accuracy
    plt.xlabel('Epizód')
    plt.ylabel('Pontosság')
    plt.legend()
    plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.tight_layout()
plt.show()
