# %% [markdown]
# # **Csomagok behívása**

# %%
#Szükséges csomagok és adatbázis importálása
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Concatenate
import numpy as np
import tensorflow as tf
import spacy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fájlok behívása, ellenőrzése és felkészítése

# %%
# Betölteni padded sequences, tokenizer, és számokat
padded_train = np.load('/content/padded_train01.npy')
padded_test = np.load('/content/padded_test01.npy')

# Tokenizer visszatöltése
with open('/content/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Címkék betöltése (real = 1, fake = 0)
train_file = '/content/train_elso.csv'
test_file = '/content/teszt_elso.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

labels_train = df_train['label'].values
labels_test = df_test['label'].values

# Betölteni embedding mátrixot
embedding_matrix = np.load('/content/embedding_matrix.npy')

# Ellenőrzés
print(f"Train padded sequences shape: {padded_train.shape}")
print(f"Test padded sequences shape: {padded_test.shape}")
print(f"Train labels shape: {labels_train.shape}")
print(f"Test labels shape: {labels_test.shape}")
# Out:
# Train padded sequences shape: (59520, 600)
# Test padded sequences shape: (14880, 600)
# Train labels shape: (59520,)
# Test labels shape: (14880,)

# %%
# Max szókincs és szekvencia hossz
MAX_VOCAB_SIZE = 25000
MAX_LENGTH = 600
EMBEDDING_DIM = 300  # GloVe 300d

# input shape
MAX_SEQUENCE_LENGTH = padded_train.shape[1]

# Szöveges input (LSTM/GRU bemenet)
text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
embedding_layer = Embedding(
    input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
    output_dim=embedding_matrix.shape[1],
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)(text_input)

model_output = embedding_layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
MAX_SEQUENCE_LENGTH = padded_train.shape[1]  # Train hossz
EMBEDDING_DIM = embedding_matrix.shape[1]  # GloVe embeddings

# 10%-os validációs halmaz leválasztása a tanító adatokból
padded_train_final, padded_val, y_train_final, y_val = train_test_split(
    padded_train, labels_train, test_size=0.1, random_state=42
)
# Float32-re konvertálás TensorFlow kompatibilitás miatt
padded_train_final = np.array(padded_train_final, dtype=np.float32)
padded_val = np.array(padded_val, dtype=np.float32)
padded_test = np.array(padded_test, dtype=np.float32)
y_train_final = np.array(y_train_final, dtype=np.float32)
y_val = np.array(y_val, dtype=np.float32)
y_test = np.array(labels_test, dtype=np.float32)

# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# # LSTM MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ## Modell lefuttatása

# %%
# LSTM modell, trainable, non-trainable embedding

def create_lstm_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings
    )(text_input)

    # LSTM rétegek
    lstm_out = LSTM(128, return_sequences=True, dropout=0.3)(text_embedding)
    lstm_out = Dropout(0.3)(lstm_out)  # Dropout réteg az első LSTM után
    lstm_out = LSTM(64,return_sequences=True, dropout=0.3)(lstm_out)
    lstm_out = Dropout(0.3)(lstm_out) # Dropout réteg az második LSTM után
    lstm_out = LSTM(32, dropout=0.3)(lstm_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(lstm_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása
lstm_trainable = create_lstm_model(trainable_embeddings=True)  # Trainable embedding

lstm_trainable.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_1 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 600, 128)            │         219,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 600, 64)             │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,781,505 (29.68 MB)
#  Trainable params: 7,781,505 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Modell tanítása a validációs adatok figyelésével
lstm_history_trainable = lstm_trainable.fit(
    padded_train_final, y_train_final,
    validation_data=(padded_val, y_val),  # Validációs halmaz
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság: {test_accuracy:.4f}, Teszthalmaz veszteség: {test_loss:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 78s 84ms/step - accuracy: 0.8162 - loss: 0.4118 - val_accuracy: 0.9207 - val_loss: 0.2034
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 80s 86ms/step - accuracy: 0.9339 - loss: 0.1842 - val_accuracy: 0.9372 - val_loss: 0.1690
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 86ms/step - accuracy: 0.9576 - loss: 0.1185 - val_accuracy: 0.9407 - val_loss: 0.1568
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9688 - loss: 0.0888 - val_accuracy: 0.9647 - val_loss: 0.1042
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9777 - loss: 0.0646 - val_accuracy: 0.9654 - val_loss: 0.1052
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 84ms/step - accuracy: 0.9882 - loss: 0.0366 - val_accuracy: 0.9704 - val_loss: 0.0978
# Epoch 7/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 0.9927 - loss: 0.0236 - val_accuracy: 0.9677 - val_loss: 0.1097
# Epoch 8/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 87ms/step - accuracy: 0.9957 - loss: 0.0142 - val_accuracy: 0.9676 - val_loss: 0.1298
# Epoch 9/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9957 - loss: 0.0128 - val_accuracy: 0.9711 - val_loss: 0.1214
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9644 - loss: 0.1178
# Teszthalmaz pontosság: 0.9627, Teszthalmaz veszteség: 0.1244

# %%
# Valószínűség becslése
lstm_y_prob = lstm_trainable.predict(padded_test)

lstm_y_pred = (lstm_y_prob > 0.5).astype(int)

lstm_accuracy = accuracy_score(y_test, lstm_y_pred)
lstm_precision = precision_score(y_test, lstm_y_pred)
lstm_recall = recall_score(y_test, lstm_y_pred)
lstm_f1 = f1_score(y_test, lstm_y_pred)

print(f"Accuracy: {lstm_accuracy:.4f}")
print(f"Precision: {lstm_precision:.4f}")
print(f"Recall: {lstm_recall:.4f}")
print(f"F1-score: {lstm_f1:.4f}")
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
# Accuracy: 0.9623
# Precision: 0.9666
# Recall: 0.9577
# F1-score: 0.9621

# %% [markdown]
# ## LSTM Modell ábrák

# %%
import matplotlib.pyplot as plt

# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = lstm_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(lstm_history_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(lstm_history_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9636 - loss: 0.1190

# %%
# Confusion Matrix
cm_lstm = confusion_matrix(y_test, lstm_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_lstm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix LSTM Modellre')
plt.show()

print(classification_report(y_test, lstm_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.96      7440
#          1.0       0.97      0.96      0.96      7440
#
#     accuracy                           0.96     14880
#    macro avg       0.96      0.96      0.96     14880
# weighted avg       0.96      0.96      0.96     14880

# %%
# Flatten
y_true = y_test.flatten()
y_pred = lstm_y_pred.flatten()
y_prob = lstm_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás besorolás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes besorolás", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás besorolás) LSTM Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": lstm_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = lstm_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_lstm.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 3    Hamis negatív (FN)           1.0                 0
# 25   Hamis pozitív (FP)           0.0                 1
# 41   Hamis negatív (FN)           1.0                 0
# 53   Hamis negatív (FN)           1.0                 0
# 151  Hamis pozitív (FP)           0.0                 1
# 153  Hamis negatív (FN)           1.0                 0
# 168  Hamis negatív (FN)           1.0                 0
# 217  Hamis negatív (FN)           1.0                 0
# 231  Hamis pozitív (FP)           0.0                 1
# 244  Hamis negatív (FN)           1.0                 0
# 275  Hamis negatív (FN)           1.0                 0
# 293  Hamis pozitív (FP)           0.0                 1
# 297  Hamis pozitív (FP)           0.0                 1
# 315  Hamis pozitív (FP)           0.0                 1
# 356  Hamis negatív (FN)           1.0                 0
# 408  Hamis negatív (FN)           1.0                 0
# 417  Hamis negatív (FN)           1.0                 0
# 443  Hamis pozitív (FP)           0.0                 1
# 464  Hamis pozitív (FP)           0.0                 1
# 467  Hamis pozitív (FP)           0.0                 1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 3    'the' 'australian' 'government' 'take' 'the' 'lead' 'president' 'donald' 'trump' 'the' 'race' 'improve' 'vet' 'immigrant' 'who' 'hold' 'hostile' 'islamic' 'attitude' 'reform' 'program' 'like' 'the' 'outsourcing' 'visa' 'we' 'define' 'a' 'commitment' 'common' 'value' 'political' 'value' 'the' 'rule' 'law' 'democracy' 'freedom' 'mutual' 'respect' 'equality' 'men' 'woman' 'prime' 'minister' 'malcolm' 'turnbull' 'tell' 'the' 'medium' 'thursday' 'he' 'describe' 'the' 'vetting' 'process' 'our' 'citizenship' 'process' 'reflect' 'so' 'today' 'we' 'announce' 'change' 'strengthen' 'citizenship' 'a' 'strong' 'australia' 'strong' 'citizenship' 'strong' 'citizen' 'you' 'apply' 'a' 'citizen' 'you' 'need' 'competent' 'english' 'a' 'vital' 'requirement' 'also' 'we' 'need' 'ensure' 'our' 'citizenship' 'test' 'enable' 'applicant' 'demonstrate' 'they' 'integrate' 'engage' 'our' 'australian' 'community' 'so' 'they' 'part' 'the' 'community' 'they' 'live' 'here' 'a' 'permanent' 'resident' 'year' 'they' 'speak' 'english' 'share' 'our' 'value' 'integrate' 'those' 'critically' 'important' 'element' 'i' 'believe' 'they' 'empower' 'applicant' 'this' 'good' 'the' 'applicant' 'good' 'the' 'nation' 'underline' 'our' 'australian' 'value' 'the' 'very' 'heart' 'australian' 'citizenship' 'australian' 'citizenship' 'the' 'foundation' 'our' 'democracy' 'these' 'political' 'value' 'what' 'bind' 'u' 'together' 'what' 'keep' 'u' 'together' 'the' 'midst' 'our' 'diversity' 'the' 'new' 'australian' 'push' 'a' 'trump' 'champion' 'immigration' 'reform' 'the' 'united' 'state' 'turnbull' 'seek' 'stabilize' 'his' 'government' 'he' 'stag' 'an' 'internal' 'party' 'vote' 'september' 'the' 'prime' 'minister' 'job' 'his' 'partys' 'leader' 'tony' 'abbott' 'an' 'immigration' 'hawk' 'who' 'entirely' 'block' 'stop' 'a' 'wave' 'immigrant' 'reach' 'australia' 'some' 'extent' 'flip' 'position' 'design' 'help' 'his' 'wing' 'the' 'party' 'wing' 'the' 'party' 'the' 'grow' 'support' 'give' 'nationalist' 'nation' 'party' 'which' 'skeptical' 'about' 'ability' 'integrate' 'australian' 'society' 'turnbull' 'repeatedly' 'endorse' 'immigration' 'invite' 'additional' 'refugee' 'tell' 'the' 'parliament' 'october' 'everyone' 'sit' 'this' 'chamber' 'every' 'australian' 'a' 'beneficiary' 'the' 'diversity' 'the' 'heart' 'our' 'nation' 'the' 'most' 'effective' 'weapon' 'the' 'muslim' 'terrorists' 'an' 'inclusive' 'nation' 'amid' 'rise' 'violence' 'welfare' 'use' 'immigrant' 'muslims' 'a' 'september' 'poll' 'show' 'half' 'all' 'australian' 'want' 'block' 'muslim' 'immigration' 'which' 'strongly' 'support' 'business' 'group' 'which' 'profit' 'the' 'inflow' 'extra' 'consumer' 'worker' 'minister' 'immigration' 'border' 'protection' 'peter' 'dutton' 'tell' 'reporter' 'the' 'press' 'conference' 'immigrant' 'an' 'upgraded' 'write' 'test' 'there' 'further' 'test' 'further' 'question' 'place' 'the' 'test' 'it' 'currently' 'operate' 'there' 'the' 'opportunity' 'people' 'comment' 'some' 'these' 'change' 'over' 'the' 'course' 'the' 'over' 'the' 'course' 'the' 'period' 'now' 'june' 'so' 'we' 'consult' 'around' 'the' 'question' 'around' 'the' 'value' 'issue' 'we' 'provide' 'further' 'detail' 'there' 'also' 'change' 'the' 'pledge' 'again' 'we' 'consult' 'particular' 'issue' 'well' 'so' 'i' 'leave' 'it' 'there' 'example' 'domestic' 'violence' 'a' 'perpetrator' 'domestic' 'violence' 'my' 'view' 'person' 'an' 'australian' 'citizen' 'we' 'ask' 'question' 'we' 'also' 'undertake' 'our' 'check' 'relation' 'police' 'check' 'whatever' 'the' 'case' 'so' 'you' 'adopt' 'apply' 'the' 'test' 'the' 'campaign' 'trail' 'his' 'executive' 'order' 'his' 'inauguration' 'president' 'donald' 'trump' 'call' 'a' 'new' 'process' 'extreme' 'vet' 'refugee' 'legal' 'immigrant' 'especially' 'muslim' 'immigrant' 'the' 'united' 'state' 'example' 'his' 'january' 'executive' 'order' 'immigration' 'declare' 'his' 'policy' 'exclude' 'people' 'hostile' 'attitude' 'order' 'protect' 'americans' 'the' 'united' 'state' 'ensure' 'those' 'admit' 'this'  ...
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'official' 'the' 'justice' 'department' 'the' 'education' 'department' 'join' 'force' 'write' 'a' 'letter' 'reject' 'the' 'obama' 'administration' 'policy' 'the' 'nondiscrimination' 'law' 'support' 'the' 'rollback' 'the' 'policy' 'they' 'explain' 'their' 'belief' 'the' 'directive' 'improperly' 'devise' 'regard' 'the' 'primary' 'role' 'the' 'state' 'local' 'school' 'district' 'establish' 'educational' 'policy' 'this' 'dispute' 'put' 'the' 'president' 'the' 'middle' 'transgender' 'right' 'issue' 'which' 'he' 'express' 'his' 'general' 'sympathy' 'the' 'campaign' 'this' 'an' 'issue' 'continue' 'split' 'the' 'republican' 'party' 'the' 'his' 'personal' 'sympathy' 'the' 'president' 'it' 'clear' 'he' 'believe' 'this' 'a' 'state' 'right' 'iss ...
# 41                                                                                                                                                                                                                                                                                                                                                        'editor' 'note' 'the' 'following' 'column' 'originally' 'appear' 'the' 'website' 'u' 'defense' 'watch' 'it' 'reprint' 'permission' 'i' 'like' 'million' 'american' 'saw' 'your' 'speech' 'the' 'dnc' 'thursday' 'night' 'i' 'wish' 'offer' 'my' 'sympathy' 'the' 'death' 'your' 'son' 'captain' 'humayun' 'khan' 'who' 'kill' 'action' 'iraq' 'a' 'u' 'army' 'officer' 'a' 'veteran' 'the' 'gulf' 'war' 'i' 'certainly' 'understand' 'the' 'pain' 'anguish' 'you' 'your' 'wife' 'endure' 'every' 'day' 'your' 'son' 'die' 'save' 'the' 'life' 'his' 'fellow' 'soldier' 'jesus' 'tell' 'his' 'disciple' 'accord' 'the' 'gospel' 'john' 'great' 'love' 'man' 'this' 'a' 'man' 'lay' 'down' 'his' 'life' 'his' 'friend' 'captain' 'khan' 'a' 'hero' 'i' 'sure' 'the' 'soldier' 'he' 'serve' 'regard' 'him' 'i' 'know' 'you' 'your' 'wife' 'rest' 'assure' 'million' 'veteran' 'regard' 'your' 'son' 'a' 'hero' 'well' 'paraphrase' 'the' 'book' 'your' 'son' 'name' 'your' 'son' 'the' 'ultimate' 'sacrifice' 'his' 'country' 'a' 'country' 'new' 'you' 'your' 'family' 'which' 'you' 'openly' 'embrace' 'certainly' 'love' 'you' 'your' 'family' 'arrive' 'america' 'pakistan' 'you' 'assimilate' 'our' 'country' 'you' 'adopt' 'american' 'way' 'learn' 'our' 'history' 'apparently' 'you' 'even' 'acquire' 'a' 'pocket' 'constitution' 'the' 'way' 'good' 'you' 'sir' 'there' 'muslim' 'america' 'who' 'only' 'desire' 'assimilate' 'wish' 'live' 'sharia' 'law' 'unacceptable' 'american' 'there' 'only' 'law' 'the' 'land' 'the' 'yous' 'constitution' 'you' 'well' 'know' 'mr' 'khan' 'we' 'live' 'violent' 'time' 'dangerous' 'time' 'muslim' 'madman' 'isis' 'radical' 'jihadi' 'group' 'a' 'murder' 'terror' 'spree' 'the' 'globe' 'your' 'religion' 'peace' 'islam' 'anything' 'a' 'fact' 'confirm' 'every' 'time' 'a' 'muslim' 'shoot' 'bomb' 'torture' 'innocent' 'men' 'woman' 'child' 'this' 'mean' 'every' 'muslim' 'a' 'terrorist' 'most' 'terrorist' 'sir' 'indeed' 'muslim' 'a' 'muslim' 'terrorist' 'attack' 'the' 'sign' 'the' 'time' 'regardless' 'what' 'the' 'feckless' 'nave' 'leftist' 'ideologue' 'barack' 'obama' 'his' 'colleague' 'john' 'kerry' 'francois' 'hollande' 'angela' 'merkel' 'state' 'the' 'united' 'state' 'the' 'west' 'war' 'radical' 'islam' 'it' 'the' 'job' 'the' 'president' 'the' 'united' 'state' 'protect' 'his' 'nation' 'all' 'enemy' 'foreign' 'domestic' 'unfortunately' 'mr' 'obama' 'islam' 'refuse' 'accept' 'reality' 'which' 'result' 'the' 'death' 'thousand' 'innocent' 'people' 'the' 'world' 'group' 'like' 'isi' 'al' 'qaeda' 'goal' 'the' 'complete' 'destruction' 'the' 'judeochristian' 'culture' 'our' 'religion' 'our' 'way' 'life' 'american' 'family' 'here' 'decade' 'even' 'century' 'family' 'like' 'mine' 'relative' 'who' 'fight' 'the' 'civil' 'war' 'wwii' 'korea' 'vietnam' 'desert' 'storm' 'some' 'family' 'relative' 'who' 'fight' 'the' 'american' 'revolution' 'we' 'plan' 'let' 'our' 'country' 'devour' 'muslim' 'maniac' 'we' 'americans' 'sir' 'unarmed' 'socialist' 'european' 'zombie' 'we' 'what' 'necessary' 'protect' 'the' 'united' 'state' 'democrat' 'liberals' 'the' 'world' 'rise' 'colored' 'glass' 'conservative' 'understand' 'there' 'good' 'evil' 'this' 'world' 'evil' 'destroy' 'it' 'destroy' 'u' 'strong' 'measure' 'wartime' 'measure' 'take' 'protect' 'this' 'country' 'those' 'wish' 'annihilate' 'u' 'our' 'way' 'life' 'mr' 'trump' 'plan' 'temporarily' 'halt' 'immigration' 'muslim' 'country' 'know' 'either' 'support' 'terrorism' 'harbor' 'terrorist' 'group' 'only' 'pragmatic' 'indeed' 'it' 'constitutional' 'it' 'the' 'constitutional' 'duty' 'the' 'president' 'the' 'united' 'state' 'protect' 'this' 'nation' 'there' 'simply' 'way' 'vet' 'hundred' 'thousand' 'muslim'  ...
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'far' 'weaken' 'the' 'environmental' 'protection' 'agency' 'donald' 'trump' 'need' 'beef' 'it' 'up' 'so' 'say' 'a' 'guy' 'the' 'new' 'york' 'time' 'the' 'name' 'william' 'd' 'a' 'march' 'the' 'time' 'write' 'a' 'strong' 'credible' 'regulatory' 'regime' 'essential' 'the' 'smooth' 'function' 'our' 'economy' 'interest' 'use' 'the' 'word' 'credible' 'there' 'the' 'worthless' 'bureaucrat' 'who' 'perhaps' 'more' 'anyone' 'embody' 'what' 'so' 'very' 'wrong' 'the' 'epa' 'it' 'so' 'urgently' 'need' 'let' 'it' 'never' 'forget' 'the' 'epa' 'administrator' 'responsible' 'probably' 'the' 'black' 'moment' 'the' 'institution' 'history' 'the' 'man' 'who' 'ban' 'the' 'you' 'consequence' 'which' 'result' 'million' 'unnecessary' 'death' 'around' 'the' 'world' 'malaria' 'sure' 'deliberately' 'murder' 'all' 'those' 'people' 'the' 'fact' 'remain' 'still' 'the' 'most' 'effective' 'killer' 'the' 'mosquito' 'ban' 'it' 'the' 'you' 'help' 'create' 'a' 'regulatory' 'effect' 'which' 'deprive' 'the' 'world' 'it' 'best' 'it' 'big' 'health' 'problem' 'i' 'tell' 'the' 'story' 'a' 'month' 'back' 'it' 'worth' 'repeat' 'repeat' 'every' 'time' 'this' 'dreadful' 'man' 'pop' 'up' 'again' 'assume' 'the' 'mantle' 'an' 'authority' 'he' 'simply' 'earn' 'i' 'note' 'then' 'a' 'lawyer' 'train' 'a' 'scientist' 'the' 'man' 'responsible' 'institute' 'the' 'ban' 'he' 'this' 'scientific' 'basis' 'whatsoever' 'fact' 'judge' 'edmund' 'sweeney' 'preside' 'over' 'a' 'epa' 'hearing' 'examine' 'more' 'page' 'expert' 'testimony' 'conclude' 'a' 'carcinogenic' 'hazard' 'man' 'a' 'hazard' 'man' 'the' 'use' 'the' 'regulation' 'involve' 'here' 'a' 'effect' 'freshwater' 'fish' 'organism' 'wild' 'bird' 'wildlife' 'who' 'attend' 'the' 'hearing' 'read' 'the' 'report' 'overrule' 'him' 'which' 'probably' 'difference' 'the' 'united' 'state' 'the' 'effect' 'the' 'near' 'worldwide' 'ban' 'follow' 'meant' 'longer' 'control' 'mosquito' 'population' 'which' 'turn' 'lead' 'an' 'explosion' 'malaria' 'cause' 'the' 'death' 'million' 'subsequently' 'distinguish' 'himself' 'endorse' 'barack' 'obama' 'you' 'president' 'most' 'r ...
# 151                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 153                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               'cnn' 'a' 'pair' 'convict' 'killer' 'who' 'escape' 'an' 'upstate' 'new' 'york' 'prison' 'head' 'the' 'border' 'vermont' 'fear' 'the' 'pressure' 'an' 'intense' 'manhunt' 'the' 'neighboring' 'state' 'authority' 'say' 'wednesday' 'new' 'york' 'state' 'police' 'superintendent' 'joseph' 'say' 'authority' 'look' 'behind' 'every' 'tree' 'every' 'rock' 'inside' 'every' 'structure' 'richard' 'matt' 'david' 'sweat' 'the' 'pair' 'a' 'brazen' 'escape' 'over' 'the' 'weekend' 'the' 'clinton' 'correctional' 'facility' 'the' 'search' 'now' 'it' 'fifth' 'day' 'involve' 'more' 'law' 'enforcement' 'officer' 'the' 'state' 'offer' 'a' 'reward' 'a' 'news' 'conference' 'outside' 'the' 'prison' 'about' 'mile' 'south' 'the' 'canadian' 'border' 'vermont' 'gov' 'peter' 'say' 'the' 'search' 'area' 'expand' 'his' 'state' 'base' 'information' 'the' 'inmate' 'believe' 'new' 'york' 'go' 'hot' 'vermont' 'cooler' 'term' 'law' 'enforcement' 'vermont' 'state' 'police' 'vessel' 'additional' 'trooper' 'conduct' 'patrol' 'lake' 'which' 'cut' 'the' 'state' 'addition' 'search' 'include' 'public' 'we' 'information' 'suggest' 'vermont' 'discuss' 'a' 'possible' 'location' 'new' 'york' 'gov' 'andrew' 'cuomo' 'say' 'the' 'news' 'conference' 'they' 'head' 'vermont' 'vermont' 'engage' 'vermont' 'mobilize' 'we' 'work' 'hand' 'glove' 'we' 'coordinate' 'time' 'a' 'day' 'sure' 'every' 'lead' 'we' 'every' 'piece' 'information' 'share' 'an' 'agreement' 'vermont' 'new' 'york' 'state' 'trooper' 'allow' 'state' 'line' 'need' 'official' 'say' 'say' 'authority' 'hard' 'information' 'the' 'men' 'leave' 'new' 'york' 'state' 'law' 'enforcement' 'personnel' 'go' 'doortodoor' 'both' 'home' 'seasonal' 'residence' 'conduct' 'checkpoint' 'hamlet' 'towns' 'surround' 'cuomo' 'say' 'the' 'inmate' 'get' 'a' 'head' 'start' 'hour' 'the' 'manhunt' 'begin' 'these' 'men' 'nothing' 'cuomo' 'say' 'the' 'first' 'time' 'the' 'escape' 'law' 'enforcement' 'official' 'acknowledge' 'publicly' 'a' 'woman' 'who' 'work' 'the' 'convict' 'the' 'shop' 'the' 'prison' 'play' 'a' 'role' 'the' 'elaborate' 'breakout' 'elaborate' 'say' 'mitchell' 'befriend' 'the' 'men' 'some' 'sort' 'role' 'assist' 'them' 'she' 'arrest' 'charge' 'connection' 'their' 'escape' 'anyone' 'else' 'the' 'source' 'add' 'mitchell' 'cooperate' 'police' 'have' 'provide' 'information' 'need' 'her' 'cell' 'phone' 'people' 'connect' 'matt' 'accord' 'another' 'source' 'knowledge' 'the' 'investigation' 'it' 'clear' 'who' 'these' 'call' 'they' 'mitchell' 'know' 'about' 'them' 'mitchell' 'go' 'the' 'hospital' 'this' 'weekend' 'panic' 'attack' 'accord' 'the' 'source' 'then' 'authority' 'discover' 'a' 'saturday' 'bed' 'check' 'matt' 'sweat' 'escape' 'mitchell' 'work' 'clinton' 'seven' 'year' 'an' 'industrial' 'training' 'supervisor' 'accord' 'jennifer' 'freeman' 'a' 'spokeswoman' 'the' 'new' 'york' 'state' 'comptroller' 'her' 'salary' 'a' 'year' 'mitchell' 'son' 'mitchell' 'tell' 'nbc' 'news' 'his' 'mother' 'a' 'hospital' 'saturday' 'even' 'she' 'have' 'severe' 'chest' 'pain' 'she' 'concern' 'about' 'he' 'add' 'his' 'mom' 'who' 'work' 'the' 'prison' 'her' 'husband' 'worry' 'a' 'lot' 'about' 'everything' 'strongly' 'challenge' 'suggestion' 'she' 'anything' 'wrong' 'she' 'the' 'kind' 'person' 'go' 'risk' 'her' 'life' 'people' 'live' 'let' 'these' 'guy' 'escape' 'prison' 'he' 'say' 'his' 'wife' 'mitchell' 'tell' 'cnn' 'wednesday' 'what' 'say' 'about' 'her' 'motherinlaw' 'true' 'they' 'the' 'fact' 'prove' 'this' 'she' 'say' 'this' 'just' 'slander' 'rumor' 'mitchell' 'say' 'she' 'believe'  ...
# 168                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'los' 'angeles' 'democratic' 'presidential' 'nominee' 'hillary' 'clinton' 'play' 'it' 'strictly' 'parry' 'decidedly' 'question' 'comedian' 'zach' 'his' 'online' 'parody' 'talk' 'release' 'thursday' 'star' 'the' 'hangover' 'film' 'know' 'his' 'banter' 'the' 'web' ' ...
# 217                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 231                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 244                                                                                                                                                                                                                                                                                                 'a' 'public' 'service' 'announcement' 'your' 'friend' 'here' 'vox' 'there' 'an' 'enormous' 'amount' 'false' 'information' 'facebook' 'the' 'internet' 'tv' 'this' 'election' 'day' 'yourself' 'the' 'country' 'a' 'favor' 'ignore' 'it' 'politician' 'always' 'play' 'fast' 'loose' 'the' 'truth' 'cable' 'news' 'network' 'always' 'get' 'story' 'wrong' 'the' 'internet' 'always' 'a' 'place' 'conspiracy' 'theory' 'mislead' 'story' 'photo' 'the' 'campaign' 'see' 'an' 'unprecedented' 'increase' 'the' 'sheer' 'number' 'false' 'news' 'story' 'share' 'facebook' 'post' 'entirely' 'fake' 'news' 'site' 'run' 'young' 'people' 'look' 'some' 'money' 'this' 'long' 'bitter' 'election' 'the' 'denver' 'guardian' 'which' 'earlier' 'this' 'month' 'run' 'a' 'story' 'the' 'headline' 'fbi' 'agent' 'suspect' 'hillary' 'email' 'leak' 'find' 'dead' 'apparent' 'the' 'article' 'ricochet' 'facebook' 'gain' 'ten' 'thousand' 'share' 'despite' 'the' 'fact' 'there' 'thing' 'the' 'denver' 'guardian' 'the' 'story' 'question' 'a' 'complete' 'fabrication' 'it' 'a' 'dynamic' 'deeply' 'concern' 'president' 'barack' 'obama' 'arguably' 'the' 'user' 'social' 'medium' 'american' 'political' 'history' 'the' 'politician' 'who' 'target' 'the' 'majority' 'facebooks' 'most' 'paranoid' 'outright' 'racist' 'viral' 'post' 'long' 'it' 'start' 'believe' 'it' 'he' 'say' 'a' 'campaign' 'stop' 'ann' 'arbor' 'michigan' 'monday' 'it' 'create' 'this' 'dust' 'cloud' 'nonsense' 'matter' 'even' 'current' 'u' 'official' 'believe' 'russia' 'try' 'deliberately' 'spread' 'false' 'information' 'election' 'day' 'wouldbe' 'hillary' 'clinton' 'voter' 'stay' 'home' 'simply' 'shake' 'overall' 'confidence' 'the' 'american' 'political' 'system' 'all' 'which' 'mean' 'you' 'read' 'something' 'election' 'day' 'appear' 'too' 'dramatic' 'true' 'there' 'probably' 'a' 'good' 'simple' 'reason' 'it' 'november' 'fox' 'news' 'air' 'a' 'video' 'clip' 'show' 'a' 'member' 'the' 'black' 'panther' 'stand' 'outside' 'a' 'polling' 'station' 'philadelphia' 'it' 'a' 'single' 'person' 'a' 'single' 'polling' 'station' 'a' 'heavily' 'black' 'heavily' 'democratic' 'area' 'fox' 'anchor' 'strongly' 'suggest' 'it' 'part' 'a' 'broad' 'pattern' 'voter' 'intimidation' 'militant' 'determine' 'stop' 'nominee' 'mitt' 'romney' 'the' 'segment' 'frequently' 'throughout' 'the' 'day' 'year' 'it' 'certainly' 'possible' 'fox' 'news' 'a' 'leftleaning' 'station' 'like' 'msnbc' 'find' 'a' 'similar' 'type' 'clip' 'present' 'it' 'a' 'way' 'deliberately' 'mislead' 'amazingly' 'literally' 'the' 'our' 'problem' 'a' 'big' 'concern' 'the' 'proliferation' 'entirely' 'fake' 'news' 'site' 'entirely' 'fake' 'story' 'often' 'operate' 'entrepreneur' 'live' 'overseas' 'a' 'buzzfeed' 'article' 'earlier' 'this' 'month' 'find' 'young' 'people' 'the' 'macedonian' 'town' 'population' 'create' 'more' 'protrump' 'news' 'site' 'run' 'post' 'every' 'day' 'aggregate' 'completely' 'fringe' 'rightwing' 'sit' 'the' 'u' 'example' 'the' 'story' 'a' 'website' 'call' 'post' 'an' 'article' 'the' 'headline' 'hillary' 'clinton' 'i' 'like' 'people' 'like' 'donald' 'trump' 'run' 'office' 'they' 'honest' 'buy' 'the' 'story' 'a' 'complete' 'fabrication' 'it' 'immediately' 'go' 'viral' 'rack' 'up' 'more' 'share' 'reaction' 'comment' 'facebook' 'less' 'a' 'week' 'contrast' 'buzzfeed' 'note' 'the' 'new' 'york' 'time' 'bombshell' 'reveal' 'trump' 'declare' 'a' 'million' 'loss' 'his' 'income' 'tax' 'return' 'draw' 'a' 'comparatively' 'small' 'facebook' 'interaction' 'over' 'an' 'entire' 'month' 'kind' 'traffic' 'lucrative' 'business' 'the' 'macedonian' 'some' 'whom' 'tell' 'buzzfeed' 'they' 'up' 'month' 'push' 'information' 'they' 'know' 'untrue' 'yes' 'the' 'info' 'the' 'blog' 'bad' 'false' 'mislead' 'th ...
# ...
# 443                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'break' 'muslim' 'shot' 'dead' 'try' 'kill' 'guar ...
# 464                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'a' 'jv' 'team' 'threat' 'shake' 'a' 'daring' 'yous' 'military' 'strike' 'deep' 'isi' 'territory' 'supporters' 'the' 'extremist' 'organization' 'vow' 'revenge' 'the' 'kill' 'senior' 'leader' 'abu' 'sayyaf' 'claim' 'the' 'special' 'operation' 'mission' 'never' 'take' 'place' 'a' 'analysis' 'reveals' 'they' 'take' 'abu' 'sayyaf' 'we' 'obama' 'isis' 'supporter' 'post' 'the' 'hour' 'the' 'raid' 'near' 'the' 'eastern' 'syrian' 'city' 'your' 'goal' 'kill' 'abu' 'sayyaf' 'then' 'our' 'goal' 'kill' 'obama' 'the' 'worshiper' 'the' 'cross' 'we' 'attack' 'come' 'american' 'commando' 'carry' 'out' 'the' 'rare' 'overnight' 'military' 'operation' 'kill' 'sayyaf' 'capture' 'his' 'wife' 'free' 'a' 'woman' 'believe' 'hold' 'their' 'slave' 'the' 'pentagon' 'say' 'saturday' 'defense' 'secretary' 'ash' 'carter' 'herald' 'the' 'mission' 'a' 'significant' 'blow' 'the' 'islamic' 'analyze' 'social' 'medium' 'syria' 'the' 'wake' 'the' 'strike' 'discover' 'some' 'isi' 'supporter' 'claim' 'the' 'news' 'yous' 'propaganda' 'time' 'counter' 'isi' 'momentum' 'take' 'most' 'the' 'iraqi' 'city' 'ramadi' 'this' 'week' 'others' 'tweet' 'outside' 'the' 'syrian' 'city' 'raqqa' 'vow' 'revenge' 'the' 'strike' 'say' 'they' 'hear' 'explosion' 'say' 'sayyaf' 'responsible' 'direct' 'the' 'group' 'military' 'activity' 'fund' 'direct' 'it' 'illicit' 'oil' 'gas' 'financial' 'operation' 'yous' 'force' 'kill' 'injure' 'the' 'operation' 'which' 'represent' 'another' 'significant' 'blow' 'the' 'group' 'carter' 'say' 'it' 'a' 'reminder' 'the' 'united' 'state' 'never' 'waver' 'deny' 'safe' 'haven' 'terrorist' 'who' 'threaten' 'our' 'citizen' 'those' 'our' 'friend' 'ally' 'he' 'continue' 'the' 'statementthe' 'mission' 'include' 'the' 'arrest' 'sayyaf' 'wife' 'umm' 'sayyaf' 'the' 'free' 'the' 'woman' 'the' 'trading' 'woman' 'a' 'major' 'reward' 'isi' 'fighters' 'the' 'past' 'the' 'follow' 'a' 'strand' 'islam' 'reject' 'mainstream' 'muslim' 'isi' 'year' 'surround' 'the' 'villages' 'northern' 'iraq' 'kill' 'capture' 'dozen' 'take' 'the' 'girl' 'woman' 'slave' 'yous' 'force' 'capture' 'umm' 'sayyaf' ...
# 467                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'a' 'lot' 'say' 'trump' 'cabinet' 'pick' 'they' 'the' 'rich' 'the' 'rich' 'the' 'low' 'the' 'low' 'the' 'most' 'corrupt' 'the' 'corrupt' 'republican' 'fully' 'aware' 'this' 'they' 'plan' 'push' 'them' 'even' 'complete' 'the' 'vet' 'process' 'a' 'federal' 'watchdog' 'just' 'call' 'them' 'out' 'their' 'shady' 'the' 'post' 'the' 'head' 'the' 'office' 'government' 'ethic' 'pen' 'a' 'letter' 'democratic' 'senator' 'saturday' 'which' 'warn' 'republican' 'plan' 'hold' 'confirmation' 'hearing' 'trump' 'nominees' 'the' 'necessary' 'paperwork' 'even' 'ensure' 'there' 'ethical' 'financial' 'criminal' 'concern' 'walter' 'm' 'shaub' 'jr' 'the' 'ethic' 'director' 'say' 'the' 'idea' 'the' 'gop' 'intend' 'hold' 'confirmation' 'hearing' 'an' 'ethic' 'review' 'great' 'concern' 'me' 'the' 'post' 'seven' 'trump' 'nominee' 'sit' 'hearing' 'capitol' 'hill' 'the' 'come' 'day' 'create' 'undue' 'pressure' 'oge' 'staff' 'agency' 'ethic' 'official' 'rush' 'these' 'important' 'review' 'shaub' 'write' 'more' 'significantly' 'it' 'leave' 'some' 'the' 'nominee' 'potentially' 'unknown' 'unresolved' 'ethic' 'issue' 'shortly' 'their' 'schedule' 'hearing' 'shaub' 'add' 'i' 'aware' 'any' 'occasion' 'the' 'decade' 'oge' 'establish' 'the' 'senate' 'hold' 'a' 'confirmation' 'hear' 'the' 'nominee' 'complete' 'the' 'ethic' 'review' 'process' 'the' 'letter' 'give' 'even' 'more' 'fire ...
#
#      Predikció valószínűsége
# 3                     0.4828
# 25                    0.9249
# 41                    0.0068
# 53                    0.0689
# 151                   0.7224
# 153                   0.1692
# 168                   0.0051
# 217                   0.0117
# 231                   0.7378
# 244                   0.1275
# 275                   0.1073
# 293                   0.8486
# 297                   0.6653
# 315                   0.7014
# 356                   0.2422
# 408                   0.0017
# 417                   0.3276
# 443                   0.6354
# 464                   0.9830
# 467                   0.7745

# %% [markdown]
# # GRU MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ### Modell lefuttatása

# %%
# GRU modell

def create_gru_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),  # Ensure within vocab limit
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings  # Toggle trainability
    )(text_input)

    # GRU rétegek
    gru_out = GRU(128, return_sequences=True, dropout=0.3)(text_embedding)
    gru_out = Dropout(0.3)(gru_out)  # Dropout réteg az első GRU után
    gru_out = GRU(64,return_sequences=True, dropout=0.3)(gru_out)
    gru_out = Dropout(0.3)(gru_out)
    gru_out = GRU(32, dropout=0.3)(gru_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(gru_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása (Trainable)
gru_trainable = create_gru_model(trainable_embeddings=True)  # Trainable

gru_trainable.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_2 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 600, 128)            │         165,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 600, 64)             │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,711,809 (29.42 MB)
#  Trainable params: 7,711,809 (29.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# GRU modell tanítása a validációs adatok figyelésével
history_gru_trainable = gru_trainable.fit(
    padded_train_final, y_train_final,  # Ugyanaz a tanító adathalmaz, mint az LSTM-nél
    validation_data=(padded_val, y_val),  # Ugyanaz a validációs halmaz, mint az LSTM-nél
    epochs=10, batch_size=64, callbacks=[early_stopping]
)

# Végső tesztelés a teljesen független teszthalmazon
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test)
print(f"Teszthalmaz pontosság (GRU): {test_accuracy_gru:.4f}, Teszthalmaz veszteség (GRU): {test_loss_gru:.4f}")
# Out:
# Epoch 1/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 70s 80ms/step - accuracy: 0.8514 - loss: 0.3336 - val_accuracy: 0.9372 - val_loss: 0.1665
# Epoch 2/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 81s 78ms/step - accuracy: 0.9576 - loss: 0.1206 - val_accuracy: 0.9632 - val_loss: 0.1017
# Epoch 3/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 84s 81ms/step - accuracy: 0.9872 - loss: 0.0396 - val_accuracy: 0.9761 - val_loss: 0.0833
# Epoch 4/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 78ms/step - accuracy: 0.9935 - loss: 0.0207 - val_accuracy: 0.9733 - val_loss: 0.1005
# Epoch 5/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 85s 81ms/step - accuracy: 0.9959 - loss: 0.0134 - val_accuracy: 0.9721 - val_loss: 0.1137
# Epoch 6/10
# 837/837 ━━━━━━━━━━━━━━━━━━━━ 79s 78ms/step - accuracy: 0.9966 - loss: 0.0108 - val_accuracy: 0.9730 - val_loss: 0.1042
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9698 - loss: 0.1001
# Teszthalmaz pontosság (GRU): 0.9694, Teszthalmaz veszteség (GRU): 0.1049

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Valószínűség becslése
gru_y_prob = gru_trainable.predict(padded_test)

gru_y_pred = (gru_y_prob > 0.5).astype(int)

accuracy = accuracy_score(y_test, gru_y_pred)
precision = precision_score(y_test, gru_y_pred)
recall = recall_score(y_test, gru_y_pred)
f1 = f1_score(y_test, gru_y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
# Accuracy: 0.9688
# Precision: 0.9735
# Recall: 0.9638
# F1-score: 0.9687

# %% [markdown]
# ## GRU modell ábrák

# %%
# Modell tesztelése a független teszthalmazon
test_loss, test_accuracy = gru_trainable.evaluate(padded_test, y_test)

# Plot tanulási, validációs és teszt veszteség
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_gru_trainable.history['loss'], label='Tanulási veszteség', color='blue')
plt.plot(history_gru_trainable.history['val_loss'], label='Validációs veszteség', color='orange')
plt.axhline(y=test_loss, color='red', linestyle='--', label='Teszthalmaz veszteség')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Plot tanulási, validációs és teszt pontosság
plt.subplot(1, 2, 2)
plt.plot(history_gru_trainable.history['accuracy'], label='Tanulási pontosság', color='blue')
plt.plot(history_gru_trainable.history['val_accuracy'], label='Validációs pontosság', color='orange')
plt.axhline(y=test_accuracy, color='red', linestyle='--', label='Teszthalmaz pontosság')  # Teszthalmaz hozzáadása
plt.xlabel('Epizód')
plt.ylabel('Pontosság')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.show()
# Out:
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9720 - loss: 0.0988

# %%
# Confusion Matrix
cm_gru = confusion_matrix(y_test, gru_y_pred)

# Plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm_gru, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Confusion Matrix GRU Modellre')
plt.show()

print(classification_report(y_test, gru_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.97      7440
#          1.0       0.97      0.96      0.97      7440
#
#     accuracy                           0.97     14880
#    macro avg       0.97      0.97      0.97     14880
# weighted avg       0.97      0.97      0.97     14880

# %%
# Flatten
y_true = y_test.flatten()
y_pred = gru_y_pred.flatten()
y_prob = gru_y_prob.flatten()

# Valódi hírek (label=1)
true_real_indices = np.where(y_true == 1)[0]
correct_real = y_prob[(y_true == 0) & (y_pred == 0)]
incorrect_real = y_prob[(y_true == 0) & (y_pred != 0)]

# Álhírek (label=0)
true_fake_indices = np.where(y_true == 0)[0]
correct_fake = y_prob[(y_true == 1) & (y_pred == 1)]
incorrect_fake = y_prob[(y_true == 1) & (y_pred != 1)]

# Plot - két hisztogram egymás mellett
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# Álhírek (label = 0)
axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (label=0)")
axes[0].set_xlabel("Predikált valószínűség")
axes[0].set_ylabel("Darabszám")
axes[0].legend()
axes[0].grid(True)

# Valódi hírek (label = 1)
axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódí hírek (label=1)")
axes[1].set_xlabel("Predikált valószínűség")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása osztályonként (Helyes vs Hibás) GRU Modellnél", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# DataFrame a valódi és predikált címkékkel
df_results = pd.DataFrame({
    "Valódi címke": y_test.flatten(),
    "Prediktált címke": gru_y_pred.flatten()
})

# Félrebesorolt példák kiszűrése
df_misclassified = df_results[df_results["Valódi címke"] != df_results["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index

# Tokenizált bemenetek kiválasztása a félrebesorolt példákhoz
misclassified_sequences = padded_test[misclassified_indices]

# Tokenek visszaalakítása szöveggé
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# <OOV> kiszűrése a szövegekből
misclassified_texts_cleaned = []
for text in misclassified_texts:
    cleaned_text = " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    misclassified_texts_cleaned.append(cleaned_text)

# Szöveg hozzáadása a táblázathoz
df_misclassified["Szöveg"] = misclassified_texts_cleaned

# Hibatípus meghatározása (FP vagy FN)
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))

# Valószínűségek hozzáadása
misclassified_probs = gru_y_prob[misclassified_indices].flatten()
df_misclassified["Predikció valószínűsége"] = np.round(misclassified_probs, 4)

# Fájl mentése
file_path = "/content/felrebesorolt_peldak_clean_gru.csv"
df_misclassified.to_csv(file_path, index=False, encoding="utf-8")

# Táblázat megjelenítése
pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 21   Hamis pozitív (FP)           0.0                 1
# 41   Hamis negatív (FN)           1.0                 0
# 53   Hamis negatív (FN)           1.0                 0
# 138  Hamis pozitív (FP)           0.0                 1
# 154  Hamis negatív (FN)           1.0                 0
# 168  Hamis negatív (FN)           1.0                 0
# 186  Hamis pozitív (FP)           0.0                 1
# 218  Hamis pozitív (FP)           0.0                 1
# 231  Hamis pozitív (FP)           0.0                 1
# 235  Hamis pozitív (FP)           0.0                 1
# 244  Hamis negatív (FN)           1.0                 0
# 286  Hamis negatív (FN)           1.0                 0
# 290  Hamis pozitív (FP)           0.0                 1
# 295  Hamis negatív (FN)           1.0                 0
# 327  Hamis pozitív (FP)           0.0                 1
# 377  Hamis pozitív (FP)           0.0                 1
# 399  Hamis pozitív (FP)           0.0                 1
# 408  Hamis negatív (FN)           1.0                 0
# 445  Hamis pozitív (FP)           0.0                 1
# 464  Hamis pozitív (FP)           0.0                 1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'the' 'white' 'house' 'lady' 'the' 'united' 'state' 'melania' 'trump' 'the' 'wife' 'president' 'donald' 'j' 'trump' 'bear' 'april' 'official' 'white' 'house' 'portrait' 'the' 'graceful' 'elegant' 'first' 'lady' 'melania' 'trump' 'melania' 'begin' 'her' 'model' 'career' 'the' 'age' 'sixteen' 'she' 'pursue' 'a' 'degree' 'the' 'university' 'ljubljana' 'slovenia' 'pause' 'her' 'study' 'advance' 'her' 'model' 'career' 'milan' 'paris' 'move' 'new' 'york' 'a' 'model' 'melania' 'appear' 'high' 'profile' 'ad' 'campaign' 'work' 'some' 'the' 'photographer' 'the' 'fashion' 'industry' 'include' 'patrick' 'newton' 'arthur' 'ellen' 'von' 'peter' 'mario' 'she' 'grace' 'the' 'cover' 'vogue' 'harper' 'bazaar' 'british' 'gq' 'ocean' 'drive' 'avenue' 'style' 'new' 'york' 'magazine' 'her' 'major' 'layout' 'include' 'the' 'sport' 'illustrate' 'swimsuit' 'issue' 'allure' 'vogue' 'self' 'glamour' 'vanity' 'fair' 'elle' 'addition' 'melania' 'appear' 'numerous' 'television' 'commercial' 'television' 'program' 'include' 'the' 'view' 'barbara' 'a' 'penchant' 'passion' 'the' 'art' 'architecture' 'design' 'fashion' 'beauty' 'melania' 'thrive' 'the' 'cultural' 'new' 'york' 'city' 'this' 'passion' 'only' 'surpass' 'her' 'dedication' 'help' 'others' 'her' 'generosity' 'note' 'she' 'honorary' 'chairwoman' 'martha' 'graham' 'dance' 'company' 'april' 'an' 'active' 'member' 'the' 'police' 'athletic' 'league' 'which' 'honor' 'her' 'woman' 'the' 'year' 'an' 'honorary' 'chairwoman' 'the' 'boy' 'club' 'new' 'york' 'consecutive' 'year' 'the' 'american' 'red' 'cross' 'award' 'her' 'goodwill' 'ambassador' 'which' 'she' 'proudly' 'serve' 'year' 'april' 'she' 'ask' 'love' 'our' 'child' 'usa' 'nasdaq' 'participate' 'the' 'fifth' 'annual' 'national' 'love' 'our' 'child' 'day' 'the' 'begin' 'national' 'child' 'abuse' 'prevention' 'month' 'ring' 'the' 'closing' 'bell' 'nasdaq' 'melania' 'the' 'chairwoman' 'the' 'american' 'heart' 'association' 'which' 'raise' 'million' 'research' 'melania' 'p ...
# 41                                                                                   'editor' 'note' 'the' 'following' 'column' 'originally' 'appear' 'the' 'website' 'u' 'defense' 'watch' 'it' 'reprint' 'permission' 'i' 'like' 'million' 'american' 'saw' 'your' 'speech' 'the' 'dnc' 'thursday' 'night' 'i' 'wish' 'offer' 'my' 'sympathy' 'the' 'death' 'your' 'son' 'captain' 'humayun' 'khan' 'who' 'kill' 'action' 'iraq' 'a' 'u' 'army' 'officer' 'a' 'veteran' 'the' 'gulf' 'war' 'i' 'certainly' 'understand' 'the' 'pain' 'anguish' 'you' 'your' 'wife' 'endure' 'every' 'day' 'your' 'son' 'die' 'save' 'the' 'life' 'his' 'fellow' 'soldier' 'jesus' 'tell' 'his' 'disciple' 'accord' 'the' 'gospel' 'john' 'great' 'love' 'man' 'this' 'a' 'man' 'lay' 'down' 'his' 'life' 'his' 'friend' 'captain' 'khan' 'a' 'hero' 'i' 'sure' 'the' 'soldier' 'he' 'serve' 'regard' 'him' 'i' 'know' 'you' 'your' 'wife' 'rest' 'assure' 'million' 'veteran' 'regard' 'your' 'son' 'a' 'hero' 'well' 'paraphrase' 'the' 'book' 'your' 'son' 'name' 'your' 'son' 'the' 'ultimate' 'sacrifice' 'his' 'country' 'a' 'country' 'new' 'you' 'your' 'family' 'which' 'you' 'openly' 'embrace' 'certainly' 'love' 'you' 'your' 'family' 'arrive' 'america' 'pakistan' 'you' 'assimilate' 'our' 'country' 'you' 'adopt' 'american' 'way' 'learn' 'our' 'history' 'apparently' 'you' 'even' 'acquire' 'a' 'pocket' 'constitution' 'the' 'way' 'good' 'you' 'sir' 'there' 'muslim' 'america' 'who' 'only' 'desire' 'assimilate' 'wish' 'live' 'sharia' 'law' 'unacceptable' 'american' 'there' 'only' 'law' 'the' 'land' 'the' 'yous' 'constitution' 'you' 'well' 'know' 'mr' 'khan' 'we' 'live' 'violent' 'time' 'dangerous' 'time' 'muslim' 'madman' 'isis' 'radical' 'jihadi' 'group' 'a' 'murder' 'terror' 'spree' 'the' 'globe' 'your' 'religion' 'peace' 'islam' 'anything' 'a' 'fact' 'confirm' 'every' 'time' 'a' 'muslim' 'shoot' 'bomb' 'torture' 'innocent' 'men' 'woman' 'child' 'this' 'mean' 'every' 'muslim' 'a' 'terrorist' 'most' 'terrorist' 'sir' 'indeed' 'muslim' 'a' 'muslim' 'terrorist' 'attack' 'the' 'sign' 'the' 'time' 'regardless' 'what' 'the' 'feckless' 'nave' 'leftist' 'ideologue' 'barack' 'obama' 'his' 'colleague' 'john' 'kerry' 'francois' 'hollande' 'angela' 'merkel' 'state' 'the' 'united' 'state' 'the' 'west' 'war' 'radical' 'islam' 'it' 'the' 'job' 'the' 'president' 'the' 'united' 'state' 'protect' 'his' 'nation' 'all' 'enemy' 'foreign' 'domestic' 'unfortunately' 'mr' 'obama' 'islam' 'refuse' 'accept' 'reality' 'which' 'result' 'the' 'death' 'thousand' 'innocent' 'people' 'the' 'world' 'group' 'like' 'isi' 'al' 'qaeda' 'goal' 'the' 'complete' 'destruction' 'the' 'judeochristian' 'culture' 'our' 'religion' 'our' 'way' 'life' 'american' 'family' 'here' 'decade' 'even' 'century' 'family' 'like' 'mine' 'relative' 'who' 'fight' 'the' 'civil' 'war' 'wwii' 'korea' 'vietnam' 'desert' 'storm' 'some' 'family' 'relative' 'who' 'fight' 'the' 'american' 'revolution' 'we' 'plan' 'let' 'our' 'country' 'devour' 'muslim' 'maniac' 'we' 'americans' 'sir' 'unarmed' 'socialist' 'european' 'zombie' 'we' 'what' 'necessary' 'protect' 'the' 'united' 'state' 'democrat' 'liberals' 'the' 'world' 'rise' 'colored' 'glass' 'conservative' 'understand' 'there' 'good' 'evil' 'this' 'world' 'evil' 'destroy' 'it' 'destroy' 'u' 'strong' 'measure' 'wartime' 'measure' 'take' 'protect' 'this' 'country' 'those' 'wish' 'annihilate' 'u' 'our' 'way' 'life' 'mr' 'trump' 'plan' 'temporarily' 'halt' 'immigration' 'muslim' 'country' 'know' 'either' 'support' 'terrorism' 'harbor' 'terrorist' 'group' 'only' 'pragmatic' 'indeed' 'it' 'constitutional' 'it' 'the' 'constitutional' 'duty' 'the' 'president' 'the' 'united' 'state' 'protect' 'this' 'nation' 'there' 'simply' 'way' 'vet' 'hundred' 'thousand' 'muslim' 'refugee' 'war' 'zone' 'like' 'syria' 'iraq' 'afghanistan' 'europe' 'destroy' 'reckless' 'leader' 'like' 'angela' 'merkel' 'open' 'the' 'continent' 'a' 'flood' 'over' 'million' 'undocumented' 'muslim' 'arrive' 'nothing' 'more' 'a' 'bad' 'attitude' 'a' 'jihad' ' ...
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'far' 'weaken' 'the' 'environmental' 'protection' 'agency' 'donald' 'trump' 'need' 'beef' 'it' 'up' 'so' 'say' 'a' 'guy' 'the' 'new' 'york' 'time' 'the' 'name' 'william' 'd' 'a' 'march' 'the' 'time' 'write' 'a' 'strong' 'credible' 'regulatory' 'regime' 'essential' 'the' 'smooth' 'function' 'our' 'economy' 'interest' 'use' 'the' 'word' 'credible' 'there' 'the' 'worthless' 'bureaucrat' 'who' 'perhaps' 'more' 'anyone' 'embody' 'what' 'so' 'very' 'wrong' 'the' 'epa' 'it' 'so' 'urgently' 'need' 'let' 'it' 'never' 'forget' 'the' 'epa' 'administrator' 'responsible' 'probably' 'the' 'black' 'moment' 'the' 'institution' 'history' 'the' 'man' 'who' 'ban' 'the' 'you' 'consequence' 'which' 'result' 'million' 'unnecessary' 'death' 'around' 'the' 'world' 'malaria' 'sure' 'deliberately' 'murder' 'all' 'those' 'people' 'the' 'fact' 'remain' 'still' 'the' 'most' 'effective' 'killer' 'the' 'mosquito' 'ban' 'it' 'the' 'you' 'help' 'create' 'a' 'regulatory' 'effect' 'which' 'deprive' 'the' 'world' 'it' 'best' 'it' 'big' 'health' 'problem' 'i' 'tell' 'the' 'story' 'a' 'month' 'back' 'it' 'worth' 'repeat' 'repeat' 'every' 'time' 'this' 'dreadful' 'man' 'pop' 'up' 'again' 'assume' 'the' 'mantle' 'an' 'authority' 'he' 'simply' 'earn' 'i' 'note' 'then' 'a' 'lawyer' 'train' 'a' 'scientist' 'the' 'man' 'responsible' 'institute' 'the' 'ban' 'he' 'this' 'scientific' 'basis' 'whatsoever' 'fact' 'judge' 'edmund' 'sweeney' 'preside' 'over' 'a' 'epa' 'hearing' 'examine' 'more' 'page' 'expert' 'testimony' 'conclude' 'a' 'carcinogenic' 'hazard' 'man' 'a' 'hazard' 'man' 'the' 'use' 'the' 'regulation' 'involve' 'here' 'a' 'effect' 'freshwater' 'fish' 'organism' 'wild' 'bird' 'wildlife' 'who' 'attend' 'the' 'hearing' 'read' 'the' 'report' 'overrule' 'him' 'which' 'probably' 'difference' 'the' 'united' 'state' 'the' 'effect' 'the' 'near' 'worldwide' 'ban' 'follow' 'meant' 'longer' 'control' 'mosquito' 'population' 'which' 'turn' 'lead' 'an' 'explosion' 'malaria' 'cause' 'the' 'death' 'million' 'subsequently' 'distinguish' 'himself' 'endorse' 'barack' 'obama' 'you' 'president' 'most' 'recently' 'head' 'the' 'blue' 'ribbon' 'panel' 'ocean' 'ocean' 'course' 'yet' 'another' 'scientifically' 'dubious' 'scare' 'story' 'design' 'mainly' 'prop' 'up' 'the' 'lucrative' 'global' 'industry' 'i' 'doubt' 'claim' 'his' 'new' 'york' 'time' 'article' 'the' ' ...
# 138                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 154                                                                                                                                                                                                                                                                        'covington' 'la' 'sour' 'grape' 'explain' 'bob' 'marino' 'weigh' 'the' 'recent' 'bombshell' 'the' 'corner' 'table' 'a' 'local' 'mcdonalds' 'sour' 'grape' 'agree' 'roger' 'noel' 'sit' 'him' 'bunch' 'crybaby' 'reed' 'offer' 'the' 'table' 'the' 'subject' 'conversation' 'the' 'report' 'release' 'united' 'state' 'intelligence' 'chief' 'friday' 'inform' 'donald' 'j' 'trump' 'their' 'unanimous' 'conclusion' 'president' 'vladimir' 'v' 'putin' 'russia' 'order' 'an' 'extensive' 'covert' 'help' 'mr' 'trump' 'win' 'the' 'election' 'the' 'russian' 'hack' 'leaked' 'email' 'unleashed' 'troll' 'social' 'medium' 'their' 'propaganda' 'machine' 'spread' 'story' 'harmful' 'hillary' 'clinton' 'the' 'report' 'view' 'extraordinary' 'both' 'it' 'timing' 'raise' 'sharp' 'question' 'about' 'the' 'legitimacy' 'the' 'verge' 'his' 'take' 'office' 'it' 'assertion' 'describe' 'the' 'operation' 'russias' 'bold' 'effort' 'yet' 'meddle' 'american' 'election' 'spread' 'discontent' 'undermine' 'the' 'you' 'democratic' 'order' 'interview' 'trump' 'supporter' 'here' 'louisiana' 'a' 'state' 'the' 'won' 'point' 'indiana' 'a' 'state' 'he' 'win' 'nearly' 'the' 'margin' 'find' 'opinion' 'about' 'the' 'report' 'range' 'general' 'indifference' 'outright' 'derision' 'the' 'part' 'the' 'report' 'i' 'see' 'say' 'rob' 'a' 'retired' 'air' 'force' 'colonel' 'who' 'twice' 'run' 'senate' 'here' 'tea' 'party' 'favorite' 'it' 'silly' 'there' 'genuine' 'concern' 'about' 'russia' 'he' 'say' 'the' 'notion' 'they' 'change' 'the' 'outcome' 'the' 'election' 'absurd' 'the' 'report' 'determination' 'they' 'affect' 'the' 'election' 'the' 'comment' 'he' 'see' 'fellow' 'trump' 'supporter' 'facebook' 'email' 'he' 'add' 'percent' 'them' 'like' 'what' 'the' 'big' 'deal' 'the' 'russian' 'very' 'well' 'get' 'involved' 'people' 'say' 'they' 'add' 'kind' 'interference' 'combat' 'assume' 'foreign' 'actor' 'long' 'tried' 'play' 'favorite' 'american' 'election' 'the' 'united' 'state' 'the' 'country' 'election' 'even' 'the' 'russian' 'it' 'which' 'some' 'more' 'willing' 'concede' 'others' 'what' 'difference' 'it' 'people' 'need' 'the' 'russian' 'up' 'their' 'mind' 'about' 'mrs' 'clinton' 'mr' 'trumps' 'election' 'opponent' 'blame' 'her' 'loss' 'the' 'russian' 'trump' 'supporter' 'here' 'say' 'just' 'sore' 'loser' 'i' 'think' 'the' 'russian' 'pose' 'big' 'a' 'problem' 'the' 'clinton' 'the' 'clinton' 'pose' 'themselves' 'say' 'paul' 'he' 'sell' 'shoulder' 'chop' 'a' 'frigid' 'outdoor' 'farmer' 'market' 'covington' 'russian' 'hack' 'concern' 'sure' 'mr' 'say' 'he' 'add' 'long' 'mr' 'trump' 'involve' 'himself' 'it' 'change' 'the' 'way' 'i' 'view' 'him' 'tina' 'take' 'blanket' 'the' 'citrus' 'tree' 'her' 'la' 'front' 'yard' 'the' 'previous' 'night' 'frost' 'a' 'similar' 'attitude' 'trump' 'trump' 'she' 'say' 'i' 'think' 'he' 'go' 'more' 'a' 'friend' 'russia' 'this' 'i' 'i' 'think' 'i' 'hope' 'his' 'focus' 'making' 'america' 'great' 'again' 'm' 'reveal' 'whom' 'she' 'vote' 'she' 'mr' 'trump' 'slogan' 'resonate' 'her' 'it' 'apparently' 'resonate' 'quite' 'widely' 'this' 'parish' 'which' 'he' 'win' 'more' 'point' 'it' 'a' 'quiet' 'support' 'she' 'say' 'she' 'know' 'only' 'yard' 'the' 'subdivision' 'a' 'sign' 'yard' 'belong' 'yates' 'sr' 'i' 'believe' 'it' 'mr' 'yates' 'say' 'flatly' 'the' 'intelligence' 'report' 'he' 'stand' 'the' 'yard' 'his' 'america' 'great' 'again' 'flag' 'which' 'he' 'buy' 'a' 'gun' 'month' 'ago' 'putin' 'even' 'want' 'trump' 'mr' 'yates' 'who' 'retire' 'a' 'career' 'pharmaceutical' 'sale' 'concern' 'about' 'what' 'mr' 'trump' 'office' 'say' 'he' 'deeply' 'alarm' 'about' 'what' 'president' 'obama' 'he' 'leave' 'office' 'it' 'mr' 'obama' 'who' 'too' 'soft' 'russia' 'who' 'let' 'mr' 'putin' 'away' 'thing' 'mr' 'yates' 'continue' ...
# 168                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'los' 'angeles' 'democratic' 'presidential' 'nominee' 'hillary' 'clinton' 'play' 'it' 'strictly' 'parry' 'decidedly' 'question' 'comedian' 'zach' 'his' 'online' 'parody' 'talk' 'release' 'thursday' 'star' 'the' 'hangover' 'film' 'know' 'his' 'banter' 'the' 'web' 'program' 'ask' 'subject' 'awkward' 'question' 'past' 'interview' 'subject' 'include' 'brad' 'pitt' 'bradley' 'cooper' 'president' 'barack' 'obama' 'sit' 'plant' 'a' 'sparse' 'set' 'dial' 'back' 'his' 'trademark' 'style' 'appear' 'uninterested' 'unprepared' 'he' ...
# 186                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 218                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'english' 'medieval' 'spain' 'portugal' 'a' 'series' 'campaign' 'christian' 'state' 'recapture' 'territory' 'the' 'muslim' 'moor' 'who' 'occupy' 'most' 'the' 'peninsula' 'the' 'early' '8th' 'young' 'they' 'take' 'a' 'clear' 'decisive' 'stand' 'a' 'government' 'who' 'clearly' 'concern' 'their' 'faith' 'their' 'heritage' 'the' 'rich' 'history' 'their' 'nation' 'an' 'unbiased' 'education' 'the' 'future' 'the' 'citizen' 'a' 'powerful' 'message' 'need' 'share' 'youth' 'form' 'recapture' 'their' 'identity' 'generation' 'a' 'fate' 'just' 'a' 'motto' 'daily' 'incentive' 'a' 'movement' 'see' 'itself' 'a' 'living' 'covenant' 'a' 'community' 'fate' 'we' 'a' 'movement' 'young' 'people' 'who' 'resist' 'the' 'left' 'liberal' 'longer' ' ...
# 231                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 235  'activist' 'post' 'the' 'yous' 'presidential' 'selection' 'circus' 'draw' 'a' 'close' 'the' 'united' 'state' 'turkey' 'announce' 'a' 'new' 'plan' 'defeat' 'isis' 'the' 'terrorist' 'organization' 'both' 'country' 'create' 'funded' 'arm' 'syria' 'the' 'plan' 'revolve' 'around' 'the' 'conquer' 'occupation' 'govern' 'sovereign' 'syrian' 'territory' 'the' 'east' 'most' 'notably' 'raqqa' 'accord' 'the' 'yous' 'joint' 'chief' 'staff' 'gen' 'joseph' 'dunford' 'meet' 'his' 'turkish' 'counterpart' 'the' 'coalition' 'turkey' 'work' 'together' 'the' 'longterm' 'plan' 'seize' 'hold' 'govern' 'raqqa' 'the' 'statement' 'dunford' 'confirm' 'the' 'fact' 'the' 'united' 'state' 'forward' 'it' 'campaign' 'raqqa' 'work' 'closely' 'the' 'turk' 'who' 'themselves' 'concern' 'about' 'the' 'makeup' 'the' 'proxy' 'force' 'destine' 'hold' 'power' 'once' 'the' 'campaign' 'over' 'the' 'syrian' 'democratic' 'force' 'the' 'proxy' 'choice' 'this' 'battle' 'up' 'kurdish' 'militia' 'fighter' 'an' 'issue' 'provide' 'worry' 'the' 'part' 'the' 'turkish' 'government' 'cnn' 'report' 'dod' 'news' 'report' 'sunday' 'meeting' 'reinforce' 'a' 'longstanding' 'agreement' 'the' 'usled' 'coalition' 'ahead' 'the' 'seizure' 'raqqa' 'incorporate' 'the' 'turk' 'their' 'perspective' 'our' 'plan' 'accord' 'dunford' 'the' 'turkish' 'army' 'say' 'a' 'statement' 'the' 'military' 'head' 'discuss' 'the' 'method' 'a' 'common' 'struggle' 'isi' 'iraq' 'syria' 'especially' 'al' 'bab' 'raqqa' 'come' 'day' 'address' 'the' 'sensitivity' 'around' 'the' 'ethnic' 'makeup' 'the' 'force' 'involve' 'the' 'operation' 'dunford' 'say' 'we' 'always' 'know' 'the' 'sdf' 'the' 'solution' 'hold' 'govern' 'raqqa' 'what' 'we' 'work' 'right' 'now' 'find' 'the' 'right' 'mix' 'force' 'the' 'operation' 'he' 'say' 'the' 'u' 'work' 'turkey' 'determine' 'the' 'composition' 'the' 'force' 'seize' 'govern' 'the' 'territory' 'he' 'say' 'he' 'say' 'the' 'right' 'approach' 'local' 'lead' 'the' 'mission' 'retake' 'the' 'city' 'run' 'it' 'isis' 'drive' 'out' 'the' 'operation' 'need' 'a' 'predominantly' 'arab' 'sunni' 'arab' 'force' 'he' 'say' 'accord' 'dod' 'news' 'there' 'force' 'like' 'there' 'the' 'moderate' 'syrian' 'opposition' 'the' 'vetted' 'syrian' 'force' 'the' 'free' 'syrian' 'army' 'force' 'there' 'some' 'initial' 'outreach' 'force' 'raqqa' 'proper' 'dunford' 'say' 'the' 'sdf' 'move' 'south' 'isolate' 'isi' 'position' 'raqqa' 'the' 'surround' 'area' 'a' 'phase' 'month' 'essentially' 'the' 'united' 'state' 'turkey' 'devise' 'a' 'plan' 'which' 'control' 'raqqa' 'the' 'territory' 'surround' 'it' 'proxy' 'force' 'overthrow' 'proxy' 'force' 'word' 'the' 'fighter' 'raqqa' 'simply' 'undergo' 'another' 'name' 'change' 'replace' 'a' 'heavy' 'kurdish' 'contingent' 'act' 'a' 'carefully' 'place' 'chess' 'piece' 'which' 'prevent' 'the' 'syrian' 'russian' 'military' 'liberate' 'the' 'city' 'all' 'these' 'sdf' 'force' 'present' 'moderate' 'a' 'label' 'attach' 'the' 'isi' 'fighter' 'currently' 'inhabit' 'raqqa' 'raqqa' 'act' 'the' 'isi' 'capital' 'the' 'mysterious' 'appearance' 'the' 'group' 'year' 'ago' 'go' 'virtually' 'untouched' 'the' 'syrian' 'military' 'bogged' 'down' 'major' 'city' 'area' 'the' 'country' 'their' 'fight' 'the' 'westernbacked' 'terrorist' 'notably' 'despite' 'it' 'rhetoric' 'fight' 'degrade' 'destroy' 'isi' 'the' 'yousled' 'coalition' 'yet' 'bomb' 'raqqa' 'fresh' 'the' 'heel' 'a' 'major' 'public' 'relation' 'victory' 'palmyra' 'however' 'the' 'syrian' 'military' 'now' 'inch' 'raqqa' 'successful' 'it' 'score' 'the' 'big' 'victory' 'the' 'fiveyear' 'war' 'this' 'only' 'the' 'de' 'facto' 'isi' 'capital' 'eliminate' 'the' 'gain' 'more' 'territory' 'it' 'the' 'liberation' 'raqqa' 'yet' 'another' 'example' 'the' 'syrian' 'military' 'accomplish' 'week' 'what' 'the' 'united' 'state' 'coalition' 'member' 'claim' 'a' 'decade' 'it' 'another' 'instance' 'the' 'lack' 'the' 'part' 'the' 'united' 'state' 'actually' 'destroy' 'daesh' 'display' 'the' 'rest' 'the' 'world' 'either' 'cause' 'the' 'yous' 'look' 'weak' 't ...
# ...
# 408                                                                                  'harris' 'lay' 'struggle' 'die' 'he' 'tell' 'the' 'surround' 'officer' 'i' 'lose' 'my' 'breath' 'officer' 'yell' 'back' 'him' 'fuck' 'your' 'breath' 'then' 'he' 'insist' 'the' 'die' 'man' 'handcuffed' 'fuck' 'your' 'breath' 'encapsulate' 'only' 'word' 'the' 'systemic' 'disregard' 'police' 'regularly' 'black' 'people' 'america' 'just' 'week' 'we' 'watch' 'michael' 'slager' 'execute' 'walter' 'scott' 'south' 'carolina' 'dare' 'run' 'away' 'now' 'this' 'week' 'we' 'also' 'tune' 'the' 'trial' 'chicago' 'police' 'officer' 'dante' 'who' 'charge' 'involuntary' 'manslaughter' 'the' 'kill' 'yearold' 'boyd' 'march' 'the' 'case' 'eric' 'garner' 'staten' 'island' 'tamir' 'rice' 'cleveland' 'walter' 'scott' 'south' 'carolina' 'eric' 'harris' 'tulsa' 'we' 'see' 'video' 'law' 'enforcement' 'officer' 'only' 'critically' 'injure' 'citizen' 'also' 'refuse' 'administer' 'medical' 'care' 'fatal' 'consequence' 'give' 'the' 'origin' 'police' 'this' 'country' 'their' 'connection' 'slave' 'patrol' 'form' 'social' 'control' 'i' 'illusion' 'the' 'police' 'ever' 'hold' 'black' 'life' 'high' 'regard' 'police' 'complicity' 'participation' 'the' 'kkk' 'clear' 'the' 'explicit' 'tacit' 'refusal' 'black' 'people' 'right' 'breathe' 'still' 'significant' 'the' 'fact' 'the' 'tulsa' 'county' 'sheriff' 'office' 'a' 'paytoplay' 'force' 'significant' 'the' 'fact' 'white' 'men' 'sign' 'up' 'government' 'approval' 'the' 'right' 'play' 'cop' 'the' 'weekend' 'appal' 'black' 'live' 'provide' 'fodder' 'sport' 'u' 'the' 'street' 'there' 'something' 'about' 'the' 'logic' 'the' 'term' 'neoliberalism' 'this' 'moment' 'feel' 'more' 'pessimistic' 'our' 'narrative' 'linear' 'progress' 'racial' 'issue' 'u' 'conclude' 'the' 'united' 'arab' 'emirate' 'give' 'million' 'the' 'new' 'york' 'city' 'police' 'foundation' 'accord' 'an' 'nypd' 'spokesperson' 'the' 'money' 'upgrade' 'equipment' 'aid' 'criminal' 'investigation' 'both' 'new' 'york' 'city' 'tulsa' 'private' 'funding' 'law' 'enforcement' 'significantly' 'impact' 'the' 'way' 'local' 'policing' 'tulsa' 'it' 'result' 'the' 'paytoplay' 'scheme' 'new' 'york' 'city' 'it' 'allow' 'large' 'infusion' 'cash' 'donation' 'specific' 'use' 'come' 'public' 'scrutiny' 'they' 'private' 'fund' 'these' 'form' 'neoliberal' 'police' 'which' 'private' 'citizen' 'private' 'monies' 'impact' 'the' 'culture' 'police' 'escape' 'governmental' 'check' 'balance' 'endanger' 'u' 'all' 'new' 'york' 'action' 'enable' 'the' 'purchase' 'unspecified' 'form' 'equipment' 'instance' 'exacerbate' 'the' 'culture' 'militarize' 'police' 'the' 'nypd' 'part' 'this' 'money' 'allow' 'the' 'nypd' 'travel' 'the' 'uae' 'learn' 'counterterrorism' 'measure' 'the' 'wake' 'some' 'external' 'training' 'helpful' 'essentially' 'this' 'sound' 'like' 'a' 'case' 'the' 'nypd' 'allow' 'money' 'play' 'global' 'cop' 'robber' 'then' 'test' 'out' 'these' 'tactic' 'the' 'black' 'brown' 'people' 'who' 'police' 'heavily' 'the' 'city' 'the' 'case' 'tulsa' 'this' 'privately' 'form' 'law' 'enforcement' 'place' 'an' 'pretend' 'deputy' 'a' 'confrontation' 'a' 'result' 'eric' 'harris' 'lose' 'his' 'life' 'he' 'just' 'lose' 'his' 'breath' 'he' 'lay' 'die' 'he' 'refuse' 'the' 'right' 'breathe' 'refusal' 'come' 'a' 'chorus' 'taunt' 'about' 'he' 'get' 'what' 'he' 'deserve' 'he' 'choose' 'run' 'his' 'breath' 'seep' 'out' 'his' 'black' 'body' 'public' 'service' 'officer' 'taunt' 'him' 'a' 'barrage' 'profanity' 'the' 'refusal' 'breath' 'black' 'people' 'endemic' 'the' 'american' 'condition' 'what' 'about' 'the' 'black' 'body' 'make' 'the' 'we' 'all' 'hold' 'so' 'dear' 'so' 'sacred' 'a' 'profane' 'devalue' 'thing' 'the' 'hand' 'white' 'people' 'the' 'famous' 'writer' 'american' 'prophet' 'james' 'baldwin' 'return' 'america' 'live' 'france' 'more' 'decade' 'an' 'interview' 'the' 'new' 'york' 'time' 'he' 'say' 'i' 'leave' 'america' 'i' 'it' 'a' 'personal' 'decision' 'i' 'want' 'write' 'it' 'the' 'it' 'big' 'picnic' 'black' 'i' 'g ...
# 445                                                                                                                                                                                                                                                                                                                                                                                      'the' 'sad' 'saga' 'john' 'walker' 'rebel' 'a' 'clue' 'the' 'sad' 'saga' 'john' 'walker' 'rebel' 'a' 'clue' 'beau' 'my' 'father' 'a' 'highranking' 'student' 'radical' 'still' 'think' 'castro' 'the' 'bee' 'knee' 'this' 'make' 'me' 'technically' 'a' 'red' 'diaper' 'baby' 'i' 'reject' 'all' 'baloney' 'early' 'these' 'day' 'i' 'write' 'story' 'mostly' 'comedy' 'science' 'fiction' 'well' 'maintain' 'a' 'blog' 'mainly' 'about' 'date' 'advice' 'political' 'commentary' 'my' 'writing' 'project' 'november' 'culture' 'john' 'walker' 'grow' 'up' 'the' 'dc' 'area' 'his' 'family' 'bring' 'him' 'california' 'he' 'another' 'year' 'he' 'know' 'the' 'american' 'taliban' 'afghanistan' 'he' 'know' 'arabic' 'moniker' 'he' 'over' 'the' 'year' 'johnny' 'join' 'the' 'jihad' 'there' 'moment' 'realize' 'one' 'vacation' 'really' 'start' 'suck' 'he' 'the' 'young' 'saw' 'spike' 'lee' 'rather' 'film' 'biography' 'about' 'malcolm' 'x' 'begin' 'his' 'fascination' 'islam' 'a' 'teenager' 'he' 'the' 'evocative' 'email' 'email' 'protect' 'posting' 'about' 'rap' 'music' 'sometimes' 'he' 'pretend' 'black' 'even' 'have' 'the' 'nerve' 'dr' 'dre' 'dog' 'hip' 'hop' 'glory' 'like' 'dr' 'dre' 'his' 'madeup' 'gangster' 'story' 'sellout' 'house' 'nigga' 'live' 'dory' 'say' 'he' 'break' 'his' 'pool' 'lap' 'all' 'these' 'playground' 'fall' 'like' 'skill' 'disappear' 'like' 'dr' 'a' 'disgrace' 'sell' 'out' 'the' 'he' 'leave' 'dead' 'naked' 'the' 'outcome' 'word' 'brother' 'malcolm' 'dre' 'shirt' 'hat' 'we' 'his' 'cereal' 'so' 'who' 'the' 'there' 'anyway' 'i' 'sure' 'laugh' 'the' 'sheer' 'cry' 'the' 'abuse' 'the' 'english' 'language' 'he' 'sixteen' 'he' 'formally' 'convert' 'begin' 'his' 'fateful' 'journey' 'meanwhile' 'his' 'family' 'situation' 'shaky' 'ground' 'his' 'father' 'turn' 'gay' 'living' 'parttime' 'his' 'male' 'lover' 'eventually' 'divorce' 'john' 'begin' 'his' 'world' 'travel' 'twice' 'venture' 'yemen' 'both' 'time' 'nearly' 'a' 'year' 'later' 'he' 'stay' 'a' 'pakistani' 'he' 'go' 'afghanistan' 'fight' 'behalf' 'the' 'taliban' 'unfortunately' 'him' 'september' 'american' 'force' 'go' 'war' 'the' 'taliban' 'he' 'capture' 'november' 'his' 'unit' 'surrender' 'kunduz' 'the' 'cia' 'question' 'him' 'he' 'claim' 'an' 'an' 'interesting' 'conversation' 'perhaps' 'the' 'ye' 'presumably' 'pretend' 'black' 'again' 'get' 'him' 'very' 'far' 'shortly' 'the' 'captive' 'jihadis' 'stag' 'a' 'bloody' 'uprising' 'escape' 'hundred' 'die' 'include' 'mike' 'his' 'interrogator' 'he' 'recapture' 'some' 'rough' 'treatment' 'i' 'shed' 'any' 'tear' 'about' 'again' 'he' 'announce' 'defiantly' 'he' 'the' 'taliban' 'rather' 'al' 'qaeda' 'his' 'action' 'seal' 'his' 'doom' 'fight' 'the' 'taliban' 'a' 'pretty' 'dumb' 'his' 'part' 'his' 'action' 'capture' 'even' 'dumber' 'what' 'he' 'differently' 'the' 'beginning' 'he' 'say' 'he' 'interest' 'islam' 'his' 'quest' 'discover' 'his' 'spiritual' 'root' 'take' 'him' 'abroad' 'then' 'he' 'lie' 'tell' 'them' 'he' 'the' 'taliban' 'he' 'quite' 'happy' 'free' 'his' 'countryman' 'he' 'tip' 'his' 'interrogator' 'about' 'the' 'planned' 'escape' 'spar' 'life' 'both' 'well' 'avoid' 'far' 'criminal' 'charge' 'himself' 'he' 'give' 'a' 'helpful' 'warning' 'about' 'the' 'uprise' 'likely' 'they' 'conclude' 'he' 'small' 'fry' 'let' 'him' 'he' 'the' 'star' 'the' 'daytime' 'tv' 'talk' 'show' 'then' 'he' 'give' 'speeches' 'the' 'antiwar' 'circuit' 'help' 'his' 'jihadi' 'buddy' 'say' 'they' 'really' 'bad' 'whatever' 'instead' 'he' 'end' 'up' 'faced' 'criminal' 'charge' 'which' 'mean' 'life' 'sentence' 'plus' 'ninety' 'year' 'finally' 'get' 'smart' 'he' 'cop' 'a' 'plea' 'year' 'the' 'possibility' 'good'  ...
# 464                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'a' 'jv' 'team' 'threat' 'shake' 'a' 'daring' 'yous' 'military' 'strike' 'deep' 'isi' 'territory' 'supporters' 'the' 'extremist' 'organization' 'vow' 'revenge' 'the' 'kill' 'senior' 'leader' 'abu' 'sayyaf' 'claim' 'the' 'special' 'operation' 'mission' 'never' 'take' 'place' 'a' 'analysis' 'reveals' 'they' 'take' 'abu' 'sayyaf' 'we' 'obama' 'isis' 'supporter' 'post' 'the' 'hour' 'the' 'raid' 'near' 'the' 'eastern' 'syrian' 'city' 'your' 'goal' 'kill' 'abu' 'sayyaf' 'then' 'our' 'goal' 'kill' 'obama' 'the' 'worshiper' 'the' 'cross' 'we' 'attack' 'come' 'american' 'commando' 'carry' 'out' 'the' 'rare' 'overnight' 'military' 'operation' 'kill' 'sayyaf' 'capture' 'his' 'wife' 'free' 'a' 'woman' 'believe' 'hold' 'their' 'slave' 'the' 'pentagon' 'say' 'saturday' 'defense' 'secretary' 'ash' 'carter' 'herald' 'the' 'mission' 'a' 'significant' 'blow' 'the' 'islamic' 'analyze' 'social' 'medium' 'syria' 'the' 'wake' 'the' 'strike' 'discover' 'some' 'isi' 'supporter' 'claim' 'the' 'news' 'yous' 'propaganda' 'time' 'counter' 'isi' 'momentum' 'take' 'most' 'the' 'iraqi' 'city' 'ramadi' 'this' 'week' 'others' 'tweet' 'outside' 'the' 'syrian' 'city' 'raqqa' 'vow' 'revenge' 'the' 'strike' 'say' 'they' 'hear' 'explosion' 'say' 'sayyaf' 'responsible' 'direct' 'the' 'group' 'military' 'activity' 'fund' 'direct' 'it' 'illicit' 'oil' 'gas' 'financial' 'operation' 'yous' 'force' 'kill' 'injure' 'the' 'operation' 'which' 'represent' 'another' 'significant' 'blow' 'the' 'group' 'carter' 'say' 'it' 'a' 'reminder' 'the' 'united' 'state' 'never' 'waver' 'deny' 'safe' 'haven' 'terrorist' 'who' 'threaten' 'our' 'citizen' 'those' 'our' 'friend' 'ally' 'he' 'continue' 'the' 'statementthe' 'mission' 'include' 'the' 'arrest' 'sayyaf' 'wife' 'umm' 'sayyaf' 'the' 'free' 'the' 'woman' 'the' 'trading' 'woman' 'a' 'major' 'reward' 'isi' 'fighters' 'the' 'past' 'the' 'follow' 'a' 'strand' 'islam' 'reject' 'mainstream' 'muslim' 'isi' 'year' 'surround' 'the' 'villages' 'northern' 'iraq' 'kill' 'capture' 'dozen' 'take' 'the' 'girl' 'woman' 'slave' 'yous' 'force' 'capture' 'umm' 'sayyaf' 'who' 'we' 'suspect' 'a' 'member' 'isi' 'play' 'an' 'important' 'role' 'isi' 'terrorist' 'activity' 'complicit' 'what' 'appear' 'the' 'enslavement' 'a' 'young' 'woman' 'rescue' 'night' 'carter' 'say' 'the' 'white' 'house' 'say' 'a' 'statement' 'umm' 'sayyaf' ' ...
#
#      Predikció valószínűsége
# 21                    0.6668
# 41                    0.0023
# 53                    0.1183
# 138                   0.6181
# 154                   0.3577
# 168                   0.0109
# 186                   0.5574
# 218                   0.8800
# 231                   0.9927
# 235                   0.5673
# 244                   0.0033
# 286                   0.2242
# 290                   0.5686
# 295                   0.4931
# 327                   0.7108
# 377                   0.6676
# 399                   0.6070
# 408                   0.0690
# 445                   0.7837
# 464                   0.8986

# %% [markdown]
# # Tanulás-validáció-teszt összehasonlítása két modellnél

# %%
test_loss_lstm, test_accuracy_lstm = lstm_trainable.evaluate(padded_test, y_test, verbose=0)
test_loss_gru, test_accuracy_gru = gru_trainable.evaluate(padded_test, y_test, verbose=0)

# Ábra létrehozása két alábrával
plt.figure(figsize=(12, 5))

# Tanulási, validációs és teszthalmaz veszteség ábrázolása
plt.subplot(1, 2, 1)
plt.plot(lstm_history_trainable.history['loss'], label='LSTM tanulási veszteség', color='blue')
plt.plot(lstm_history_trainable.history['val_loss'], label='LSTM validációs veszteség', color='#7fcdbb')
plt.plot(history_gru_trainable.history['loss'], label='GRU tanulási veszteség', color='red')
plt.plot(history_gru_trainable.history['val_loss'], label='GRU validációs veszteség', color='orange')
plt.axhline(y=test_loss_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz veszteség')  # LSTM teszt loss
plt.axhline(y=test_loss_gru, color='red', linestyle='--', label='GRU teszthalmaz veszteség')  # GRU teszt loss
plt.xlabel('Epizód')
plt.ylabel('Veszteség')
plt.legend()
plt.title('Tanulási, validációs és teszthalmaz veszteség')

# Ttanulási, validációs és teszthalmaz precízió ábrázolása
if 'accuracy' in lstm_history_trainable.history and 'accuracy' in history_gru_trainable.history:
    plt.subplot(1, 2, 2)
    plt.plot(lstm_history_trainable.history['accuracy'], label='LSTM tanulási pontosság', color='blue')
    plt.plot(lstm_history_trainable.history['val_accuracy'], label='LSTM validációs pontosság', color='#7fcdbb')
    plt.plot(history_gru_trainable.history['accuracy'], label='GRU tanulási pontosság', color='red')
    plt.plot(history_gru_trainable.history['val_accuracy'], label='GRU validációs pontosság', color='orange')
    plt.axhline(y=test_accuracy_lstm, color='blue', linestyle='--', label='LSTM teszthalmaz pontosság')  # LSTM teszt accuracy
    plt.axhline(y=test_accuracy_gru, color='red', linestyle='--', label='GRU teszthalmaz pontosság')  # GRU teszt accuracy
    plt.xlabel('Epizód')
    plt.ylabel('Pontosság')
    plt.legend()
    plt.title('Tanulási, validációs és teszthalmaz pontosság')

plt.tight_layout()
plt.show()
