# %% [markdown]
# # **Csomagok behívása**

# %%
#Szükséges csomagok és adatbázis importálása
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Concatenate
import numpy as np
import tensorflow as tf
import spacy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fájlok behívása, ellenőrzése és felkészítése

# %%
# Betölteni padded sequences, tokenizer, és számokat
padded_train = np.load('/content/padded_train03.npy')
padded_test = np.load('/content/padded_independent03.npy')

# Tokenizer visszatöltése
with open('/content/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Címkék betöltése (real = 1, fake = 0)
train_file = '/content/train_harmadik.csv'
test_file = '/content/indep_harmadik.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

labels_train = df_train['label'].values
labels_test = df_test['label'].values

# Betölteni embedding mátrixot
embedding_matrix = np.load('/content/embedding_matrix.npy')

# Ellenőrzés
print(f"Train padded sequences shape: {padded_train.shape}")
print(f"Test padded sequences shape: {padded_test.shape}")
print(f"Train labels shape: {labels_train.shape}")
print(f"Test labels shape: {labels_test.shape}")
# Out:
# Train padded sequences shape: (59520, 600)
# Test padded sequences shape: (14304, 600)
# Train labels shape: (59520,)
# Test labels shape: (14304,)

# %%
# Max szókincs és szekvencia hossz
MAX_VOCAB_SIZE = 25000
MAX_LENGTH = 600
EMBEDDING_DIM = 300  # GloVe 300d

# input shape
MAX_SEQUENCE_LENGTH = padded_train.shape[1]

# Szöveges input (LSTM/GRU bemenet)
text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
embedding_layer = Embedding(
    input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
    output_dim=embedding_matrix.shape[1],
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)(text_input)

model_output = embedding_layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
MAX_SEQUENCE_LENGTH = padded_train.shape[1]  # Train hossz
EMBEDDING_DIM = embedding_matrix.shape[1]  # GloVe embeddings

# 10%-os validációs halmaz leválasztása a tanító adatokból
padded_train_final, padded_val, y_train_final, y_val = train_test_split(
    padded_train, labels_train, test_size=0.1, random_state=42
)
# Float32-re konvertálás TensorFlow kompatibilitás miatt
padded_train_final = np.array(padded_train_final, dtype=np.float32)
padded_val = np.array(padded_val, dtype=np.float32)
padded_test = np.array(padded_test, dtype=np.float32)
y_train_final = np.array(y_train_final, dtype=np.float32)
y_val = np.array(y_val, dtype=np.float32)
y_test = np.array(labels_test, dtype=np.float32)

# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# # LSTM MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ## Modell lefuttatása

# %%
# LSTM modell, trainable, non-trainable embedding

def create_lstm_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings
    )(text_input)

    # LSTM rétegek
    lstm_out = LSTM(128, return_sequences=True, dropout=0.3)(text_embedding)
    lstm_out = Dropout(0.3)(lstm_out)  # Dropout réteg az első LSTM után
    lstm_out = LSTM(64,return_sequences=True, dropout=0.3)(lstm_out)
    lstm_out = Dropout(0.3)(lstm_out) # Dropout réteg az második LSTM után
    lstm_out = LSTM(32, dropout=0.3)(lstm_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(lstm_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása
lstm_trainable = create_lstm_model(trainable_embeddings=True)  # Trainable embedding

lstm_trainable.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_1 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 600, 128)            │         219,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 600, 64)             │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,781,505 (29.68 MB)
#  Trainable params: 7,781,505 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Inicializálás
n_runs = 5
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
test_losses, test_accuracies = [], []

all_preds, all_probs, all_true = [], [], []

results = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': []
}

# Többszöri futtatás
for i in range(n_runs):
    print(f"\nFutás {i+1}/{n_runs}")

    lstm_trainable = create_lstm_model(trainable_embeddings=True)

    history = lstm_trainable.fit(
        padded_train_final, y_train_final,
        validation_data=(padded_val, y_val),
        epochs=10,
        batch_size=64,
        callbacks=[early_stopping],
        verbose=0
    )

    # Tanulási görbékhez szükséges adatok
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])
    train_accuracies.append(history.history['accuracy'])
    val_accuracies.append(history.history['val_accuracy'])

    # Teszt pontosság/veszteség
    loss, acc = lstm_trainable.evaluate(padded_test, y_test, verbose=0)
    test_losses.append(loss)
    test_accuracies.append(acc)

    # Predikció
    lstm_y_prob = lstm_trainable.predict(padded_test)
    lstm_y_pred = (lstm_y_prob > 0.5).astype(int)

    all_preds.append(lstm_y_pred.flatten())
    all_probs.append(lstm_y_prob.flatten())
    all_true.append(y_test.flatten())

    # Metrikák
    results['accuracy'].append(accuracy_score(y_test, lstm_y_pred))
    results['precision'].append(precision_score(y_test, lstm_y_pred))
    results['recall'].append(recall_score(y_test, lstm_y_pred))
    results['f1_score'].append(f1_score(y_test, lstm_y_pred))


# Aggregált adatok
y_true_all = np.concatenate(all_true)
y_pred_all = np.concatenate(all_preds)
y_prob_all = np.concatenate(all_probs)
padded_test_repeated = np.tile(padded_test, (n_runs, 1))
# Out:
# Futás 1/5
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
#
# Futás 2/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step
#
# Futás 3/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step
#
# Futás 4/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step
#
# Futás 5/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step

# %%
df_metrics = pd.DataFrame(results)
print("\n Metrikák statisztikája (10 futás):")
print(df_metrics.describe().T)
# Out:
#  Metrikák statisztikája (10 futás):
#            count      mean       std       min       25%       50%       75%  \
# accuracy     5.0  0.751063  0.030092  0.701272  0.745316  0.763353  0.769225
# precision    5.0  0.932617  0.018465  0.909764  0.920894  0.935790  0.938296
# recall       5.0  0.540828  0.058166  0.446868  0.525168  0.562919  0.576202
# f1_score     5.0  0.683364  0.050724  0.599344  0.673420  0.708867  0.709240
#
#                 max
# accuracy   0.776147
# precision  0.958343
# recall     0.592981
# f1_score   0.725950

# %% [markdown]
# ## LSTM Modell ábrák

# %%
# Egységesítés (early stopping miatt lehetnek eltérések)
min_epochs = min(len(run) for run in train_losses)

train_losses_np = np.array([run[:min_epochs] for run in train_losses])
val_losses_np = np.array([run[:min_epochs] for run in val_losses])
train_accuracies_np = np.array([run[:min_epochs] for run in train_accuracies])
val_accuracies_np = np.array([run[:min_epochs] for run in val_accuracies])
epochs = min_epochs

# Ábrák
plt.figure(figsize=(12, 5))

# Veszteség
plt.subplot(1, 2, 1)
plt.plot(train_losses_np.mean(axis=0), label='Tanulási veszteség (átlag)', color='blue')
plt.fill_between(range(epochs), train_losses_np.mean(axis=0) - train_losses_np.std(axis=0),
                 train_losses_np.mean(axis=0) + train_losses_np.std(axis=0), alpha=0.2, color='blue')
plt.plot(val_losses_np.mean(axis=0), label='Validációs veszteség (átlag)', color='orange')
plt.fill_between(range(epochs), val_losses_np.mean(axis=0) - val_losses_np.std(axis=0),
                 val_losses_np.mean(axis=0) + val_losses_np.std(axis=0), alpha=0.2, color='orange')
plt.axhline(np.mean(test_losses), color='red', linestyle='--', label='Teszthalmaz veszteség (átlag)')
plt.xlabel('Epizód'); plt.ylabel('Veszteség'); plt.title('Tanulási / validációs veszteség')
plt.legend()

# Pontosság
plt.subplot(1, 2, 2)
plt.plot(train_accuracies_np.mean(axis=0), label='Tanulási pontosság (átlag)', color='blue')
plt.fill_between(range(epochs), train_accuracies_np.mean(axis=0) - train_accuracies_np.std(axis=0),
                 train_accuracies_np.mean(axis=0) + train_accuracies_np.std(axis=0), alpha=0.2, color='blue')
plt.plot(val_accuracies_np.mean(axis=0), label='Validációs pontosság (átlag)', color='orange')
plt.fill_between(range(epochs), val_accuracies_np.mean(axis=0) - val_accuracies_np.std(axis=0),
                 val_accuracies_np.mean(axis=0) + val_accuracies_np.std(axis=0), alpha=0.2, color='orange')
plt.axhline(np.mean(test_accuracies), color='red', linestyle='--', label='Teszthalmaz pontosság (átlag)')
plt.xlabel('Epizód'); plt.ylabel('Pontosság'); plt.title('Tanulási / validációs pontosság')
plt.legend()
plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_true_all, y_pred_all)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Konfúziós mátrix (10 futás aggregálva)')
plt.show()

print("\n Classification Report (összesített):")
print(classification_report(y_true_all, y_pred_all))
# Out:
#  Classification Report (összesített):
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.96      0.79     35760
#          1.0       0.93      0.54      0.68     35760
#
#     accuracy                           0.75     71520
#    macro avg       0.80      0.75      0.74     71520
# weighted avg       0.80      0.75      0.74     71520

# %%
correct_real = y_prob_all[(y_true_all == 0) & (y_pred_all == 0)]
incorrect_real = y_prob_all[(y_true_all == 0) & (y_pred_all != 0)]
correct_fake = y_prob_all[(y_true_all == 1) & (y_pred_all == 1)]
incorrect_fake = y_prob_all[(y_true_all == 1) & (y_pred_all != 1)]

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (valódi=0)"); axes[0].set_xlabel("Valószínűség"); axes[0].legend(); axes[0].grid(True)

axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódi hírek (valódi=1)"); axes[1].set_xlabel("Valószínűség"); axes[1].legend(); axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása (10 futás aggregálva)", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Eredeti félrebesorolt DataFrame
df_results_full = pd.DataFrame({
    "Valódi címke": y_true_all,
    "Prediktált címke": y_pred_all
})

# Félrebesorolt indexek
df_misclassified = df_results_full[df_results_full["Valódi címke"] != df_results_full["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index.to_numpy()

# Tokenek visszaalakítása szöveggé
misclassified_sequences = padded_test_repeated[misclassified_indices]
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# OOV-mentesítés
misclassified_texts_cleaned = [
    " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    for text in misclassified_texts
]

# Hibatípus, szöveg és valószínűség hozzáadása
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))
df_misclassified["Szöveg"] = misclassified_texts_cleaned
df_misclassified["Predikció valószínűsége"] = np.round(y_prob_all[misclassified_indices], 4)

# Duplikált szövegek eltávolítása (megtartja az első előfordulást)
df_misclassified_unique = df_misclassified.drop_duplicates(subset="Szöveg").reset_index(drop=True)

# Mentés CSV-be
df_misclassified_unique.to_csv("felrebesorolt_peldak_aggregalt_lstm.csv", index=False, encoding="utf-8")

# Megjelenítés
pd.set_option("display.max_colwidth", None)
display(df_misclassified_unique.head(20))
# Out:
#            Hiba típusa  Valódi címke  Prediktált címke  \
# 0   Hamis negatív (FN)           1.0                 0
# 1   Hamis negatív (FN)           1.0                 0
# 2   Hamis negatív (FN)           1.0                 0
# 3   Hamis negatív (FN)           1.0                 0
# 4   Hamis negatív (FN)           1.0                 0
# 5   Hamis pozitív (FP)           0.0                 1
# 6   Hamis negatív (FN)           1.0                 0
# 7   Hamis negatív (FN)           1.0                 0
# 8   Hamis negatív (FN)           1.0                 0
# 9   Hamis negatív (FN)           1.0                 0
# 10  Hamis negatív (FN)           1.0                 0
# 11  Hamis negatív (FN)           1.0                 0
# 12  Hamis negatív (FN)           1.0                 0
# 13  Hamis negatív (FN)           1.0                 0
# 14  Hamis negatív (FN)           1.0                 0
# 15  Hamis negatív (FN)           1.0                 0
# 16  Hamis negatív (FN)           1.0                 0
# 17  Hamis negatív (FN)           1.0                 0
# 18  Hamis negatív (FN)           1.0                 0
# 19  Hamis pozitív (FP)           0.0                 1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'department' 'transportation' 'ask' 'understanding' 'metro' 'manila' 'land' 'near' ' ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'unidentified' 'muslim' 'run' 'stab' 'people' 'frankfurt' 'train' 'station' 'attack' 'afternoon' 'occur' 'station' 'police' 'say' 'victim' 'stage' 'motive' 'stabbings' 'clear' 'crystal' 'clear' 'identify' 'attacker' 'muslim' 'uk'  ...
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'los' 'angeles' 'usa' 'return' 'table' 'international' 'ballroom' 'beverly' 'hilton' 'lisa' 'marie' 'priscilla' 'arrive' 'red' 'carpet' 'medium' 'line' 'golden' 'globe' 'award' 'january' 'ballroom' 'pack' 'woman' 'stop' 'traffic' 'pause' 'stair' 'lead' 'pit' 'level' 'near' 'stage' 'lady' 'sit' 'table' 'elvis' 'star' 'austin' 'butler' 'director' 'austin' 'win' 'best' 'actor' 'motion' 'picture' 'drama' 'play' 'rock' 'roll' 'legend' 'die' 'thanked' 'lisa' 'marie' 'hand' 'face' 'austin' 'eerily' 'speak' 'voice' 'accent' 'king' 'say' 'want' 'thank' 'incredible' 'producer' 'warner' 'brother' 'family' 'thank' 'guy' 'thank' 'open' 'heart' 'memory' 'home' 'lisa' 'marie' 'priscilla' 'love' 'forever' 'play' 'suspicious' 'mind' 'lastly' 'elvis' 'icon' 'rebel' 'love' 'thank' 'remember' 'forget' 'backstage' 'press' 'austin' 'ask' 'advice' 'get' 'prepare' 'role' 'answer' 'advice' 'feeling' 'bless' 'meant' 'imagine' 'shock' 'read' 'online' 'daughter' 'elvis' 'priscilla' 'die' 'cardiac' 'arrest' 'day' 'attend' 'globe' 'lisa' 'marie' 'career' 'news' 'story' 'report' 'lisa' 'marie' 'appear' 'frail' 'interview' 'extra' 'host' 'billy' 'bush' 'carpet' 'point' 'tell' 'jerry' 'schilling' 'friend' 'manager' 'go' 'grab' 'arm' 'riley' 'lisa' 'mary' 'daughter' 'exhusband' 'danny' 'eldest' 'grandchild' 'elvis' 'priscilla' 'golden' 'globe' 'best' 'actress' 'limited' 'series' 'series' 'television' 'motion' 'picture' 'nominee' 'girlfriend' 'experience' 'riley' 'feature' 'direct' 'debut' 'gina' 'war' 'pony' 'win' 'cannes' 'film' 'festival' 'golden' 'camera' 'prize' 'new' 'york' 'time' 'write' 'day' 'pass' 'away' 'lisa' 'marie' 'go' 'elvis' 'famed' 'mansion' 'inherit' 'commemorate' 'dad' 'birthday' 'representative' 'say' 'lisa' 'marie' 'bury' 'alongside' 'son' 'benjamin' 'die' 'ground' 'elvis' 'family' 'member' 'bury' 'lisa' 'mary' 'pass' 'sad' 'note' 'golden' 'globe' 'mark' 'return' 'year' 'inperson' 'ceremony' 'award' 'present' 'hollywood' 'foreign' 'press' 'association' 'honor' 'excellence' 'film' 'television' 'follow' 'ramble' 'note' 'highlight' 'red' 'carpet' 'inside' 'ballroom' 'despite' 'prediction' 'rain' 'pelt' 'california' 'day' 'sky' 'clear' 'january' 'film' 'director' 'cue' 'red' 'carpet' 'actually' 'gray' 'keep' 'motif' 'show' 'producer' 'pick' 'open' 'dolly' 'de' 'leon' 'entrance' 'carpet' 'filipino' 'best' 'support' 'actress' 'nominee' 'triangle' 'sadness' 'year' 'history' 'limo' 'end' 'carpet' 'line' 'stay' 'hilton' 'entered' 'gray' 'carpet' 'lobby' 'interview' 'janet' 'gma' 'yong' 'chavez' 'pose' 'photo' 'filipino' 'guest' 'designer' 'david' 'geoffrey' 'jimenez' 'baker' 'benjamin' 'cabrera' 'actress' 'way' 'carpet' 'line' 'despite' 'carpet' 'medium' 'line' 'frenzy' 'dolly' 'fellow' 'nominee' 'star' 'talent' 'get' 'pose' 'hunter' 'abrams' 'stun' 'portrait' 'take' 'room' 'plush' 'drape' 'wall' 'dolly' 'good' 'company' 'portrait' 'take' 'eddie' 'wife' 'hannah' 'viola' 'davis' 'jamie' 'lee' 'curtis' 'michelle' 'matt' 'michelle' 'williams' 'jenna' 'ortega' 'rodriguez' 'filmmaker' 'tim' 'burton' 'ryan' 'james' 'cameron' 'walk' 'carpet' 'bring' 'reporter' 'occupational' 'hazard' 'step' 'long' 'train' 'talent' 'year' 'star' 'voluminous' 'skirt' 'extra' 'careful' 'l' 'step' 'train' 'include' 'billy' 'porter' 'lily' 'jam' 'jenna' 'ortega' 'james' 'cam ...
# ...
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'kyiv' 'ukraine' 'ukrainian' 'president' 'volodymyr' 'urge' 'eu' 'leader' 'talk' 'kyiv' 'thursday' 'february' 'slap' 'sanction' 'russia' 'moscow' 'force' 'press' 'offensive' 'eastern' 'ukraine' 'fire' 'missile' 'city' 'near' 'line' 'missile' 'destroy' 'apartment' 'building' 'late' 'wednesday' 'kill' 'people' 'wound' 'police' 'say' 'russia' 'say' 'thursday' 'strike' 'usmade' 'rocket' 'launcher' 'area' 'head' 'european' 'commission' 'pledge' 'eu' 'aid' 'ukraine' 'arrive' 'kyiv' 'train' 'dozen' 'senior' 'eu' 'official' 'day' 'talk' 'see' 'key' 'ukraine' 'hope' 'day' 'join' 'bloc' 'russia' 'pay' 'heavy' 'price' 'war' 'sanction' 'erode' 'economy' 'throw' 'generation' 'turn' 'pressure' 'ursula' 'von' 'der' 'leyen' 'later' 'tell' 'joint' 'news' 'conference' 'west' 'impose' 'sweeping' 'sanction' 'russia' 'invasion' 'ukraine' 'february' 'year' 'aim' 'cripple' 'ability' 'wage' 'war' 'devastate' 'ukrainian' 'city' 'town' 'kill' 'ten' 'thousand' 'people' 'force' 'million' 'flee' 'home' 'call' 'sanction' 'say' 'pace' 'slightly' 'slow' 'late' 'moscow' 'adapt' 'joint' 'european' 'task' 'reduce' 'russias' 'ability' 'evade' 'sanction' 'faster' 'well' 'task' 'accomplish' 'closer' 'defeat' 'aggression' 'russian' 'federation' 'say' 'von' 'der' 'leyen' 'say' 'eu' 'new' 'package' 'sanction' 'place' 'anniversary' 'war' 'big' 'arm' 'conflict' 'europe' 'world' 'war' 'avoid' 'commitment' 'fasttrack' 'ukraine' 'eu' 'membership' 'bid' 'expect' 'year' 'team' 'brussels' 'discuss' 'send' 'arm' 'money' 'ukraine' 'increase' 'access' 'ukrainian' 'product' 'eu' 'help' 'kyiv' 'cover' 'energy' 'need' 'strengthen' 'sanction' 'russia' 'prosecute' 'russian' 'leader' 'war' 'earlier' 'give' 'bleak' 'assessment' 'battlefield' 'situation' 'eastern' 'ukraine' 'russian' 'force' 'make' 'incremental' 'gain' 'anniversary' 'moscow' 'invasion' 'loom' 'russian' 'tactical' 'missile' 'strike' 'pm' 'gmt' 'wednesday' 'police' 'say' 'apartment' 'building' 'damage' 'completely' 'destroy' 'say' 'facebook' 'post' 'people' 'remain' 'rubble' 'daily' 'update' 'russia' 'defense' 'ministry' 'say' 'thursday' 'destroy' 'usmade' 'himars' 'launch' 'pad' 'attack' 'region' 'reference' 'strike' 'residential' 'building' 'km' 'mile' 'northwest' 'currently' 'main' 'focus' 'fight' 'eastern' 'ukraine' 'russia' 'determine' 'progress' 'ukraine' 'receives' 'newly' 'promise' 'western' 'battle' 'tank' 'armour' 'vehicle' 'pick' 'momentum' 'battlefield' 'announce' 'advance' 'north' 'south' 'suffer' 'persistent' 'russian' 'bombardment' 'month' 'enemy' 'try' 'achieve' 'russia' 'chance' 'anniversary' 'invasion' 'say' 'video' 'address' 'late' 'wednesday' 'town' 'village' 'come' 'russian' 'fire' 'ukrainian' 'military' 'say' 'russian' 'force' 'push' 'north' 'south' 'encircle' 'superior' 'troop' 'number' 'try' 'cut' 'resupply' 'force' 'ukrainian' 'ukrainian' 'military' 'analyst' 'say' 'enemy' 'able' 'use' 'sole' 're ...
# 18                                                                                                                                                                                                                                                                                                                                               'final' 'vote' 'state' 'house' 'lopsided' 'flag' 'apologist' 'quietly' 'debate' 'last' 'hour' 'exhaust' 'thursday' 'leader' 'republican' 'state' 'rep' 'michael' 'yearold' 'white' 'male' 'baptist' 'retire' 'cop' 'nra' 'devotee' 'best' 'know' 'back' 'south' 'carolinas' 'second' 'amendment' 'weekend' 'state' 'sale' 'tax' 'rifle' 'handgun' 'plan' 'replace' 'yous' 'paper' 'currency' 'silver' 'gold' 'coin' 'mint' 'state' 'pitt' 'insists' 'confederate' 'soldier' 'know' 'heard' 'general' 'store' 'northern' 'state' 'attack' 'southern' 'state' 'say' 'learn' 'child' 'civil' 'war' 'war' 'northern' 'aggression' 'call' 'accuse' 'scrub' 'history' 'favorite' 'theme' 'flag' 'defender' 'rep' 'eric' 'say' 'thing' 'prayer' 'call' 'pastor' 'pray' 'learn' 'erase' 'history' 'rep' 'j' 'gary' 'accuse' 'cultural' 'genocide' 'sheer' 'color' 'beat' 'senate' 'majority' 'leader' 'harvey' 'sum' 'thing' 'lovely' 'word' 'remove' 'flag' 'think' 'change' 'history' 'like' 'remove' 'tattoo' 'corpse' 'love' 'think' 'change' 'love' 'one' 'obituary' 'year' 'folk' 'like' 'history' 'south' 'south' 'carolina' 'declare' 'war' 'union' 'percent' 'citizen' 'africanamerican' 'slave' 'scrub' 'tale' 'southern' 'heritage' 'pious' 'ancestor' 'worshipper' 'know' 'confederate' 'flag' 'flag' 'racism' 'slavery' 'sedition' 'take' 'year' 'arduous' 'scrub' 'lie' 'satanic' 'ingenuity' 'think' 'truth' 'restore' 'overnight' 'aftermath' 'terrorist' 'attack' 'emanuel' 'ame' 'church' 'effort' 'south' 'remove' 'confederate' 'monument' 'new' 'orleans' 'mayor' 'mitch' 'landrieu' 'want' 'honor' 'confederate' 'president' 'jefferson' 'davis' 'confederate' 'general' 'robert' 'e' 'lee' 'pg' 'beauregard' 'fourth' 'honor' 'war' 'revolt' 'louisianas' 'reconstruction' 'government' 'band' 'call' 'white' 'league' 'money' 'landrieu' 'mere' 'fact' 'monument' 'stand' 'suggest' 'hard' 'get' 'south' 'face' 'past' 'easy' 'day' 'south' 'carolina' 'vote' 'low' 'flag' 'loony' 'republican' 'yous' 'house' 'push' 'display' 'confederate' 'memorial' 'day' 'holiday' 'state' 'sell' 'souvenir' 'shop' 'federal' 'land' 'fearful' 'john' 'boehner' 'shut' 'month' 'year' 'ahead' 'memory' 'charleston' 'fade' 'few' 'mayor' 'governor' 'house' 'speaker' 'need' 'spend' 'political' 'capital' 'fight' 'harder' 'fight' 'state' 'spreading' 'lie' 'harder' 'fight' 'south' 'country' 'commit' 'tell' 'truth' 'civil' 'war' 'year' 'right' 'wag' 'war' 'history' 'bit' 'relentless' 'effective' 'war' 'science' 'george' 'orwell' 'famously' 'observe' 'control' 'past' 'control' 'future' 'america' 'outside' 'political' 'right' 'take' 'point' 'carry' 'fight' 'college' 'medium' 'government' 'especially' 'public' 'school' 'lesson' 'charleston' 'leave' 'finally' 'fight' 'far' 'religious' 'right' 'sought' 'elect' 'people' 'school' 'board' 'instruct' 'conceal' 'view' 'elect' 'sex' 'education' 'priority' 'dive' 'history' 'social' 'study' 'book' 'texas' 'go' 'lone' 'star' 'state' 'hijack' 'american' 'agenda' 'new' 'york' 'time' 'columnist' 'gail' 'collins' 'tell' 'story' 'texas' 'school' 'board' 'chill' 'tale' 'texas' 'americas' 'second' 'big' 'purchaser' 'textbook' 'state' 'control' 'purchase' 'publisher' 'long' 'bow' 'dictate' 'content' 'board' 'conservative' 'real' 'fanatic' 'take' 'begin' 'furiously' 'rewrite' 'curriculum' 'substitute' 'ideological' 'scholarship' 'possible' 'banner' 'year' 'bump' 'thomas' 'jefferson' 'list' 'influential' 'felt' 'misguided' 'mater' 'separation' 'church' 'promote' 'phyllis' 'schlafly' 'place' 'encourage' 'study' 'george' 'wallace' 'nra' 'moral' 'majority' 'jefferson' 'davis' 'inaugural' 'address' 'heritage' 'foundation' 'tell' 'school' 'tell' 'kid' 'joe' 'mccarthy' 'right' 'communist' 'infiltr ...
# 19  'united' 'state' 'reformation' 'fracture' 'thierry' 'observe' 'presidential' 'electoral' 'campaign' 'thierry' 'analyse' 'resurgence' 'old' 'weighty' 'conflict' 'civilisation' 'hillary' 'clinton' 'declare' 'election' 'programme' 'question' 'american' 'reason' 'political' 'republican' 'leader' 'withdraw' 'support' 'candidate' 'donald' 'trump' 'personal' 'behaviour' 'accord' 'thierry' 'united' 'state' 'compose' 'migrant' 'different' 'horizon' 'accept' 'submit' 'ideology' 'particular' 'community' 'model' 'process' 'break' 'risk' 'shatter' 'country' 'voltaire' 'year' 'electoral' 'campaign' 'weather' 'rhetoric' 'profoundly' 'change' 'unexpected' 'rift' 'appear' 'camp' 'begin' 'candidate' 'speak' 'subject' 'genuinely' 'political' 'share' 'wealth' 'national' 'security' 'today' 'talk' 'sex' 'money' 'dialogue' 'political' 'question' 'cause' 'explosion' 'republican' 'party' 'main' 'leader' 'withdraw' 'support' 'candidate' 'political' 'chessboard' 'awaken' 'ancient' 'civilisation' 'mr' 'clinton' 'work' 'appear' 'politically' 'correct' 'donald' 'blow' 'hypocrisy' 'lady' 'hillary' 'clinton' 'promise' 'male' 'female' 'equality' 'hesitate' 'attack' 'defile' 'woman' 'reveal' 'slept' 'husband' 'present' 'personal' 'quality' 'wife' 'expresident' 'accuse' 'donald' 'trump' 'misogyny' 'hide' 'appreciation' 'female' 'gender' 'donald' 'trump' 'denounces' 'state' 'racket' 'foreign' 'personality' 'clinton' 'foundation' 'obtain' 'appointment' 'state' 'department' 'creation' 'obamacare' 'interest' 'citizen' 'profit' 'medical' 'insurance' 'company' 'go' 'far' 'question' 'honesty' 'electoral' 'system' 'perfectly' 'aware' 'way' 'donald' 'trump' 'express' 'encourage' 'racism' 'believe' 'second' 'question' 'heart' 'electoral' 'debate' 'despite' 'hype' 'proclinton' 'medias' 'interest' 'lewinsky' 'affair' 'president' 'bill' 'clinton' 'apologise' 'nation' 'convene' 'number' 'preacher' 'pray' 'salvation' 'accuse' 'similar' 'misconduct' 'audio' 'record' 'donald' 'trump' 'simply' 'people' 'upset' 'make' 'appeal' 'member' 'clergy' 'divide' 'revolt' 'catholic' 'orthodox' 'lutheran' 'value' 'mainly' 'represent' 'usa' 'presbyterian' 'baptist' 'methodist' 'candidate' 'raise' 'puritan' 'tradition' 'clinton' 'methodist' 'trump' 'presbyterian' 'mr' 'clinton' 'return' 'religion' 'father' 'participates' 'today' 'prayer' 'group' 'compose' 'army' 'chiefs' 'staff' 'family' 'mr' 'trump' 'practise' 'interior' 'form' 'spirituality' 'rarely' 'go' 'church' 'course' 'lock' 'system' 'raise' 'people' 'act' 'think' 'unconsciously' 'reproduce' 'system' 'question' 'religious' 'environment' 'candidate' 'important' 'order' 'understand' 'stake' 'game' 'look' '17th' 'century' 'england' 'oliver' 'cromwell' 'military' 'coup' 'detat' 'overthrow' 'king' 'charles' '1st' 'want' 'install' 'republic' 'purify' 'soul' 'country' 'order' 'decapitation' 'create' 'sectarian' 'inspire' 'idea' 'calvin' 'massacre' 'thousand' 'irish' 'impose' 'puritan' 'way' 'life' 'create' 'zionism' 'invite' 'jew' 'england' 'head' 'state' 'world' 'demand' 'creation' 'jewish' 'state' 'palestine' 'bloody' 'episode' 'know' 'british' 'civil' 'war' 'monarchy' 'reinstate' 'cromwell' 'puritan' 'flee' 'england' 'set' 'holland' 'leave' 'americas' 'aboard' 'mayflower' 'pilgrim' 'father' 'found' 'community' 'south' 'africa' 'war' 'independence' '18th' 'century' 'united' 'state' 'saw' 'resurgence' 'struggle' 'british' 'monarchy' 'current' 'manual' 'british' 'history' 'know' 'second' 'civil' 'war' '19th' 'century' 'american' 'civil' 'war' 'oppose' 'southern' 'state' 'mainly' 'inhabit' 'catholic' 'colonist' 'north' 'inhabit' 'protestant' 'colonist' 'history' 'win' 'present' 'confrontation' 'fight' 'freedom' 'face' 'slavery' 'pure' 'propaganda' 'southern' 'state' 'abolish' 'slavery' 'war' 'conclude' 'agreement' 'british' 'monarchy' 'result' 'saw' 'revolt' 'puritan' 'throne' 'historian' 'speak' 'british' 'civil' 'war' '20th' 'century' 'interior' 'confrontation' 'british' 'civilisation' 'apart' 'puritan' 'united' 'kingdom' 'christian' 'pr ...
#
#     Predikció valószínűsége
# 0                    0.1108
# 1                    0.0062
# 2                    0.1510
# 3                    0.0055
# 4                    0.0027
# 5                    0.8475
# 6                    0.0038
# 7                    0.0025
# 8                    0.3045
# 9                    0.1985
# 10                   0.1802
# 11                   0.0013
# 12                   0.0018
# 13                   0.3501
# 14                   0.3944
# 15                   0.0109
# 16                   0.0073
# 17                   0.0375
# 18                   0.3216
# 19                   0.5038

# %% [markdown]
# # GRU MODELL 3. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ### Modell lefuttatása

# %%
# GRU Modell

def create_gru_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),  # Ensure within vocab limit
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings  # Toggle trainability
    )(text_input)

    # GRU rétegek
    gru_out = GRU(128, return_sequences=True, dropout=0.3)(text_embedding)
    gru_out = Dropout(0.3)(gru_out)  # Dropout réteg az első GRU után
    gru_out = GRU(64,return_sequences=True, dropout=0.3)(gru_out)
    gru_out = Dropout(0.3)(gru_out)
    gru_out = GRU(32, dropout=0.3)(gru_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(gru_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása (Trainable)
gru_trainable = create_gru_model(trainable_embeddings=True)

gru_trainable.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_7 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 600, 128)            │         165,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 600, 64)             │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,711,809 (29.42 MB)
#  Trainable params: 7,711,809 (29.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Inicializálás
n_runs = 5
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
test_losses, test_accuracies = [], []

all_preds, all_probs, all_true = [], [], []

results2 = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': []
}

# Többszöri futtatás
for i in range(n_runs):
    print(f"\nFutás {i+1}/{n_runs}")

    gru_trainable = create_gru_model(trainable_embeddings=True)

    history = gru_trainable.fit(
        padded_train_final, y_train_final,
        validation_data=(padded_val, y_val),
        epochs=10,
        batch_size=64,
        callbacks=[early_stopping],
        verbose=0
    )

    # Tanulási görbékhez szükséges adatok
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])
    train_accuracies.append(history.history['accuracy'])
    val_accuracies.append(history.history['val_accuracy'])

    # Teszt pontosság/veszteség
    loss, acc = gru_trainable.evaluate(padded_test, y_test, verbose=0)
    test_losses.append(loss)
    test_accuracies.append(acc)

    # Predikció
    gru_y_prob = gru_trainable.predict(padded_test)
    gru_y_pred = (gru_y_prob > 0.5).astype(int)

    all_preds.append(gru_y_pred.flatten())
    all_probs.append(gru_y_prob.flatten())
    all_true.append(y_test.flatten())

    # Metrikák
    results2['accuracy'].append(accuracy_score(y_test, gru_y_pred))
    results2['precision'].append(precision_score(y_test, gru_y_pred))
    results2['recall'].append(recall_score(y_test, gru_y_pred))
    results2['f1_score'].append(f1_score(y_test, gru_y_pred))


# Aggregált adatok
y_true_all = np.concatenate(all_true)
y_pred_all = np.concatenate(all_preds)
y_prob_all = np.concatenate(all_probs)
padded_test_repeated = np.tile(padded_test, (n_runs, 1))
# Out:
# Futás 1/5
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step
#
# Futás 2/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step
#
# Futás 3/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step
#
# Futás 4/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step
#
# Futás 5/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step

# %%
df_metrics2 = pd.DataFrame(results2)
print("\n Metrikák statisztikája (10 futás):")
print(df_metrics2.describe().T)
# Out:
#  Metrikák statisztikája (10 futás):
#            count      mean       std       min       25%       50%       75%  \
# accuracy     5.0  0.762528  0.012103  0.750839  0.755733  0.756641  0.768736
# precision    5.0  0.932117  0.022621  0.906444  0.921276  0.921721  0.950011
# recall       5.0  0.566499  0.016551  0.548238  0.560123  0.561242  0.570330
# f1_score     5.0  0.704571  0.015888  0.687533  0.697541  0.700137  0.707774
#
#                 max
# accuracy   0.780691
# precision  0.961132
# recall     0.592562
# f1_score   0.729872

# %% [markdown]
# ## GRU modell ábrák

# %%
# Egységesítés (early stopping miatt lehetnek eltérések)
min_epochs = min(len(run) for run in train_losses)

train_losses_np = np.array([run[:min_epochs] for run in train_losses])
val_losses_np = np.array([run[:min_epochs] for run in val_losses])
train_accuracies_np = np.array([run[:min_epochs] for run in train_accuracies])
val_accuracies_np = np.array([run[:min_epochs] for run in val_accuracies])
epochs = min_epochs

# Ábrák
plt.figure(figsize=(12, 5))

# Veszteség
plt.subplot(1, 2, 1)
plt.plot(train_losses_np.mean(axis=0), label='Tanulási veszteség (átlag)', color='blue')
plt.fill_between(range(epochs), train_losses_np.mean(axis=0) - train_losses_np.std(axis=0),
                 train_losses_np.mean(axis=0) + train_losses_np.std(axis=0), alpha=0.2, color='blue')
plt.plot(val_losses_np.mean(axis=0), label='Validációs veszteség (átlag)', color='orange')
plt.fill_between(range(epochs), val_losses_np.mean(axis=0) - val_losses_np.std(axis=0),
                 val_losses_np.mean(axis=0) + val_losses_np.std(axis=0), alpha=0.2, color='orange')
plt.axhline(np.mean(test_losses), color='red', linestyle='--', label='Teszthalmaz veszteség (átlag)')
plt.xlabel('Epizód'); plt.ylabel('Veszteség'); plt.title('Tanulási / validációs veszteség')
plt.legend()

# Pontosság
plt.subplot(1, 2, 2)
plt.plot(train_accuracies_np.mean(axis=0), label='Tanulási pontosság (átlag)', color='blue')
plt.fill_between(range(epochs), train_accuracies_np.mean(axis=0) - train_accuracies_np.std(axis=0),
                 train_accuracies_np.mean(axis=0) + train_accuracies_np.std(axis=0), alpha=0.2, color='blue')
plt.plot(val_accuracies_np.mean(axis=0), label='Validációs pontosság (átlag)', color='orange')
plt.fill_between(range(epochs), val_accuracies_np.mean(axis=0) - val_accuracies_np.std(axis=0),
                 val_accuracies_np.mean(axis=0) + val_accuracies_np.std(axis=0), alpha=0.2, color='orange')
plt.axhline(np.mean(test_accuracies), color='red', linestyle='--', label='Teszthalmaz pontosság (átlag)')
plt.xlabel('Epizód'); plt.ylabel('Pontosság'); plt.title('Tanulási / validációs pontosság')
plt.legend()
plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_true_all, y_pred_all)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Konfúziós mátrix (10 futás aggregálva)')
plt.show()

print("\n Classification Report (összesített):")
print(classification_report(y_true_all, y_pred_all))
# Out:
#  Classification Report (összesített):
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.96      0.80     35760
#          1.0       0.93      0.57      0.70     35760
#
#     accuracy                           0.76     71520
#    macro avg       0.81      0.76      0.75     71520
# weighted avg       0.81      0.76      0.75     71520

# %%
correct_real = y_prob_all[(y_true_all == 0) & (y_pred_all == 0)]
incorrect_real = y_prob_all[(y_true_all == 0) & (y_pred_all != 0)]
correct_fake = y_prob_all[(y_true_all == 1) & (y_pred_all == 1)]
incorrect_fake = y_prob_all[(y_true_all == 1) & (y_pred_all != 1)]

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (valódi=0)"); axes[0].set_xlabel("Valószínűség"); axes[0].legend(); axes[0].grid(True)

axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódi hírek (valódi=1)"); axes[1].set_xlabel("Valószínűség"); axes[1].legend(); axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása (10 futás aggregálva)", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
df_results_full = pd.DataFrame({
    "Valódi címke": y_true_all,
    "Prediktált címke": y_pred_all
})
df_misclassified = df_results_full[df_results_full["Valódi címke"] != df_results_full["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index.to_numpy()
misclassified_sequences = padded_test_repeated[misclassified_indices]
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)
misclassified_texts_cleaned = [
    " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    for text in misclassified_texts
]
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))
df_misclassified["Szöveg"] = misclassified_texts_cleaned
df_misclassified["Predikció valószínűsége"] = np.round(y_prob_all[misclassified_indices], 4)
df_misclassified.to_csv("felrebesorolt_peldak_aggregalt_gru.csv", index=False, encoding="utf-8")

pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 5    Hamis negatív (FN)           1.0                 0
# 8    Hamis negatív (FN)           1.0                 0
# 12   Hamis negatív (FN)           1.0                 0
# 15   Hamis negatív (FN)           1.0                 0
# 23   Hamis negatív (FN)           1.0                 0
# 51   Hamis negatív (FN)           1.0                 0
# 56   Hamis negatív (FN)           1.0                 0
# 57   Hamis negatív (FN)           1.0                 0
# 58   Hamis negatív (FN)           1.0                 0
# 59   Hamis negatív (FN)           1.0                 0
# 70   Hamis negatív (FN)           1.0                 0
# 77   Hamis negatív (FN)           1.0                 0
# 79   Hamis negatív (FN)           1.0                 0
# 82   Hamis negatív (FN)           1.0                 0
# 90   Hamis negatív (FN)           1.0                 0
# 91   Hamis negatív (FN)           1.0                 0
# 109  Hamis negatív (FN)           1.0                 0
# 111  Hamis negatív (FN)           1.0                 0
# 115  Hamis negatív (FN)           1.0                 0
# 134  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               'oslo' 'norway' 'wealth' 'fund' 'worlds' 'large' 'investor' 'post' 'record' 'loss' 'trillion' 'crown' 'billion' 'bring' 'end' 'threeyear' 'run' 'soar' 'profit' 'stock' 'bond' 'hit' 'ukraine' 'war' 'inflation' 'previous' 'large' 'loss' 'billion' 'crown' 'end' 'recordbreaking' 'streak' 'fund' 'annual' 'return' 'exceed' 'trillion' 'crown' 'year' 'amount' 'trillion' 'crown' 'combine' 'invest' 'company' 'country' 'hide' 'fund' 'chief' 'executive' 'tell' 'news' 'conference' 'single' 'big' 'stock' 'market' 'loss' 'come' 'fund' 'stake' 'amazon' 'decline' 'value' 'billion' 'crown' 'follow' 'loss' 'share' 'facebook' 'owner' 'platform' 'billion' 'tesla' 'billion' 'despite' 'record' 'loss' 'value' 'fund' 'rise' 'overall' 'billion' 'crown' 'billion' 'partly' 'weak' 'norwegian' 'currency' 'record' 'trillion' 'crown' 'cash' 'inflow' 'inflow' 'nearly' 'times' 'previous' 'record' 'billion' 'crown' 'set' 'fund' 'inve ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'city' 'philippine' 'heavily' 'arm' 'men' 'brutally' 'kill' 'village' 'chief' 'love' 'one' 'coldblooded' 'ambush' 'del' 'province' 'thursday' 'afternoon' 'january' 'attack' 'leave' 'wounded' 'take' 'place' 'remote' 'village' 'locate' 'approximately' 'kilometer' 'southwest' 'city' 'fear' 'uncertainty' 'spread' 'community' 'military' 'police' 'force' 'swiftly' 'deploy' 'predominantly' 'muslim' 'town' 'del' '3rd' 'district' 'bid' 'prevent' 'act' 'violence' 'retaliation ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'official' 'philippine' 'national' 'police' 'pnp' 'drug' 'enforcement' 'group' 'special' ...
# 51                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 56                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'ukraine' 'veteran' 'envoy' 'president' 'vladimir' 'putin' 'resign' 'ukraine' 'war' 'leave' 'russia' 'intention' 'return' 'source' 'say' 'wednesday' 'senior' 'official' 'break' 'kremlin' 'putin' 'launch' 'invasion' 'month' 'ago' 'kremlin' 'confirm' 'anatoly' 'resign' 'accord' 'principal' 'architect' 'boris' 'economic' 'reform' '1990s' 'putin' 'bos' 'future' 'president' 'kremlin' 'job' 'hold' 'senior' 'business' 'political' 'job' 'putin' 'lately' 'serve' 'kremlin' 'special' 'envoy' 'international' 'organization' 'hung' 'phone' 'contact' 'source' 'president' 'joe' 'biden' 'fly' 'europe' 'wednesday' 'emergency' 'nato' 'summit' 'ukraine' 'invade' 'russian' 'troop' 'stall' 'city' 'bombardment' 'besiege' 'port' 'flame' 'week' 'war' 'driven' 'quarter' 'ukraines' 'million' 'people' 'home' 'russia' 'failed' 'capture' 'single' 'major' 'ukrainian' 'city' 'western' 'sanction' 'ostracize' 'world' 'economy' 'fail' 'western' 'country' 'attempt' 'seize' 'kyiv' 'depose' 'government' 'russian' 'force' 'take' 'heavy' 'loss' 'frozen' 'place' 'week' 'front' 'face' 'supply' 'problem' 'fierce' 'resistance' 'turned' 'siege' 'tactic' 'bombardment' 'city' 'cause' 'massive' 'destruction' 'civilian' 'death' 'moscow' 'say' 'aim' 'disarm' 'neighbor' 'special' 'military' 'operation' 'go' 'plan' 'denies' 'target' 'civilian' 'bad' 'hit' 'southern' 'port' 'completely' 'surround' 'russian' 'force' 'hundred' 'thousand' 'people' 'shelter' 'war' 'early' 'day' 'constant' 'bombardment' 'food' 'water' 'heat' 'supply' 'cut' 'new' 'satellite' 'photograph' 'commercial' 'firm' 'release' 'overnight' 'show' 'massive' 'destruction' 'city' 'people' 'columns' 'smoke' 'rise' 'residential' 'apartment' 'building' 'flame' 'journalist' 'able' 'report' 'inside' 'part' 'city' 'week' 'time' 'ukrainian' 'official' 'russia' 'bomb' 'theatre' 'art' 'school' 'bomb' 'shelter' 'bury' 'hundred' 'people' 'alive' 'russia' 'denies' 'target' 'building' 'biden' 'arrive' 'brussels' 'wednesday' 'even' 'foreign' 'trip' 'war' 'begin' 'meet' 'nato' 'european' 'leader' 'emergency' 'summit' 'western' 'military' 'alliance' 'headquarters' 'leader' 'expect' 'roll' 'additional' 'sanction' 'russia' 'thursday' 'source' 'say' 'yous' 'package' 'include' 'measure' 'target' 'russian' 'member' 'parliament' 'biden' 'visit' 'poland' 'take' 'million' 'refugee' 'flee' 'ukraine' 'main' 'route' 'western' 'supply' 'weapon' 'ukraine' 'sign' 'moscows' 'isolation' 'poland' 'announce' 'expel' 'russian' 'diplomat' 'accuse' 'undercover' 'spy' 'associate' 'eastern' 'european' 'country' 'announce' 'similar' 'move' 'recent' 'day' 'large' 'scale' 'russia' 'reject' 'accusation' 'ukrainians' 'life' 'continue' 'relentless' 'bombardment' 'east' 'maternity' 'clinic' 'move' 'patient' 'basement' 'safety' 'tearful' 'mother' 'cradle' 'baby' 'room' 'bed' 'line' 'wall' 'house' 'bomb' 'say' 'far' 'away' 'southern' 'port' 'russian' 'force' 'try' 'failed' 'storm' 'past' 'day' 'tamara' 'lay' 'baby' 'minute' 'old' 'chest' 'scar' 'especially' 'explosion' 'burst' 'meter' 'hospital' 'say' 'baby' 'melt' 'fear' 'awa ...
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 58                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'syria' 'hussein' 'little' 'hope' 'rebuild' 'home' 'food' 'distribution' 'business' 'northwest' 'syrian' 'city' 'reduce' 'rubble' 'month' 'deadly' 'earthquake' 'wipe' 'life' 'work' 'tent' 'instead' 'tent' 'say' 'stand' 'mangle' 'ruin' 'home' 'rebelheld' 'region' 'february' 'earthquake' 'worst' 'modernday' 'natural' 'disaster' 'strike' 'syria' 'turkey' 'kill' 'people' 'country' 'turkey' 'pledge' 'effort' 'rebuild' 'home' 'year' 'cashstrapped' 'syrian' 'government' 'create' 'compensation' 'fund' 'victim' 'offer' 'temporary' 'housing' 'displace' 'help' 'unlikely' 'reach' 'syria' 'northwest' 'enclave' 'control' 'rival' 'antigovernment' 'rebel' 'home' 'million' 'people' 'million' 'live' 'camp' 'quake' 'struck' 'accord' 'united' 'nation' 'international' 'organization' 'struggle' 'access' 'zone' 'regularly' 'visible' 'centralized' 'reconstruction' 'effort' 'un' 'say' 'people' 'displaced' 'region' 'quake' 'strike' 'february' 'edge' 'turn' 'resident' 'try' 'recover' 'possession' 'help' 'local' 'entrepreneur' 'agree' 'rubble' 'home' 'return' 'keep' 'metal' 'inside' 'ita' 'deal' 'underscoring' 'deep' 'deprivation' 'area' 'help' 'see' 'say' 'obstacle' 'damage' 'limit' 'home' 'area' 'half' 'school' 'require' 'reconstruction' 'repair' 'kilometer' 'water' 'sanitation' 'network' 'citys' 'road' 'say' 'mahmoud' 'head' 'local' 'council' 'say' 'local' 'authority' 'resource' 'rebuild' 'frankly' 'local' 'capability' 'limit' 'rebuild' 'require' 'international' 'help' 'clear' 'funding' 'reconstruction' 'repair' 'say' 'donor' 'conference' 'monday' 'pledge' 'billion' 'euro' 'help' 'reconstruct' 'turkey' 'bloc' 'sanction' 'damascus' 'place' 'say' 'finance' 'humanitarian' 'assistance' 'early' 'recovery' 'fullscale' 'reconstruction' 'long' 'political' 'dialogue' 'assad' 'adversary' 'foreign' 'state' 'funding' 'reconstruction' 'region' 'hold' 'rebel' 'seek' 'assads' 'ouster' 'face' 'additional' 'block' 'accord' 'diplomat' 'work' 'syria' 'presence' 'rival' 'arm' 'group' 'region' 'main' 'issue' 'note' 'powerful' 'group' 'hayat' 'tahrir' 'alsham' 'designate' 'terrorist' 'organization' 'unite' 'nation' 'international' 'aid' 'reach' 'area' 'past' 'decade' 'earmark' 'humanitarian' 'relief' 'reconstruction' 'trend' 'likely' 'continue' 'accord' 'political' 'economist' 'middle' 'east' 'institute' 'thinktank' 'foreseeable' 'future' 'people' 'continue' 'rely' 'private' 'funding' 'reconstruct' 'building' 'tent' 'instead' 'say' 'recovery' 'quake' 'strike' 'syrian' 'ngo' 'team' 'build' 'sprawl' 'unit' 'housing' 'complex' 'driven' 'ambitious' 'goal' 'relocate' 'family' 'tent' 'formal' 'housing' 'team' 'member' 'say' 'inspire' 'realization' 'syrian' 'wait' 'help' 'outside' 'financed' 'online' 'quake' 'launch' 'new' 'appeal' 'raise' 'million' 'intended' 'construction' 'additional' 'unit' 'idlib' 'area' 'hit' 'hard' 'quake' 'property' 'developer' 'area' 'begin' 'adapt' 'construction' 'plan' 'fit' 'quake' 'trauma' 'potential' 'shortage' 'raw' 'material' 'director' 'local' 'construction' 'company' 'say' 'project' 'quake' 'building' 'consultation' 'local' 'show' 'people' 'want' 'live' 'building' 'deem' 'safer' 'price' 'rise' 'construction' 'material' 'enclave' 'entirely' 'import' 'turkey' 'raise' 'fear' 'syrian' 'zone' 'face' 'shortage' 'mass' 'reconstruction' 'begin' 'border' 'struggle' 'pay' 'high' 'price' 'price' 'cement' 'metal' 'risen' 'percent' 'accord' 'developer' 's ...
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'number' 'dengue' 'case' 'continue' 'increase' 'philippine' 'region' 'department' 'health' 'officer' 'charge' 'ma' 'rosario' 'say' 'friday' 'statement' 'saturday' 'doh' 'say' 'region' 'recently' 'exceed' 'threshold' 'past' 'week' 'valley' 'central' 'western' 'central' 'peninsula' 'administrative' 'region' 'national' 'capital' 'region' 'accord' 'country' 'log' 'dengue' 'case' 'base' ' ...
# ...
# 111                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'sevenday' 'positivity' 'rate' 'national' 'capital' 'region' 'decrease' 'previous' 'independent' 'monitoring' 'group' 'research' 'say' 'monday' 'fellow' 'dr' 'guido' 'david' 'report' 'positivity' 'rate' 'go' 'october' 'peak' 'october' 'positivity' 'rate' 'refers' 'percentage' 'people' 'find' 'positive' 'total' 'number' 'individual' 'test' 'reproduction' 'number' 'sl ...
# 115                                                                                                                                                                                                                                                                                                                                                                                                                        'kyiv' 'ukraine' 'ukrainian' 'president' 'volodymyr' 'urge' 'eu' 'leader' 'talk' 'kyiv' 'thursday' 'february' 'slap' 'sanction' 'russia' 'moscow' 'force' 'press' 'offensive' 'eastern' 'ukraine' 'fire' 'missile' 'city' 'near' 'line' 'missile' 'destroy' 'apartment' 'building' 'late' 'wednesday' 'kill' 'people' 'wound' 'police' 'say' 'russia' 'say' 'thursday' 'strike' 'usmade' 'rocket' 'launcher' 'area' 'head' 'european' 'commission' 'pledge' 'eu' 'aid' 'ukraine' 'arrive' 'kyiv' 'train' 'dozen' 'senior' 'eu' 'official' 'day' 'talk' 'see' 'key' 'ukraine' 'hope' 'day' 'join' 'bloc' 'russia' 'pay' 'heavy' 'price' 'war' 'sanction' 'erode' 'economy' 'throw' 'generation' 'turn' 'pressure' 'ursula' 'von' 'der' 'leyen' 'later' 'tell' 'joint' 'news' 'conference' 'west' 'impose' 'sweeping' 'sanction' 'russia' 'invasion' 'ukraine' 'february' 'year' 'aim' 'cripple' 'ability' 'wage' 'war' 'devastate' 'ukrainian' 'city' 'town' 'kill' 'ten' 'thousand' 'people' 'force' 'million' 'flee' 'home' 'call' 'sanction' 'say' 'pace' 'slightly' 'slow' 'late' 'moscow' 'adapt' 'joint' 'european' 'task' 'reduce' 'russias' 'ability' 'evade' 'sanction' 'faster' 'well' 'task' 'accomplish' 'closer' 'defeat' 'aggression' 'russian' 'federation' 'say' 'von' 'der' 'leyen' 'say' 'eu' 'new' 'package' 'sanction' 'place' 'anniversary' 'war' 'big' 'arm' 'conflict' 'europe' 'world' 'war' 'avoid' 'commitment' 'fasttrack' 'ukraine' 'eu' 'membership' 'bid' 'expect' 'year' 'team' 'brussels' 'discuss' 'send' 'arm' 'money' 'ukraine' 'increase' 'access' 'ukrainian' 'product' 'eu' 'help' 'kyiv' 'cover' 'energy' 'need' 'strengthen' 'sanction' 'russia' 'prosecute' 'russian' 'leader' 'war' 'earlier' 'give' 'bleak' 'assessment' 'battlefield' 'situation' 'eastern' 'ukraine' 'russian' 'force' 'make' 'incremental' 'gain' 'anniversary' 'moscow' 'invasion' 'loom' 'russian' 'tactical' 'missile' 'strike' 'pm' 'gmt' 'wednesday' 'police' 'say' 'apartment' 'building' 'damage' 'completely' 'destroy' 'say' 'facebook' 'post' 'people' 'remain' 'rubble' 'daily' 'update' 'russia' 'defense' 'ministry' 'say' 'thursday' 'destroy' 'usmade' 'himars' 'launch' 'pad' 'attack' 'region' 'reference' 'strike' 'residential' 'building' 'km' 'mile' 'northwest' 'currently' 'main' 'focus' 'fight' 'eastern' 'ukraine' 'russia' 'determine' 'progress' 'ukraine' 'receives' 'newly' 'promise' 'western' 'battle' 'tank' 'armour' 'vehicle' 'pick' 'momentum' 'battlefield' 'announce' 'advance' 'north' 'south' 'suffer' 'persistent' 'russian' 'bombardment' 'month' 'enemy' 'try' 'achieve' 'russia' 'chance' 'anniversary' 'invasion' 'say' 'video' 'address' 'late' 'wednesday' 'town' 'village' 'come' 'russian' 'fire' 'ukrainian' 'military' 'say' 'russian' 'force' 'push' 'north' 'south' 'encircle' 'superior' 'troop' 'number' 'try' 'cut' 'resupply' 'force' 'ukrainian' 'ukrainian' 'military' 'analyst' 'say' 'enemy' 'able' 'use' 'sole' 'resource' 'excess' 'men' 'tell' 'tv' 'describe' 'landscape' 'northeast' 'literally' 'cover' 'corps' 'ukraine' 'western' 'ally' 'moscow' 'take' 'huge' 'loss' 'send' 'wave' 'poorly' 'equip' 'troop' 'include' 'thousand' 'convict' 'recruit' 'prison' 'mercenary' 'commander' 'russia' 'wagner' 'mercenary' 'group' 'flee' 'norway' 'january' 'tell' 'want' 'apologise' 'fight' 'ukraine' 'speak' 'bring' 'perpetrator' 'atrocity' 'justice' 'repeatedly' 'like' 'apologise' 'say' 'yearold' 'andrei' 'medvedev' 'ukraine' 'secure' 'pledge' 'weapon' 'west' 'offer' 'new' 'capability' 'late' 'expect' 'week' 'include' 'rocket' 'united' 'state' 'nearly' 'double' 'range' 'ukrainian' 'force' 'focused' 'provide' 'ukraine' 'capabilit ...
# 134                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'senator' 'thursday' 'claim' 'company' 'ask' 'p5' 'million' 'million' 'fast' 'track' 'renewal' 'certificate' 'product' 'registration' 'food' 'drug' 'administration' 'fda' 'raise' 'allegation' 'senate' 'plenary' 'deliberation' 'department' 'health' 'budget' 'cite' 'complaint' 'pharmaceutical' 'firm' 'wait' 'year' 'renewal' 'say' 'ask' 'price' 'fast' 'track' 'process' 'range' 'p5' 'million' 'million' 'product' 'fda' 'director' 'general' 'samuel' 'appoint' 'post' 'august' 'say' 'claim' 'dismay' 'yan' 'po' 'po' 'yan' 'actually' 'po' 'tolerate' 'agency' 'say' 'mention' 'conversation' 'director' 'general' 'agency' 'supposedly' 'admit' 'fda' 'admit' 'na' 'agency' 'admit' 'p5' 'million' 'million' 'say' 'go' 'stop' 'practice' 'na' 'say' 'wag' 'kang' 'wag' 'na' 'accept' 'fact' 'na' 'sa' 'fda' 'yan' 'add' 'response' 'admit' 'hear' 'story' 'allege' 'corruption' 'agency' 'proof' 'pursue' 'investigation' 'po' 'problem' 'lead' 'say' 'ko' 'po' 'want' 'coordinate' 'people' 'knowledge ...
#
#      Predikció valószínűsége
# 5                     0.0750
# 8                     0.0014
# 12                    0.0032
# 15                    0.0048
# 23                    0.0255
# 51                    0.0099
# 56                    0.0272
# 57                    0.0017
# 58                    0.0374
# 59                    0.0115
# 70                    0.4182
# 77                    0.0369
# 79                    0.0023
# 82                    0.0009
# 90                    0.0053
# 91                    0.0052
# 109                   0.0026
# 111                   0.0030
# 115                   0.0045
# 134                   0.0010
