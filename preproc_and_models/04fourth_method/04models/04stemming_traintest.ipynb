# %% [markdown]
# # **Csomagok behívása**

# %%
#Szükséges csomagok és adatbázis importálása
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Concatenate
import numpy as np
import tensorflow as tf
import spacy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fájlok behívása, ellenőrzése és felkészítése

# %%
# Betölteni padded sequences, tokenizer, és számokat
padded_train = np.load('/content/padded_train04.npy')
padded_test = np.load('/content/padded_test04.npy')

# Tokenizer visszatöltése
with open('/content/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Címkék betöltése (real = 1, fake = 0)
train_file = '/content/train_negyedik.csv'
test_file = '/content/teszt_negyedik.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

labels_train = df_train['label'].values
labels_test = df_test['label'].values

# Betölteni embedding mátrixot
embedding_matrix = np.load('/content/embedding_matrix.npy')

# Ellenőrzés
print(f"Train padded sequences shape: {padded_train.shape}")
print(f"Test padded sequences shape: {padded_test.shape}")
print(f"Train labels shape: {labels_train.shape}")
print(f"Test labels shape: {labels_test.shape}")
# Out:
# Train padded sequences shape: (59520, 600)
# Test padded sequences shape: (14880, 600)
# Train labels shape: (59520,)
# Test labels shape: (14880,)

# %%
# Max szókincs és szekvencia hossz
MAX_VOCAB_SIZE = 25000
MAX_LENGTH = 600
EMBEDDING_DIM = 300  # GloVe 300d

# input shape
MAX_SEQUENCE_LENGTH = padded_train.shape[1]

# Szöveges input (LSTM/GRU bemenet)
text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
embedding_layer = Embedding(
    input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
    output_dim=embedding_matrix.shape[1],
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)(text_input)

model_output = embedding_layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
MAX_SEQUENCE_LENGTH = padded_train.shape[1]  # Train hossz
EMBEDDING_DIM = embedding_matrix.shape[1]  # GloVe embeddings

# 10%-os validációs halmaz leválasztása a tanító adatokból
padded_train_final, padded_val, y_train_final, y_val = train_test_split(
    padded_train, labels_train, test_size=0.1, random_state=42
)
# Float32-re konvertálás TensorFlow kompatibilitás miatt
padded_train_final = np.array(padded_train_final, dtype=np.float32)
padded_val = np.array(padded_val, dtype=np.float32)
padded_test = np.array(padded_test, dtype=np.float32)
y_train_final = np.array(y_train_final, dtype=np.float32)
y_val = np.array(y_val, dtype=np.float32)
y_test = np.array(labels_test, dtype=np.float32)

# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# # LSTM MODELL 4. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ## Modell lefuttatása

# %%
# LSTM modell, trainable, non-trainable embedding

def create_lstm_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings
    )(text_input)

    # LSTM rétegek
    lstm_out = LSTM(128, return_sequences=True, dropout=0.3)(text_embedding)
    lstm_out = Dropout(0.3)(lstm_out)  # Dropout réteg az első LSTM után
    lstm_out = LSTM(64,return_sequences=True, dropout=0.3)(lstm_out)
    lstm_out = Dropout(0.3)(lstm_out) # Dropout réteg az második LSTM után
    lstm_out = LSTM(32, dropout=0.3)(lstm_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(lstm_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása
lstm_trainable = create_lstm_model(trainable_embeddings=True)  # Trainable embedding

lstm_trainable.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_1 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 600, 128)            │         219,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 600, 64)             │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,781,505 (29.68 MB)
#  Trainable params: 7,781,505 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Inicializálás
n_runs = 5
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
test_losses, test_accuracies = [], []

all_preds, all_probs, all_true = [], [], []

results = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': []
}

# Többszöri futtatás
for i in range(n_runs):
    print(f"\nFutás {i+1}/{n_runs}")

    lstm_trainable = create_lstm_model(trainable_embeddings=True)

    history = lstm_trainable.fit(
        padded_train_final, y_train_final,
        validation_data=(padded_val, y_val),
        epochs=10,
        batch_size=64,
        callbacks=[early_stopping],
        verbose=0
    )

    # Tanulási görbékhez szükséges adatok
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])
    train_accuracies.append(history.history['accuracy'])
    val_accuracies.append(history.history['val_accuracy'])

    # Teszt pontosság/veszteség
    loss, acc = lstm_trainable.evaluate(padded_test, y_test, verbose=0)
    test_losses.append(loss)
    test_accuracies.append(acc)

    # Predikció
    lstm_y_prob = lstm_trainable.predict(padded_test)
    lstm_y_pred = (lstm_y_prob > 0.5).astype(int)

    all_preds.append(lstm_y_pred.flatten())
    all_probs.append(lstm_y_prob.flatten())
    all_true.append(y_test.flatten())

    # Metrikák
    results['accuracy'].append(accuracy_score(y_test, lstm_y_pred))
    results['precision'].append(precision_score(y_test, lstm_y_pred))
    results['recall'].append(recall_score(y_test, lstm_y_pred))
    results['f1_score'].append(f1_score(y_test, lstm_y_pred))


# Aggregált adatok
y_true_all = np.concatenate(all_true)
y_pred_all = np.concatenate(all_preds)
y_prob_all = np.concatenate(all_probs)
padded_test_repeated = np.tile(padded_test, (n_runs, 1))
# Out:
# Futás 1/5
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
# Futás 2/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
# Futás 3/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step
#
# Futás 4/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step
#
# Futás 5/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step

# %%
df_metrics = pd.DataFrame(results)
print("\n Metrikák statisztikája (10 futás):")
print(df_metrics.describe().T)
# Out:
#  Metrikák statisztikája (10 futás):
#            count      mean       std       min       25%       50%       75%  \
# accuracy     5.0  0.967097  0.002512  0.962970  0.967339  0.967540  0.967809
# precision    5.0  0.964767  0.005960  0.959874  0.960896  0.962034  0.966671
# recall       5.0  0.969677  0.009513  0.959005  0.960349  0.974059  0.974328
# f1_score     5.0  0.967170  0.002676  0.962823  0.967305  0.967565  0.968009
#
#                 max
# accuracy   0.969825
# precision  0.974362
# recall     0.980645
# f1_score   0.970148

# %% [markdown]
# ## LSTM Modell ábrák

# %%
# Egységesítés (early stopping miatt lehetnek eltérések)
min_epochs = min(len(run) for run in train_losses)

train_losses_np = np.array([run[:min_epochs] for run in train_losses])
val_losses_np = np.array([run[:min_epochs] for run in val_losses])
train_accuracies_np = np.array([run[:min_epochs] for run in train_accuracies])
val_accuracies_np = np.array([run[:min_epochs] for run in val_accuracies])
epochs = min_epochs

# Ábrák
plt.figure(figsize=(12, 5))

# Veszteség
plt.subplot(1, 2, 1)
plt.plot(train_losses_np.mean(axis=0), label='Tanulási veszteség (átlag)', color='blue')
plt.fill_between(range(epochs), train_losses_np.mean(axis=0) - train_losses_np.std(axis=0),
                 train_losses_np.mean(axis=0) + train_losses_np.std(axis=0), alpha=0.2, color='blue')
plt.plot(val_losses_np.mean(axis=0), label='Validációs veszteség (átlag)', color='orange')
plt.fill_between(range(epochs), val_losses_np.mean(axis=0) - val_losses_np.std(axis=0),
                 val_losses_np.mean(axis=0) + val_losses_np.std(axis=0), alpha=0.2, color='orange')
plt.axhline(np.mean(test_losses), color='red', linestyle='--', label='Teszthalmaz veszteség (átlag)')
plt.xlabel('Epizód'); plt.ylabel('Veszteség'); plt.title('Tanulási / validációs veszteség')
plt.legend()

# Pontosság
plt.subplot(1, 2, 2)
plt.plot(train_accuracies_np.mean(axis=0), label='Tanulási pontosság (átlag)', color='blue')
plt.fill_between(range(epochs), train_accuracies_np.mean(axis=0) - train_accuracies_np.std(axis=0),
                 train_accuracies_np.mean(axis=0) + train_accuracies_np.std(axis=0), alpha=0.2, color='blue')
plt.plot(val_accuracies_np.mean(axis=0), label='Validációs pontosság (átlag)', color='orange')
plt.fill_between(range(epochs), val_accuracies_np.mean(axis=0) - val_accuracies_np.std(axis=0),
                 val_accuracies_np.mean(axis=0) + val_accuracies_np.std(axis=0), alpha=0.2, color='orange')
plt.axhline(np.mean(test_accuracies), color='red', linestyle='--', label='Teszthalmaz pontosság (átlag)')
plt.xlabel('Epizód'); plt.ylabel('Pontosság'); plt.title('Tanulási / validációs pontosság')
plt.legend()
plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_true_all, y_pred_all)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Konfúziós mátrix (10 futás aggregálva)')
plt.show()

print("\n Classification Report (összesített):")
print(classification_report(y_true_all, y_pred_all))
# Out:
#  Classification Report (összesített):
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.96      0.97     37200
#          1.0       0.96      0.97      0.97     37200
#
#     accuracy                           0.97     74400
#    macro avg       0.97      0.97      0.97     74400
# weighted avg       0.97      0.97      0.97     74400

# %%
correct_real = y_prob_all[(y_true_all == 0) & (y_pred_all == 0)]
incorrect_real = y_prob_all[(y_true_all == 0) & (y_pred_all != 0)]
correct_fake = y_prob_all[(y_true_all == 1) & (y_pred_all == 1)]
incorrect_fake = y_prob_all[(y_true_all == 1) & (y_pred_all != 1)]

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (valódi=0)"); axes[0].set_xlabel("Valószínűség"); axes[0].legend(); axes[0].grid(True)

axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódi hírek (valódi=1)"); axes[1].set_xlabel("Valószínűség"); axes[1].legend(); axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása (10 futás aggregálva)", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Eredeti félrebesorolt DataFrame
df_results_full = pd.DataFrame({
    "Valódi címke": y_true_all,
    "Prediktált címke": y_pred_all
})

# Félrebesorolt indexek
df_misclassified = df_results_full[df_results_full["Valódi címke"] != df_results_full["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index.to_numpy()

# Tokenek visszaalakítása szöveggé
misclassified_sequences = padded_test_repeated[misclassified_indices]
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# OOV-mentesítés
misclassified_texts_cleaned = [
    " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    for text in misclassified_texts
]

# Hibatípus, szöveg és valószínűség hozzáadása
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))
df_misclassified["Szöveg"] = misclassified_texts_cleaned
df_misclassified["Predikció valószínűsége"] = np.round(y_prob_all[misclassified_indices], 4)

# Duplikált szövegek eltávolítása (megtartja az első előfordulást)
df_misclassified_unique = df_misclassified.drop_duplicates(subset="Szöveg").reset_index(drop=True)

# Mentés CSV-be
df_misclassified_unique.to_csv("felrebesorolt_peldak_aggregalt_lstm.csv", index=False, encoding="utf-8")

# Megjelenítés
pd.set_option("display.max_colwidth", None)
display(df_misclassified_unique.head(20))
# Out:
#            Hiba típusa  Valódi címke  Prediktált címke  \
# 0   Hamis pozitív (FP)           0.0                 1
# 1   Hamis negatív (FN)           1.0                 0
# 2   Hamis pozitív (FP)           0.0                 1
# 3   Hamis pozitív (FP)           0.0                 1
# 4   Hamis pozitív (FP)           0.0                 1
# 5   Hamis negatív (FN)           1.0                 0
# 6   Hamis pozitív (FP)           0.0                 1
# 7   Hamis negatív (FN)           1.0                 0
# 8   Hamis pozitív (FP)           0.0                 1
# 9   Hamis pozitív (FP)           0.0                 1
# 10  Hamis pozitív (FP)           0.0                 1
# 11  Hamis negatív (FN)           1.0                 0
# 12  Hamis pozitív (FP)           0.0                 1
# 13  Hamis pozitív (FP)           0.0                 1
# 14  Hamis negatív (FN)           1.0                 0
# 15  Hamis pozitív (FP)           0.0                 1
# 16  Hamis pozitív (FP)           0.0                 1
# 17  Hamis pozitív (FP)           0.0                 1
# 18  Hamis pozitív (FP)           0.0                 1
# 19  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           'by' 'top' 'right' 'news' 'on' 'novemb' 'in' 'by' 'brian' 'hay' 'top' 'right' 'news' 'presidentelect' 'donald' 'j' 'trump' 'just' 'made' 'hi' 'decis' 'for' 'the' 'nation' 'highest' 'legal' 'offici' 'senat' 'jeff' 'session' 'of' 'alabama' 'and' 'it' 'is' 'a' 'nightmar' 'for' 'liber' 'democrat' 'in' 'fact' 'that' 'is' 'exactli' 'what' 'the' 'huffington' 'post' 'call' 'him' 'in' 'their' 'flash' 'headlin' 'moment' 'ago' 'jefferson' 'beauregard' 'session' 'iii' 'would' 'serv' 'as' 'the' 'nation' 'top' 'law' 'enforc' 'offici' 'if' 'nomin' 'by' 'trump' 'and' 'confirm' 'by' 'hi' 'fellow' 'member' 'of' 'the' 'senat' 'session' 'an' 'earli' 'trump' 'backer' 'is' 'an' 'immigr' 'hardlin' 'who' 'ha' 'been' 'in' 'the' 'senat' 'sinc' 'and' 'previous' 'serv' 'as' 'attorney' 'gener' 'for' 'the' 'state' 'of' 'alabama' 'session' 'is' 'as' 'hardlin' 'as' 'a' 'conserv' 'can' 'get' 'on' 'the' 'core' 'issu' 'of' 'the' 'trump' 'agenda' 'and' 'signal' 'to' 'that' 'trump' 'is' 'about' 'enforc' 'law' 'against' 'illeg' 'immigr' 'enforc' 'voter' 'id' 'and' 'gut' 'the' 'hardleft' 'civil' 'right' 'divis' 'at' 'the' 'depart' 'of' 'justic' 'session' 'is' 'a' 'former' 'you' 'attorney' 'for' 'the' 'southern' 'district' 'of' 'alabama' 'appoint' 'by' 'ronald' 'reagan' 'and' 'a' 'tough' 'prosecutor' 'with' 'littl' 'patienc' 'for' 'liber' 'argument' 'and' 'a' 'deep' 'respect' 'for' 'the' 'constitut' 'session' 'is' 'credit' 'with' 'craft' 'trump' 'entir' 'immigr' 'platform' 'releas' 'last' 'august' 'hi' 'plan' 'includ' 'build' 'a' 'perman' 'border' 'wall' 'includ' 'detail' 'on' 'how' 'he' 'would' 'make' 'mexico' 'pay' 'for' 'it' 'end' 'birthright' 'citizenship' 'overhaul' 'the' 'refuge' 'program' 'that' 'ha' 'overwhelm' 'america' 'heartland' 'enact' 'mandatori' 'everifi' 'to' 'block' 'illeg' 'from' 'job' 'a' 'paus' 'in' 'green' 'card' 'approv' 'to' 'allow' 'unemploy' 'american' 'a' 'chanc' 'at' 'job' 'posit' 'and' 'an' 'increas' 'in' 'salari' 'of' ...
# 1                                                                                                                                                                                                                'editor' 'note' 'the' 'follow' 'column' 'origin' 'appear' 'on' 'the' 'websit' 'us' 'defens' 'watch' 'it' 'is' 'reprint' 'with' 'permiss' 'i' 'like' 'million' 'of' 'american' 'saw' 'your' 'speech' 'at' 'the' 'dnc' 'on' 'thursday' 'night' 'i' 'wish' 'to' 'offer' 'my' 'sympathi' 'for' 'the' 'death' 'of' 'your' 'son' 'captain' 'humayun' 'khan' 'who' 'wa' 'kill' 'in' 'action' 'in' 'iraq' 'as' 'a' 'former' 'us' 'armi' 'offic' 'and' 'a' 'veteran' 'of' 'the' 'gulf' 'war' 'i' 'can' 'certainli' 'understand' 'the' 'pain' 'and' 'anguish' 'that' 'you' 'and' 'your' 'wife' 'endur' 'everi' 'day' 'your' 'son' 'die' 'save' 'the' 'live' 'of' 'hi' 'fellow' 'soldier' 'as' 'jesu' 'told' 'hi' 'discipl' 'accord' 'to' 'the' 'gospel' 'of' 'john' 'greater' 'love' 'hath' 'no' 'man' 'than' 'thi' 'that' 'a' 'man' 'lay' 'down' 'hi' 'life' 'for' 'hi' 'friend' 'captain' 'khan' 'is' 'a' 'hero' 'i' 'am' 'sure' 'the' 'soldier' 'he' 'serv' 'with' 'regard' 'him' 'as' 'one' 'i' 'know' 'you' 'and' 'your' 'wife' 'do' 'rest' 'assur' 'that' 'million' 'of' 'veteran' 'regard' 'your' 'son' 'as' 'a' 'hero' 'as' 'well' 'to' 'paraphras' 'from' 'the' 'book' 'of' 'your' 'son' 'name' 'for' 'your' 'son' 'made' 'the' 'ultim' 'sacrific' 'for' 'hi' 'countri' 'a' 'countri' 'that' 'wa' 'new' 'to' 'you' 'and' 'your' 'famili' 'and' 'one' 'which' 'you' 'openli' 'embrac' 'and' 'certainli' 'love' 'when' 'you' 'and' 'your' 'famili' 'arriv' 'to' 'america' 'from' 'pakistan' 'you' 'assimil' 'into' 'our' 'countri' 'you' 'adopt' 'american' 'way' 'learn' 'our' 'histori' 'and' 'appar' 'you' 'even' 'acquir' 'a' 'pocket' 'constitut' 'along' 'the' 'way' 'good' 'for' 'you' 'sir' 'but' 'there' 'are' 'mani' 'muslim' 'in' 'america' 'who' 'not' 'onli' 'have' 'no' 'desir' 'to' 'assimil' 'but' 'wish' 'to' 'live' 'under' 'sharia' 'law' 'that' 'is' 'unaccept' 'to' 'american' 'there' 'is' 'onli' 'one' 'law' 'of' 'the' 'land' 'that' 'is' 'the' 'you' 'constitut' 'as' 'you' 'well' 'know' 'mr' 'khan' 'we' 'live' 'in' 'violent' 'time' 'danger' 'time' 'muslim' 'from' 'isi' 'and' 'other' 'radic' 'jihadi' 'group' 'are' 'on' 'a' 'murder' 'and' 'terror' 'spree' 'across' 'the' 'globe' 'your' 'religion' 'of' 'peac' 'islam' 'is' 'anyth' 'but' 'that' 'in' 'that' 'is' 'a' 'fact' 'that' 'is' 'confirm' 'everi' 'time' 'a' 'muslim' 'shoot' 'bomb' 'behead' 'and' 'tortur' 'innoc' 'men' 'women' 'and' 'children' 'thi' 'doe' 'not' 'mean' 'that' 'everi' 'muslim' 'is' 'a' 'terrorist' 'but' 'most' 'terrorist' 'sir' 'are' 'inde' 'muslim' 'a' 'muslim' 'terrorist' 'attack' 'ha' 'becom' 'the' 'sign' 'of' 'the' 'time' 'regardless' 'of' 'what' 'the' 'feckless' 'nave' 'leftist' 'ideologu' 'barack' 'obama' 'and' 'hi' 'dimwit' 'colleagu' 'john' 'kerri' 'francoi' 'holland' 'and' 'angela' 'merkel' 'state' 'the' 'unit' 'state' 'and' 'the' 'west' 'are' 'at' 'war' 'with' 'radic' 'islam' 'it' 'is' 'the' 'job' 'of' 'the' 'presid' 'of' 'the' 'unit' 'state' 'to' 'protect' 'hi' 'nation' 'from' 'all' 'enemi' 'foreign' 'and' 'domest' 'unfortun' 'mr' 'obama' 'romantic' 'islam' 'and' 'refus' 'to' 'accept' 'realiti' 'which' 'ha' 'result' 'in' 'the' 'death' 'of' 'thousand' 'of' 'innoc' 'peopl' 'across' 'the' 'world' 'group' 'like' 'isi' 'and' 'al' 'qaeda' 'have' 'one' 'goal' 'the' 'complet' 'destruct' 'of' 'the' 'judeochristian' 'cultur' 'our' 'religion' 'and' 'our' 'way' 'of' 'life' 'mani' 'american' 'have' 'famili' 'that' 'have' 'been' 'here' 'for' 'decad' 'even' 'centuri' 'mani' 'famili' 'like' 'mine' 'have' 'rel' 'who' 'fought' 'in' 'the' 'civil' 'war' 'wwii' 'korea' 'vietnam' 'and' 'desert' 'storm' 'some' 'famili' 'have' 'rel' 'who' 'fought' 'in' 'the' 'american' 'revolut' 'we' 'do' 'not' 'plan' 'on' 'let' 'our' 'countri' 'be' 'devour' 'by' 'muslim' 'maniac' 'we' 'are' 'american' 'sir' 'and' 'not' 'unarm' 'socialist' 'european' 'zombi' 'we' 'will' 'd ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'bana' 'alabedbana' 'septemb' 'she' 'is' 'year' 'old' 'and' 'live' 'in' 'aleppo' 'syria' 'as' 'vox' 'report' 'aleppo' 'ha' 'been' 'one' 'of' 'the' 'most' 'signific' 'battlefield' 'in' 'the' 'countri' 'continu' 'fight' 'between' 'bashar' 'alassad' 'and' 'govern' 'rebel' 'sinc' 'bana' 'recent' 'creat' 'a' 'twitter' 'account' 'with' 'her' 'mother' 'to' 'final' 'show' 'the' 'world' 'what' 'life' 'is' 'like' 'for' 'those' 'in' 'their' 'wartorn' 'citi' 'in' 'an' 'interview' 'with' 'independ' 'journal' 'review' 'bana' 'said' 'the' 'violenc' 'in' 'her' 'countri' 'is' 'all' 'she' 'know' 'when' 'ask' 'to' 'describ' 'what' 'happen' 'when' 'a' 'bomb' 'goe' 'off' 'she' 'said' 'the' 'bomb' 'is' 'predict' 'it' 'alway' 'hit' 'civilian' 'place' 'so' 'there' 'is' 'alway' 'fear' 'not' 'just' 'me' 'but' 'thousand' 'live' 'in' 'fear' 'everi' 'day' 'i' 'am' 'veri' 'afraid' 'i' 'will' 'die' 'tonight' 'thi' 'bomb' 'will' 'kill' 'me' 'now' 'bana' 'aleppo' 'bana' 'alabedbana' 'octob' 'unlik' 'mani' 'children' 'bana' 'doe' 'not' 'go' 'to' 'school' 'she' 'explain' 'that' 'a' 'typic' 'day' 'doe' 'not' 'even' 'involv' 'play' 'outsid' 'we' 'just' 'keep' 'strong' 'have' 'hope' 'thi' 'is' 'what' 'remain' 'of' 'our' 'childhood' 'memori' 'bana' 'aleppo' 'bana' 'alabedbana' 'octob' 'here' 'she' 'is' 'in' 'what' 'use' 'to' 'be' 'her' 'famili' 'garden' 'which' 'is' 'now' 'just' 'a' 'pile' 'of' 'rubbl' 'thi' 'is' 'our' 'bomb' 'garden' 'i' 'use' 'to' 'play' 'on' 'it' 'now' 'nowher' 'to' 'play' 'bana' 'aleppo' 'bana' 'alabedbana' 'octob' 'as' 'you' 'can' 'see' 'life' 'in' 'aleppo' 'is' 'a' 'far' 'cri' 'from' 'what' 'mani' 'in' 'the' 'unit' 'state' 'will' 'ever' 'experi' 'bana' 'hope' 'that' 'her' 'messag' 'for' 'presid' 'barack' 'obama' 'will' 'be' 'heard' 'loud' 'and' 'clear' 'instead' 'of' 'a' 'plea' 'for' 'her' 'person' 'safeti' 'her' 'request' 'show' 'tremend' 'understand' 'of' 'the' 'broader' 'pictur' 'and' 'concern' 'for' 'all' 'involv' 'stop' 'the' 'war' 'and' 'bring' 'peac' 'pretti' 'profound' 'for' 'a' 'yearold' 'bana' 'ha' 'amass' 'a' 'twitter' 'follow' 'of' 'more' 'than' 'peopl' 'when' 'ask' 'about' 'have' 'such' 'a' 'huge' 'platform' 'to' 'share' 'aleppo' 'stori' 'she' 'gave' 'the' 'most' 'humbl' 'and' 'selfless' 'respons' 'i' 'am' 'veri' 'happi' 'and' 'good' 'one' 'day' 'peopl' 'will' 'help' 'us' 'hello' 'world' 'we' 'are' 'still' 'aliv' 'wake' 'up' 'thi' 'morn' 'aliv' 'aleppo' 'bana' 'alabedbana' 'octob' 'bana' 'possess' 'an' 'innat' 'abil' 'to' 'have' 'faith' 'in' 'a' 'situat' 'that' 'should' 'give' 'her' 'everi' 'reason' 'to' 'doubt' 'god' 'exist' 'the' 'yearold' 'admit' 'she' 'believ' 'in' 'god' 'pray' 'and' 'said' 'her' 'faith' 'ha' 'increas' 'in' 'light' 'of' 'her' 'circumst' 'but' 'she' 'doe' 'not' 'just' 'pray' 'for' 'herself' 'she' 'also' 'said' 'she' 'pray' 'everi' 'day' 'for' 'peac' 'around' 'the' 'world' 'thi' 'is' 'me' 'befor' ' ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'novemb' 'gop' 'senat' 'warn' 'negoti' 'us' 'climat' 'goal' 'might' 'not' 'last' 'a' 'group' 'of' 'republican' 'senat' 'on' 'thursday' 'advis' 'american' 'negoti' 'to' 'warn' 'their' 'intern' 'counterpart' 'that' 'presid' 'obama' 'climat' 'goal' 'might' 'not' 'surviv' 'the' 'next' 'administr' 'in' 'a' 'letter' 'to' 'secretari' 'of' 'state' 'john' 'kerri' 'the' 'senat' 'led' 'by' 'environ' 'and' 'public' 'work' 'committe' 'chairman' 'jame' 'inhof' 'note' 'that' 'american' 'commit' 'to' 'the' 'intern' 'pari' 'climat' 'deal' 'are' 'not' 'bind' 'and' 'could' 'be' 'undon' 'by' 'an' 'unfriendli' 'congress' 'or ...
# 4                                                                                                                                                          'activist' 'post' 'as' 'the' 'you' 'presidenti' 'select' 'circu' 'draw' 'to' 'a' 'close' 'the' 'unit' 'state' 'and' 'turkey' 'have' 'announc' 'a' 'new' 'plan' 'to' 'defeat' 'isi' 'the' 'same' 'terrorist' 'organ' 'both' 'countri' 'have' 'creat' 'fund' 'arm' 'and' 'facilit' 'in' 'syria' 'the' 'plan' 'revolv' 'around' 'the' 'conquer' 'occup' 'and' 'govern' 'of' 'sovereign' 'syrian' 'territori' 'in' 'the' 'east' 'most' 'notabl' 'raqqa' 'accord' 'to' 'the' 'you' 'joint' 'chief' 'of' 'staff' 'gen' 'joseph' 'dunford' 'after' 'meet' 'with' 'hi' 'turkish' 'counterpart' 'that' 'the' 'coalit' 'and' 'turkey' 'will' 'work' 'togeth' 'on' 'the' 'longterm' 'plan' 'for' 'seiz' 'hold' 'and' 'govern' 'raqqa' 'the' 'statement' 'by' 'dunford' 'seem' 'to' 'confirm' 'the' 'fact' 'that' 'the' 'unit' 'state' 'will' 'not' 'move' 'forward' 'in' 'it' 'campaign' 'for' 'raqqa' 'without' 'work' 'close' 'with' 'the' 'turk' 'who' 'are' 'themselv' 'concern' 'about' 'the' 'makeup' 'of' 'the' 'proxi' 'forc' 'destin' 'to' 'hold' 'power' 'onc' 'the' 'campaign' 'is' 'over' 'the' 'syrian' 'democrat' 'forc' 'the' 'proxi' 'of' 'choic' 'in' 'thi' 'battl' 'are' 'made' 'up' 'of' 'mani' 'kurdish' 'militia' 'and' 'fighter' 'an' 'issu' 'that' 'provid' 'much' 'worri' 'on' 'the' 'part' 'of' 'the' 'turkish' 'govern' 'as' 'cnn' 'report' 'but' 'dod' 'news' 'report' 'that' 'sunday' 'meet' 'reinforc' 'a' 'longstand' 'agreement' 'that' 'the' 'usl' 'coalit' 'would' 'not' 'move' 'ahead' 'with' 'the' 'seizur' 'of' 'raqqa' 'without' 'incorpor' 'the' 'turk' 'and' 'their' 'perspect' 'into' 'our' 'plan' 'accord' 'to' 'dunford' 'the' 'turkish' 'armi' 'said' 'in' 'a' 'statement' 'that' 'the' 'militari' 'head' 'had' 'discuss' 'the' 'method' 'of' 'a' 'common' 'struggl' 'against' 'isi' 'in' 'iraq' 'and' 'syria' 'especi' 'in' 'al' 'bab' 'and' 'raqqa' 'in' 'come' 'day' 'address' 'the' 'sensit' 'around' 'the' 'ethnic' 'makeup' 'of' 'the' 'forc' 'involv' 'in' 'the' 'oper' 'dunford' 'said' 'we' 'alway' 'knew' 'the' 'sdf' 'wa' 'not' 'the' 'solut' 'for' 'hold' 'and' 'govern' 'raqqa' 'what' 'we' 'are' 'work' 'on' 'right' 'now' 'is' 'to' 'find' 'the' 'right' 'mix' 'of' 'forc' 'for' 'the' 'oper' 'he' 'said' 'the' 'us' 'would' 'work' 'with' 'turkey' 'to' 'determin' 'the' 'composit' 'of' 'the' 'forc' 'that' 'would' 'seiz' 'and' 'govern' 'the' 'territori' 'he' 'said' 'he' 'said' 'the' 'right' 'approach' 'wa' 'for' 'local' 'to' 'lead' 'the' 'mission' 'to' 'retak' 'the' 'citi' 'and' 'run' 'it' 'after' 'isi' 'wa' 'driven' 'out' 'the' 'oper' 'need' 'a' 'predominantli' 'arab' 'and' 'sunni' 'arab' 'forc' 'he' 'said' 'accord' 'to' 'dod' 'news' 'and' 'there' 'are' 'forc' 'like' 'that' 'there' 'is' 'the' 'moder' 'syrian' 'opposit' 'the' 'vet' 'syrian' 'forc' 'and' 'the' 'free' 'syrian' 'armi' 'forc' 'and' 'there' 'is' 'some' 'initi' 'outreach' 'to' 'forc' 'in' 'raqqa' 'proper' 'dunford' 'said' 'the' 'sdf' 'were' 'move' 'south' 'to' 'isol' 'isi' 'posit' 'in' 'raqqa' 'and' 'the' 'surround' 'area' 'a' 'phase' 'that' 'would' 'take' 'month' 'essenti' 'the' 'unit' 'state' 'and' 'turkey' 'are' 'devis' 'a' 'plan' 'by' 'which' 'to' 'control' 'raqqa' 'and' 'the' 'territori' 'surround' 'it' 'by' 'use' 'proxi' 'forc' 'to' 'overthrow' 'other' 'proxi' 'forc' 'in' 'other' 'word' 'the' 'fighter' 'in' 'raqqa' 'will' 'simpli' 'undergo' 'anoth' 'name' 'chang' 'be' 'replac' 'with' 'a' 'heavi' 'kurdish' 'conting' 'and' 'act' 'as' 'a' 'care' 'place' 'chess' 'piec' 'by' 'which' 'to' 'prevent' 'the' 'syrian' 'or' 'russian' 'militari' 'from' 'liber' 'the' 'citi' 'after' 'all' 'these' 'sdf' 'forc' 'will' 'be' 'present' 'as' 'moder' 'a' 'label' 'that' 'can' 'not' 'be' 'attach' 'to' 'the' 'isi' 'fighter' 'current' 'inhabit' 'raqqa' 'raqqa' 'ha' 'act' 'as' 'the' 'isi' 'capit' 'sinc' 'the' 'mysteri' 'appear' 'of' 'the' 'group' 'two' 'year' 'ago' 'and' 'ha' 'gone' 'virtual' 'untouch' 'as' 'the ...
# 5                                                                                                                                                                       'a' 'public' 'servic' 'announc' 'from' 'your' 'friend' 'here' 'at' 'vox' 'there' 'will' 'be' 'an' 'enorm' 'amount' 'of' 'fals' 'inform' 'on' 'facebook' 'the' 'internet' 'and' 'tv' 'thi' 'elect' 'day' 'do' 'yourself' 'and' 'the' 'countri' 'a' 'favor' 'and' 'ignor' 'it' 'politician' 'have' 'alway' 'play' 'fast' 'and' 'loos' 'with' 'the' 'truth' 'cabl' 'news' 'network' 'have' 'alway' 'gotten' 'stori' 'wrong' 'and' 'the' 'internet' 'ha' 'alway' 'been' 'a' 'place' 'for' 'conspiraci' 'theori' 'and' 'mislead' 'stori' 'and' 'photo' 'but' 'the' 'campaign' 'ha' 'seen' 'an' 'unpreced' 'increas' 'in' 'the' 'sheer' 'number' 'of' 'fals' 'news' 'stori' 'be' 'share' 'on' 'facebook' 'or' 'post' 'to' 'but' 'entir' 'fake' 'news' 'site' 'run' 'by' 'young' 'peopl' 'look' 'to' 'make' 'some' 'money' 'off' 'thi' 'long' 'and' 'bitter' 'elect' 'take' 'the' 'denver' 'guardian' 'which' 'earlier' 'thi' 'month' 'ran' 'a' 'stori' 'with' 'the' 'headlin' 'fbi' 'agent' 'suspect' 'in' 'hillari' 'email' 'leak' 'found' 'dead' 'in' 'appar' 'the' 'articl' 'ricochet' 'across' 'facebook' 'and' 'gain' 'ten' 'of' 'thousand' 'of' 'share' 'despit' 'the' 'fact' 'that' 'there' 'is' 'no' 'such' 'thing' 'as' 'the' 'denver' 'guardian' 'and' 'that' 'the' 'stori' 'in' 'question' 'is' 'a' 'complet' 'fabric' 'it' 'is' 'a' 'dynam' 'that' 'deepli' 'concern' 'presid' 'barack' 'obama' 'arguabl' 'the' 'user' 'of' 'social' 'media' 'in' 'american' 'polit' 'histori' 'and' 'the' 'politician' 'who' 'ha' 'been' 'target' 'in' 'the' 'major' 'of' 'facebook' 'most' 'paranoid' 'and' 'outright' 'racist' 'viral' 'post' 'as' 'long' 'as' 'it' 'is' 'on' 'start' 'believ' 'it' 'he' 'said' 'dure' 'a' 'campaign' 'stop' 'in' 'ann' 'arbor' 'michigan' 'on' 'monday' 'it' 'creat' 'thi' 'dust' 'cloud' 'of' 'nonsens' 'to' 'make' 'matter' 'even' 'mani' 'current' 'and' 'former' 'us' 'offici' 'believ' 'that' 'russia' 'may' 'tri' 'to' 'deliber' 'spread' 'fals' 'inform' 'on' 'elect' 'day' 'to' 'make' 'wouldb' 'hillari' 'clinton' 'voter' 'stay' 'home' 'or' 'simpli' 'to' 'shake' 'overal' 'confid' 'in' 'the' 'american' 'polit' 'system' 'all' 'of' 'which' 'mean' 'that' 'if' 'you' 'see' 'or' 'read' 'someth' 'on' 'elect' 'day' 'that' 'appear' 'too' 'dramat' 'to' 'be' 'true' 'there' 'is' 'probabl' 'a' 'good' 'and' 'simpl' 'reason' 'it' 'is' 'not' 'in' 'novemb' 'fox' 'news' 'air' 'a' 'video' 'clip' 'show' 'a' 'member' 'of' 'the' 'black' 'panther' 'stand' 'outsid' 'a' 'poll' 'station' 'in' 'philadelphia' 'it' 'wa' 'a' 'singl' 'person' 'at' 'a' 'singl' 'poll' 'station' 'in' 'a' 'heavili' 'black' 'heavili' 'democrat' 'area' 'but' 'fox' 'anchor' 'strongli' 'suggest' 'that' 'it' 'wa' 'part' 'of' 'a' 'broader' 'pattern' 'of' 'voter' 'intimid' 'by' 'milit' 'determin' 'to' 'stop' 'nomine' 'mitt' 'romney' 'the' 'segment' 'wa' 'frequent' 'throughout' 'the' 'day' 'four' 'year' 'it' 'is' 'certainli' 'possibl' 'that' 'fox' 'news' 'or' 'a' 'leftlean' 'station' 'like' 'msnbc' 'will' 'find' 'a' 'similar' 'type' 'of' 'clip' 'and' 'present' 'it' 'in' 'a' 'way' 'that' 'is' 'deliber' 'mislead' 'amazingli' 'though' 'that' 'could' 'liter' 'be' 'the' 'least' 'of' 'our' 'problem' 'a' 'much' 'bigger' 'concern' 'is' 'the' 'prolifer' 'of' 'entir' 'fake' 'news' 'site' 'with' 'entir' 'fake' 'stori' 'often' 'oper' 'by' 'entrepreneur' 'live' 'oversea' 'a' 'buzzfe' 'articl' 'earlier' 'thi' 'month' 'found' 'that' 'young' 'peopl' 'in' 'the' 'macedonian' 'town' 'of' 'popul' 'had' 'creat' 'more' 'than' 'protrump' 'news' 'site' 'run' 'post' 'everi' 'day' 'that' 'are' 'aggreg' 'or' 'complet' 'plagiar' 'from' 'fring' 'and' 'rightw' 'site' 'in' 'the' 'us' 'to' 'take' 'one' 'exampl' 'from' 'the' 'stori' 'a' 'websit' 'call' 'post' 'an' 'articl' 'with' 'the' 'headlin' 'hillari' 'clinton' 'in' 'i' 'would' 'like' 'to' 'see' 'peopl' 'like' 'donald' 'trump' 'run' 'for' 'offic' 'they' 'are' 'honest' 'and'  ...
# 6                                                                                                                                                                                                                                                                                                'but' 'wait' 'wasn' 't' 'the' 'muslim' 'brotherhood' 's' 'arab' 'spring' 'sharia' 'law' 'for' 'all' 'egyptian' 'suppos' 'to' 'be' 'a' 'good' 'thing' 'an' 'egyptian' 'court' 'sentenc' 'moham' 'leader' 'of' 'the' 'outlaw' 'muslim' 'brotherhood' 'and' 'other' 'senior' 'member' 'of' 'the' 'group' 'to' 'death' 'for' 'incit' 'chao' 'and' 'violenc' 'and' 'gave' 'a' 'life' 'term' 'to' 'a' 'citizen' 'for' 'tie' 'to' 'the' 'men' 'were' 'among' 'thousand' 'of' 'peopl' 'detain' 'after' 'freeli' 'elect' 'islamist' 'presid' 'moham' 'mursi' 'wa' 'toppl' 'in' 'by' 'the' 'militari' 'under' 'abdel' 'fattah' 'alsisi' 'who' 'is' 'now' 'describ' 'the' 'brotherhood' 'as' 'a' 'major' 'secur' 'threat' 'the' 'group' 'say' 'it' 'is' 'commit' 'to' 'peac' 'activ' 'and' 'had' 'noth' 'to' 'do' 'with' 'islamist' 'milit' 'violenc' 'in' 'egypt' 'sinc' 'mursi' 's' 'fall' 'follow' 'mass' 'protest' 'against' 'hi' 's' 'mass' 'trial' 'of' 'brotherhood' 'member' 'and' 'peopl' 'accus' 'of' 'link' 'to' 'the' 'group' 'as' 'well' 'as' 'it' 'tough' 'crackdown' 'on' 'islamist' 'and' 'liber' 'opposit' 'alik' 'have' 'drawn' 'intern' 'critic' 'of' 'it' 'judici' 'system' 'and' 'human' 'right' 'sentenc' 'pronounc' 'at' 'a' 'televis' 'court' 'session' 'on' 'saturday' 'can' 'be' 'appeal' 'befor' 'egypt' 's' 'highest' 'civilian' 'court' 'in' 'a' 'process' 'that' 'could' 'take' 'year' 'to' 'reach' 'a' 'final' 'citizen' 'moham' 'wa' 'sentenc' 'to' 'life' 'in' 'jail' 'for' 'support' 'the' 'veteran' 'islamist' 'movement' 'and' 'transmit' 'fals' 'news' 'he' 'is' 'the' 'son' 'of' 'brotherhood' 'preacher' 'salah' 'who' 'wa' 'among' 'those' 'sentenc' 'to' 'one' 'of' 'the' 'defens' 'lawyer' 'condemn' 'the' 'verdict' 'the' 'court' 'did' 'not' 'differenti' 'between' 'the' 'defend' 'and' 'put' 'them' 'all' 'in' 'the' 'same' 'basket' 'he' 'told' 'report' 'at' 'the' 'courthous' 'none' 'of' 'the' 'defend' 'were' 'present' 'dure' 'the' 'is' 'the' 'brotherhood' 's' 'gener' 'guid' 'and' 'ha' 'alreadi' 'been' 'sentenc' 'to' 'sever' 'death' 'and' 'life' 'sentenc' 'hi' 'deputi' 'wa' 'given' 'a' 'life' 'sentenc' 'on' 'saturday' 'oper' 'room' 'group' 'say' 'egypt' 'where' 'a' 'popular' 'upris' 'toppl' 'veteran' 'autocrat' 'hosni' 'mubarak' 'in' 'and' 'start' 'year' 'of' 'polit' 'turmoil' 'is' 'now' 'crack' 'down' 'on' 'all' 'dissent' 'sisi' 'say' 'stabil' 'is' 'need' 'to' 'reviv' 'the' 'shatter' 'advoc' 'have' 'critic' 'a' 'you' 'decis' 'to' 'end' 'a' 'freez' 'on' 'militari' 'aid' 'to' 'cairo' 'say' 'is' 'put' 'human' 'right' 'on' 'the' 'the' 'unit' 'state' 'ha' 'said' 'the' 'decis' 'to' 'end' 'the' 'freez' 'wa' 'in' 'the' 'interest' 'of' 'nation' 'arrest' 'in' 'august' 'had' 'been' 'on' 'hunger' 'strike' 'while' 'in' 'prison' 'he' 'deserv' 'the' 'punish' 'becaus' 'of' 'the' 'money' 'and' 'instruct' 'from' 'the' 'brotherhood' 'which' 'were' 'found' 'with' 'him' 'and' 'for' 'spread' 'chao' 'and' 'horror' 'in' 'societi' 'presid' 'judg' 'moham' 'told' 'moham' 'a' 'rel' 'of' 'the' 'famili' 'said' 'they' 'would' 'appeal' 'the' 'verdict' 'it' 'wa' 'a' 'farc' 'trial' 'of' 'the' 'first' 'class' 'none' 'of' 'the' 'defend' 'attend' 'the' 'session' 'she' 'told' 'reuter' 'by' 'websit' 'call' 'for' 'moham' 's' 'releas' 'say' 'he' 'wa' 'not' 'a' 'member' 'of' 'the' 'brotherhood' 'describ' 'him' 'as' 'a' 'peac' 'activist' 'who' 'wa' 'involv' 'in' 'youth' 'event' 'and' 'chariti' 'the' 'websit' 'show' 'pictur' 'of' 'him' 'lie' 'on' 'a' 'stretcher' 'while' 'in' 's' 'case' 'wa' 'known' 'in' 'local' 'media' 'as' 'the' 'oper' 'room' 'trial' 'thi' 'is' 'in' 'refer' 'to' 'a' 'sitin' 'at' 'squar' 'in' 'in' 'which' 'hundr' 'of' 'peopl' 'protest' 'at' 'the' 'overthrow' 'of' 'mursi' 'were' 'kill' 'when' 'secur' 'forc' 'tri' 'to' 'clear' 'the' ' ...
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    'michael' 'brown' 'parent' 'plan' 'to' 'bring' 'a' 'civil' 'lawsuit' 'for' 'the' 'wrong' 'death' 'of' 'their' 'son' 'against' 'darren' 'wilson' 'and' 'the' 'citi' 'of' 'fe ...
# 8   'trump' 's' 'choic' 'of' 'govern' 'outspoken' 'conserv' 'and' 'former' 'texa' 'governor' 'rick' 'perri' 'for' 'secretari' 'of' 'energi' 'is' 'sure' 'to' 'ruffl' 'the' 'feather' 'of' 'leftist' 'environmentalist' 'not' 'just' 'in' 'america' 'but' 'around' 'the' 'world' 'rick' 'perri' 'presidentelect' 'donald' 'trump' 's' 'choic' 'for' 'energi' 'secretari' 'ha' 'close' 'tie' 'to' 'the' 'texa' 'oil' 'industri' 'and' 'ha' 'corpor' 'role' 'in' 'two' 'petroleum' 'compani' 'push' 'to' 'get' 'govern' 'approv' 'for' 'the' 'propos' 'mile' 'crude' 'oil' 'pipelin' 'that' 'ha' 'stoke' 'mass' 'protest' 'in' 'north' 's' 'current' 'role' 'as' 'board' 'director' 'at' 'energi' 'transfer' 'partner' 'lp' 'and' 'also' 'at' 'sunoco' 'logist' 'partner' 'lp' 'which' 'jointli' 'develop' 'the' 'controversi' 'dakota' 'access' 'pipelin' 'project' 'is' 'a' 'strong' 'indic' 'of' 'the' 'industri' 'sentiment' 'that' 'will' 'like' 'take' 'root' 'at' 'the' 'energi' 'depart' 'under' 'hi' 'oversight' 'perri' 'is' 'close' 'to' 'texa' 'energi' 'industri' 'execut' 'and' 'hi' 'polit' 'campaign' 'includ' 'two' 'abort' 'presidenti' 'campaign' 'benefit' 'substanti' 'from' 'their' 'announc' 'hi' 'choic' 'of' 'perri' 'in' 'an' 'earli' 'morn' 'releas' 'wednesday' 'from' 'trump' 'tower' 'in' 'new' 'call' 'perri' 'one' 'of' 'the' 'most' 'success' 'governor' 'in' 'modern' 'histori' 'have' 'led' 'texa' 'through' 'a' 'sustain' 'period' 'of' 'econom' 'growth' 'and' 'prosper' 'by' 'develop' 'the' 'state' 's' 'energi' 'resourc' 'and' 'infrastructur' 'and' 'make' 'lowcost' 'energi' 'avail' 'to' 'compani' 'and' 'famili' 'it' 'is' 'a' 'tremend' 'honor' 'to' 'be' 'select' 'to' 'serv' 'as' 'secretari' 'of' 'energi' 'by' 'presidentelect' 'trump' 'perri' 'said' 'i' 'am' 'deepli' 'humbl' 'by' 'hi' 'trust' 'in' 'me' 'perri' 's' 'close' 'relat' 'with' 'energi' 'execut' 'and' 'hi' 'longtim' 'depend' 'on' 'them' 'for' 'polit' 'contribut' 'signal' 'an' 'abrupt' 'chang' 'of' 'cours' 'at' 'the' 'energi' 'depart' 'perri' 'is' 'expect' 'to' 'welcom' 'the' 'pipelin' 'and' 'similar' 'project' 'set' 'an' 'opendoor' 'polici' 'for' 'oil' 'industri' 'interest' 'and' 'possibl' 'tear' 'down' 'the' 'depart' 'altogeth' 'fox' 'he' 'said' 'farewel' 'to' 'the' 'texa' 'legislatur' 'in' 'januari' 'rick' 'perri' 'couldn' 't' 'help' 'but' 'reflect' 'on' 'how' 'energi' 'technolog' 'and' 'polici' 'had' 'transform' 'the' 'state' 's' 'landscap' 'and' 'fuel' 'it' 'economi' 'dure' 'hi' 'record' 'year' 'as' 'governor' 'today' 'horizont' 'slant' 'drill' 'is' 'tap' 'oil' 'and' 'ga' 'field' 'unreach' 'just' 'a' 'few' 'year' 'ago' 'he' 'said' 'go' 'on' 'to' 'scold' 'new' 'york' 'for' 'ban' 'hydraul' 'fractur' 'in' 'texa' 'we' 'have' 'chosen' 'job' 'we' 'have' 'chosen' 'energi' 'secur' 'and' 'we' 'will' 'one' 'day' 'end' 'america' 's' 'depend' 'on' 'hostil' 'sourc' 'of' 'foreign' 'energi' 'although' 'texa' 'longestserv' 'governor' 'wa' 'perhap' 'unsurprisingli' 'and' 'ga' 'dure' 'hi' 'tenur' 'he' 'didn' 't' 'simpli' 'nod' 'to' 'those' 'icon' 'stapl' 'fuel' 'you' 'can' 'be' 'proud' 'that' 'texa' 'produc' 'more' 'energi' 'from' 'wind' 'turbin' 'than' 'all' 'but' 'five' 'countri' 'he' 'perri' 'left' 'a' 'nuanc' 'energi' 'legaci' 'includ' 'overse' 'boom' 'in' 'fossil' 'fuel' 'and' 'renew' 'dure' 'hi' 'time' 'in' 'austin' 'texa' 'is' 'now' 'the' 'no' 'you' 'produc' 'of' 'both' 'natur' 'ga' 'and' 'wind' 'energi' 'now' 'he' 'is' 'pois' 'to' 'take' 'hi' 'experi' 'to' 'where' 'presidentelect' 'donald' 'trump' 'ha' 'chosen' 'him' 'as' 'you' 'secretari' 'of' 'energi' 'the' 'appoint' 'would' 'mark' 'a' 'full' 'repair' 'in' 'perri' 's' 'relationship' 'with' 'trump' 'whom' 'he' 'call' 'a' 'cancer' 'on' 'conservat' 'last' 'year' 'while' 'the' 'two' 'men' 'were' 'in' 'a' 'crowd' 'field' 'for' 'the' 'republican' 'presidenti' 'confirm' 'perri' 'would' 'becom' 'the' 'third' 'texan' 'to' 'land' 'that' 'job' 'which' 'involv' 'overse' 'energi' 'research' 'and' 'polici' 'with' 'ramif' 'on' 'the' 'economi' 'environ' 'and' 'nation' 'secur' 'and'  ...
# 9                                                                                                                                                                                                                        'after' 'nearli' 'a' 'year' 'of' 'caus' 'hysteria' 'mass' 'travel' 'cancel' 'and' 'unnecessari' 'abort' 'it' 'final' 'daunt' 'to' 'journalist' 'and' 'expert' 'that' 'the' 'zika' 'viru' 'is' 'harmless' 'it' 'can' 'caus' 'a' 'veri' 'minor' 'two' 'day' 'of' 'a' 'low' 'fever' 'and' 'uncomfort' 'feel' 'for' 'a' 'quarter' 'of' 'those' 'infect' 'that' 'is' 'all' 'it' 'doe' 'not' 'becaus' 'as' 'wa' 'claim' 'by' 'sensationalist' 'in' 'the' 'media' 'and' 'variou' 'selfserv' 'scientist' 'birth' 'defect' 'like' 'microcephali' 'we' 'told' 'you' 'so' 'in' 'februari' 'we' 'wrote' 'the' 'zika' 'viru' 'is' 'harmless' 'who' 'then' 'benefit' 'from' 'thi' 'media' 'panic' 'the' 'piec' 'refere' 'to' 'a' 'congression' 'research' 'servic' 'report' 'and' 'variou' 'sound' 'scientif' 'paper' 'it' 'conclud' 'there' 'is' 'absolut' 'no' 'sane' 'reason' 'for' 'the' 'scari' 'headlin' 'and' 'the' 'panic' 'they' 'viru' 'is' 'harmless' 'it' 'is' 'possibl' 'but' 'seem' 'for' 'now' 'veri' 'unlik' 'that' 'it' 'affect' 'some' 'unborn' 'children' 'there' 'is' 'absolut' 'no' 'reason' 'to' 'be' 'concern' 'about' 'it' 'the' 'artifici' 'media' 'panic' 'continu' 'and' 'huge' 'amount' 'of' 'money' 'were' 'pour' 'into' 'danger' 'insecticid' 'to' 'kill' 'mosquito' 'and' 'import' 'pollin' 'that' 'did' 'not' 'do' 'ani' 'harm' 'inde' 'gener' 'use' 'of' 'some' 'of' 'these' 'insecticid' 'like' 'were' 'the' 'veri' 'becaus' 'of' 'a' 'blip' 'in' 'case' 'in' 'northeastern' 'brazil' 'in' 'march' 'we' 'wrote' 'read' 'about' 'zika' 'may' 'hurt' 'your' 'brain' 'we' 'list' 'sensat' 'news' 'headlin' 'about' 'potenti' 'catastroph' 'relat' 'to' 'a' 'zika' 'epidem' 'the' 'common' 'factor' 'of' 'those' 'panic' 'creat' 'media' 'wave' 'all' 'those' 'headlin' 'includ' 'the' 'miracul' 'littl' 'word' 'may' 'the' 'piec' 'were' 'pure' 'specul' 'with' 'some' 'quot' 'thi' 'or' 'that' 'expert' 'who' 'wa' 'hunt' 'for' 'research' 'fund' 'or' 'lobbi' 'for' 'some' 'pharmaceut' 'or' 'pesticid' 'conglomer' 'in' 'june' 'we' 'ad' 'zika' 'viru' 'doe' 'not' 'becaus' 'birth' 'defect' 'fight' 'it' 'probabl' 'doe' 'new' 'seriou' 'research' 'found' 'what' 'some' 'peopl' 'in' 'brazil' 'had' 'suspect' 'from' 'the' 'veri' 'start' 'of' 'the' 'small' 'and' 'strictli' 'local' 'limit' 'jump' 'in' 'case' 'in' 'brazil' 'doctor' 'in' 'the' 'zika' 'affect' 'area' 'in' 'brazil' 'point' 'out' 'that' 'the' 'real' 'becaus' 'of' 'somewhat' 'increas' 'microcephali' 'in' 'the' 'region' 'wa' 'probabl' 'the' 'insecticid' 'use' 'to' 'kill' 'mosquito' 'larva' 'in' 'drink' 'water' 'the' 'brazilian' 'doctor' 'note' 'that' 'the' 'area' 'of' 'northeast' 'brazil' 'that' 'had' 'wit' 'the' 'greatest' 'number' 'of' 'microcephali' 'case' 'match' 'with' 'area' 'where' 'is' 'ad' 'to' 'drink' 'water' 'in' 'an' 'effort' 'to' 'combat' 'mosquito' 'is' 'report' 'to' 'caus' 'in' 'mosquito' 'larva' 'and' 'ha' 'been' 'ad' 'to' 'drink' 'water' 'in' 'the' 'region' 'for' 'the' 'past' 'month' 'is' 'produc' 'by' 'a' 'chemic' 'an' 'import' 'japanes' 'poison' 'giant' 'it' 'wa' 'therefor' 'unsurpris' 'that' 'the' 'new' 'york' 'time' 'and' 'other' 'call' 'the' 'brazilian' 'doctor' 'report' 'a' 'conspiraci' 'theori' 'and' 'trot' 'out' 'some' 'expert' 'to' 'debunk' 'it' 'but' 'scientist' 'at' 'the' 'new' 'england' 'complex' 'system' 'institut' 'also' 'research' 'the' 'thesi' 'they' 'found' 'is' 'an' 'analog' 'of' 'juvenil' 'hormon' 'which' 'correspond' 'in' 'mammal' 'to' 'regulatori' 'molecul' 'includ' 'acid' 'a' 'vitamin' 'a' 'with' 'which' 'it' 'ha' 'and' 'whose' 'applic' 'dure' 'develop' 'caus' 'microcephali' 'test' 'of' 'by' 'the' 'manufactur' 'wide' 'quot' 'as' 'give' 'no' 'evid' 'for' 'development' 'toxic' 'actual' 'found' 'some' 'evid' 'for' 'such' 'an' 'effect' 'includ' 'low' 'brain' 'mass' 'and' 'format' 'of' 'the' 'cerebr' 'rat' 'pup' 'final' ' ...
# ...
# 17                                                                                                                                                                                                                                               'dougla' 'murray' 'author' 'of' 'the' 'strang' 'death' 'of' 'europ' 'immigr' 'ident' 'islam' 'give' 'a' 'stun' 'account' 'of' 'the' 'self' 'murder' 'or' 'europ' 'in' 'the' 'death' 'of' 'europ' 'articl' 'publish' 'by' 'have' 'travel' 'to' 'the' 'place' 'where' 'migrant' 'continu' 'to' 'land' 'and' 'the' 'place' 'where' 'they' 'keep' 'end' 'up' 'everywher' 'i' 'have' 'gone' 'i' 'have' 'come' 'to' 'the' 'same' 'conclus' 'our' 'contin' 'is' 'in' 'the' 'process' 'of' 'the' 'daytoday' 'distract' 'of' 'life' 'and' 'polit' 'it' 'is' 'easi' 'to' 'forget' 'thi' 'biggest' 'event' 'of' 'our' 'time' 'all' 'pale' 'into' 'insignific' 'besid' 'the' 'stori' 'of' 'the' 'loss' 'by' 'european' 'of' 'the' 'onli' 'place' 'we' 'had' 'to' 'call' 'thi' 'countri' 'doe' 'have' 'a' 'debat' 'about' 'immigr' 'it' 'is' 'minuscul' 'it' 'tend' 'to' 'focu' 'on' 'calai' 'the' 'british' 'public' 'see' 'footag' 'of' 'peopl' 'sit' 'in' 'makeshift' 'tent' 'or' 'hurl' 'missil' 'into' 'the' 'road' 'to' 'slow' 'the' 'truck' 'down' 'so' 'they' 'can' 'board' 'them' 'and' 'break' 'into' 'time' 'actor' 'celebr' 'and' 'politician' 'head' 'to' 'calai' 'and' 'visit' 'the' 'camp' 'they' 'return' 'to' 'tell' 'the' 'british' 'public' 'that' 'it' 'must' 'be' 'more' 'and' 'argument' 'they' 'make' 'is' 'human' 'it' 'is' 'an' 'understand' 'reaction' 'to' 'human' 'miseri' 'but' 'it' 'is' 'a' 'core' 'part' 'of' 'our' 'societi' 's' 'suicid' 'that' 'exampl' 'of' 'calai' 'befor' 'the' 'latest' 'clearanc' 'of' 'the' 'camp' 'there' 'were' 'about' 'peopl' 'live' 'there' 'none' 'of' 'them' 'should' 'have' 'been' 'therebi' 'be' 'there' 'they' 'had' 'alreadi' 'broken' 'everi' 'one' 'of' 'the' 'rule' 'that' 'our' 'contin' 'put' 'in' 'place' 'which' 'demand' 'they' 'seek' 'asylum' 'in' 'the' 'first' 'countri' 'of' 'arriv' 'almost' 'nobodi' 'arriv' 'into' 'franc' 'these' 'peopl' 'have' 'land' 'in' 'greec' 'or' 'itali' 'and' 'made' 'their' 'way' 'yet' 'still' 'the' 'celebr' 'and' 'other' 'pick' 'at' 'our' 'conscienc' 'can' 'we' 'not' 'be' 'gener' 'and' 'at' 'least' 'let' 'in' 'the' 'peopl' 'who' 'are' 'there' 'it' 'is' 'wholli' 'understand' 'and' 'also' 'illinform' 'thi' 'year' 's' 'easter' 'weekend' 'alon' 'about' 'peopl' 'were' 'pick' 'up' 'between' 'the' 'coast' 'of' 'north' 'africa' 'and' 'the' 'south' 'of' 'were' 'describ' 'as' 'everyon' 'alway' 'is' 'as' 'be' 'rescu' 'in' 'fact' 'what' 'happen' 'what' 'ha' 'been' 'happen' 'for' 'year' 'is' 'that' 'each' 'day' 'boat' 'fill' 'with' 'migrant' 'set' 'out' 'from' 'north' 'the' 'height' 'of' 'the' 'migrat' 'crisi' 'of' 'when' 'germani' 's' 'chancellor' 'angela' 'merkel' 'open' 'up' 'the' 'door' 'of' 'europ' 'to' 'the' 'world' 'the' 'whole' 'contin' 'began' 'to' 'in' 'realiti' 'that' 'flood' 'of' 'million' 'into' 'europ' 'onli' 'sped' 'up' 'a' 'process' 'that' 'had' 'been' 'under' 'way' 'for' 'year' 'ever' 'sinc' 'the' 'postwar' 'period' 'european' 'govern' 'had' 'encourag' 'migrant' 'worker' 'to' 'come' 'first' 'as' 'chancellor' 'merkel' 'herself' 'admit' 'in' 'a' 'speech' 'in' 'they' 'expect' 'the' 'worker' 'to' 'return' 'home' 'but' 'they' 'didn' 't' 'they' 'stay' 'as' 'did' 'the' 'flow' 'after' 'that' 'and' 'the' 'one' 'for' 'decad' 'after' 'thatth' 'govern' 'of' 'countri' 'such' 'as' 'our' 'fail' 'to' 'get' 'anyth' 'right' 'all' 'their' 'predict' 'were' 'wrong' 'for' 'decad' 'they' 'were' 'wrong' 'that' 'peopl' 'would' 'stay' 'for' 'onli' 'a' 'short' 'time' 'wrong' 'to' 'think' 'that' 'they' 'would' 'not' 'continu' 'to' 'come' 'in' 'larg' 'that' 'they' 'might' 'not' 'want' 'to' 'bring' 'their' 'extend' 'famili' 'to' 'join' 'them' 'and' 'wrong' 'to' 'think' 'that' 'onc' 'the' 'tap' 'wa' 'turn' 'on' 'anyth' 'but' 'veri' 'radic' 'action' 'could' 'ever' 'bring' 'the' 'number' 'to' 'a' 'control' 'the' 'cours' ' ...
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 19                                                                                                                                                                                                                                                                                                                                                              'perhap' 'the' 'in' 'a' 'catalog' 'load' 'with' 'bleak' 'album' 'kid' 'a' 'close' 'with' 'motion' 'pictur' 'soundtrack' 'a' 'song' 'that' 'obliqu' 'suggest' 'the' 'end' 'of' 'a' 'relationship' 'but' 'is' 'more' 'broadli' 'about' 'disillusion' 'and' 'death' 'it' 'is' 'not' 'like' 'the' 'movi' 'singer' 'thom' 'york' 'lament' 'they' 'fed' 'us' 'on' 'littl' 'white' 'lie' 'ha' 'provid' 'the' 'music' 'accompani' 'for' 'sinc' 'the' 'second' 'episod' 'when' 'no' 'surpris' 'scroll' 'through' 'the' 'player' 'piano' 'as' 'she' 'unsuccess' 'solicit' 'a' 'guest' 'in' 'thi' 'week' 'episod' 'wake' 'up' 'to' 'an' 'instrument' 'version' 'fake' 'plastic' 'tree' 'which' 'continu' 'as' 'she' 'walk' 'to' 'work' 'unfaz' 'by' 'the' 'mundan' 'spectacl' 'of' 'a' 'bloodi' 'shootout' 'on' 'the' 'street' 'behind' 'her' 'when' 'motion' 'pictur' 'soundtrack' 'play' 'it' 'again' 'serv' 'as' 'a' 'kind' 'of' 'as' 'a' 'technician' 'give' 'her' 'a' 'guid' 'tour' 'through' 'the' 'westworld' 'sausag' 'factori' 'wit' 'the' 'creation' 'and' 'process' 'of' 'synthet' 'be' 'have' 'come' 'to' 'realiz' 'she' 'is' 'one' 'of' 'them' 'the' 'steadi' 'diet' 'of' 'white' 'lie' 'as' 'it' 'were' 'is' 'over' 'it' 'is' 'the' 'most' 'haunt' 'and' 'affect' 'sequenc' 'the' 'show' 'ha' 'yet' 'produc' 'the' 'obviou' 'reason' 'the' 'robot' 'of' 'westworld' 'draw' 'more' 'sympathi' 'than' 'the' 'human' 'is' 'their' 'vulner' 'the' 'fact' 'that' 'their' 'daili' 'live' 'requir' 'a' 'passiv' 'accept' 'of' 'the' 'abus' 'terror' 'and' 'tragedi' 'that' 'is' 'heap' 'upon' 'them' 'but' 'peek' 'behind' 'the' 'curtain' 'hint' 'at' 'a' 'more' 'fundament' 'becaus' 'as' 'the' 'engin' 'coder' 'and' 'technician' 'dismantl' 'and' 'reconstruct' 'the' 'host' 'the' 'show' 'constantli' 'forc' 'us' 'to' 'reflect' 'on' 'how' 'we' 'human' 'are' 'compos' 'too' 'how' 'mani' 'of' 'our' 'own' 'action' 'are' 'script' 'how' 'much' 'can' 'we' 'realli' 'improvis' 'and' 'what' 'purpos' 'did' 'our' 'own' 'creator' 'have' 'in' 'mind' 'for' 'us' 'if' 'we' 'were' 'put' 'through' 'the' 'full' 'diagnost' 'test' 'experi' 'here' 'perhap' 'the' 'result' 'would' 'be' 'equal' 'unsettl' 'the' 'tour' 'signal' 'a' 'tip' 'point' 'for' 'the' 'season' 'and' 'the' 'seri' 'at' 'larg' 'the' 'world' 'as' 'ha' 'understood' 'it' 'is' 'gone' 'and' 'more' 'pain' 'still' 'she' 'learn' 'that' 'neither' 'she' 'nor' 'it' 'wa' 'ever' 'authent' 'she' 'see' 'dead' 'bodi' 'get' 'hose' 'off' 'befor' 'the' 'tech' 'throw' 'them' 'on' 'the' 'slab' 'and' 'them' 'she' 'see' 'buffalo' 'and' 'deer' 'get' 'their' 'movement' 'calibr' 'in' 'glass' 'pen' 'she' 'see' 'the' 'program' 'interact' 'like' 'lesbian' 'and' 'a' 'she' 'see' 'a' 'design' 'liter' 'facial' 'detail' 'and' 'final' 'she' 'see' 'her' 'life' 'and' 'memori' 'edit' 'into' 'a' 'slick' 'advertis' 'for' 'real' 'peopl' 'to' 'live' 'without' 'limit' 'for' 'it' 'is' 'simultan' 'a' 'death' 'and' 'a' 'the' 'end' 'of' 'her' 'old' 'life' 'or' 'live' 'given' 'the' 'sloppi' 'accumul' 'of' 'past' 'construct' 'and' 'the' 'begin' 'of' 'a' 'new' 'one' 'what' 'happen' 'to' 'in' 'episod' 'is' 'a' 'variat' 'of' 'what' 'happen' 'in' 'the' 'previou' 'episod' 'to' 'who' 'gun' 'down' 'a' 'pack' 'of' 'outlaw' 'and' 'chose' 'to' 'pursu' 'a' 'destini' 'more' 'assert' 'than' 'her' 'loop' 'both' 'women' 'are' 'now' 'though' 'ha' 'the' 'extra' 'advantag' 'of' 'be' 'abl' 'to' 'manipul' 'her' 'attribut' 'matrix' 'dial' 'down' 'her' 'sens' 'of' 'loyalti' 'and' 'her' 'abil' 'to' 'feel' 'pain' 'while' 'amp' 'up' 'her' 'bulk' 'which' 'will' 'make' 'her' 'smarter' 'and' 'more' 'power' 'than' 'the' 'human' 'who' 'built' 'her' 'have' 'play' 'the' 'victim' 'for' 'year' 'in' 'ha' 'essenti' 'tu ...
#
#     Predikció valószínűsége
# 0                    0.5245
# 1                    0.0281
# 2                    0.9873
# 3                    0.8259
# 4                    0.9253
# 5                    0.0493
# 6                    0.8613
# 7                    0.0144
# 8                    0.5115
# 9                    0.9864
# 10                   0.6930
# 11                   0.0074
# 12                   0.9672
# 13                   0.7945
# 14                   0.3862
# 15                   0.5782
# 16                   0.8697
# 17                   0.8211
# 18                   0.8550
# 19                   0.4924

# %% [markdown]
# # GRU MODELL 4. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ### Modell lefuttatása

# %%
# GRU Modell

def create_gru_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),  # Ensure within vocab limit
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings  # Toggle trainability
    )(text_input)

    # GRU rétegek
    gru_out = GRU(128, return_sequences=True, dropout=0.3)(text_embedding)
    gru_out = Dropout(0.3)(gru_out)  # Dropout réteg az első GRU után
    gru_out = GRU(64,return_sequences=True, dropout=0.3)(gru_out)
    gru_out = Dropout(0.3)(gru_out)
    gru_out = GRU(32, dropout=0.3)(gru_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(gru_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása (Trainable)
gru_trainable = create_gru_model(trainable_embeddings=True)

gru_trainable.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)              │ (None, 600)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_7 (Embedding)              │ (None, 600, 300)            │       7,500,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 600, 128)            │         165,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 600, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 600, 64)             │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 600, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 32)                  │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,711,809 (29.42 MB)
#  Trainable params: 7,711,809 (29.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Inicializálás
n_runs = 5
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
test_losses, test_accuracies = [], []

all_preds, all_probs, all_true = [], [], []

results2 = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': []
}

# Többszöri futtatás
for i in range(n_runs):
    print(f"\nFutás {i+1}/{n_runs}")

    gru_trainable = create_gru_model(trainable_embeddings=True)

    history = gru_trainable.fit(
        padded_train_final, y_train_final,
        validation_data=(padded_val, y_val),
        epochs=10,
        batch_size=64,
        callbacks=[early_stopping],
        verbose=0
    )

    # Tanulási görbékhez szükséges adatok
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])
    train_accuracies.append(history.history['accuracy'])
    val_accuracies.append(history.history['val_accuracy'])

    # Teszt pontosság/veszteség
    loss, acc = gru_trainable.evaluate(padded_test, y_test, verbose=0)
    test_losses.append(loss)
    test_accuracies.append(acc)

    # Predikció
    gru_y_prob = gru_trainable.predict(padded_test)
    gru_y_pred = (gru_y_prob > 0.5).astype(int)

    all_preds.append(gru_y_pred.flatten())
    all_probs.append(gru_y_prob.flatten())
    all_true.append(y_test.flatten())

    # Metrikák
    results2['accuracy'].append(accuracy_score(y_test, gru_y_pred))
    results2['precision'].append(precision_score(y_test, gru_y_pred))
    results2['recall'].append(recall_score(y_test, gru_y_pred))
    results2['f1_score'].append(f1_score(y_test, gru_y_pred))


# Aggregált adatok
y_true_all = np.concatenate(all_true)
y_pred_all = np.concatenate(all_preds)
y_prob_all = np.concatenate(all_probs)
padded_test_repeated = np.tile(padded_test, (n_runs, 1))
# Out:
# Futás 1/5
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step
#
# Futás 2/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step
#
# Futás 3/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step
#
# Futás 4/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step
#
# Futás 5/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 465/465 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step

# %%
df_metrics2 = pd.DataFrame(results2)
print("\n Metrikák statisztikája (10 futás):")
print(df_metrics2.describe().T)
# Out:
#  Metrikák statisztikája (10 futás):
#            count      mean       std       min       25%       50%       75%  \
# accuracy     5.0  0.970887  0.001827  0.968145  0.970161  0.971237  0.972043
# precision    5.0  0.971663  0.002865  0.968022  0.969268  0.972634  0.973996
# recall       5.0  0.970081  0.005122  0.961559  0.969758  0.971640  0.972446
# f1_score     5.0  0.970860  0.001904  0.967934  0.970229  0.971194  0.972125
#
#                 max
# accuracy   0.972849
# precision  0.974394
# recall     0.975000
# f1_score   0.972817

# %% [markdown]
# ## GRU modell ábrák

# %%
# Egységesítés (early stopping miatt lehetnek eltérések)
min_epochs = min(len(run) for run in train_losses)

train_losses_np = np.array([run[:min_epochs] for run in train_losses])
val_losses_np = np.array([run[:min_epochs] for run in val_losses])
train_accuracies_np = np.array([run[:min_epochs] for run in train_accuracies])
val_accuracies_np = np.array([run[:min_epochs] for run in val_accuracies])
epochs = min_epochs

# Ábrák
plt.figure(figsize=(12, 5))

# Veszteség
plt.subplot(1, 2, 1)
plt.plot(train_losses_np.mean(axis=0), label='Tanulási veszteség (átlag)', color='blue')
plt.fill_between(range(epochs), train_losses_np.mean(axis=0) - train_losses_np.std(axis=0),
                 train_losses_np.mean(axis=0) + train_losses_np.std(axis=0), alpha=0.2, color='blue')
plt.plot(val_losses_np.mean(axis=0), label='Validációs veszteség (átlag)', color='orange')
plt.fill_between(range(epochs), val_losses_np.mean(axis=0) - val_losses_np.std(axis=0),
                 val_losses_np.mean(axis=0) + val_losses_np.std(axis=0), alpha=0.2, color='orange')
plt.axhline(np.mean(test_losses), color='red', linestyle='--', label='Teszthalmaz veszteség (átlag)')
plt.xlabel('Epizód'); plt.ylabel('Veszteség'); plt.title('Tanulási / validációs veszteség')
plt.legend()

# Pontosság
plt.subplot(1, 2, 2)
plt.plot(train_accuracies_np.mean(axis=0), label='Tanulási pontosság (átlag)', color='blue')
plt.fill_between(range(epochs), train_accuracies_np.mean(axis=0) - train_accuracies_np.std(axis=0),
                 train_accuracies_np.mean(axis=0) + train_accuracies_np.std(axis=0), alpha=0.2, color='blue')
plt.plot(val_accuracies_np.mean(axis=0), label='Validációs pontosság (átlag)', color='orange')
plt.fill_between(range(epochs), val_accuracies_np.mean(axis=0) - val_accuracies_np.std(axis=0),
                 val_accuracies_np.mean(axis=0) + val_accuracies_np.std(axis=0), alpha=0.2, color='orange')
plt.axhline(np.mean(test_accuracies), color='red', linestyle='--', label='Teszthalmaz pontosság (átlag)')
plt.xlabel('Epizód'); plt.ylabel('Pontosság'); plt.title('Tanulási / validációs pontosság')
plt.legend()
plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_true_all, y_pred_all)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Fake 0", "Real 1"], yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Konfúziós mátrix (10 futás aggregálva)')
plt.show()

print("\n Classification Report (összesített):")
print(classification_report(y_true_all, y_pred_all))
# Out:
#  Classification Report (összesített):
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     37200
#          1.0       0.97      0.97      0.97     37200
#
#     accuracy                           0.97     74400
#    macro avg       0.97      0.97      0.97     74400
# weighted avg       0.97      0.97      0.97     74400

# %%
correct_real = y_prob_all[(y_true_all == 0) & (y_pred_all == 0)]
incorrect_real = y_prob_all[(y_true_all == 0) & (y_pred_all != 0)]
correct_fake = y_prob_all[(y_true_all == 1) & (y_pred_all == 1)]
incorrect_fake = y_prob_all[(y_true_all == 1) & (y_pred_all != 1)]

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (valódi=0)"); axes[0].set_xlabel("Valószínűség"); axes[0].legend(); axes[0].grid(True)

axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódi hírek (valódi=1)"); axes[1].set_xlabel("Valószínűség"); axes[1].legend(); axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása (10 futás aggregálva)", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
df_results_full = pd.DataFrame({
    "Valódi címke": y_true_all,
    "Prediktált címke": y_pred_all
})
df_misclassified = df_results_full[df_results_full["Valódi címke"] != df_results_full["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index.to_numpy()
misclassified_sequences = padded_test_repeated[misclassified_indices]
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)
misclassified_texts_cleaned = [
    " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    for text in misclassified_texts
]
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))
df_misclassified["Szöveg"] = misclassified_texts_cleaned
df_misclassified["Predikció valószínűsége"] = np.round(y_prob_all[misclassified_indices], 4)
df_misclassified.to_csv("felrebesorolt_peldak_aggregalt_gru.csv", index=False, encoding="utf-8")

pd.set_option("display.max_colwidth", None)
display(df_misclassified.head(20))
# Out:
#             Hiba típusa  Valódi címke  Prediktált címke  \
# 41   Hamis negatív (FN)           1.0                 0
# 81   Hamis pozitív (FP)           0.0                 1
# 235  Hamis pozitív (FP)           0.0                 1
# 244  Hamis negatív (FN)           1.0                 0
# 259  Hamis pozitív (FP)           0.0                 1
# 273  Hamis pozitív (FP)           0.0                 1
# 275  Hamis negatív (FN)           1.0                 0
# 293  Hamis pozitív (FP)           0.0                 1
# 297  Hamis pozitív (FP)           0.0                 1
# 408  Hamis negatív (FN)           1.0                 0
# 464  Hamis pozitív (FP)           0.0                 1
# 490  Hamis pozitív (FP)           0.0                 1
# 508  Hamis negatív (FN)           1.0                 0
# 576  Hamis pozitív (FP)           0.0                 1
# 642  Hamis negatív (FN)           1.0                 0
# 650  Hamis negatív (FN)           1.0                 0
# 660  Hamis pozitív (FP)           0.0                 1
# 690  Hamis negatív (FN)           1.0                 0
# 707  Hamis pozitív (FP)           0.0                 1
# 725  Hamis negatív (FN)           1.0                 0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 41                                                                                                                                                                            'editor' 'note' 'the' 'follow' 'column' 'origin' 'appear' 'on' 'the' 'websit' 'us' 'defens' 'watch' 'it' 'is' 'reprint' 'with' 'permiss' 'i' 'like' 'million' 'of' 'american' 'saw' 'your' 'speech' 'at' 'the' 'dnc' 'on' 'thursday' 'night' 'i' 'wish' 'to' 'offer' 'my' 'sympathi' 'for' 'the' 'death' 'of' 'your' 'son' 'captain' 'humayun' 'khan' 'who' 'wa' 'kill' 'in' 'action' 'in' 'iraq' 'as' 'a' 'former' 'us' 'armi' 'offic' 'and' 'a' 'veteran' 'of' 'the' 'gulf' 'war' 'i' 'can' 'certainli' 'understand' 'the' 'pain' 'and' 'anguish' 'that' 'you' 'and' 'your' 'wife' 'endur' 'everi' 'day' 'your' 'son' 'die' 'save' 'the' 'live' 'of' 'hi' 'fellow' 'soldier' 'as' 'jesu' 'told' 'hi' 'discipl' 'accord' 'to' 'the' 'gospel' 'of' 'john' 'greater' 'love' 'hath' 'no' 'man' 'than' 'thi' 'that' 'a' 'man' 'lay' 'down' 'hi' 'life' 'for' 'hi' 'friend' 'captain' 'khan' 'is' 'a' 'hero' 'i' 'am' 'sure' 'the' 'soldier' 'he' 'serv' 'with' 'regard' 'him' 'as' 'one' 'i' 'know' 'you' 'and' 'your' 'wife' 'do' 'rest' 'assur' 'that' 'million' 'of' 'veteran' 'regard' 'your' 'son' 'as' 'a' 'hero' 'as' 'well' 'to' 'paraphras' 'from' 'the' 'book' 'of' 'your' 'son' 'name' 'for' 'your' 'son' 'made' 'the' 'ultim' 'sacrific' 'for' 'hi' 'countri' 'a' 'countri' 'that' 'wa' 'new' 'to' 'you' 'and' 'your' 'famili' 'and' 'one' 'which' 'you' 'openli' 'embrac' 'and' 'certainli' 'love' 'when' 'you' 'and' 'your' 'famili' 'arriv' 'to' 'america' 'from' 'pakistan' 'you' 'assimil' 'into' 'our' 'countri' 'you' 'adopt' 'american' 'way' 'learn' 'our' 'histori' 'and' 'appar' 'you' 'even' 'acquir' 'a' 'pocket' 'constitut' 'along' 'the' 'way' 'good' 'for' 'you' 'sir' 'but' 'there' 'are' 'mani' 'muslim' 'in' 'america' 'who' 'not' 'onli' 'have' 'no' 'desir' 'to' 'assimil' 'but' 'wish' 'to' 'live' 'under' 'sharia' 'law' 'that' 'is' 'unaccept' 'to' 'american' 'there' 'is' 'onli' 'one' 'law' 'of' 'the' 'land' 'that' 'is' 'the' 'you' 'constitut' 'as' 'you' 'well' 'know' 'mr' 'khan' 'we' 'live' 'in' 'violent' 'time' 'danger' 'time' 'muslim' 'from' 'isi' 'and' 'other' 'radic' 'jihadi' 'group' 'are' 'on' 'a' 'murder' 'and' 'terror' 'spree' 'across' 'the' 'globe' 'your' 'religion' 'of' 'peac' 'islam' 'is' 'anyth' 'but' 'that' 'in' 'that' 'is' 'a' 'fact' 'that' 'is' 'confirm' 'everi' 'time' 'a' 'muslim' 'shoot' 'bomb' 'behead' 'and' 'tortur' 'innoc' 'men' 'women' 'and' 'children' 'thi' 'doe' 'not' 'mean' 'that' 'everi' 'muslim' 'is' 'a' 'terrorist' 'but' 'most' 'terrorist' 'sir' 'are' 'inde' 'muslim' 'a' 'muslim' 'terrorist' 'attack' 'ha' 'becom' 'the' 'sign' 'of' 'the' 'time' 'regardless' 'of' 'what' 'the' 'feckless' 'nave' 'leftist' 'ideologu' 'barack' 'obama' 'and' 'hi' 'dimwit' 'colleagu' 'john' 'kerri' 'francoi' 'holland' 'and' 'angela' 'merkel' 'state' 'the' 'unit' 'state' 'and' 'the' 'west' 'are' 'at' 'war' 'with' 'radic' 'islam' 'it' 'is' 'the' 'job' 'of' 'the' 'presid' 'of' 'the' 'unit' 'state' 'to' 'protect' 'hi' 'nation' 'from' 'all' 'enemi' 'foreign' 'and' 'domest' 'unfortun' 'mr' 'obama' 'romantic' 'islam' 'and' 'refus' 'to' 'accept' 'realiti' 'which' 'ha' 'result' 'in' 'the' 'death' 'of' 'thousand' 'of' 'innoc' 'peopl' 'across' 'the' 'world' 'group' 'like' 'isi' 'and' 'al' 'qaeda' 'have' 'one' 'goal' 'the' 'complet' 'destruct' 'of' 'the' 'judeochristian' 'cultur' 'our' 'religion' 'and' 'our' 'way' 'of' 'life' 'mani' 'american' 'have' 'famili' 'that' 'have' 'been' 'here' 'for' 'decad' 'even' 'centuri' 'mani' 'famili' 'like' 'mine' 'have' 'rel' 'who' 'fought' 'in' 'the' 'civil' 'war' 'wwii' 'korea' 'vietnam' 'and' 'desert' 'storm' 'some' 'famili' 'have' 'rel' 'who' 'fought' 'in' 'the' 'american' 'revolut' 'we' 'do' 'not' 'plan' 'on' 'let' 'our' 'countri' 'be' 'devour' 'by' 'muslim' 'maniac' 'we' 'are' 'american' 'sir' 'and' 'not' 'unarm' 'socialist' 'european' 'zombi' 'we' 'will' 'do' 'what' 'is' 'necessari' 'to' 'pr ...
# 81                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'bana' 'alabedbana' 'septemb' 'she' 'is' 'year' 'old' 'and' 'live' 'in' 'aleppo' 'syria' 'as' 'vox' 'report' 'aleppo' 'ha' 'been' 'one' 'of' 'the' 'most' 'signific' 'battlefield' 'in' 'the' 'countri' 'continu' 'fight' 'between' 'bashar' 'alassad' 'and' 'govern' 'rebel' 'sinc' 'bana' 'recent' 'creat' 'a' 'twitter' 'account' 'with' 'her' 'mother' 'to' 'final' 'show' 'the' 'world' 'what' 'life' 'is' 'like' 'for' 'those' 'in' 'their' 'wartorn' 'citi' 'in' 'an' 'interview' 'with' 'independ' 'journal' 'review' 'bana' 'said' 'the' 'violenc' 'in' 'her' 'countri' 'is' 'all' 'she' 'know' 'when' 'ask' 'to' 'describ' 'what' 'happen' 'when' 'a' 'bomb' 'goe' 'off' 'she' 'said' 'the' 'bomb' 'is' 'predict' 'it' 'alway' 'hit' 'civilian' 'place' 'so' 'there' 'is' 'alway' 'fear' 'not' 'just' 'me' 'but' 'thousand' 'live' 'in' 'fear' 'everi' 'day' 'i' 'am' 'veri' 'afraid' 'i' 'will' 'die' 'tonight' 'thi' 'bomb' 'will' 'kill' 'me' 'now' 'bana' 'aleppo' 'bana' 'alabedbana' 'octob' 'unlik' 'mani' 'children' 'bana' 'doe' 'not' 'go' 'to' 'school' 'she' 'explain' 'that' 'a' 'typic' 'day' 'doe' 'not' 'even' 'involv' 'play' 'outsid' 'we' 'just' 'keep' 'strong' 'have' 'hope' 'thi' 'is' 'what' 'remain' 'of' 'our' 'childhood' 'memori' 'bana' 'aleppo' 'bana' 'alabedbana' 'octob' 'here' 'she' 'is' 'in' 'what' 'use' 'to' 'be' 'her' 'famili' 'garden' 'which' 'is' 'now' 'just' 'a' 'pile' 'of' 'rubbl' 'thi' 'is' 'our' 'bomb' 'garden' 'i' 'use' 'to' 'play' 'on' 'it' 'now' 'nowher' 'to' 'play' 'bana' 'aleppo' 'bana' 'alabedbana' 'octob' 'as' 'you' 'can' 'see' 'life' 'in' 'aleppo' 'is' 'a' 'far' 'cri' 'from' 'what' 'mani' 'in' 'the' 'unit' 'state' 'will' 'ever' 'experi' 'bana' 'hope' 'that' 'her' 'messag' 'for' 'presid' 'barack' 'obama' 'will' 'be' 'heard' 'loud' 'and' 'clear' 'instead' 'of' 'a' 'plea' 'for' 'her' 'person' 'safeti' 'her' 'request' 'show' 'tremend' 'understand' 'of' 'the' 'broader' 'pictur' 'and' 'concern' 'for' 'all' 'involv' 'stop' 'the' 'war' 'and' 'bring' 'peac' 'pretti' 'profound' 'for' 'a' 'yearold' 'bana' 'ha' 'amass' 'a' 'twitter' 'follow' 'of' 'more' 'than' 'peopl' 'when' 'ask' 'about' 'have' 'such' 'a' 'huge' 'platform' 'to' 'share' 'aleppo' 'stori' 'she' 'gave' 'the' 'most' 'humbl' 'and' 'selfless' 'respons' 'i' 'am' 'veri' 'happi' 'and' 'good' 'one' 'day' 'peopl' 'will' 'help' 'us' 'hello' 'world' 'we' 'are' 'still' 'aliv' 'wake' 'up' 'thi' 'morn' 'aliv' 'aleppo' 'bana' 'alabedbana' 'octob' 'bana' 'possess' 'an' 'innat' 'abil' 'to' 'have' 'faith' 'in' 'a' 'situat' 'that' 'should' 'give' 'her' 'everi' 'reason' 'to' 'doubt' 'god' 'exist' 'the' 'yearold' 'admit' 'she' 'believ' 'in' 'god' 'pray' 'and' 'said' 'her' 'faith' 'ha' 'increas' 'in' 'light' 'of' 'her' 'circumst' 'but' 'she' 'doe' 'not' 'just' 'pray' 'for' 'herself' 'she' 'also' 'said' 'she' 'pray' 'everi' 'day' 'for' 'peac' 'around' 'the' 'world' 'thi' 'is' 'me' 'befor' 'the' 'war' 'tonight' 'i' 'am' 'pray ...
# 235                                                                                                                     'activist' 'post' 'as' 'the' 'you' 'presidenti' 'select' 'circu' 'draw' 'to' 'a' 'close' 'the' 'unit' 'state' 'and' 'turkey' 'have' 'announc' 'a' 'new' 'plan' 'to' 'defeat' 'isi' 'the' 'same' 'terrorist' 'organ' 'both' 'countri' 'have' 'creat' 'fund' 'arm' 'and' 'facilit' 'in' 'syria' 'the' 'plan' 'revolv' 'around' 'the' 'conquer' 'occup' 'and' 'govern' 'of' 'sovereign' 'syrian' 'territori' 'in' 'the' 'east' 'most' 'notabl' 'raqqa' 'accord' 'to' 'the' 'you' 'joint' 'chief' 'of' 'staff' 'gen' 'joseph' 'dunford' 'after' 'meet' 'with' 'hi' 'turkish' 'counterpart' 'that' 'the' 'coalit' 'and' 'turkey' 'will' 'work' 'togeth' 'on' 'the' 'longterm' 'plan' 'for' 'seiz' 'hold' 'and' 'govern' 'raqqa' 'the' 'statement' 'by' 'dunford' 'seem' 'to' 'confirm' 'the' 'fact' 'that' 'the' 'unit' 'state' 'will' 'not' 'move' 'forward' 'in' 'it' 'campaign' 'for' 'raqqa' 'without' 'work' 'close' 'with' 'the' 'turk' 'who' 'are' 'themselv' 'concern' 'about' 'the' 'makeup' 'of' 'the' 'proxi' 'forc' 'destin' 'to' 'hold' 'power' 'onc' 'the' 'campaign' 'is' 'over' 'the' 'syrian' 'democrat' 'forc' 'the' 'proxi' 'of' 'choic' 'in' 'thi' 'battl' 'are' 'made' 'up' 'of' 'mani' 'kurdish' 'militia' 'and' 'fighter' 'an' 'issu' 'that' 'provid' 'much' 'worri' 'on' 'the' 'part' 'of' 'the' 'turkish' 'govern' 'as' 'cnn' 'report' 'but' 'dod' 'news' 'report' 'that' 'sunday' 'meet' 'reinforc' 'a' 'longstand' 'agreement' 'that' 'the' 'usl' 'coalit' 'would' 'not' 'move' 'ahead' 'with' 'the' 'seizur' 'of' 'raqqa' 'without' 'incorpor' 'the' 'turk' 'and' 'their' 'perspect' 'into' 'our' 'plan' 'accord' 'to' 'dunford' 'the' 'turkish' 'armi' 'said' 'in' 'a' 'statement' 'that' 'the' 'militari' 'head' 'had' 'discuss' 'the' 'method' 'of' 'a' 'common' 'struggl' 'against' 'isi' 'in' 'iraq' 'and' 'syria' 'especi' 'in' 'al' 'bab' 'and' 'raqqa' 'in' 'come' 'day' 'address' 'the' 'sensit' 'around' 'the' 'ethnic' 'makeup' 'of' 'the' 'forc' 'involv' 'in' 'the' 'oper' 'dunford' 'said' 'we' 'alway' 'knew' 'the' 'sdf' 'wa' 'not' 'the' 'solut' 'for' 'hold' 'and' 'govern' 'raqqa' 'what' 'we' 'are' 'work' 'on' 'right' 'now' 'is' 'to' 'find' 'the' 'right' 'mix' 'of' 'forc' 'for' 'the' 'oper' 'he' 'said' 'the' 'us' 'would' 'work' 'with' 'turkey' 'to' 'determin' 'the' 'composit' 'of' 'the' 'forc' 'that' 'would' 'seiz' 'and' 'govern' 'the' 'territori' 'he' 'said' 'he' 'said' 'the' 'right' 'approach' 'wa' 'for' 'local' 'to' 'lead' 'the' 'mission' 'to' 'retak' 'the' 'citi' 'and' 'run' 'it' 'after' 'isi' 'wa' 'driven' 'out' 'the' 'oper' 'need' 'a' 'predominantli' 'arab' 'and' 'sunni' 'arab' 'forc' 'he' 'said' 'accord' 'to' 'dod' 'news' 'and' 'there' 'are' 'forc' 'like' 'that' 'there' 'is' 'the' 'moder' 'syrian' 'opposit' 'the' 'vet' 'syrian' 'forc' 'and' 'the' 'free' 'syrian' 'armi' 'forc' 'and' 'there' 'is' 'some' 'initi' 'outreach' 'to' 'forc' 'in' 'raqqa' 'proper' 'dunford' 'said' 'the' 'sdf' 'were' 'move' 'south' 'to' 'isol' 'isi' 'posit' 'in' 'raqqa' 'and' 'the' 'surround' 'area' 'a' 'phase' 'that' 'would' 'take' 'month' 'essenti' 'the' 'unit' 'state' 'and' 'turkey' 'are' 'devis' 'a' 'plan' 'by' 'which' 'to' 'control' 'raqqa' 'and' 'the' 'territori' 'surround' 'it' 'by' 'use' 'proxi' 'forc' 'to' 'overthrow' 'other' 'proxi' 'forc' 'in' 'other' 'word' 'the' 'fighter' 'in' 'raqqa' 'will' 'simpli' 'undergo' 'anoth' 'name' 'chang' 'be' 'replac' 'with' 'a' 'heavi' 'kurdish' 'conting' 'and' 'act' 'as' 'a' 'care' 'place' 'chess' 'piec' 'by' 'which' 'to' 'prevent' 'the' 'syrian' 'or' 'russian' 'militari' 'from' 'liber' 'the' 'citi' 'after' 'all' 'these' 'sdf' 'forc' 'will' 'be' 'present' 'as' 'moder' 'a' 'label' 'that' 'can' 'not' 'be' 'attach' 'to' 'the' 'isi' 'fighter' 'current' 'inhabit' 'raqqa' 'raqqa' 'ha' 'act' 'as' 'the' 'isi' 'capit' 'sinc' 'the' 'mysteri' 'appear' 'of' 'the' 'group' 'two' 'year' 'ago' 'and' 'ha' 'gone' 'virtual' 'untouch' 'as' 'the' 'syrian' 'militari' 'ha' 'been' ' ...
# 244                                                                                                                                  'a' 'public' 'servic' 'announc' 'from' 'your' 'friend' 'here' 'at' 'vox' 'there' 'will' 'be' 'an' 'enorm' 'amount' 'of' 'fals' 'inform' 'on' 'facebook' 'the' 'internet' 'and' 'tv' 'thi' 'elect' 'day' 'do' 'yourself' 'and' 'the' 'countri' 'a' 'favor' 'and' 'ignor' 'it' 'politician' 'have' 'alway' 'play' 'fast' 'and' 'loos' 'with' 'the' 'truth' 'cabl' 'news' 'network' 'have' 'alway' 'gotten' 'stori' 'wrong' 'and' 'the' 'internet' 'ha' 'alway' 'been' 'a' 'place' 'for' 'conspiraci' 'theori' 'and' 'mislead' 'stori' 'and' 'photo' 'but' 'the' 'campaign' 'ha' 'seen' 'an' 'unpreced' 'increas' 'in' 'the' 'sheer' 'number' 'of' 'fals' 'news' 'stori' 'be' 'share' 'on' 'facebook' 'or' 'post' 'to' 'but' 'entir' 'fake' 'news' 'site' 'run' 'by' 'young' 'peopl' 'look' 'to' 'make' 'some' 'money' 'off' 'thi' 'long' 'and' 'bitter' 'elect' 'take' 'the' 'denver' 'guardian' 'which' 'earlier' 'thi' 'month' 'ran' 'a' 'stori' 'with' 'the' 'headlin' 'fbi' 'agent' 'suspect' 'in' 'hillari' 'email' 'leak' 'found' 'dead' 'in' 'appar' 'the' 'articl' 'ricochet' 'across' 'facebook' 'and' 'gain' 'ten' 'of' 'thousand' 'of' 'share' 'despit' 'the' 'fact' 'that' 'there' 'is' 'no' 'such' 'thing' 'as' 'the' 'denver' 'guardian' 'and' 'that' 'the' 'stori' 'in' 'question' 'is' 'a' 'complet' 'fabric' 'it' 'is' 'a' 'dynam' 'that' 'deepli' 'concern' 'presid' 'barack' 'obama' 'arguabl' 'the' 'user' 'of' 'social' 'media' 'in' 'american' 'polit' 'histori' 'and' 'the' 'politician' 'who' 'ha' 'been' 'target' 'in' 'the' 'major' 'of' 'facebook' 'most' 'paranoid' 'and' 'outright' 'racist' 'viral' 'post' 'as' 'long' 'as' 'it' 'is' 'on' 'start' 'believ' 'it' 'he' 'said' 'dure' 'a' 'campaign' 'stop' 'in' 'ann' 'arbor' 'michigan' 'on' 'monday' 'it' 'creat' 'thi' 'dust' 'cloud' 'of' 'nonsens' 'to' 'make' 'matter' 'even' 'mani' 'current' 'and' 'former' 'us' 'offici' 'believ' 'that' 'russia' 'may' 'tri' 'to' 'deliber' 'spread' 'fals' 'inform' 'on' 'elect' 'day' 'to' 'make' 'wouldb' 'hillari' 'clinton' 'voter' 'stay' 'home' 'or' 'simpli' 'to' 'shake' 'overal' 'confid' 'in' 'the' 'american' 'polit' 'system' 'all' 'of' 'which' 'mean' 'that' 'if' 'you' 'see' 'or' 'read' 'someth' 'on' 'elect' 'day' 'that' 'appear' 'too' 'dramat' 'to' 'be' 'true' 'there' 'is' 'probabl' 'a' 'good' 'and' 'simpl' 'reason' 'it' 'is' 'not' 'in' 'novemb' 'fox' 'news' 'air' 'a' 'video' 'clip' 'show' 'a' 'member' 'of' 'the' 'black' 'panther' 'stand' 'outsid' 'a' 'poll' 'station' 'in' 'philadelphia' 'it' 'wa' 'a' 'singl' 'person' 'at' 'a' 'singl' 'poll' 'station' 'in' 'a' 'heavili' 'black' 'heavili' 'democrat' 'area' 'but' 'fox' 'anchor' 'strongli' 'suggest' 'that' 'it' 'wa' 'part' 'of' 'a' 'broader' 'pattern' 'of' 'voter' 'intimid' 'by' 'milit' 'determin' 'to' 'stop' 'nomine' 'mitt' 'romney' 'the' 'segment' 'wa' 'frequent' 'throughout' 'the' 'day' 'four' 'year' 'it' 'is' 'certainli' 'possibl' 'that' 'fox' 'news' 'or' 'a' 'leftlean' 'station' 'like' 'msnbc' 'will' 'find' 'a' 'similar' 'type' 'of' 'clip' 'and' 'present' 'it' 'in' 'a' 'way' 'that' 'is' 'deliber' 'mislead' 'amazingli' 'though' 'that' 'could' 'liter' 'be' 'the' 'least' 'of' 'our' 'problem' 'a' 'much' 'bigger' 'concern' 'is' 'the' 'prolifer' 'of' 'entir' 'fake' 'news' 'site' 'with' 'entir' 'fake' 'stori' 'often' 'oper' 'by' 'entrepreneur' 'live' 'oversea' 'a' 'buzzfe' 'articl' 'earlier' 'thi' 'month' 'found' 'that' 'young' 'peopl' 'in' 'the' 'macedonian' 'town' 'of' 'popul' 'had' 'creat' 'more' 'than' 'protrump' 'news' 'site' 'run' 'post' 'everi' 'day' 'that' 'are' 'aggreg' 'or' 'complet' 'plagiar' 'from' 'fring' 'and' 'rightw' 'site' 'in' 'the' 'us' 'to' 'take' 'one' 'exampl' 'from' 'the' 'stori' 'a' 'websit' 'call' 'post' 'an' 'articl' 'with' 'the' 'headlin' 'hillari' 'clinton' 'in' 'i' 'would' 'like' 'to' 'see' 'peopl' 'like' 'donald' 'trump' 'run' 'for' 'offic' 'they' 'are' 'honest' 'and' 'can' 'not' 'be' 'bought' 'the' 'st ...
# 259                                                                                                                                                           'iraq' 'and' 'turkey' 'are' 'threaten' 'to' 'go' 'to' 'war' 'with' 'each' 'other' 'over' 'who' 'should' 'hold' 'power' 'in' 'mosul' 'and' 'the' 'surround' 'region' 'after' 'the' 'defeat' 'of' 'isi' 'turkish' 'tank' 'and' 'artilleri' 'have' 'deploy' 'along' 'the' 'border' 'and' 'iraqi' 'prime' 'minist' 'haider' 'alabadi' 'ha' 'said' 'that' 'while' 'iraq' 'did' 'not' 'want' 'war' 'with' 'turkey' 'it' 'is' 'readi' 'to' 'fight' 'one' 'if' 'necessari' 'the' 'confront' 'is' 'sharpen' 'as' 'the' 'iraqi' 'armi' 'enter' 'eastern' 'mosul' 'and' 'shia' 'militia' 'known' 'as' 'the' 'hashd' 'alshaabi' 'advanc' 'toward' 'the' 'town' 'of' 'tal' 'afar' 'threaten' 'to' 'cut' 'isiss' 'last' 'escap' 'rout' 'from' 'mosul' 'to' 'syria' 'turkey' 'see' 'itself' 'as' 'the' 'protector' 'of' 'the' 'sunni' 'arab' 'of' 'mosul' 'and' 'northern' 'iraq' 'a' 'commun' 'left' 'vulner' 'by' 'the' 'like' 'defeat' 'of' 'isi' 'by' 'shia' 'and' 'kurdish' 'forc' 'back' 'by' 'usl' 'airpow' 'the' 'depend' 'of' 'the' 'antiisi' 'forc' 'on' 'air' 'strike' 'and' 'drone' 'wa' 'underlin' 'on' 'wednesday' 'when' 'iraqi' 'special' 'forc' 'delay' 'their' 'advanc' 'into' 'east' 'mosul' 'becaus' 'high' 'humid' 'and' 'cloud' 'made' 'it' 'difficult' 'for' 'aircraft' 'to' 'identifi' 'and' 'attack' 'target' 'on' 'the' 'ground' 'they' 'had' 'enter' 'the' 'industri' 'suburb' 'of' 'on' 'tuesday' 'and' 'were' 'wednesday' 'go' 'from' 'hous' 'to' 'hous' 'look' 'for' 'improvis' 'explos' 'devic' 'i' 'and' 'boobi' 'trap' 'the' 'popul' 'of' 'mosul' 'east' 'of' 'the' 'tigri' 'river' 'which' 'divid' 'the' 'citi' 'in' 'half' 'ha' 'in' 'the' 'past' 'consist' 'larg' 'of' 'welleduc' 'profession' 'peopl' 'such' 'as' 'doctor' 'and' 'engin' 'few' 'of' 'whom' 'are' 'like' 'to' 'be' 'sympathet' 'to' 'isi' 'resid' 'in' 'the' 'east' 'say' 'they' 'expect' 'isi' 'to' 'withdraw' 'to' 'the' 'western' 'side' 'of' 'mosul' 'which' 'is' 'more' 'sympathet' 'to' 'them' 'cross' 'the' 'five' 'bridg' 'span' 'the' 'tigri' 'which' 'the' 'resid' 'say' 'have' 'been' 'rig' 'with' 'demolit' 'charg' 'the' 'iraqi' 'govern' 'react' 'angrili' 'to' 'the' 'possibl' 'of' 'turkish' 'intervent' 'the' 'invas' 'of' 'iraq' 'will' 'lead' 'to' 'turkey' 'be' 'dismantl' 'said' 'mr' 'abadi' 'at' 'a' 'news' 'confer' 'in' 'baghdad' 'on' 'tuesday' 'we' 'do' 'not' 'want' 'war' 'with' 'turkey' 'and' 'we' 'do' 'not' 'want' 'a' 'confront' 'with' 'turkey' 'but' 'if' 'a' 'confront' 'happen' 'we' 'are' 'readi' 'for' 'it' 'he' 'ad' 'that' 'iraq' 'would' 'consid' 'turkey' 'as' 'an' 'enemi' 'and' 'would' 'deal' 'with' 'it' 'as' 'an' 'enemi' 'the' 'exchang' 'of' 'abus' 'between' 'ankara' 'and' 'baghdad' 'continu' 'on' 'wednesday' 'when' 'turkish' 'foreign' 'minist' 'mevlut' 'cavusoglu' 'denounc' 'mr' 'abadi' 'as' 'weak' 'ask' 'if' 'you' 'have' 'the' 'strength' 'whi' 'did' 'you' 'surrend' 'mosul' 'to' 'terror' 'organis' 'if' 'you' 'are' 'so' 'strong' 'whi' 'ha' 'the' 'pkk' 'occupi' 'your' 'land' 'for' 'year' 'earlier' 'turkey' 'deputi' 'prime' 'minist' 'had' 'tri' 'to' 'lower' 'the' 'temperatur' 'by' 'say' 'that' 'the' 'militari' 'buildup' 'wa' 'a' 'precaut' 'and' 'not' 'a' 'threat' 'iraqi' 'leader' 'in' 'baghdad' 'have' 'long' 'privat' 'blame' 'turkey' 'for' 'aid' 'or' 'toler' 'movement' 'like' 'isi' 'which' 'oper' 'in' 'iraq' 'but' 'the' 'is' 'now' 'becom' 'more' 'public' 'on' 'both' 'side' 'on' 'octob' 'presid' 'recep' 'tayyip' 'erdogan' 'launch' 'a' 'furiou' 'tirad' 'against' 'mr' 'abadi' 'say' 'he' 'insult' 'me' 'you' 'are' 'not' 'on' 'the' 'same' 'level' 'as' 'me' 'you' 'are' 'not' 'my' 'equal' 'scream' 'all' 'you' 'want' 'from' 'iraq' 'it' 'will' 'not' 'chang' 'anyth' 'we' 'will' 'do' 'what' 'we' 'want' 'to' 'do' 'on' 'octob' 'mr' 'erdogan' 'further' 'rais' 'the' 'stake' 'by' 'assert' 'mosul' 'ha' 'histor' 'belong' 'to' 'turkey' 'and' 'it' 'should' 'therefor' 'play' 'a' 'role' 'in' 'determin'  ...
# 273                                                                                                                                                                                                                                                           'but' 'wait' 'wasn' 't' 'the' 'muslim' 'brotherhood' 's' 'arab' 'spring' 'sharia' 'law' 'for' 'all' 'egyptian' 'suppos' 'to' 'be' 'a' 'good' 'thing' 'an' 'egyptian' 'court' 'sentenc' 'moham' 'leader' 'of' 'the' 'outlaw' 'muslim' 'brotherhood' 'and' 'other' 'senior' 'member' 'of' 'the' 'group' 'to' 'death' 'for' 'incit' 'chao' 'and' 'violenc' 'and' 'gave' 'a' 'life' 'term' 'to' 'a' 'citizen' 'for' 'tie' 'to' 'the' 'men' 'were' 'among' 'thousand' 'of' 'peopl' 'detain' 'after' 'freeli' 'elect' 'islamist' 'presid' 'moham' 'mursi' 'wa' 'toppl' 'in' 'by' 'the' 'militari' 'under' 'abdel' 'fattah' 'alsisi' 'who' 'is' 'now' 'describ' 'the' 'brotherhood' 'as' 'a' 'major' 'secur' 'threat' 'the' 'group' 'say' 'it' 'is' 'commit' 'to' 'peac' 'activ' 'and' 'had' 'noth' 'to' 'do' 'with' 'islamist' 'milit' 'violenc' 'in' 'egypt' 'sinc' 'mursi' 's' 'fall' 'follow' 'mass' 'protest' 'against' 'hi' 's' 'mass' 'trial' 'of' 'brotherhood' 'member' 'and' 'peopl' 'accus' 'of' 'link' 'to' 'the' 'group' 'as' 'well' 'as' 'it' 'tough' 'crackdown' 'on' 'islamist' 'and' 'liber' 'opposit' 'alik' 'have' 'drawn' 'intern' 'critic' 'of' 'it' 'judici' 'system' 'and' 'human' 'right' 'sentenc' 'pronounc' 'at' 'a' 'televis' 'court' 'session' 'on' 'saturday' 'can' 'be' 'appeal' 'befor' 'egypt' 's' 'highest' 'civilian' 'court' 'in' 'a' 'process' 'that' 'could' 'take' 'year' 'to' 'reach' 'a' 'final' 'citizen' 'moham' 'wa' 'sentenc' 'to' 'life' 'in' 'jail' 'for' 'support' 'the' 'veteran' 'islamist' 'movement' 'and' 'transmit' 'fals' 'news' 'he' 'is' 'the' 'son' 'of' 'brotherhood' 'preacher' 'salah' 'who' 'wa' 'among' 'those' 'sentenc' 'to' 'one' 'of' 'the' 'defens' 'lawyer' 'condemn' 'the' 'verdict' 'the' 'court' 'did' 'not' 'differenti' 'between' 'the' 'defend' 'and' 'put' 'them' 'all' 'in' 'the' 'same' 'basket' 'he' 'told' 'report' 'at' 'the' 'courthous' 'none' 'of' 'the' 'defend' 'were' 'present' 'dure' 'the' 'is' 'the' 'brotherhood' 's' 'gener' 'guid' 'and' 'ha' 'alreadi' 'been' 'sentenc' 'to' 'sever' 'death' 'and' 'life' 'sentenc' 'hi' 'deputi' 'wa' 'given' 'a' 'life' 'sentenc' 'on' 'saturday' 'oper' 'room' 'group' 'say' 'egypt' 'where' 'a' 'popular' 'upris' 'toppl' 'veteran' 'autocrat' 'hosni' 'mubarak' 'in' 'and' 'start' 'year' 'of' 'polit' 'turmoil' 'is' 'now' 'crack' 'down' 'on' 'all' 'dissent' 'sisi' 'say' 'stabil' 'is' 'need' 'to' 'reviv' 'the' 'shatter' 'advoc' 'have' 'critic' 'a' 'you' 'decis' 'to' 'end' 'a' 'freez' 'on' 'militari' 'aid' 'to' 'cairo' 'say' 'is' 'put' 'human' 'right' 'on' 'the' 'the' 'unit' 'state' 'ha' 'said' 'the' 'decis' 'to' 'end' 'the' 'freez' 'wa' 'in' 'the' 'interest' 'of' 'nation' 'arrest' 'in' 'august' 'had' 'been' 'on' 'hunger' 'strike' 'while' 'in' 'prison' 'he' 'deserv' 'the' 'punish' 'becaus' 'of' 'the' 'money' 'and' 'instruct' 'from' 'the' 'brotherhood' 'which' 'were' 'found' 'with' 'him' 'and' 'for' 'spread' 'chao' 'and' 'horror' 'in' 'societi' 'presid' 'judg' 'moham' 'told' 'moham' 'a' 'rel' 'of' 'the' 'famili' 'said' 'they' 'would' 'appeal' 'the' 'verdict' 'it' 'wa' 'a' 'farc' 'trial' 'of' 'the' 'first' 'class' 'none' 'of' 'the' 'defend' 'attend' 'the' 'session' 'she' 'told' 'reuter' 'by' 'websit' 'call' 'for' 'moham' 's' 'releas' 'say' 'he' 'wa' 'not' 'a' 'member' 'of' 'the' 'brotherhood' 'describ' 'him' 'as' 'a' 'peac' 'activist' 'who' 'wa' 'involv' 'in' 'youth' 'event' 'and' 'chariti' 'the' 'websit' 'show' 'pictur' 'of' 'him' 'lie' 'on' 'a' 'stretcher' 'while' 'in' 's' 'case' 'wa' 'known' 'in' 'local' 'media' 'as' 'the' 'oper' 'room' 'trial' 'thi' 'is' 'in' 'refer' 'to' 'a' 'sitin' 'at' 'squar' 'in' 'in' 'which' 'hundr' 'of' 'peopl' 'protest' 'at' 'the' 'overthrow' 'of' 'mursi' 'were' 'kill' 'when' 'secur' 'forc' 'tri' 'to' 'clear' 'the' 'area' 'by' 'ha' 'defend' 'it' 'acti ...
# 275                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               'michael' 'brown' 'parent' 'plan' 'to' 'bring' 'a' 'civil' 'lawsuit' 'for' 'the' 'wrong' 'death' 'of' 'their' 'son' 'against' 'darren' 'wilson' 'and' 'the' 'citi' 'of' 'ferguson' 'missouri' 'the' 'announc'  ...
# 293                 'feder' 'prosecutor' 'warn' 'you' 'district' 'judg' 'gregori' 'that' 'gang' 'member' 'and' 'radic' 'muslim' 'marcu' 'dwayn' 'robertson' 'wa' 'danger' 'and' 'wa' 'recruit' 'inmat' 'for' 'terror' 'yet' 'the' 'judg' 'releas' 'him' 'the' 'gunman' 'who' 'murder' 'at' 'least' 'peopl' 'in' 'a' 'florida' 'nightclub' 'earli' 'sunday' 'morn' 'wa' 'a' 'follow' 'of' 'a' 'controversi' 'gang' 'robber' 'who' 'wa' 'releas' 'from' 'prison' 'last' 'year' 'despit' 'warn' 'from' 'prosecutor' 'that' 'he' 'would' 'recruit' 'peopl' 'to' 'carri' 'out' 'violent' 'act' 'sourc' 'told' 'mateen' 'whose' 'bloodi' 'sieg' 'insid' 'a' 'pack' 'orlando' 'gay' 'nightclub' 'end' 'when' 'swat' 'team' 'storm' 'the' 'build' 'and' 'kill' 'him' 'wa' 'a' 'radic' 'muslim' 'who' 'follow' 'marcu' 'dwayn' 'robertson' 'a' 'law' 'enforc' 'sourc' 'said' 'it' 'is' 'no' 'coincid' 'that' 'thi' 'happen' 'in' 'orlando' 'said' 'a' 'law' 'enforc' 'sourc' 'familiar' 'with' 'robertson' 's' 'histori' 'of' 'recruit' 'terrorist' 'and' 'incit' 'violenc' 'mateen' 'wa' 'enrol' 'in' 'robertson' 's' 'onlin' 'fundament' 'islam' 'knowledg' 'seminari' 'robertson' 'and' 'sever' 'associ' 'were' 'round' 'up' 'for' 'question' 'earli' 'sunday' 'accord' 'to' 'law' 'enforc' 'sourc' 'a' 'develop' 'hi' 'attorney' 'refus' 'to' 'confirm' 'or' 's' 'school' 'may' 'not' 'have' 'been' 'the' 'onli' 'sourc' 'of' 'mateen' 's' 'spiritu' 'guidanc' 'the' 'gunman' 'wa' 'at' 'the' 'islam' 'center' 'of' 'fort' 'pierc' 'with' 'imam' 'shafiq' 'rahman' 'two' 'day' 'befor' 'the' 'nightclub' 'attack' 'accord' 'to' 'the' 'post' 'that' 'mosqu' 'wa' 'frequent' 'by' 'americanborn' 'suicid' 'bomber' 'abu' 'who' 'blew' 'himself' 'up' 'in' 'syria' 'in' 'and' 'the' 'two' 'knew' 'each' 'other' 'accord' 'to' 'offici' 'mateen' 's' 'associ' 'with' 'led' 'the' 'fbi' 'to' 'interview' 'him' 'in' 'rep' 'michael' 'mccaul' 'chairman' 'of' 'the' 'hous' 'homeland' 'secur' 'committe' 'mike' 'mccaul' 'told' 'fox' 'news' 'law' 'enforc' 'determin' 'at' 'the' 'time' 'their' 'contact' 'wa' 'minim' 'foxnewscom' 'ha' 'report' 'extens' 'on' 'robertson' 'a' 'former' 'you' 'marin' 'who' 'serv' 'as' 'a' 'bodyguard' 'to' 'the' 'blind' 'sheik' 'involv' 'in' 'the' 'world' 'trade' 'center' 'attack' 'and' 'led' 'a' 'gang' 'of' 'new' 'york' 'bank' 'robber' 'call' 'ali' 'baba' 'and' 'the' 'thiev' 'befor' 'resurfac' 'in' 'orlando' 'where' 'he' 'start' 'an' 'islam' 'school' 'recent' 'renam' 'the' 'seminari' 'is' 'oper' 'by' 'robertson' 'a' 'yearold' 'firebrand' 'known' 'to' 'hi' 'thousand' 'of' 'follow' 'as' 'abu' 'who' 'recent' 'spent' 'four' 'year' 'in' 'prison' 'in' 'florida' 'on' 'illeg' 'weapon' 'and' 'tax' 'fraud' 'charg' 'befor' 'be' 'releas' 'by' 'a' 'florida' 'judg' 'one' 'year' 'ago' 'ha' 'openli' 'and' 'enthusiast' 'preach' 'against' 'homosexu' 'the' 'target' 'of' 'mateen' 's' 'bloodi' 'rampag' 'were' 'member' 'of' 'the' 'gay' 'commun' 'of' 'orlando' 'mile' 'from' 'the' 'yearold' 's' 'home' 'in' 'fort' 'said' 'wiretap' 'from' 'prove' 'robertson' 'instruct' 'one' 'of' 'hi' 'student' 'jonathan' 'paul' 'jimenez' 'to' 'file' 'fals' 'tax' 'return' 'to' 'obtain' 'a' 'tax' 'refund' 'to' 'pay' 'for' 'travel' 'to' 'mauritania' 'for' 'terror' 'studi' 'with' 'robertson' 'for' 'a' 'year' 'in' 'prepar' 'for' 'hi' 'travel' 'to' 'mauritania' 'where' 'he' 'would' 'studi' 'and' 'further' 'hi' 'train' 'in' 'kill' 'suicid' 'bomb' 'and' 'identifi' 'and' 'murder' 'you' 'militari' 'personnel' 'he' 'plead' 'guilti' 'in' 'to' 'lie' 'to' 'author' 'and' 'conspir' 'to' 'defraud' 'the' 'ir' 'and' 'wa' 'sentenc' 'to' 'year' 'in' 'feder' 'wa' 'arrest' 'on' 'a' 'firearm' 'charg' 'in' 'and' 'plead' 'guilti' 'in' 'januari' 'on' 'march' 'feder' 'author' 'charg' 'him' 'with' 'conspir' 'to' 'defraud' 'the' 'ir' 'which' 'he' 'wa' 'convict' 'of' 'in' 'decemb' 'while' 'in' 'the' 'john' 'e' 'polk' 'correct' 'facil' 'in' 'counti' 'robertson' 'wa' 'consid' 'so' 'danger' 'he' 'wa' 'kept' 'in' 'shackl' 'and' 'assign' 'hi' 'own' 'guard' 'whenev' 'he' 'wa' 'transport' 'to' 'cour ...
# 297                                                                                                                                                                                   'after' 'nearli' 'a' 'year' 'of' 'caus' 'hysteria' 'mass' 'travel' 'cancel' 'and' 'unnecessari' 'abort' 'it' 'final' 'daunt' 'to' 'journalist' 'and' 'expert' 'that' 'the' 'zika' 'viru' 'is' 'harmless' 'it' 'can' 'caus' 'a' 'veri' 'minor' 'two' 'day' 'of' 'a' 'low' 'fever' 'and' 'uncomfort' 'feel' 'for' 'a' 'quarter' 'of' 'those' 'infect' 'that' 'is' 'all' 'it' 'doe' 'not' 'becaus' 'as' 'wa' 'claim' 'by' 'sensationalist' 'in' 'the' 'media' 'and' 'variou' 'selfserv' 'scientist' 'birth' 'defect' 'like' 'microcephali' 'we' 'told' 'you' 'so' 'in' 'februari' 'we' 'wrote' 'the' 'zika' 'viru' 'is' 'harmless' 'who' 'then' 'benefit' 'from' 'thi' 'media' 'panic' 'the' 'piec' 'refere' 'to' 'a' 'congression' 'research' 'servic' 'report' 'and' 'variou' 'sound' 'scientif' 'paper' 'it' 'conclud' 'there' 'is' 'absolut' 'no' 'sane' 'reason' 'for' 'the' 'scari' 'headlin' 'and' 'the' 'panic' 'they' 'viru' 'is' 'harmless' 'it' 'is' 'possibl' 'but' 'seem' 'for' 'now' 'veri' 'unlik' 'that' 'it' 'affect' 'some' 'unborn' 'children' 'there' 'is' 'absolut' 'no' 'reason' 'to' 'be' 'concern' 'about' 'it' 'the' 'artifici' 'media' 'panic' 'continu' 'and' 'huge' 'amount' 'of' 'money' 'were' 'pour' 'into' 'danger' 'insecticid' 'to' 'kill' 'mosquito' 'and' 'import' 'pollin' 'that' 'did' 'not' 'do' 'ani' 'harm' 'inde' 'gener' 'use' 'of' 'some' 'of' 'these' 'insecticid' 'like' 'were' 'the' 'veri' 'becaus' 'of' 'a' 'blip' 'in' 'case' 'in' 'northeastern' 'brazil' 'in' 'march' 'we' 'wrote' 'read' 'about' 'zika' 'may' 'hurt' 'your' 'brain' 'we' 'list' 'sensat' 'news' 'headlin' 'about' 'potenti' 'catastroph' 'relat' 'to' 'a' 'zika' 'epidem' 'the' 'common' 'factor' 'of' 'those' 'panic' 'creat' 'media' 'wave' 'all' 'those' 'headlin' 'includ' 'the' 'miracul' 'littl' 'word' 'may' 'the' 'piec' 'were' 'pure' 'specul' 'with' 'some' 'quot' 'thi' 'or' 'that' 'expert' 'who' 'wa' 'hunt' 'for' 'research' 'fund' 'or' 'lobbi' 'for' 'some' 'pharmaceut' 'or' 'pesticid' 'conglomer' 'in' 'june' 'we' 'ad' 'zika' 'viru' 'doe' 'not' 'becaus' 'birth' 'defect' 'fight' 'it' 'probabl' 'doe' 'new' 'seriou' 'research' 'found' 'what' 'some' 'peopl' 'in' 'brazil' 'had' 'suspect' 'from' 'the' 'veri' 'start' 'of' 'the' 'small' 'and' 'strictli' 'local' 'limit' 'jump' 'in' 'case' 'in' 'brazil' 'doctor' 'in' 'the' 'zika' 'affect' 'area' 'in' 'brazil' 'point' 'out' 'that' 'the' 'real' 'becaus' 'of' 'somewhat' 'increas' 'microcephali' 'in' 'the' 'region' 'wa' 'probabl' 'the' 'insecticid' 'use' 'to' 'kill' 'mosquito' 'larva' 'in' 'drink' 'water' 'the' 'brazilian' 'doctor' 'note' 'that' 'the' 'area' 'of' 'northeast' 'brazil' 'that' 'had' 'wit' 'the' 'greatest' 'number' 'of' 'microcephali' 'case' 'match' 'with' 'area' 'where' 'is' 'ad' 'to' 'drink' 'water' 'in' 'an' 'effort' 'to' 'combat' 'mosquito' 'is' 'report' 'to' 'caus' 'in' 'mosquito' 'larva' 'and' 'ha' 'been' 'ad' 'to' 'drink' 'water' 'in' 'the' 'region' 'for' 'the' 'past' 'month' 'is' 'produc' 'by' 'a' 'chemic' 'an' 'import' 'japanes' 'poison' 'giant' 'it' 'wa' 'therefor' 'unsurpris' 'that' 'the' 'new' 'york' 'time' 'and' 'other' 'call' 'the' 'brazilian' 'doctor' 'report' 'a' 'conspiraci' 'theori' 'and' 'trot' 'out' 'some' 'expert' 'to' 'debunk' 'it' 'but' 'scientist' 'at' 'the' 'new' 'england' 'complex' 'system' 'institut' 'also' 'research' 'the' 'thesi' 'they' 'found' 'is' 'an' 'analog' 'of' 'juvenil' 'hormon' 'which' 'correspond' 'in' 'mammal' 'to' 'regulatori' 'molecul' 'includ' 'acid' 'a' 'vitamin' 'a' 'with' 'which' 'it' 'ha' 'and' 'whose' 'applic' 'dure' 'develop' 'caus' 'microcephali' 'test' 'of' 'by' 'the' 'manufactur' 'wide' 'quot' 'as' 'give' 'no' 'evid' 'for' 'development' 'toxic' 'actual' 'found' 'some' 'evid' 'for' 'such' 'an' 'effect' 'includ' 'low' 'brain' 'mass' 'and' 'format' 'of' 'the' 'cerebr' 'rat' 'pup' 'final' 'the' 'use' 'in' 'brazil' 'is' 'ha'  ...
# 408                                                                                                                                                                            'as' 'harri' 'lay' 'struggl' 'and' 'die' 'he' 'told' 'the' 'surround' 'offic' 'i' 'am' 'lose' 'my' 'breath' 'one' 'offic' 'yell' 'back' 'at' 'him' 'fuck' 'your' 'breath' 'then' 'he' 'insist' 'that' 'the' 'die' 'man' 'be' 'handcuf' 'fuck' 'your' 'breath' 'encapsul' 'in' 'onli' 'three' 'word' 'the' 'system' 'disregard' 'that' 'polic' 'regularli' 'show' 'to' 'black' 'peopl' 'in' 'america' 'just' 'last' 'week' 'we' 'watch' 'michael' 'slager' 'execut' 'walter' 'scott' 'in' 'south' 'carolina' 'for' 'dare' 'to' 'run' 'away' 'now' 'thi' 'week' 'we' 'are' 'also' 'tune' 'into' 'the' 'trial' 'of' 'former' 'chicago' 'polic' 'offic' 'dant' 'who' 'is' 'charg' 'with' 'involuntari' 'manslaught' 'in' 'the' 'kill' 'of' 'yearold' 'boyd' 'in' 'march' 'in' 'the' 'case' 'of' 'eric' 'garner' 'in' 'staten' 'island' 'tamir' 'rice' 'in' 'cleveland' 'walter' 'scott' 'in' 'south' 'carolina' 'and' 'eric' 'harri' 'in' 'tulsa' 'we' 'have' 'seen' 'video' 'of' 'law' 'enforc' 'offic' 'not' 'onli' 'critic' 'injur' 'citizen' 'but' 'also' 'refus' 'to' 'administ' 'medic' 'care' 'with' 'fatal' 'consequ' 'given' 'the' 'origin' 'of' 'polic' 'in' 'thi' 'countri' 'and' 'their' 'connect' 'to' 'slave' 'patrol' 'and' 'other' 'form' 'of' 'racial' 'social' 'control' 'i' 'am' 'under' 'no' 'illus' 'that' 'the' 'polic' 'have' 'ever' 'held' 'black' 'life' 'in' 'high' 'regard' 'polic' 'complic' 'and' 'particip' 'in' 'lynch' 'and' 'in' 'the' 'kkk' 'make' 'that' 'clear' 'but' 'the' 'explicit' 'tacit' 'refus' 'of' 'black' 'peopl' 'right' 'to' 'breath' 'is' 'still' 'signific' 'the' 'fact' 'that' 'the' 'tulsa' 'counti' 'sheriff' 'offic' 'is' 'a' 'paytoplay' 'forc' 'is' 'signific' 'the' 'fact' 'that' 'white' 'men' 'can' 'sign' 'up' 'with' 'govern' 'approv' 'for' 'the' 'right' 'to' 'play' 'cop' 'and' 'robber' 'on' 'the' 'weekend' 'is' 'appal' 'that' 'black' 'live' 'provid' 'fodder' 'for' 'sport' 'should' 'have' 'us' 'in' 'the' 'street' 'there' 'is' 'someth' 'about' 'the' 'logic' 'of' 'selfgovern' 'under' 'the' 'term' 'of' 'neoliber' 'that' 'make' 'thi' 'moment' 'feel' 'more' 'pessimist' 'than' 'our' 'narr' 'of' 'linear' 'progress' 'on' 'racial' 'issu' 'would' 'have' 'us' 'conclud' 'in' 'the' 'unit' 'arab' 'emir' 'gave' 'million' 'to' 'the' 'new' 'york' 'citi' 'polic' 'foundat' 'accord' 'to' 'an' 'nypd' 'spokesperson' 'the' 'money' 'wa' 'use' 'to' 'upgrad' 'equip' 'and' 'aid' 'in' 'crimin' 'investig' 'in' 'both' 'new' 'york' 'citi' 'and' 'tulsa' 'privat' 'fund' 'of' 'law' 'enforc' 'significantli' 'impact' 'the' 'way' 'local' 'polic' 'is' 'done' 'in' 'tulsa' 'it' 'result' 'in' 'the' 'paytoplay' 'scheme' 'in' 'new' 'york' 'citi' 'it' 'allow' 'for' 'larg' 'infus' 'of' 'cash' 'donat' 'whose' 'specif' 'use' 'do' 'not' 'come' 'under' 'public' 'scrutini' 'becaus' 'they' 'are' 'privat' 'fund' 'these' 'form' 'of' 'neoliber' 'polic' 'in' 'which' 'privat' 'citizen' 'and' 'privat' 'moni' 'impact' 'the' 'cultur' 'of' 'polic' 'but' 'escap' 'government' 'check' 'and' 'balanc' 'endang' 'us' 'all' 'in' 'new' 'york' 'such' 'action' 'enabl' 'the' 'purchas' 'of' 'unspecifi' 'form' 'of' 'equip' 'that' 'might' 'for' 'instanc' 'be' 'use' 'to' 'exacerb' 'the' 'cultur' 'of' 'militar' 'polic' 'in' 'the' 'nypd' 'part' 'of' 'thi' 'money' 'allow' 'the' 'nypd' 'to' 'travel' 'to' 'the' 'uae' 'to' 'learn' 'counterterror' 'measur' 'in' 'the' 'wake' 'of' 'some' 'extern' 'train' 'might' 'be' 'help' 'but' 'essenti' 'thi' 'sound' 'like' 'a' 'case' 'of' 'the' 'nypd' 'be' 'allow' 'money' 'to' 'play' 'global' 'cop' 'and' 'robber' 'and' 'to' 'then' 'test' 'out' 'these' 'tactic' 'on' 'the' 'black' 'and' 'brown' 'peopl' 'who' 'are' 'polic' 'heavili' 'within' 'the' 'citi' 'in' 'the' 'case' 'of' 'tulsa' 'thi' 'privat' 'form' 'of' 'law' 'enforc' 'place' 'an' 'pretend' 'deputi' 'into' 'a' 'seriou' 'confront' 'as' 'a' 'result' 'eric' 'harri' 'lost' 'hi' 'life' ' ...
# ...
# 690                                                                                                                                                                                                                                                                                                                                                     'what' 'doe' 'it' 'realli' 'mean' 'to' 'dress' 'like' 'a' 'woman' 'social' 'media' 'recent' 'took' 'it' 'upon' 'itself' 'to' 'answer' 'that' 'question' 'after' 'a' 'brief' 'flurri' 'of' 'rumor' 'about' 'a' 'possibl' 'white' 'hous' 'dress' 'code' 'at' 'the' 'grammi' 'so' 'did' 'beyonc' 'who' 'appar' 'decid' 'it' 'meant' 'look' 'like' 'the' 'golden' 'goddess' 'of' 'now' 'design' 'are' 'have' 'their' 'turn' 'it' 'is' 'after' 'all' 'a' 'question' 'that' 'lie' 'at' 'the' 'heart' 'of' 'fashion' 'and' 'that' 'they' 'at' 'least' 'theoret' 'are' 'suppos' 'to' 'be' 'ask' 'themselv' 'everi' 'season' 'of' 'cours' 'that' 'doe' 'not' 'mean' 'they' 'alway' 'come' 'up' 'with' 'viabl' 'answer' 'inde' 'dure' 'new' 'york' 'fashion' 'week' 'show' 'on' 'sunday' 'they' 'sometim' 'seem' 'to' 'get' 'so' 'entangl' 'in' 'the' 'mani' 'possibl' 'respons' 'that' 'they' 'trip' 'over' 'their' 'own' 'or' 'in' 'the' 'case' 'of' 'sander' 'at' 'the' 'mani' 'bit' 'that' 'dangl' 'flap' 'ruffl' 'and' 'wobbl' 'in' 'hi' 'process' 'of' 'peach' 'mint' 'green' 'and' 'fluoresc' 'pink' 'even' 'with' 'some' 'snap' 'to' 'ground' 'them' 'hi' 'dress' 'and' 'sleev' 'and' 'trouser' 'look' 'as' 'if' 'they' 'would' 'taken' 'a' 'wrong' 'turn' 'on' 'the' 'way' 'to' 'a' 'martha' 'graham' 'danc' 'perform' 'and' 'end' 'up' 'in' 'the' 'ballroom' 'of' 'the' 'sixth' 'avenu' 'hilton' 'by' 'mistak' 'howev' 'seem' 'to' 'know' 'exactli' 'where' 'he' 'wa' 'go' 'toward' 'multipl' 'way' 'to' 'celebr' 'the' 'exuber' 'of' 'be' 'a' 'woman' 'and' 'to' 'interpret' 'her' 'feminin' 'as' 'she' 'see' 'fit' 'accord' 'to' 'the' 'show' 'note' 'that' 'is' 'kind' 'of' 'broad' 'territori' 'wit' 'giant' 'braid' 'and' 'tuft' 'nepales' 'knit' 'in' 'wool' 'and' 'with' 'fox' 'trim' 'sleek' 'fur' 'in' 'lemon' 'oliv' 'green' 'and' 'white' 'made' 'for' 'a' 'park' 'avenu' 'warrior' 'silver' 'shirt' 'and' 'flare' 'trouser' 'fit' 'for' 'a' 'rock' 'star' 'and' 'sheer' 'even' 'gown' 'with' 'bra' 'top' 'for' 'well' 'it' 'wa' 'not' 'entir' 'clear' 'for' 'whom' 'someon' 'who' 'doe' 'a' 'lot' 'of' 'soul' 'cycl' 'mayb' 'and' 'a' 'final' 'of' 'person' 'for' 'each' 'model' 'includ' 'those' 'of' 'welcom' 'nontradit' 'runway' 'size' 'and' 'bear' 'such' 'messag' 'as' 'the' 'futur' 'is' 'femal' 'my' 'boyfriend' 'is' 'a' 'feminist' 'i' 'am' 'an' 'immigr' 'and' 'so' 'on' 'by' 'the' 'time' 'mr' 'appear' 'for' 'hi' 'bow' 'wear' 'one' 'of' 'hi' 'own' 'tee' 'thi' 'is' 'what' 'a' 'feminist' 'look' 'like' 'hi' 'celebr' 'front' 'row' 'the' 'most' 'divers' 'yet' 'for' 'ani' 'design' 'with' 'misti' 'copeland' 'sarah' 'jessica' 'parker' 'huma' 'abedin' 'and' 'dian' 'among' 'other' 'were' 'on' 'their' 'feet' 'in' 'ecstasi' 'yet' 'with' 'the' 'myriad' 'possibl' 'it' 'wa' 'also' 'a' 'bit' 'of' 'a' 'muddl' 'it' 'is' 'not' 'enough' 'to' 'be' 'inspir' 'by' 'all' 'women' 'love' 'as' 'that' 'sentiment' 'is' 'design' 'also' 'have' 'to' 'know' 'what' 'they' 'stand' 'for' 'the' 'specif' 'thing' 'they' 'offer' 'women' 'and' 'to' 'make' 'aesthet' 'choic' 'while' 'some' 'of' 'mr' 'were' 'great' 'those' 'knit' 'some' 'were' 'a' 'dress' 'drip' 'with' 'at' 'the' 'sleev' 'and' 'a' 'host' 'of' 'cover' 'button' 'down' 'the' 'skirt' 'and' 'some' 'were' 'just' 'plain' 'silli' 'dress' 'like' 'a' 'woman' 'doe' 'not' 'mean' 'put' 'the' 'breast' 'front' 'and' 'center' 'via' 'an' 'entir' 'sheer' 'the' 'movement' 'asid' 'whether' 'it' 'instead' 'mean' 'dress' 'in' 'the' 'gray' 'cape' 'of' 'a' 'renaiss' 'princ' 'on' 'the' 'other' 'hand' 'as' 'joseph' 'seem' 'to' 'think' 'it' 'doe' 'is' 'far' 'from' 'certain' 'in' 'an' 'from' 'last' 'season' 'romp' 'through' 'the' 'for' 'fall' 'mr' 'took' 'a' 'decidedli' 'more' 'and' 'turn' 'in' 'black ...
# 707                                                                                                                                                                                                           'dougla' 'murray' 'author' 'of' 'the' 'strang' 'death' 'of' 'europ' 'immigr' 'ident' 'islam' 'give' 'a' 'stun' 'account' 'of' 'the' 'self' 'murder' 'or' 'europ' 'in' 'the' 'death' 'of' 'europ' 'articl' 'publish' 'by' 'have' 'travel' 'to' 'the' 'place' 'where' 'migrant' 'continu' 'to' 'land' 'and' 'the' 'place' 'where' 'they' 'keep' 'end' 'up' 'everywher' 'i' 'have' 'gone' 'i' 'have' 'come' 'to' 'the' 'same' 'conclus' 'our' 'contin' 'is' 'in' 'the' 'process' 'of' 'the' 'daytoday' 'distract' 'of' 'life' 'and' 'polit' 'it' 'is' 'easi' 'to' 'forget' 'thi' 'biggest' 'event' 'of' 'our' 'time' 'all' 'pale' 'into' 'insignific' 'besid' 'the' 'stori' 'of' 'the' 'loss' 'by' 'european' 'of' 'the' 'onli' 'place' 'we' 'had' 'to' 'call' 'thi' 'countri' 'doe' 'have' 'a' 'debat' 'about' 'immigr' 'it' 'is' 'minuscul' 'it' 'tend' 'to' 'focu' 'on' 'calai' 'the' 'british' 'public' 'see' 'footag' 'of' 'peopl' 'sit' 'in' 'makeshift' 'tent' 'or' 'hurl' 'missil' 'into' 'the' 'road' 'to' 'slow' 'the' 'truck' 'down' 'so' 'they' 'can' 'board' 'them' 'and' 'break' 'into' 'time' 'actor' 'celebr' 'and' 'politician' 'head' 'to' 'calai' 'and' 'visit' 'the' 'camp' 'they' 'return' 'to' 'tell' 'the' 'british' 'public' 'that' 'it' 'must' 'be' 'more' 'and' 'argument' 'they' 'make' 'is' 'human' 'it' 'is' 'an' 'understand' 'reaction' 'to' 'human' 'miseri' 'but' 'it' 'is' 'a' 'core' 'part' 'of' 'our' 'societi' 's' 'suicid' 'that' 'exampl' 'of' 'calai' 'befor' 'the' 'latest' 'clearanc' 'of' 'the' 'camp' 'there' 'were' 'about' 'peopl' 'live' 'there' 'none' 'of' 'them' 'should' 'have' 'been' 'therebi' 'be' 'there' 'they' 'had' 'alreadi' 'broken' 'everi' 'one' 'of' 'the' 'rule' 'that' 'our' 'contin' 'put' 'in' 'place' 'which' 'demand' 'they' 'seek' 'asylum' 'in' 'the' 'first' 'countri' 'of' 'arriv' 'almost' 'nobodi' 'arriv' 'into' 'franc' 'these' 'peopl' 'have' 'land' 'in' 'greec' 'or' 'itali' 'and' 'made' 'their' 'way' 'yet' 'still' 'the' 'celebr' 'and' 'other' 'pick' 'at' 'our' 'conscienc' 'can' 'we' 'not' 'be' 'gener' 'and' 'at' 'least' 'let' 'in' 'the' 'peopl' 'who' 'are' 'there' 'it' 'is' 'wholli' 'understand' 'and' 'also' 'illinform' 'thi' 'year' 's' 'easter' 'weekend' 'alon' 'about' 'peopl' 'were' 'pick' 'up' 'between' 'the' 'coast' 'of' 'north' 'africa' 'and' 'the' 'south' 'of' 'were' 'describ' 'as' 'everyon' 'alway' 'is' 'as' 'be' 'rescu' 'in' 'fact' 'what' 'happen' 'what' 'ha' 'been' 'happen' 'for' 'year' 'is' 'that' 'each' 'day' 'boat' 'fill' 'with' 'migrant' 'set' 'out' 'from' 'north' 'the' 'height' 'of' 'the' 'migrat' 'crisi' 'of' 'when' 'germani' 's' 'chancellor' 'angela' 'merkel' 'open' 'up' 'the' 'door' 'of' 'europ' 'to' 'the' 'world' 'the' 'whole' 'contin' 'began' 'to' 'in' 'realiti' 'that' 'flood' 'of' 'million' 'into' 'europ' 'onli' 'sped' 'up' 'a' 'process' 'that' 'had' 'been' 'under' 'way' 'for' 'year' 'ever' 'sinc' 'the' 'postwar' 'period' 'european' 'govern' 'had' 'encourag' 'migrant' 'worker' 'to' 'come' 'first' 'as' 'chancellor' 'merkel' 'herself' 'admit' 'in' 'a' 'speech' 'in' 'they' 'expect' 'the' 'worker' 'to' 'return' 'home' 'but' 'they' 'didn' 't' 'they' 'stay' 'as' 'did' 'the' 'flow' 'after' 'that' 'and' 'the' 'one' 'for' 'decad' 'after' 'thatth' 'govern' 'of' 'countri' 'such' 'as' 'our' 'fail' 'to' 'get' 'anyth' 'right' 'all' 'their' 'predict' 'were' 'wrong' 'for' 'decad' 'they' 'were' 'wrong' 'that' 'peopl' 'would' 'stay' 'for' 'onli' 'a' 'short' 'time' 'wrong' 'to' 'think' 'that' 'they' 'would' 'not' 'continu' 'to' 'come' 'in' 'larg' 'that' 'they' 'might' 'not' 'want' 'to' 'bring' 'their' 'extend' 'famili' 'to' 'join' 'them' 'and' 'wrong' 'to' 'think' 'that' 'onc' 'the' 'tap' 'wa' 'turn' 'on' 'anyth' 'but' 'veri' 'radic' 'action' 'could' 'ever' 'bring' 'the' 'number' 'to' 'a' 'control' 'the' 'cours' 'of' 'research' 'the' 'strang' 'deat ...
# 725  'as' 'the' 'movement' 'continu' 'to' 'grow' 'and' 'expand' 'in' 'the' 'age' 'of' 'presid' 'trump' 'a' 'new' 'gener' 'of' 'energ' 'voter' 'and' 'young' 'peopl' 'will' 'do' 'well' 'to' 'arm' 'themselv' 'with' 'the' 'intellectu' 'firepow' 'of' 'the' 'giant' 'upon' 'whose' 'shoulder' 'today' 'movement' 'rest' 'here' 'then' 'are' 'seven' 'conserv' 'classic' 'that' 'should' 'be' 'on' 'everi' 'american' 'idea' 'have' 'consequ' 'by' 'richard' 'weaver' 'origin' 'publish' 'in' 'idea' 'have' 'consequ' 'the' 'corros' 'influenc' 'of' 'moral' 'and' 'cultur' 'decad' 'befor' 'the' 'left' 'har' 'those' 'forc' 'to' 'undermin' 'western' 'civil' 'one' 'of' 'america' 'greatest' 'conserv' 'intellectu' 'and' 'an' 'esteem' 'rhetor' 'scholar' 'richard' 'weaver' 'erect' 'an' 'intellectu' 'fortress' 'around' 'absolut' 'truth' 'long' 'befor' 'progress' 'mount' 'their' 'frontal' 'assault' 'on' 'notion' 'of' 'right' 'versu' 'wrong' 'good' 'versu' 'evil' 'the' 'road' 'to' 'by' 'f' 'a' 'in' 'the' 'age' 'of' 'berni' 'sander' 'today' 'young' 'gener' 'of' 'socialist' 'would' 'do' 'well' 'to' 'read' 'friedrich' 'classic' 'broadsid' 'against' 'social' 'the' 'road' 'to' 'a' 'member' 'of' 'the' 'austrian' 'school' 'of' 'econom' 'and' 'a' 'winner' 'of' 'the' 'nobel' 'prize' 'in' 'econom' 'warn' 'of' 'the' 'totalitarian' 'realiti' 'of' 'social' 'conceit' 'as' 'he' 'put' 'it' 'elsewher' 'a' 'claim' 'for' 'equal' 'of' 'materi' 'posit' 'can' 'be' 'met' 'onli' 'by' 'a' 'govern' 'with' 'totalitarian' 'power' 'the' 'close' 'of' 'the' 'american' 'mind' 'by' 'allan' 'bloom' 'long' 'befor' 'rioter' 'spark' 'violenc' 'at' 'uc' 'berkeley' 'a' 'univers' 'of' 'chicago' 'professor' 'name' 'allan' 'bloom' 'lit' 'academia' 'ablaz' 'with' 'thi' 'classic' 'take' 'the' 'to' 'task' 'for' 'erod' 'higher' 'educ' 'curriculum' 'with' 'progress' 'a' 'staunch' 'defend' 'of' 'the' 'classic' 'canon' 'of' 'great' 'work' 'everi' 'think' 'person' 'must' 'read' 'bloom' 'explain' 'how' 'the' 'intellectu' 'corrupt' 'of' 'the' 'human' 'and' 'art' 'led' 'to' 'an' 'erasur' 'of' 'student' 'understand' 'of' 'the' 'proper' 'moral' 'order' 'that' 'undergird' 'western' 'civil' 'a' 'choic' 'not' 'an' 'echo' 'by' 'phylli' 'schlafli' 'the' 'late' 'great' 'of' 'modern' 'conservat' 'phylli' 'schlafli' 'did' 'more' 'to' 'advanc' 'and' 'win' 'the' 'battl' 'of' 'idea' 'than' 'mani' 'young' 'conserv' 'understand' 'the' 'tip' 'of' 'her' 'intellectu' 'spear' 'a' 'choic' 'not' 'an' 'echo' 'reshap' 'the' 'contour' 'of' 'american' 'conservat' 'and' 'ha' 'sold' 'an' 'astound' 'three' 'million' 'copi' 'sinc' 'it' 'releas' 'over' 'a' 'ago' 'the' 'origin' 'crusad' 'schlafli' 'book' 'argu' 'that' 'conserv' 'must' 'be' 'will' 'to' 'fight' 'for' 'a' 'voic' 'within' 'the' 'republican' 'parti' 'establish' 'leadership' 'and' 'help' 'pave' 'a' 'path' 'for' 'barri' 'goldwat' 'nomin' 'capit' 'and' 'freedom' 'by' 'milton' 'friedman' 'nobel' 'economist' 'milton' 'friedman' 'redefin' 'the' 'field' 'of' 'econom' 'in' 'addit' 'to' 'be' 'an' 'intellectu' 'titan' 'he' 'wa' 'a' 'sterl' 'writer' 'with' 'a' 'knack' 'for' 'distil' 'complex' 'topic' 'with' 'wit' 'and' 'clariti' 'ani' 'nobel' 'prize' 'winner' 'who' 'can' 'string' 'togeth' 'a' 'sentenc' 'like' 'thi' 'deserv' 'to' 'be' 'read' 'if' 'you' 'put' 'the' 'feder' 'govern' 'in' 'charg' 'of' 'the' 'sahara' 'desert' 'in' 'year' 'there' 'would' 'be' 'a' 'shortag' 'of' 'sand' 'a' 'conflict' 'of' 'vision' 'by' 'thoma' 'sowel' 'there' 'are' 'no' 'bad' 'thoma' 'sowel' 'book' 'so' 'we' 'could' 'have' 'easili' 'recommend' 'mani' 'of' 'hi' 'other' 'classic' 'but' 'a' 'conflict' 'of' 'vision' 'crystal' 'the' 'stake' 'involv' 'in' 'the' 'clash' 'between' 'conserv' 'and' 'progress' 'ideolog' 'and' 'how' 'radic' 'differ' 'outcom' 'are' 'when' 'one' 'side' 'prevail' 'over' 'the' 'other' 'one' 'of' 'america' 'most' 'lucid' 'conserv' 'economist' 'sowel' 'book' 'draw' 'upon' 'everyth' 'from' 'to' 'hobb' 'to' 'adam' 'smith' 'to' 'illustr' 'the' 'intellectu' 'impuls' 'that' 'drive' 'conserv' 'and' 'progre ...
#
#      Predikció valószínűsége
# 41                    0.0156
# 81                    0.7066
# 235                   0.9601
# 244                   0.0794
# 259                   0.9191
# 273                   0.5667
# 275                   0.0597
# 293                   0.7585
# 297                   0.9721
# 408                   0.4800
# 464                   0.9908
# 490                   0.8241
# 508                   0.0386
# 576                   0.8538
# 642                   0.0227
# 650                   0.0675
# 660                   0.6605
# 690                   0.4820
# 707                   0.6241
# 725                   0.3164
