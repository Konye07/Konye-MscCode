# %% [markdown]
# # **Csomagok behívása**

# %%
#Szükséges csomagok és adatbázis importálása
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Concatenate
import numpy as np
import tensorflow as tf
import spacy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Fájlok behívása, ellenőrzése és felkészítése

# %%
# Betölteni padded sequences, tokenizer, és számokat
padded_train = np.load('/content/padded_train01.npy')
padded_test = np.load('/content/padded_independent01.npy')

# Tokenizer visszatöltése
with open('/content/tokenizer.pkl', 'rb') as f:
    tokenizer = pickle.load(f)

# Címkék betöltése (real = 1, fake = 0)
train_file = '/content/train_elso.csv'
test_file = '/content/indep_elso.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

labels_train = df_train['label'].values
labels_test = df_test['label'].values

# Betölteni embedding mátrixot
embedding_matrix = np.load('/content/embedding_matrix.npy')

# Ellenőrzés
print(f"Train padded sequences shape: {padded_train.shape}")
print(f"Test padded sequences shape: {padded_test.shape}")
print(f"Train labels shape: {labels_train.shape}")
print(f"Test labels shape: {labels_test.shape}")
# Out:
# Train padded sequences shape: (59520, 600)
# Test padded sequences shape: (14304, 600)
# Train labels shape: (59520,)
# Test labels shape: (14304,)

# %%
# Max szókincs és szekvencia hossz
MAX_VOCAB_SIZE = 25000
MAX_LENGTH = 600
EMBEDDING_DIM = 300  # GloVe 300d

# input shape
MAX_SEQUENCE_LENGTH = padded_train.shape[1]

# Szöveges input (LSTM/GRU bemenet)
text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
embedding_layer = Embedding(
    input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
    output_dim=embedding_matrix.shape[1],
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)(text_input)

model_output = embedding_layer
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
MAX_SEQUENCE_LENGTH = padded_train.shape[1]  # Train hossz
EMBEDDING_DIM = embedding_matrix.shape[1]  # GloVe embeddings

# 10%-os validációs halmaz leválasztása a tanító adatokból
padded_train_final, padded_val, y_train_final, y_val = train_test_split(
    padded_train, labels_train, test_size=0.1, random_state=42
)
# Float32-re konvertálás TensorFlow kompatibilitás miatt
padded_train_final = np.array(padded_train_final, dtype=np.float32)
padded_val = np.array(padded_val, dtype=np.float32)
padded_test = np.array(padded_test, dtype=np.float32)
y_train_final = np.array(y_train_final, dtype=np.float32)
y_val = np.array(y_val, dtype=np.float32)
y_test = np.array(labels_test, dtype=np.float32)

# Korai leállítás beállítása
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# # LSTM MODELL 1. ELŐFELDOLGOZÁSNÁL

# %% [markdown]
# ## Modell lefuttatása

# %%
# LSTM modell, trainable, non-trainable embedding

def create_lstm_model(trainable_embeddings=True):
    # Szöveges input
    text_input = Input(shape=(MAX_SEQUENCE_LENGTH,), name="text_input")
    text_embedding = Embedding(
        input_dim=min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE),
        output_dim=EMBEDDING_DIM,
        weights=[embedding_matrix],
        input_length=MAX_SEQUENCE_LENGTH,
        trainable=trainable_embeddings
    )(text_input)

    # LSTM rétegek
    lstm_out = LSTM(128, return_sequences=True, dropout=0.3)(text_embedding)
    lstm_out = Dropout(0.3)(lstm_out)  # Dropout réteg az első LSTM után
    lstm_out = LSTM(64,return_sequences=True, dropout=0.3)(lstm_out)
    lstm_out = Dropout(0.3)(lstm_out) # Dropout réteg az második LSTM után
    lstm_out = LSTM(32, dropout=0.3)(lstm_out)

    # Kimeneti réteg
    output = Dense(1, activation='sigmoid')(lstm_out)  # Binary classification

    # Modell létrehozása
    model = Model(inputs=text_input, outputs=output)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# Modell létrehozása
lstm_trainable = create_lstm_model(trainable_embeddings=True)  # Trainable embedding

lstm_trainable.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ text_input (InputLayer)         │ (None, 600)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_1 (Embedding)         │ (None, 600, 300)       │     7,500,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 600, 128)       │       219,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 600, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 600, 64)        │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 600, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,781,505 (29.68 MB)
#  Trainable params: 7,781,505 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Inicializálás
n_runs = 5
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
test_losses, test_accuracies = [], []

all_preds, all_probs, all_true = [], [], []

results = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': []
}

confusion_matrices = []

# Többszöri futtatás
for i in range(n_runs):
    print(f"\nFutás {i+1}/{n_runs}")

    lstm_trainable = create_lstm_model(trainable_embeddings=True)

    history = lstm_trainable.fit(
        padded_train_final, y_train_final,
        validation_data=(padded_val, y_val),
        epochs=10,
        batch_size=64,
        callbacks=[early_stopping],
        verbose=0
    )

    # Tanulási görbékhez szükséges adatok
    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])
    train_accuracies.append(history.history['accuracy'])
    val_accuracies.append(history.history['val_accuracy'])

    # Teszt pontosság/veszteség
    loss, acc = lstm_trainable.evaluate(padded_test, y_test, verbose=0)
    test_losses.append(loss)
    test_accuracies.append(acc)

    # Predikció
    lstm_y_prob = lstm_trainable.predict(padded_test)
    lstm_y_pred = (lstm_y_prob > 0.5).astype(int)

    all_preds.append(lstm_y_pred.flatten())
    all_probs.append(lstm_y_prob.flatten())
    all_true.append(y_test.flatten())

    # Metrikák
    results['accuracy'].append(accuracy_score(y_test, lstm_y_pred))
    results['precision'].append(precision_score(y_test, lstm_y_pred))
    results['recall'].append(recall_score(y_test, lstm_y_pred))
    results['f1_score'].append(f1_score(y_test, lstm_y_pred))

    # konf
    cm = confusion_matrix(y_test, lstm_y_pred)
    confusion_matrices.append(cm)


# Aggregált adatok
y_true_all = np.concatenate(all_true)
y_pred_all = np.concatenate(all_preds)
y_prob_all = np.concatenate(all_probs)
padded_test_repeated = np.tile(padded_test, (n_runs, 1))
# Out:
# Futás 1/5
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step
#
# Futás 2/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
#
# Futás 3/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
#
# Futás 4/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step
#
# Futás 5/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step

# %%
df_metrics = pd.DataFrame(results)
print("\n Metrikák statisztikája (10 futás):")
print(df_metrics.describe().T)
# Out:
#  Metrikák statisztikája (10 futás):
#            count      mean       std       min       25%       50%       75%  \
# accuracy     5.0  0.745176  0.025280  0.705956  0.736298  0.753286  0.759088
# precision    5.0  0.930247  0.011606  0.919897  0.921236  0.924880  0.939791
# recall       5.0  0.529922  0.051388  0.451202  0.516779  0.541247  0.549916
# f1_score     5.0  0.674121  0.043737  0.605441  0.662128  0.686896  0.695368
#
#                 max
# accuracy   0.771253
# precision  0.945433
# recall     0.590464
# f1_score   0.720771

# %% [markdown]
# ## LSTM Modell ábrák

# %%
# Egységesítés (early stopping miatt lehetnek eltérések)
min_epochs = min(len(run) for run in train_losses)

train_losses_np = np.array([run[:min_epochs] for run in train_losses])
val_losses_np = np.array([run[:min_epochs] for run in val_losses])
train_accuracies_np = np.array([run[:min_epochs] for run in train_accuracies])
val_accuracies_np = np.array([run[:min_epochs] for run in val_accuracies])
epochs = min_epochs

# Ábrák
plt.figure(figsize=(12, 5))

# Veszteség
plt.subplot(1, 2, 1)
plt.plot(train_losses_np.mean(axis=0), label='Tanulási veszteség (átlag)', color='blue')
plt.fill_between(range(epochs), train_losses_np.mean(axis=0) - train_losses_np.std(axis=0),
                 train_losses_np.mean(axis=0) + train_losses_np.std(axis=0), alpha=0.2, color='blue')
plt.plot(val_losses_np.mean(axis=0), label='Validációs veszteség (átlag)', color='orange')
plt.fill_between(range(epochs), val_losses_np.mean(axis=0) - val_losses_np.std(axis=0),
                 val_losses_np.mean(axis=0) + val_losses_np.std(axis=0), alpha=0.2, color='orange')
plt.axhline(np.mean(test_losses), color='red', linestyle='--', label='Teszthalmaz veszteség (átlag)')
plt.xlabel('Epizód'); plt.ylabel('Veszteség'); plt.title('Tanulási / validációs veszteség')
plt.legend()

# Pontosság
plt.subplot(1, 2, 2)
plt.plot(train_accuracies_np.mean(axis=0), label='Tanulási pontosság (átlag)', color='blue')
plt.fill_between(range(epochs), train_accuracies_np.mean(axis=0) - train_accuracies_np.std(axis=0),
                 train_accuracies_np.mean(axis=0) + train_accuracies_np.std(axis=0), alpha=0.2, color='blue')
plt.plot(val_accuracies_np.mean(axis=0), label='Validációs pontosság (átlag)', color='orange')
plt.fill_between(range(epochs), val_accuracies_np.mean(axis=0) - val_accuracies_np.std(axis=0),
                 val_accuracies_np.mean(axis=0) + val_accuracies_np.std(axis=0), alpha=0.2, color='orange')
plt.axhline(np.mean(test_accuracies), color='red', linestyle='--', label='Teszthalmaz pontosság (átlag)')
plt.xlabel('Epizód'); plt.ylabel('Pontosság'); plt.title('Tanulási / validációs pontosság')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np

conf_matrices_array = np.array(confusion_matrices)

cm_mean = np.mean(conf_matrices_array, axis=0)
cm_std = np.std(conf_matrices_array, axis=0)

# Formázás megjelenítéshez: "átlag (szórás)"
annot = np.empty_like(cm_mean, dtype=object)
for i in range(2):
    for j in range(2):
        annot[i, j] = f"{int(cm_mean[i, j])} ({cm_std[i, j]:.1f})"

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.heatmap(cm_mean, annot=annot, fmt='', cmap="Blues",
            xticklabels=["Fake 0", "Real 1"],
            yticklabels=["Fake 0", "Real 1"])
plt.xlabel('Becsült osztály')
plt.ylabel('Valós osztály')
plt.title('Konfúziós mátrix (átlag ± szórás, 5 futás)')
plt.show()

# %%
correct_real = y_prob_all[(y_true_all == 0) & (y_pred_all == 0)]
incorrect_real = y_prob_all[(y_true_all == 0) & (y_pred_all != 0)]
correct_fake = y_prob_all[(y_true_all == 1) & (y_pred_all == 1)]
incorrect_fake = y_prob_all[(y_true_all == 1) & (y_pred_all != 1)]

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

axes[0].hist(correct_real, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[0].hist(incorrect_real, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[0].set_title("Álhírek (valódi=0)"); axes[0].set_xlabel("Valószínűség"); axes[0].legend(); axes[0].grid(True)

axes[1].hist(correct_fake, bins=20, alpha=0.7, label="Helyes", color="blue", edgecolor="black")
axes[1].hist(incorrect_fake, bins=20, alpha=0.7, label="Hibás", color="red", edgecolor="black")
axes[1].set_title("Valódi hírek (valódi=1)"); axes[1].set_xlabel("Valószínűség"); axes[1].legend(); axes[1].grid(True)

plt.suptitle("Predikciós valószínűségek eloszlása (10 futás aggregálva)", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Eredeti félrebesorolt DataFrame
df_results_full = pd.DataFrame({
    "Valódi címke": y_true_all,
    "Prediktált címke": y_pred_all
})

# Félrebesorolt indexek
df_misclassified = df_results_full[df_results_full["Valódi címke"] != df_results_full["Prediktált címke"]].copy()
misclassified_indices = df_misclassified.index.to_numpy()

# Tokenek visszaalakítása szöveggé
misclassified_sequences = padded_test_repeated[misclassified_indices]
misclassified_texts = tokenizer.sequences_to_texts(misclassified_sequences)

# OOV-mentesítés
misclassified_texts_cleaned = [
    " ".join([word for word in text.split() if word.lower().strip() not in ["<oov>", "oov", "[oov]", "(oov)"]])
    for text in misclassified_texts
]

# Hibatípus, szöveg és valószínűség hozzáadása
df_misclassified.insert(0, "Hiba típusa", df_misclassified.apply(
    lambda row: "Hamis pozitív (FP)" if row["Valódi címke"] == 0 else "Hamis negatív (FN)", axis=1))
df_misclassified["Szöveg"] = misclassified_texts_cleaned
df_misclassified["Predikció valószínűsége"] = np.round(y_prob_all[misclassified_indices], 4)

# Duplikált szövegek eltávolítása (megtartja az első előfordulást)
df_misclassified_unique = df_misclassified.drop_duplicates(subset="Szöveg").reset_index(drop=True)

# Mentés CSV-be
df_misclassified_unique.to_csv("felrebesorolt_peldak_aggregalt_lstm.csv", index=False, encoding="utf-8")

# Megjelenítés
pd.set_option("display.max_colwidth", None)
display(df_misclassified_unique.head(20))
# Out:
#            Hiba típusa  Valódi címke  Prediktált címke  \
# 0   Hamis negatív (FN)           1.0                 0
# 1   Hamis negatív (FN)           1.0                 0
# 2   Hamis negatív (FN)           1.0                 0
# 3   Hamis negatív (FN)           1.0                 0
# 4   Hamis negatív (FN)           1.0                 0
# 5   Hamis negatív (FN)           1.0                 0
# 6   Hamis pozitív (FP)           0.0                 1
# 7   Hamis negatív (FN)           1.0                 0
# 8   Hamis negatív (FN)           1.0                 0
# 9   Hamis negatív (FN)           1.0                 0
# 10  Hamis pozitív (FP)           0.0                 1
# 11  Hamis negatív (FN)           1.0                 0
# 12  Hamis pozitív (FP)           0.0                 1
# 13  Hamis negatív (FN)           1.0                 0
# 14  Hamis negatív (FN)           1.0                 0
# 15  Hamis negatív (FN)           1.0                 0
# 16  Hamis negatív (FN)           1.0                 0
# 17  Hamis pozitív (FP)           0.0                 1
# 18  Hamis negatív (FN)           1.0                 0
# 19  Hamis pozitív (FP)           0.0                 1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'oslo' 'norway' 'wealth' 'fund' 'the' 'world' 'large' 'investor' 'post' 'a' 'record' 'loss' 'trillion' 'crown' 'billion' 'bring' 'an' 'end' 'a' 'threeyear' 'run' 'soar' 'profit' 'stock' 'bond' 'hit' 'the' 'ukraine' 'war' 'inflation' 'the' 'previous' 'large' 'loss' 'billion' 'crown' 'it' 'end' 'a' 'recordbreaking' 'streak' 'the' 'fund' 'annual' 'return' 'exceed' 'trillion' 'crown' 'each' 'the' 'year' 'amount' 'more' 'trillion' 'crown' 'combine' 'we' 'invest' 'company' 'country' 'there' 'just' 'nowhere' 'hide' 'fund' 'chief' 'executive' 'tell' 'a' 'news' 'conference' 'the' 'single' 'big' 'stock' 'market' 'loss' 'come' 'the' 'fund' 'stake' 'amazon' 'which' 'decline' 'value' 'billion' 'crown' 'follow' 'a' 'loss' 'share' 'facebook' 'owner' 'platform' 'billion' 'tesla' 'billion' 'still' 'despite' 'the' 'record' 'loss' 'the' 'value' 'the' 'fund' 'rise' 'overall' 'billion' 'crown' 'billion' 'partly' 'the' 'weak' 'norwegian' 'currency' 'a' 'record' 'trillion' 'crown' 'cash' 'inflow' 'the' 'inflow' 'nearly' 'times'  ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'geneva' 'the' 'world' 'health' 'organization' 'say' 'wednesday' 'it' 'too' 'early' 'lift' 'the' 'alert' 'the' 'crisis' 'the' 'pandemic' 'remain' 'a' 'global' 'health' 'emergency' 'despite' 'recent' 'progress' 'the' 'who' 'emergency' 'committee' 'meet' 'week' 'conclude' 'the' 'pandemic' 'still' 'constitute' 'a' 'public' 'health' 'emergency' 'international' 'concern' 'a' 'status' 'it' 'declare' 'back' 'january' 'who' 'chief' 'tedros' 'tell' 'reporter' 'wednesday' 'he' 'agree' 'the' 'committee' 'advice' 'the' 'committee' 'emphasize' 'the' 'need' 'strengthen' 'surveillance' 'expand' 'access' 'test' 'treatment' 'vaccine' 'those' 'most' 'risk' 'he' 'say' 'speak' 'the' 'un' 'health' 'agency' 'headquarters' 'geneva' 'the' 'who' 'first' 'declare' 'the' 'outbreak' 'a' 'january' 'outside' 'china' 'few' 'case' 'death' 'report' 'it' 'the' 'mechanism' 'trigger' 'an' 'international' 'response' 'it' 'only' 'march' 'tedros' 'describe' 'the' 'worsen' 'situation' 'a' 'pandemic' 'country' 'wake' 'up' 'the' 'danger' 'the' 'start' 'the' 'pandemic' 'more' 'million' 'confirm' 'case' 'report' 'who' 'more' 'million' 'death' 'those' 'number' 'believe' 'significant' 'underestimate' 'accord' 'who' 'global' 'dashboard' 'the' 'situation' 'new' 'case' 'report' 'the' 'previous' 'hour' 'new' 'death' 'report' 'the' 'past' 'week' 'tedros' 'acknowledge' 'wednesday' 'the' 'global' 'situation' 'obviously' 'improve' 'the' ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'city' 'philippine' 'heavily' 'arm' 'men' 'brutally' 'kill' 'a' 'village' 'chief' 'his' 'loved' 'one' 'a' 'coldblooded' 'ambush' 'del' 'province' 'thursday' 'afternoon' 'january' 'the' 'attack' 'which' 'also' 'leave' 'others' 'wound' 'take' 'place' 'the' 'remote' 'village' 'locate' 'approximately' 'kilometer' 'southwest' 'city' 'fear' 'uncertainty' 'spread' 'throughout' 'the' 'community' 'military' 'police' 'force' 'swiftly' 'deploy' 'the' 'predominantly' 'muslim' ' ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'flipflop' 'vox' 'warn' 'risk' 'election' 'day' 'violence' 'the' 'good' 'kind' 'either' 'post' 'brett' 's ...
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ...
# 17  'country' 'south' 'korea' 'we' 'continue' 'inform' 'our' 'reader' 'the' 'scandal' 'around' 'choi' 'confidante' 'president' 'park' 'geunhye' 'the' 'crisis' 'cause' 'her' 'interference' 'the' 'affair' 'the' 'state' 'link' 'corruption' 'continue' 'roll' 'recap' 'choi' 'official' 'right' 'so' 'access' 'read' 'official' 'material' 'correct' 'the' 'president' 'speech' 'there' 'still' 'evidence' 'an' 'ideological' 'rather' 'nature' 'the' 'correction' 'suspect' 'raise' 'fund' 'major' 'company' 'include' 'lotte' 'group' 'mir' 'foundation' 'relate' 'her' 'november' 'the' 'south' 'korean' 'president' 'appear' 'live' 'tv' 'apologize' 'admit' 'choi' 'blind' 'my' 'objectivity' 'allow' 'my' 'guard' 'drop' 'she' 'speak' 'great' 'emotion' 'which' 'unusual' 'her' 'take' 'responsibility' 'the' 'scandal' 'say' 'she' 'very' 'sorry' 'she' 'disappoint' 'the' 'people' 'who' 'entrust' 'her' 'the' 'right' 'rule' 'the' 'state' 'park' 'say' 'she' 'work' 'improve' 'the' 'economy' 'living' 'standard' 'some' 'individual' 'act' 'illegally' 'their' 'interest' 'about' 'which' 'she' 'deeply' 'concerned' 'her' 'emotional' 'reaction' 'reasonable' 'look' 'her' 'biography' 'her' 'parent' 'death' 'the' 'background' 'very' 'difficult' 'relationship' 'her' 'family' 'choi' 'the' 'daughter' 'her' 'spiritual' 'advisor' 'her' 'closest' 'friend' 'a' 'a' 'very' 'long' 'time' 'the' 'president' 'emphasize' 'she' 'ready' 'accept' 'all' 'the' 'demand' 'the' 'population' 'the' 'national' 'assembly' 'the' 'course' 'perform' 'her' 'duty' 'this' 'include' 'necessary' 'render' 'assistance' 'the' 'prosecutor' 'office' 'investigation' 'take' 'part' 'the' 'special' 'investigation' 'formally' 'she' 'legitimately' 'refuse' 'so' 'however' 'park' 'geunhye' 'note' 'the' 'countrys' 'security' 'economics' 'currently' 'great' 'threat' 'therefore' 'it' 'the' 'implementation' 'state' 'policy' 'halt' 'however' 'the' 'president' 'apologies' 'go' 'down' 'well' 'everyone' 'the' 'incumbent' 'party' 'receive' 'the' 'president' 'speech' 'quite' 'positively' 'state' 'the' 'president' 'agree' 'all' 'the' 'public' 'demand' 'express' 'a' 'firm' 'commitment' 'clarify' 'all' 'the' 'detail' 'the' 'scandal' 'prevent' 'similar' 'situation' 'the' 'future' 'the' 'head' 'the' 'opposition' 'democratic' 'party' 'the' 'contrary' 'say' 'the' 'apology' 'park' 'geunhye' 'provide' 'any' 'answer' 'which' 'the' 'outraged' 'people' 'wait' 'call' 'the' 'president' 'speech' 'mere' 'disingenuous' 'apology' 'the' 'chairman' 'the' 'interim' 'committee' 'the' 'people' 'party' 'pak' 'point' 'out' 'the' 'park' 'statement' 'the' 'choi' 'matter' 'it' 'action' 'aim' 'improve' 'the' 'economy' 'living' 'standard' 'the' 'population' 'praise' 'the' 'willingness' 'park' 'geunhye' 'cooperate' 'the' 'prosecutor' 'office' 'the' 'investigation' 'a' 'result' 'the' 'opposition' 'only' 'increase' 'it' 'pressure' 'actually' 'present' 'an' 'ultimatum' 'the' 'president' 'either' 'the' 'parliament' 'initiate' 'impeachment' 'park' 'step' 'down' 'domestic' 'politics' 'remove' 'the' 'prime' 'minister' 'newly' 'appoint' 'her' 'he' 'a' 'representative' 'the' 'leave' 'the' 'who' 'satisfy' 'the' 'opposition' 'leader' 'this' 'demand' 'all' 'back' 'up' 'the' 'disgruntled' 'general' 'public' 'november' 'there' 'a' 'demonstration' 'seoul' 'which' 'accord' 'official' 'data' 'attend' 'thousand' 'people' 'accord' 'the' 'data' 'the' 'opposition' 'attendance' 'reach' 'thousand' 'some' 'even' 'mention' 'thousand' 'this' 'an' 'obvious' 'exaggeration' 'there' 'outright' 'confrontation' 'the' 'police' 'about' 'thousand' 'officer' 'car' 'behave' 'appropriately' 'november' 'protest' 'recur' 'the' 'investigation' 'go' 'the' 'meantime' 'november' 'choi' 'detain' 'custody' 'charge' 'this' 'a' 'practice' 'the' 'republic' 'korea' 'which' 'repeatedly' 'criticize' 'human' 'right' 'activist' 'it' 'permit' 'hold' 'person' 'custody' 'up' 'day' 'even' 'there' 'enough' 'evidence' 'press' 'charge' 'them' 'the' 'decision' 'hold' 'choi' 'the' 'seoul' 'central' 'district' 'court' 'th ...
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'online' 'channel' 'the' 'social' 'security' 'system' 'temporarily' 'unavailable' 'monday' 'follow' 'a' 'fire' 'hit' 'the' 'agencys' 'facility' 'over' 'the' 'weekend' 'an' 'advisory' 'the' 'ss' 'say' 'it' 'online' 'platforms' 'it' 'official' ...
# 19                                                                                                                                                                                                                                       'region' 'usa' 'the' 'world' 'the' 'world' 'economies' 'a' 'crisis' 'they' 'provide' 'the' 'need' 'well' 'the' 'people' 'guarantee' 'them' 'peace' 'act' 'effective' 'concert' 'stop' 'reverse' 'the' 'rapid' 'global' 'warm' 'these' 'economy' 'create' 'which' 'utterly' 'destroy' 'civilisation' 'our' 'lifetime' 'the' 'crisis' 'capitalism' 'evident' 'a' 'century' 'result' 'world' 'war' 'threaten' 'a' 'the' 'remain' 'socialist' 'country' 'provide' 'another' 'model' 'economic' 'development' 'another' 'view' 'humanity' 'reach' 'their' 'potential' 'they' 'surround' 'an' 'international' 'system' 'capital' 'tolerate' 'any' 'interference' 'it' 'search' 'profit' 'aggressively' 'undermines' 'attack' 'people' 'who' 'choose' 'the' 'socialist' 'path' 'we' 'see' 'what' 'the' 'socialist' 'republic' 'the' 'ussr' 'suffer' 'they' 'succeed' 'only' 'a' 'return' 'a' 'mixed' 'economy' 'a' 'revival' 'some' 'state' 'industry' 'the' 'defeat' 'the' 'gangster' 'first' 'appear' 'the' 'representative' 'capital' 'improved' 'condition' 'the' 'people' 'those' 'republic' 'particular' 'russia' 'the' 'new' 'russian' 'state' 'still' 'hold' 'some' 'the' 'principle' 'the' 'hope' 'international' 'law' 'sovereignty' 'nation' 'people' 'a' 'defining' 'characteristic' 'the' 'soviet' 'union' 'it' 'still' 'believe' 'the' 'world' 'people' 'all' 'live' 'cooperation' 'each' 'the' 'communist' 'party' 'leave' 'party' 'still' 'strong' 'an' 'influence' 'the' 'people' 'the' 'government' 'the' 'linger' 'legacy' 'the' 'socialist' 'epoch' 'produce' 'a' 'leadership' 'comparison' 'those' 'capitalist' 'country' 'rational' 'even' 'some' 'way' 'enlighten' 'still' 'russia' 'also' 'now' 'part' 'the' 'capitalist' 'international' 'subject' 'it' 'law' 'so' 'the' 'people' 'the' 'united' 'state' 'the' 'nato' 'country' 'those' 'law' 'cruel' 'criminal' 'they' 'stipulate' 'more' 'profit' 'work' 'people' 'pay' 'less' 'profit' 'come' 'out' 'thin' 'air' 'western' 'economist' 'it' 'it' 'come' 'the' 'value' 'add' 'product' 'labour' 'power' 'force' 'worker' 'compensation' 'word' 'the' 'profit' 'they' 'it' 'this' 'fact' 'dictate' 'the' 'only' 'way' 'which' 'presidentelect' 'trump' 'bring' 'back' 'job' 'america' 'low' 'wag' 'the' 'level' 'we' 'now' 'china' 'bad' 'africa' 'worker' 'pay' 'about' 'a' 'dollar' 'a' 'day' 'american' 'company' 'move' 'their' 'production' 'out' 'the' 'u' 'canada' 'free' 'trade' 'cheap' 'labour' 'market' 'increase' 'their' 'profit' 'they' 'go' 'return' 'the' 'usa' 'just' 'donald' 'trump' 'promise' 'the' 'people' 'they' 'return' 'pay' 'high' 'wage' 'even' 'those' 'which' 'relatively' 'low' 'the' 'standard' 'the' 'return' 'lose' 'money' 'trump' 'about' 'create' 'job' 'then' 'the' 'only' 'way' 'he' 'succeed' 'force' 'the' 'cost' 'labour' 'down' 'reduce' 'wage' 'we' 'expect' 'more' 'attack' 'union' 'union' 'organise' 'a' 'freeze' 'a' 'lower' 'the' 'minimum' 'wage' 'an' 'influx' 'more' 'cheap' 'labour' 'mexico' 'country' 'his' 'promise' 'build' 'a' 'wall' 'the' 'mexican' 'border' 'a' 'lot' 'hot' 'air' 'build' 'it' 'raise' 'the' 'cost' 'business' 'too' 'small' 'industry' 'service' 'the' 'u' 'depend' 'this' 'cheap' 'labour' 'it' 'presence' 'wag' 'the' 'rest' 'we' 'see' 'this' 'happen' 'the' 'western' 'world' 'the' 'capitalist' 'seize' 'power' 'the' 'ussr' 'soon' 'occur' 'every' 'western' 'country' 'begin' 'the' 'roll' 'back' 'all' 'the' 'gain' 'work' 'people' 'achieve' 'the' 'second' 'world' 'war' 'this' 'rollback' 'this' 'rapid' 'lower' 'the' 'standard' 'live' 'the' 'mass' 'the' 'people' 'every' 'country' 'follow' 'recession' 'more' 'war' 'they' 'fight' 'resource' 'our' 'money' 'body' 'accelerate' 'the' 'rise' 'the' 'far' 'right' 'party' 'europe' 'the' 'united' 'state' 'reflect' 'this' 'decline' 'the' 'live' 'the' 'majority' 'the' 'mass' 'medium' 'effectively'  ...
#
#     Predikció valószínűsége
# 0                    0.4917
# 1                    0.1315
# 2                    0.1339
# 3                    0.0662
# 4                    0.0888
# 5                    0.0083
# 6                    0.5717
# 7                    0.0010
# 8                    0.0080
# 9                    0.0196
# 10                   0.7447
# 11                   0.2912
# 12                   0.7371
# 13                   0.0057
# 14                   0.0019
# 15                   0.0144
# 16                   0.0066
# 17                   0.7323
# 18                   0.3162
# 19                   0.5882
